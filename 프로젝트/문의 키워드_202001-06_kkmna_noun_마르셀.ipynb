# %%
import nltk
import numpy as np
import pandas as pd
from konlpy.tag import Okt
from konlpy.tag import Komoran
from konlpy.tag import Hannanum
from konlpy.tag import Kkma
from keras.models import load_model
from tqdm import tqdm
from tqdm import tqdm_notebook
from gensim import corpora
from gensim import models
from time import time
from wordcloud import WordCloud
import seaborn as sns
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'Malgun Gothic'
# %matplotlib inline
import warnings
warnings.filterwarnings(action='ignore') 

# mecab = Mecab()
# okt = Okt()
# komoran=Komoran()
# hannanum=Hannanum()
kkma=Kkma()

# %% [markdown]
# # 데이터 불러오기

# %%
df = pd.read_excel('Raw Data/(공유) 더샵약국몰_상담내역_2020.01-06.xlsx')
#(공유) 더샵약국몰_상담내역_2019.04-06.xlsx
#(공유) 더샵약국몰_상담내역_2019.07-12.xlsx
#(공유) 더샵약국몰_상담내역_2020.01-06.xlsx
#(공유) 더샵약국몰_상담내역_2020.07-12.xlsx
#(공유) 더샵약국몰_상담내역_2021.01-05.xlsx

# %%
df.head(3)
# Out:
#                   상담일시 통화유형 상담구분  상담유형        상담상세 상담결과  \
# 0  2020-06-30 18:07:55   발신  약국몰  배송관련  단순배송확인/ 요청   완결
# 1  2020-06-30 18:03:46   발신  약국몰  이용문의     마일리지 문의   완결
# 2  2020-06-30 18:02:19   수신  약국몰  반품관련        대웅제약   완결
#
#                                                 문의사항
# 0  \n\nPO1020267145 결제완료(2020-06-29 08:40:24)대웅제약...
# 1         \n\n더샵 마일리지 -> 약구매시 사용불가 / 생활기프트신청 안내드림 \n
# 2  \n\n1) 개성약국-서인혜\n임팩타민실버정/102.02mg/120정 * 1개 반품...

# %%
df.shape
# Out:
# (30100, 7)

# %% [markdown]
# # 문의사항 중 null 데이터 개수 확인

# %%
df['문의사항'].isnull().sum()
# Out:
# 552

# %% [markdown]
# # 본문 중 null 데이터 제외

# %%
temp_idx = df[df['문의사항'].isnull()].index

# %%
df = df.drop(temp_idx)

# %%
df['문의사항'].isnull().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (29548, 7)

# %% [markdown]
# # 상담 내용 데이터 정제

# %%
import re
# from pykospacing import spacing

def define_stopwords(path):
    
    SW = set()
    # 불용어를 추가하는 방법 1.
    #for i in string.punctuation:
        #SW.add(i)
    SW.update(["요청", "완료", "안내", "확인", "반품", "결제", "약국", "신청", "배송", "취소", "가능", "문의", "주문", "구매"])
    SW.update(['예정', '연락', '처리', '대웅', '제품', '사용', '더샵', '발송', '업체', '변경', '방법', '안내드림', '쿠폰', '이벤트', '등록', '문자'])
    SW.update(['대웅제약', '상품', '적립', '이상', '카드', '금일', '승인', '해당', '전달', '거점', '수정', '담당자', '전화', '통화', '팩스'])
    SW.update(['다함', '진행', '오후', '사업자', '잔고', '할인', '금액', '오늘', '회수', '오산', '약사', '번호', '검색', '판매', '도착', '주소'])
    SW.update(['메일', '관리', '환불', '페이', '기간', '유효', '사유', '기사', '불가', '출고', '약품', '약속', '영업', '세금', '발행', '전체'])
    SW.update(['사원', '방문', '재고', '제조', '이오', '부분', '포장', '주문건', '관련', '박스', '공장', '반품건', '수량', '정지', '배송문', '제약'])
    SW.update(['즉시', '통장', '처방전', '포인트', '전용', '서비스', '보관', '복원', '대웅바이', '사용법', '선구매', '소멸', '적용', '개선', '오후시'])
    SW.update(['포인트몰', '선발행', '마감', '환입실', '등급', '지급', '서울지점', '삭제', '안내함', '구입', '연락처', '마일리지', '마이너스', '연락드림'])
    SW.update(['차장', '드림', '바이오', '이력', '어려움', '판촉물', '코드', '본인', '품절', '혜택', '직거래', '사입', '인천', '가입', '내일', '통화건'])
    SW.update(['예치금', '양해', '지연', '시간', '이후', '부재', '폐업', '오전', '내역', '여부', '연락드리', '교환', '접수', '이마트', '추가', '소비자'])
    SW.update(['특별', '경우', '수신', '공급관', '품목', '월요일', '중단', '상품권', '내용', '배정', '추후', '익일', '서울', '정보', '오류', '택배'])
    SW.update(['기존', '일자', '미배송', '시스템', '새벽', '당첨', '입금', '시분', '계좌', '국민', '통합', '복합', '이동', '오결재', '매핑', '향남'])
    SW.update(['참여', '역대', '성규', '가상', '채널', '스마', '김선', '산서', '이번', '상태', '공지', '어제', '입력', '매출', '전송', '장바구니'])
    SW.update(['소통', '사본', '지문', '소요', '기재', '조회', '다음', '고객', '발급', '도매', '부족', '연결', '오주문', '지역', '정도', '건강'])
    SW.update(['핸드폰', '가격', '종료', '인천약', '이용', '인수', '기한', '오주문', '부천시', '유통', '작업', '동물', '확인차', '알반품', '노출', '종료'])
    SW.update(['공급', '예정일', '건지', '송문', '품건', '현재', '거래', '계산서', '하심', '환입', '페이지', '전용관', '아이디', '지점', '카톡', '만우절'])
    SW.update(['필요', '결제완료', '반품신청', '확인요청', '만원', '취소요청', '영업사원', '있음', '기사님', '배송예정일', '배송예정', '문건', '유효기간', '취소완료','반품신청건', '주신', '백제'])
    SW.update(['수거', '통장사본', '구입문의', '명세표', '민정', '회원', '마트', '이전', '거래명세표', '배송문의', '희망', '누락', '이관', '거부', '회신', '확인후', '재연락', '이지'])
    SW.update(['마이너스잔고', '주시길', '안됨', '마이', '취소요청사유', '하다', '개월', '반품요청', '쿠폰사용', '지금', '개가', '인수', '인수인계', '주시', '온누리', '지금', '구매시', '당일', '세금계산서', '재발', '문의확인후', '바구니', '재발송'])
    SW.update(['제일', '제일헬스케어', '주심', '수령', '카드취소', '부탁', '양해드림'])
    #SW.update(["안내", "프로슈머", "요청", "긴급", "문의", "수정", "리스트", "감사", "관련", "부탁", "재문", "재문의", "추가", "제목", "등록", "정보"])
    #SW.update(['입니다', '또는', '추가', '드립니다', '드려요', '드릴게요', '가격', '합니다', '바랍니다', '부탁드립니다', '습니다', '지역', '급급', '월일'])
    #SW.update(['병원', '박일', '모두', '월호', '게시물', '위주', '드림', '의원', '투명', '이야기', '연세', '이비인후과', '에서'])
    #SW.update(['제공', '추천', '원내', '제작', '주력', '견적', '일정', '분석', '제작', '관리', '실장', '선생', '메일', '파일', '방법', '하나', '우리'])
    #SW.update(['구매', '후기', '테일', '구입', '이것저것', '이거', '직구', '추천', '가지', '오바', '성공', '주문', '오늘', '여러분', '하세', '오랜만','기타'])
    # 불용어를 추가하는 방법 2.
    # stopwords-ko.txt에 직접 추가
    
    with open(path, encoding='utf-8') as f:
        for word in f:
            SW.add(word)

    return SW


def list_of_list(docs):
    temp_list = []
    
    for doc in docs:
        temp = doc.split(', ')
        temp_list.append(temp)
        
    return temp_list


def text_cleaning(docs):
    """
        1. 한글만 추출.
        
        2. 자음/모음 표현 처리방법.
        
            1) "ㅇㅇ" ,"ㅋㅋㅋㅋㅋ" 같은 자음만 존재하는 표현이나, "ㅡㅡ", "ㅠㅠ" 같은 모음만 존재하는 표현들은
            의미는 있으나 중요한 의미를 가지고 있지 않다고 판단하여 제거.
            
            2) 이러한 표현들도 전부 emoticon 같은 감정 표현의 의성어로 쓰거나, 단축 표현이므로 제거하지 않음. 
            
        3. http:// 로 시작하는 hyperlink 제거.
        
        4. 특수문자 제거.
        
        5. 이메일 주소 제거.
    
    """
    # Series의 object를 str로 변경.
    #docs = [str(doc) for doc in docs]
    
    # 1
    pattern1 = re.compile('[^ ㄱ-ㅣ가-힣]+')
    docs = [pattern1.sub("", docs)] 
    #print(docs)
    
    # 2
    pattern2 = re.compile("[ㄱ-ㅎ]*[ㅏ-ㅢ]*")
    docs = [pattern2.sub("", doc) for doc in docs]
    #print(docs)
    
    # 3
    #pattern3 = re.compile(r"\b(https?:\/\/)?([\w.]+){1,2}(\.[\w]{2,4}){1,2}(.*)")
    #docs = pattern3.sub("", docs) 
    
    # 4
    pattern4 = re.compile("[\{\}\[\]\/?.,;:|\)*~`!^\-_+<>@\#$%&\\\=\(\'\"]")
    docs = pattern4.sub("", str(docs))
    #print(docs)
    
    # 5
    pattern5 = re.compile('\S*@\S*\s?')
    docs = pattern5.sub("", docs)
    #print(docs)
    
    # 띄어쓰기 다시하기
    # docs = spacing(docs)
    #print(docs)
    
    print('Done!')
        
    return docs


def slicing_time_str(time_str):
    return time_str[0:10]

# %% [markdown]
# # 본문 데이터 정제 후 본문클리닝에 저장

# %%
df['문의사항_클리닝'] = df['문의사항'].apply(text_cleaning)
# Out:
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# ...
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!

# %%
df.head()
# Out:
#                   상담일시 통화유형 상담구분  상담유형        상담상세 상담결과  \
# 0  2020-06-30 18:07:55   발신  약국몰  배송관련  단순배송확인/ 요청   완결
# 1  2020-06-30 18:03:46   발신  약국몰  이용문의     마일리지 문의   완결
# 2  2020-06-30 18:02:19   수신  약국몰  반품관련        대웅제약   완결
# 3  2020-06-30 18:02:13   발신  약국몰  이용문의       이벤트관련   완결
# 4  2020-06-30 18:01:43   수신  약국몰  배송관련  단순배송확인/ 요청   완결
#
#                                                 문의사항  \
# 0  \n\nPO1020267145 결제완료(2020-06-29 08:40:24)대웅제약...
# 1         \n\n더샵 마일리지 -> 약구매시 사용불가 / 생활기프트신청 안내드림 \n
# 2  \n\n1) 개성약국-서인혜\n임팩타민실버정/102.02mg/120정 * 1개 반품...
# 3  \n\n6월 대웅 OTC구매금액 확인 요청 \n-> 총 1,032,790 원임. 마...
# 4  \n\nPO1020267145 결제완료(2020-06-29 08:40:24)대웅제약...
#
#                                             문의사항_클리닝
# 0   결제완료 대웅제약 미배송건 문의  현재 시 이후라 확인어렵고 내일 확인해서 오전에...
# 1                  더샵 마일리지  약구매시 사용불가  생활기프트신청 안내드림
# 2   개성약국서인혜임팩타민실버정정  개 반품요청사유 유효기간임박  신청완료 열린약국이동...
# 3  월 대웅 구매금액 확인 요청  총  원임 마일리지 점 오늘 소멸되므로 필히 패밀리존...
# 4              결제완료 대웅제약 미배송건 문의  확인해서 연락드리겠다고 안내드림

# %% [markdown]
# ## 혹시 모를 상황에 대비해서 전처리된 데이터 프레임을 저장

# %%
df.to_csv('Data/2020.01-06_상담내역.csv', index = False, encoding = 'utf-8')

# %%
temp = pd.read_csv('Data/2020.01-06_상담내역.csv', encoding='utf-8')
temp.head()
# Out:
#                   상담일시 통화유형 상담구분  상담유형        상담상세 상담결과  \
# 0  2020-06-30 18:07:55   발신  약국몰  배송관련  단순배송확인/ 요청   완결
# 1  2020-06-30 18:03:46   발신  약국몰  이용문의     마일리지 문의   완결
# 2  2020-06-30 18:02:19   수신  약국몰  반품관련        대웅제약   완결
# 3  2020-06-30 18:02:13   발신  약국몰  이용문의       이벤트관련   완결
# 4  2020-06-30 18:01:43   수신  약국몰  배송관련  단순배송확인/ 요청   완결
#
#                                                 문의사항  \
# 0  \n\nPO1020267145 결제완료(2020-06-29 08:40:24)대웅제약...
# 1         \n\n더샵 마일리지 -> 약구매시 사용불가 / 생활기프트신청 안내드림 \n
# 2  \n\n1) 개성약국-서인혜\n임팩타민실버정/102.02mg/120정 * 1개 반품...
# 3  \n\n6월 대웅 OTC구매금액 확인 요청 \n-> 총 1,032,790 원임. 마...
# 4  \n\nPO1020267145 결제완료(2020-06-29 08:40:24)대웅제약...
#
#                                             문의사항_클리닝
# 0   결제완료 대웅제약 미배송건 문의  현재 시 이후라 확인어렵고 내일 확인해서 오전에...
# 1                  더샵 마일리지  약구매시 사용불가  생활기프트신청 안내드림
# 2   개성약국서인혜임팩타민실버정정  개 반품요청사유 유효기간임박  신청완료 열린약국이동...
# 3  월 대웅 구매금액 확인 요청  총  원임 마일리지 점 오늘 소멸되므로 필히 패밀리존...
# 4              결제완료 대웅제약 미배송건 문의  확인해서 연락드리겠다고 안내드림

# %% [markdown]
# # 상담일시 판다스 포멧에 맞게 전환

# %%
df = pd.read_csv('Data/2020.01-06_상담내역.csv', encoding='utf-8')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29548 entries, 0 to 29547
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   상담일시      29548 non-null  object
#  1   통화유형      29548 non-null  object
#  2   상담구분      29548 non-null  object
#  3   상담유형      29548 non-null  object
#  4   상담상세      29548 non-null  object
#  5   상담결과      29548 non-null  object
#  6   문의사항      29548 non-null  object
#  7   문의사항_클리닝  29507 non-null  object
# dtypes: object(8)
# memory usage: 1.8+ MB

# %%
df['상담일시'] = df['상담일시'].apply(slicing_time_str)
df['상담일시'] = pd.to_datetime(df['상담일시'], format='%Y/%m/%d')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29548 entries, 0 to 29547
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   상담일시      29548 non-null  datetime64[ns]
#  1   통화유형      29548 non-null  object
#  2   상담구분      29548 non-null  object
#  3   상담유형      29548 non-null  object
#  4   상담상세      29548 non-null  object
#  5   상담결과      29548 non-null  object
#  6   문의사항      29548 non-null  object
#  7   문의사항_클리닝  29507 non-null  object
# dtypes: datetime64[ns](1), object(7)
# memory usage: 1.8+ MB

# %%
df.head(3)
# Out:
#         상담일시 통화유형 상담구분  상담유형        상담상세 상담결과  \
# 0 2020-06-30   발신  약국몰  배송관련  단순배송확인/ 요청   완결
# 1 2020-06-30   발신  약국몰  이용문의     마일리지 문의   완결
# 2 2020-06-30   수신  약국몰  반품관련        대웅제약   완결
#
#                                                 문의사항  \
# 0  \n\nPO1020267145 결제완료(2020-06-29 08:40:24)대웅제약...
# 1         \n\n더샵 마일리지 -> 약구매시 사용불가 / 생활기프트신청 안내드림 \n
# 2  \n\n1) 개성약국-서인혜\n임팩타민실버정/102.02mg/120정 * 1개 반품...
#
#                                             문의사항_클리닝
# 0   결제완료 대웅제약 미배송건 문의  현재 시 이후라 확인어렵고 내일 확인해서 오전에...
# 1                  더샵 마일리지  약구매시 사용불가  생활기프트신청 안내드림
# 2   개성약국서인혜임팩타민실버정정  개 반품요청사유 유효기간임박  신청완료 열린약국이동...

# %% [markdown]
# # 월별 문의사항 데이터 TF-IDF 분석

# %%
df['문의사항_클리닝'].isnull().sum()
# Out:
# 41

# %%
idx = df[df['문의사항_클리닝'].isnull()].index
df = df.drop(idx)

# %%
SW = define_stopwords("stopwords-ko.txt")

# %%
def list_of_list(docs):
    temp_list = []
    
    for doc in docs:
        temp = doc.split(', ')
        temp_list.append(temp)
        
    return temp_list

# %%
def month_context_extract_tfidf(df, month_start, month_end):
    
    # 시간정보 열 datetime 정보로 변환
    df['상담일시'] = pd.to_datetime(df['상담일시'], format='%Y/%m/%d')
    #연도, 월 데이터 dataframe 받음
    year_month_df = df.loc[(df['상담일시'] > month_start) & (df['상담일시'] < month_end)]
    #제목 데이터 프레임 슬라이싱
    corpus = year_month_df['문의사항_클리닝']
    #리스트화
    cleaned_corpus = corpus.tolist() #--> list of str
    
    #okt를 이용한 형태소 분석
    temp_list = []
    for i in tqdm_notebook(cleaned_corpus):
        #temp_list.append(okt.morphs(i)) #temp_list.append(okt.nouns(i)) #명사형 
        #temp_list.append(mecab.morphs(i)) #temp_list.append(mecab.nouns(i))
        #temp_list.append(komoran.morphs(i)) #temp_list.append(komoran.nouns(i))
        #temp_list.append(hannanum.morphs(i)) #temp_list.append(hannanum.nouns(i))
        temp_list.append(kkma.nouns(i)) #temp_list.append(kkma.nouns(i))
    #2차원 리스트를 1차원으로    
    single_de_list = sum(temp_list, [])
    #불용어 제거
    final_list = [word for word in single_de_list if word not in SW and len(word) > 1]
    return final_list

# %%
# vectorizer 내에서 높은 순위로 고려되는 단어들을 불러오는 함수를 생성 
def rank_words(terms, feature_matrix):
    sums = feature_matrix.sum(axis=0) # 문서마다 단어의 tfidf 합산
    data = []
    for col, term in enumerate(terms): 
        data.append( (term, sums[0,col])) # 단어의 tfidf 값 매핑하여 리스트에 추가
    ranked = pd.DataFrame(data, columns=['term','rank']).sort_values('rank',ascending=False) 
    #ranked = pd.DataFrame(data, columns=['term','rank']).sort_values('rank',ascending=False) 
    # tfidf 내림차순으로 정렬하여 데이터프레임 생성  
    return ranked

# %%
df.head(3)
# Out:
#         상담일시 통화유형 상담구분  상담유형        상담상세 상담결과  \
# 0 2020-06-30   발신  약국몰  배송관련  단순배송확인/ 요청   완결
# 1 2020-06-30   발신  약국몰  이용문의     마일리지 문의   완결
# 2 2020-06-30   수신  약국몰  반품관련        대웅제약   완결
#
#                                                 문의사항  \
# 0  \n\nPO1020267145 결제완료(2020-06-29 08:40:24)대웅제약...
# 1         \n\n더샵 마일리지 -> 약구매시 사용불가 / 생활기프트신청 안내드림 \n
# 2  \n\n1) 개성약국-서인혜\n임팩타민실버정/102.02mg/120정 * 1개 반품...
#
#                                             문의사항_클리닝
# 0   결제완료 대웅제약 미배송건 문의  현재 시 이후라 확인어렵고 내일 확인해서 오전에...
# 1                  더샵 마일리지  약구매시 사용불가  생활기프트신청 안내드림
# 2   개성약국서인혜임팩타민실버정정  개 반품요청사유 유효기간임박  신청완료 열린약국이동...

# %%
tfidf_corpus = month_context_extract_tfidf(df,'2020-01-01', '2020-06-30') #2019년 4월에서 6월까지 하려면 (df,'2019-04-01', '2019-06-30')로 작성하면 됨.
tfidf_corpus
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=29170.0), HTML(value='')))
# ['운동장',
#  '운동장약국',
#  '출고정지',
#  '약이',
#  '대웅제약꺼',
#  '오배송',
#  '내일중',
#  '대웅바이오',
#  '폐업반품신청건',
#  '요청하심',
#  '신청완료',
#  '월일',
#  '영님통화',
#  '전달완료',
#  '샵플러스',
#  '플러스',
#  '선풍기',
#  '교환요청',
#  '사유작동안',
#  '유작',
#  '동안',
#  '겉박스',
#  '심주',
#  '심주문일',
#  '취소일',
#  '주문번호',
#  '교환신청',
#  '사이트',
#  '박스포장부탁',
#  '부탁',
#  '회수요청',
#  '교환건',
#  '일단',
#  '연락요청',
#  '유미',
#  '유미선님',
#  '제품박스',
#  '하심맞교환요청',
#  '맞교',
#  '업체측',
#  '영님연락',
#  '이번주',
#  '화수',
#  '회수후',
#  '샵플러스',
#  '플러스',
#  '선풍기',
#  '교환요청',
#  '사유작동안',
#  '유작',
#  '동안',
#  '겉박스',
#  '심주',
#  '심주문일',
#  '취소일',
#  '주문번호',
#  '교환신청',
#  '사이트',
#  '박스포장부탁',
#  '부탁',
#  '회수요청',
#  '교환건',
#  '일단',
#  '연락요청',
#  '유미',
#  '유미선님',
#  '제품박스',
#  '하심맞교환요청',
#  '맞교',
#  '업체측',
#  '함소',
#  '함소영님',
#  '미선',
#  '미선님',
#  '호전환',
#  '전환',
#  '다이아',
#  '다이아벡스정',
#  '벡스',
#  '일정',
#  '공문',
#  '공문요청',
#  '삼거리',
#  '삼거리약국',
#  '반품관련문의',
#  '국장',
#  '재문의',
#  '내상',
#  '약국장',
#  '확인시',
#  '구매후',
#  '반품기한문의',
#  '도매업',
#  '구입일로',
#  '일로',
#  '개월이내',
#  '이내',
#  '반품안내',
#  '마이크로',
#  '마이크로그램',
#  '뉴에어',
#  '리라',
#  '에어',
#  '그램',
#  '사입이',
#  '입이',
#  '스타',
#  '스타정',
#  '거래명세서',
#  '명세서',
#  '스타정과',
#  '정과',
#  '올메텍정',
#  '개도',
#  '확인요청잘못기재',
#  '잘못',
#  '메텍정',
#  '부분배송',
#  '확인요청올메텍정',
#  '요청올메텍정',
#  '익일배송',
#  '삼거리',
#  '삼거리약국',
#  '반품관련문의',
#  '국장',
#  '재문의',
#  '창원',
#  '백제종합',
#  '종합',
#  '온누리약국',
#  '주문건중',
#  '스멕',
#  '현탁액',
#  '오배송',
#  '회수후',
#  '재배',
#  '재배송',
#  '양해안내드림',
#  '인천약품',
#  '마이칼디정병',
#  '정병',
#  '덱실란트디알',
#  '실란트',
#  '캡슐',
#  '개인',
#  '개인천약품',
#  '주기',
#  '임팩',
#  '민케어',
#  '케어',
#  '등록문의',
#  '구글시트',
#  '시트',
#  '접수후',
#  '권장',
#  '권장소비자',
#  '만원준수',
#  '준수',
#  '천지인',
#  '밴드',
#  '밴드골드',
#  '골드',
#  '슈퍼',
#  '슈퍼포',
#  '직접',
#  '처리요청업체',
#  '연락주시기',
#  '시기',
#  '스타',
#  '스타정',
#  '거래명세서',
#  '명세서',
#  '스타정과',
#  '정과',
#  '올메텍정',
#  '개도',
#  '확인요청잘못기재',
#  '잘못',
#  '메텍정',
#  '부분배송',
#  '확인요청납품번호',
#  '납품',
#  '하온누리약국',
#  '송경철결제완료',
#  '경철',
#  '창원',
#  '백제종합',
#  '종합',
#  '온누리약국',
#  '주문건중',
#  '스멕',
#  '현탁액',
#  '오배송',
#  '전달완료',
#  '환불요청사유',
#  '반품처리통장사본',
#  '환불예정일',
#  '헬스',
#  '헬스인',
#  '전체취소요청',
#  '사유금액',
#  '취소불가',
#  '대흥',
#  '약국정인선',
#  '정인',
#  '헬스',
#  '헬스인',
#  '전체취소요청',
#  '사유금액',
#  '취소불가',
#  '헬스',
#  '헬스인',
#  '전체취소요청',
#  '사유금액',
#  '백제종합약국',
#  '종합',
#  '소상',
#  '소상문',
#  '다이아',
#  '다이아벡스정염',
#  '벡스',
#  '정염',
#  '메트',
#  '메트폴민',
#  '개다이아벡스정염',
#  '장바구니담기요청',
#  '담기',
#  '대웅제약오산거점',
#  '스타',
#  '스타정',
#  '거래명세서',
#  '명세서',
#  '스타정과',
#  '정과',
#  '올메텍정',
#  '개도',
#  '확인요청잘못기재',
#  '잘못',
#  '메텍정',
#  '부분배송',
#  '임팩',
#  '민케어',
#  '케어',
#  '페이지대웅',
#  '특별공급관',
#  '창원',
#  '백제종합',
#  '종합',
#  '온누리약국',
#  '주문건중',
#  '스멕',
#  '현탁액',
#  '오배송',
#  '샵플러스',
#  '플러스',
#  '접속',
#  '왼쪽',
#  '종모양',
#  '모양',
#  '에브',
#  '에브리데이',
#  '리데이',
#  '중필터',
#  '필터',
#  '대형',
#  '일회용',
#  '마스크',
#  '끈조절가능블랙',
#  '조절',
#  '블랙',
#  '반품쿠폰사용',
#  '제일',
#  '제일헬스케어',
#  '헬스',
#  '케어',
#  '반품완료',
#  '회수안됨',
#  '회수요청',
#  '어린이',
#  '중구조',
#  '구조',
#  '부직포',
#  '아동용',
#  '아동용백색',
#  '백색',
#  '쿠폰사용개',
#  '제이',
#  '예치금적립',
#  '반품처리',
#  '지연문의',
#  '미방',
#  '미방약국',
#  '방순열결제완료',
#  '순열',
#  '천지인',
#  '밴드',
#  '밴드골드',
#  '골드',
#  '슈퍼',
#  '슈퍼포',
#  '직접',
#  '처리요청',
#  '해당건',
#  '천지인',
#  '밴드',
#  '밴드골드',
#  '골드',
#  '슈퍼',
#  '슈퍼포',
#  '직접',
#  '처리요청',
#  '공급사',
#  '실적',
#  '대웅제약제품',
#  '공급사가',
#  '사가',
#  '해당건',
#  '샵고객지원',
#  '지원',
#  '세이',
#  '확인안내드림',
#  '반품회수요청건',
#  '전달완료에벤에셀약국',
#  '에벤에셀',
#  '민영기',
#  '영기',
#  '건종로당온누리',
#  '종로',
#  '성보영',
#  '보영',
#  '회수요청',
#  '한올',
#  '주문시',
#  '웹페이지',
#  '발생',
#  '함확인',
#  '위한',
#  '사업자등록증',
#  '등록증',
#  '배송가능',
#  '주문가능',
#  '한올담당자',
#  '월부족금액',
#  '만유',
#  '차처',
#  '일전',
#  '물건',
#  '이달',
#  '이달말',
#  '문의주심',
#  '주심',
#  '월매출',
#  '부족금액',
#  '신진',
#  '신진선님',
#  '회수요청',
#  '문자발송',
#  '배송비',
#  '금요',
#  '한번',
#  '노즈',
#  '노즈큐',
#  '리필',
#  '분말',
#  '분말포',
#  '코세척기',
#  '세척기',
#  '정기',
#  '거치대',
#  '거치대포함',
#  '포함',
#  '반품신청시',
#  '무료',
#  '무료반품쿠폰',
#  '미사',
#  '재신청예정',
#  '월부족금액',
#  '만유',
#  '차처',
#  '스타',
#  '스타벅스',
#  '벅스',
#  '디카페인라떼',
#  '카페인',
#  '청해',
#  '청해드림',
#  '임팩',
#  '민개정',
#  '개정',
#  '마트상품권',
#  '월매출',
#  '부족금액',
#  '신진',
#  '신진선님',
#  '칼텍스',
#  '텍스',
#  '장과',
#  '부외품',
#  '부외품할인',
#  '천원',
#  '역대급',
#  '월역대급이벤트',
#  '만원이상',
#  '도달',
#  '미사용',
#  '미수신',
#  '스팸저장함',
#  '보시',
#  '한올',
#  '주문시',
#  '웹페이지',
#  '발생',
#  '함확인',
#  '길홤',
#  '부스',
#  '개동',
#  '정로',
#  '브롬화',
#  '코판당의정',
#  '브롬화부틸스코폴',
#  '당의정',
#  '부틸',
#  '스코',
#  '라민',
#  '환당의정개',
#  '당의',
#  '정개',
#  '반품신청요청',
#  '반품신청완료',
#  '확인요청안내드림',
#  '주소지',
#  '김담령님',
#  '조은',
#  '조은약국김영애',
#  '영애',
#  '미사용',
#  '백광',
#  '백광의약품',
#  '의약품',
#  '둘코락스에스',
#  '락스',
#  '에스',
#  '핑크',
#  '반품요청사유',
#  '재고과다',
#  '과다',
#  '유통기한',
#  '재판매',
#  '반품어려움',
#  '월부족금액',
#  '만유',
#  '차처',
#  '스타',
#  '스타벅스',
#  '벅스',
#  '디카페인라떼',
#  '카페인',
#  '청해',
#  '청해드림',
#  '임팩',
#  '민개정',
#  '개정',
#  '마트상품권',
#  '월매출',
#  '부족금액',
#  '신진',
#  '신진선님',
#  '칼텍스',
#  '텍스',
#  '장과',
#  '부외품',
#  '부외품할인',
#  '천원',
#  '역대급',
#  '샵마일리지',
#  '패밀리',
#  '패밀리존',
#  '부외품',
#  '부외품할인쿠폰',
#  '교환요청',
#  '부외품할인',
#  '천원',
#  '드리고',
#  '유효기간안내드림',
#  '고경',
#  '고경혜',
#  '부스',
#  '개동',
#  '정로',
#  '브롬화',
#  '코판당의정',
#  '브롬화부틸스코폴',
#  '당의정',
#  '부틸',
#  '스코',
#  '라민',
#  '환당의정개',
#  '당의',
#  '정개',
#  '반품신청요청',
#  '부스코판당의',
#  '정은',
#  '반품신청가능하심',
#  '동성',
#  '환당의정은',
#  '확인필요',
#  '단풍',
#  '단풍약국이혜',
#  '이혜',
#  '백광',
#  '백광의약품',
#  '의약품',
#  '둘코락스에스',
#  '락스',
#  '에스',
#  '핑크',
#  '반품요청사유',
#  '재고과다',
#  '과다',
#  '반품가능',
#  '주기',
#  '함소',
#  '영님통화',
#  '백광의약품남',
#  '유통기한',
#  '재판매',
#  '반품어려움',
#  '영님전달',
#  '부스',
#  '개동',
#  '정로',
#  '브롬화',
#  '코판당의정',
#  '브롬화부틸스코폴',
#  '당의정',
#  '부틸',
#  '스코',
#  '라민',
#  '환당의정개',
#  '당의',
#  '정개',
#  '반품신청요청',
#  '단풍',
#  '단풍약국이혜',
#  '이혜',
#  '백광',
#  '백광의약품',
#  '의약품',
#  '둘코락스에스',
#  '락스',
#  '에스',
#  '핑크',
#  '반품요청사유',
#  '재고과다',
#  '과다',
#  '반품가능',
#  '연락주기',
#  '주기',
#  '행복',
#  '이소',
#  '이소현주문',
#  '현주',
#  '거래처',
#  '로컬',
#  '로컬사업부',
#  '사업부',
#  '편승',
#  '주문이력',
#  '해당거래처',
#  '월주문건',
#  '전경진님',
#  '경진',
#  '인계',
#  '백광',
#  '백광의약품',
#  '의약품',
#  '둘코락스에스',
#  '락스',
#  '에스',
#  '핑크',
#  '반품요청사유',
#  '재고과다',
#  '과다',
#  '사용방법문의',
#  '반품하면',
#  '하면',
#  '주문결제',
#  '진행시',
#  '할인정보',
#  '대웅마이너스잔고',
#  '임팩',
#  '케어',
#  '등록후',
#  '개이상',
#  '권장',
#  '권장소비자',
#  '준수',
#  '지윤님상담',
#  '상담',
#  '처리후',
#  '내용임',
#  '확인햇으',
#  '지속',
#  '전상담원',
#  '상담원',
#  '통화요청',
#  '지윤님',
#  '통화중',
#  '대신',
#  '사과',
#  '거냐',
#  '짜증',
#  '짜증불만제기',
#  '불만',
#  '제기',
#  '해당내용',
#  '응대',
#  '양해안내드림',
#  '페이지대웅',
#  '특별공급관',
#  '확인가능',
#  '그것',
#  '했냐',
#  '주의',
#  '안내케어',
#  '등록요청',
#  '최소',
#  '제품임',
#  '건의',
#  '그린',
#  '백지',
#  '백지흔승인요청',
#  '면허증',
#  '영메일',
#  '비말',
#  '비말마스크',
#  '마스크',
#  '마스크가격',
#  '냐며',
#  '시중',
#  '판매중인',
#  '중인',
#  '건의',
#  '건의요청',
#  '편의점',
#  '기함',
#  '기함운영팀',
#  '운영',
#  '요청드림양해',
#  '카톡으',
#  '환불요청',
#  '폐업예정',
#  '차주',
#  '금요일',
#  '환급',
#  '성희',
#  '성희님',
#  '이번주',
#  '화요일',
#  '클럽',
#  '이처',
#  '구연산',
#  '식용',
#  '식용구연산',
#  '스푼',
#  '스푼포함',
#  '포함',
#  '오늘출고요청',
#  '오늘출고',
#  '종로',
#  '종로당온누리약국',
#  '기승',
#  '기승호결제완료',
#  '클럽',
#  '이처',
#  '구연산',
#  '식용',
#  '식용구연산',
#  '스푼',
#  '스푼포함',
#  '포함',
#  '오늘출고요청',
#  '주신다심',
#  '다심',
#  '클럽',
#  '이처',
#  '구연산',
#  '식용',
#  '식용구연산',
#  '스푼',
#  '스푼포함',
#  '포함',
#  '오늘출고요청',
#  '대웅서울',
#  '덤씬가위포함',
#  '가위',
#  '포함',
#  '매입',
#  '개매매',
#  '매매',
#  '이번주중',
#  '주중',
#  '권장',
#  '권장소비자가격',
#  '천원',
#  '천원만원',
#  '도매몰문의',
#  '매몰',
#  '내선',
#  '마트온누리약국',
#  '김종',
#  '용마',
#  '용마임팩',
#  '민케어',
#  '케어',
#  '공장출고분',
#  '용마배송',
#  '내역문의',
#  '도매부외품반품',
#  '부외품',
#  '진행현황',
#  '현황',
#  '분포',
#  '아신',
#  '반품가능',
#  '이내',
#  '때문',
#  '반품불가하다',
#  '삼일',
#  '삼일약국',
#  '김영민여',
#  '분포',
#  '아신',
#  '반품가능',
#  '개월이내',
#  '이내',
#  '반품불가',
#  '감약국감경전',
#  '감경',
#  '세화',
#  '세화약품테넬',
#  '엠서방정',
#  '서방',
#  '배송예정확인안내',
#  '분포',
#  '아신',
#  '반품가능',
#  '수정요청톡으',
#  '렌품절문의',
#  '대웅바이오',
#  '렌정',
#  '말경',
#  '예정이엇으',
#  '미정',
#  '미정상태',
#  '월말',
#  '정확',
#  '정확치가',
#  '치가',
#  '전고객',
#  '품절양해안내드림',
#  '제약공장',
#  '락피더스아이',
#  '더스',
#  '아이',
#  '공장출고분',
#  '오늘주문건',
#  '이번달',
#  '거라',
#  '새물',
#  '새물약국',
#  '김수진',
#  '수진',
#  '씨엠랩',
#  '멀티',
#  '멀티체온계',
#  '체온계',
#  '접촉',
#  '접촉비접촉생활온도',
#  '비접촉',
#  '생활',
#  '온도',
#  '년무상',
#  '무상',
#  '반품쿠폰사용',
#  '회수지연',
#  '전달완료',
#  '현서',
#  '재인',
#  '재인입',
#  '운수',
#  '운수트레이드남',
#  '트레이드',
#  '독촉',
#  '대웅복산약품',
#  '배송예정시간',
#  '이화',
#  '이화온누리약국',
#  '임강현',
#  '오영',
#  '록신',
#  '반품회수지연',
#  '회수요청완료',
#  '지오영',
#  '오영',
#  '록신',
#  '반품회수지연',
#  '회수요청',
#  '다이아',
#  '다이아벡스',
#  '벡스',
#  '재고문의',
#  '미차장',
#  '내선',
#  '내선안내',
#  '약국몰',
#  '병원',
#  '병원몰',
#  '리브',
#  '리브레',
#  '도매상',
#  '구입가능',
#  '도매몰',
#  '매몰',
#  '가입조건',
#  '조건',
#  '사업자등록증',
#  '등록증',
#  '종목',
#  '의약품',
#  '가입가능',
#  '구입시',
#  '입시',
#  '실적',
#  '실적여부',
#  '구입가능가입시',
#  '추천',
#  '이름',
#  '실적인정가능리브',
#  '인정',
#  '의료기',
#  '의료기상사',
#  '상사',
#  '부외품',
#  '부외품할인쿠폰사용법',
#  '생명',
#  '생명사랑약국',
#  '사랑',
#  '임순하',
#  '삭제요청',
#  '하기',
#  '통화당시',
#  '당시',
#  '출하',
#  '출하정지',
#  '문의옴',
#  '결제취소완료',
#  '오더',
#  '오더삭제되있',
#  '되있',
#  '납품',
#  '대전지오영제',
#  '전지',
#  '영제',
#  '양해안내드림',
#  '출고정지삭제요청',
#  '담당',
#  '담당부서',
#  '부서',
#  '답변',
#  '인터페이스',
#  '납품삭제',
#  '안내드렷으',
#  '우리',
#  '안됬다',
#  '영업팀',
#  '통화종료',
#  '비용',
#  '비용할인',
#  '합계',
#  '합계금액',
#  '결제금액',
#  '안내드림오상담',
#  '상담',
#  '재안내',
#  '주문금액',
#  '합산',
#  '우루',
#  '우루사연질캡슐',
#  '연질',
#  '캡슐',
#  '하나',
#  '주문이력있으심',
#  '있으',
#  '카드정보',
#  '마스크',
#  '전화주신다심',
#  '다심',
#  '지윤님',
#  '신용',
#  '신용카드',
#  '사전',
#  '사전등록',
#  '비용',
#  '비용할인',
#  '합계',
#  '합계금액',
#  '결제금액',
#  '안내드림오상담',
#  '상담',
#  '재안내',
#  '패밀리',
#  '패밀리존',
#  '사용방법문의',
#  '경로',
#  '경로안내',
#  '생활기',
#  '생활기프트부외품할인',
#  '프트',
#  '부외품',
#  '등등',
#  '안전',
#  '안전보호',
#  '보호',
#  '일회용',
#  '마스크',
#  '중필터',
#  '필터',
#  '성인',
#  '성인청색',
#  '제일',
#  '제일헬스케어',
#  '헬스',
#  '케어',
#  '회수요청',
#  '씨엠랩',
#  '멀티',
#  '멀티체온계',
#  '체온계',
#  '접촉',
#  '접촉비접촉생활온도',
#  '비접촉',
#  '생활',
#  '온도',
#  '년무상',
#  '무상',
#  '반품쿠폰사용',
#  '회수지연',
#  '전달완료',
#  '현서',
#  '재인',
#  '조은',
#  '조은약국',
#  '지현',
#  '주문취소',
#  '음약',
#  '음약국과',
#  '국과',
#  '소통완료',
#  '카드정보',
#  '마스크',
#  '전화주신다심',
#  '다심',
#  '가입관련',
#  '배정문',
#  '배정원',
#  '정원',
#  '메디',
#  '메디타운',
#  '타운',
#  '최윤미',
#  '러브',
#  '러브러브',
#  '러브러브초코케익',
#  '케익',
#  '유효기간연장',
#  '연장',
#  '재발송요청',
#  '엔제이',
#  '제이',
#  '출고해',
#  '약국변혜경',
#  '엔제이',
#  '제이',
#  '부외품',
#  '부외품업체',
#  '할인쿠폰사용',
#  '사라',
#  '월드',
#  '월드비젼',
#  '비젼',
#  '신규',
#  '신규업체라',
#  '업데이트',
#  '완료시',
#  '전달완료',
#  '유미',
#  '유미선님',
#  '반영',
#  '쿠폰적용가능하다',
#  ...]

# %%
len(tfidf_corpus)
# Out:
# 312902

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer(
                            use_idf=True,
                            ngram_range=(1,1)) #오직 1-grams만 고려함
#                             min_df = 0.01,     #1% 미만으로 문서에서 출현하는 단어들은 삭제
#                             max_df = 0.05)      #5% 이상으로 문서에서 존재하는 단어들은 삭제(너무 흔함)

t0=time() 


tfidf = vectorizer.fit_transform(tfidf_corpus)

print("완료시간 : %0.3f초" % (time() - t0))
# Out:
# 완료시간 : 2.591초

# %%
ranked = rank_words(terms=vectorizer.get_feature_names(), feature_matrix=tfidf)

fix, ax = plt.subplots(figsize=(6,10), ncols=1, nrows=1)
sns.barplot(x='rank',y='term',data=ranked[:20], palette="Reds_r", ax=ax)
# Out:
# <AxesSubplot:xlabel='rank', ylabel='term'>

# %% [markdown]
# # 월별 문의사항 데이터 Gensim 분석

# %%
def text_tokenizing(corpus, tokenizer):
    
    # okt = Okt()
    kkma=Kkma()
    token_corpus = []
    

    if tokenizer == "noun":
        for n in tqdm_notebook(range(len(corpus)), desc="Preprocessing"):
            # token_text = okt.nouns(corpus[n])
            #token_text = mecab.nouns(corpus[n])
            token_text = kkma.nouns(corpus[n])
            #token_text = komoran.nouns(corpus[n])
            #token_text = hannanum.nouns(corpus[n])
            token_text = [word for word in token_text if word not in SW and len(word) > 1]
            token_corpus.append(token_text)
            
    elif tokenizer == "morph":
        for n in tqdm_notebook(range(len(corpus)), desc="Preprocessing"):
            # token_text = okt.morphs(corpus[n])
            #token_text = mecab.morphs(corpus[n])
            token_text = kkma.morphs(corpus[n])
            #token_text = komoran.morphs(corpus[n])
            #token_text = hannanum.morphs(corpus[n])
            token_text = [word for word in token_text if word not in SW and len(word) > 1]
            token_corpus.append(token_text)
            

    return token_corpus

# %%
def month_context_extract_gensim(df, month_start, month_end):
    
    # 시간정보 열 datetime 정보로 변환
    df['상담일시'] = pd.to_datetime(df['상담일시'], format='%Y/%m/%d')
    #연도, 월 데이터 dataframe 받음
    year_month_df = df.loc[(df['상담일시'] > month_start) & (df['상담일시'] < month_end)]
    #텍스트 정제
    corpus = year_month_df[['문의사항_클리닝']].values.tolist()
    #corpus --> list of list
    temp_list = sum(corpus, [])
    #okt 형태소 추출
    per_month_keyword = text_tokenizing(temp_list, "noun")
    
    
    return per_month_keyword

# %%
#2019년 4월에서 6월까지 하려면 (df,'2019-04-01', '2019-06-30')로 작성하면 됨.
gensim_corpus = month_context_extract_gensim(df, '2020-01-01', '2020-06-30')
# Out:
# HBox(children=(HTML(value='Preprocessing'), FloatProgress(value=0.0, max=29170.0), HTML(value='')))

# %%
gensim_corpus
# Out:
# [['운동장', '운동장약국', '출고정지'],
#  ['약이', '대웅제약꺼', '오배송', '내일중'],
#  ['대웅바이오', '폐업반품신청건', '요청하심', '신청완료', '월일', '영님통화', '전달완료'],
#  ['샵플러스',
#   '플러스',
#   '선풍기',
#   '교환요청',
#   '사유작동안',
#   '유작',
#   '동안',
#   '겉박스',
#   '심주',
#   '심주문일',
#   '취소일',
#   '주문번호',
#   '교환신청',
#   '사이트',
#   '박스포장부탁',
#   '부탁',
#   '회수요청',
#   '교환건',
#   '일단',
#   '연락요청',
#   '유미',
#   '유미선님',
#   '제품박스',
#   '하심맞교환요청',
#   '맞교',
#   '업체측',
#   '영님연락',
#   '이번주',
#   '화수',
#   '회수후'],
#  ['샵플러스',
#   '플러스',
#   '선풍기',
#   '교환요청',
#   '사유작동안',
#   '유작',
#   '동안',
#   '겉박스',
#   '심주',
#   '심주문일',
#   '취소일',
#   '주문번호',
#   '교환신청',
#   '사이트',
#   '박스포장부탁',
#   '부탁',
#   '회수요청',
#   '교환건',
#   '일단',
#   '연락요청',
#   '유미',
#   '유미선님',
#   '제품박스',
#   '하심맞교환요청',
#   '맞교',
#   '업체측',
#   '함소',
#   '함소영님',
#   '미선',
#   '미선님',
#   '호전환',
#   '전환'],
#  ['다이아', '다이아벡스정', '벡스', '일정', '공문', '공문요청'],
#  ['삼거리',
#   '삼거리약국',
#   '반품관련문의',
#   '국장',
#   '재문의',
#   '내상',
#   '약국장',
#   '확인시',
#   '구매후',
#   '반품기한문의',
#   '도매업',
#   '구입일로',
#   '일로',
#   '개월이내',
#   '이내',
#   '반품안내'],
#  ['마이크로', '마이크로그램', '뉴에어', '리라', '에어', '그램', '사입이', '입이'],
#  ['스타',
#   '스타정',
#   '거래명세서',
#   '명세서',
#   '스타정과',
#   '정과',
#   '올메텍정',
#   '개도',
#   '확인요청잘못기재',
#   '잘못',
#   '메텍정',
#   '부분배송',
#   '확인요청올메텍정',
#   '요청올메텍정',
#   '익일배송'],
#  ['삼거리', '삼거리약국', '반품관련문의', '국장', '재문의'],
#  ['창원',
#   '백제종합',
#   '종합',
#   '온누리약국',
#   '주문건중',
#   '스멕',
#   '현탁액',
#   '오배송',
#   '회수후',
#   '재배',
#   '재배송',
#   '양해안내드림'],
#  ['인천약품', '마이칼디정병', '정병', '덱실란트디알', '실란트', '캡슐', '개인', '개인천약품', '주기'],
#  ['임팩', '민케어', '케어', '등록문의', '구글시트', '시트', '접수후', '권장', '권장소비자', '만원준수', '준수'],
#  ['천지인', '밴드', '밴드골드', '골드', '슈퍼', '슈퍼포', '직접', '처리요청업체', '연락주시기', '시기'],
#  ['스타',
#   '스타정',
#   '거래명세서',
#   '명세서',
#   '스타정과',
#   '정과',
#   '올메텍정',
#   '개도',
#   '확인요청잘못기재',
#   '잘못',
#   '메텍정',
#   '부분배송',
#   '확인요청납품번호',
#   '납품'],
#  ['하온누리약국',
#   '송경철결제완료',
#   '경철',
#   '창원',
#   '백제종합',
#   '종합',
#   '온누리약국',
#   '주문건중',
#   '스멕',
#   '현탁액',
#   '오배송',
#   '전달완료'],
#  ['환불요청사유', '반품처리통장사본', '환불예정일'],
#  ['헬스', '헬스인', '전체취소요청', '사유금액', '취소불가'],
#  ['대흥', '약국정인선', '정인', '헬스', '헬스인', '전체취소요청', '사유금액', '취소불가'],
#  ['헬스', '헬스인', '전체취소요청', '사유금액'],
#  ['백제종합약국',
#   '종합',
#   '소상',
#   '소상문',
#   '다이아',
#   '다이아벡스정염',
#   '벡스',
#   '정염',
#   '메트',
#   '메트폴민',
#   '개다이아벡스정염',
#   '장바구니담기요청',
#   '담기'],
#  ['대웅제약오산거점',
#   '스타',
#   '스타정',
#   '거래명세서',
#   '명세서',
#   '스타정과',
#   '정과',
#   '올메텍정',
#   '개도',
#   '확인요청잘못기재',
#   '잘못',
#   '메텍정',
#   '부분배송'],
#  ['임팩', '민케어', '케어', '페이지대웅', '특별공급관'],
#  ['창원', '백제종합', '종합', '온누리약국', '주문건중', '스멕', '현탁액', '오배송'],
#  ['샵플러스', '플러스', '접속', '왼쪽', '종모양', '모양'],
#  ['에브',
#   '에브리데이',
#   '리데이',
#   '중필터',
#   '필터',
#   '대형',
#   '일회용',
#   '마스크',
#   '끈조절가능블랙',
#   '조절',
#   '블랙',
#   '반품쿠폰사용',
#   '제일',
#   '제일헬스케어',
#   '헬스',
#   '케어',
#   '반품완료',
#   '회수안됨',
#   '회수요청',
#   '어린이',
#   '중구조',
#   '구조',
#   '부직포',
#   '아동용',
#   '아동용백색',
#   '백색',
#   '쿠폰사용개',
#   '제이',
#   '예치금적립',
#   '반품처리',
#   '지연문의'],
#  ['미방',
#   '미방약국',
#   '방순열결제완료',
#   '순열',
#   '천지인',
#   '밴드',
#   '밴드골드',
#   '골드',
#   '슈퍼',
#   '슈퍼포',
#   '직접',
#   '처리요청',
#   '해당건'],
#  ['천지인', '밴드', '밴드골드', '골드', '슈퍼', '슈퍼포', '직접', '처리요청'],
#  ['공급사', '실적', '대웅제약제품', '공급사가', '사가', '해당건', '샵고객지원', '지원'],
#  ['세이', '확인안내드림'],
#  ['반품회수요청건',
#   '전달완료에벤에셀약국',
#   '에벤에셀',
#   '민영기',
#   '영기',
#   '건종로당온누리',
#   '종로',
#   '성보영',
#   '보영',
#   '회수요청'],
#  ['한올',
#   '주문시',
#   '웹페이지',
#   '발생',
#   '함확인',
#   '위한',
#   '사업자등록증',
#   '등록증',
#   '배송가능',
#   '주문가능',
#   '한올담당자'],
#  ['월부족금액',
#   '만유',
#   '차처',
#   '일전',
#   '물건',
#   '이달',
#   '이달말',
#   '문의주심',
#   '주심',
#   '월매출',
#   '부족금액',
#   '신진',
#   '신진선님',
#   '회수요청',
#   '문자발송',
#   '배송비',
#   '금요',
#   '한번'],
#  ['노즈',
#   '노즈큐',
#   '리필',
#   '분말',
#   '분말포',
#   '코세척기',
#   '세척기',
#   '정기',
#   '거치대',
#   '거치대포함',
#   '포함',
#   '반품신청시',
#   '무료',
#   '무료반품쿠폰',
#   '미사',
#   '재신청예정'],
#  ['월부족금액',
#   '만유',
#   '차처',
#   '스타',
#   '스타벅스',
#   '벅스',
#   '디카페인라떼',
#   '카페인',
#   '청해',
#   '청해드림',
#   '임팩',
#   '민개정',
#   '개정',
#   '마트상품권',
#   '월매출',
#   '부족금액',
#   '신진',
#   '신진선님',
#   '칼텍스',
#   '텍스',
#   '장과',
#   '부외품',
#   '부외품할인',
#   '천원',
#   '역대급',
#   '월역대급이벤트',
#   '만원이상',
#   '도달',
#   '미사용',
#   '미수신',
#   '스팸저장함',
#   '보시'],
#  ['한올', '주문시', '웹페이지', '발생', '함확인', '길홤'],
#  ['부스',
#   '개동',
#   '정로',
#   '브롬화',
#   '코판당의정',
#   '브롬화부틸스코폴',
#   '당의정',
#   '부틸',
#   '스코',
#   '라민',
#   '환당의정개',
#   '당의',
#   '정개',
#   '반품신청요청',
#   '반품신청완료',
#   '확인요청안내드림'],
#  ['주소지', '김담령님'],
#  ['조은', '조은약국김영애', '영애', '미사용'],
#  ['백광',
#   '백광의약품',
#   '의약품',
#   '둘코락스에스',
#   '락스',
#   '에스',
#   '핑크',
#   '반품요청사유',
#   '재고과다',
#   '과다',
#   '유통기한',
#   '재판매',
#   '반품어려움'],
#  ['월부족금액',
#   '만유',
#   '차처',
#   '스타',
#   '스타벅스',
#   '벅스',
#   '디카페인라떼',
#   '카페인',
#   '청해',
#   '청해드림',
#   '임팩',
#   '민개정',
#   '개정',
#   '마트상품권',
#   '월매출',
#   '부족금액',
#   '신진',
#   '신진선님',
#   '칼텍스',
#   '텍스',
#   '장과',
#   '부외품',
#   '부외품할인',
#   '천원',
#   '역대급'],
#  ['샵마일리지',
#   '패밀리',
#   '패밀리존',
#   '부외품',
#   '부외품할인쿠폰',
#   '교환요청',
#   '부외품할인',
#   '천원',
#   '드리고',
#   '유효기간안내드림'],
#  ['고경',
#   '고경혜',
#   '부스',
#   '개동',
#   '정로',
#   '브롬화',
#   '코판당의정',
#   '브롬화부틸스코폴',
#   '당의정',
#   '부틸',
#   '스코',
#   '라민',
#   '환당의정개',
#   '당의',
#   '정개',
#   '반품신청요청',
#   '부스코판당의',
#   '정은',
#   '반품신청가능하심',
#   '동성',
#   '환당의정은',
#   '확인필요'],
#  ['단풍',
#   '단풍약국이혜',
#   '이혜',
#   '백광',
#   '백광의약품',
#   '의약품',
#   '둘코락스에스',
#   '락스',
#   '에스',
#   '핑크',
#   '반품요청사유',
#   '재고과다',
#   '과다',
#   '반품가능',
#   '주기',
#   '함소',
#   '영님통화',
#   '백광의약품남',
#   '유통기한',
#   '재판매',
#   '반품어려움',
#   '영님전달'],
#  ['부스',
#   '개동',
#   '정로',
#   '브롬화',
#   '코판당의정',
#   '브롬화부틸스코폴',
#   '당의정',
#   '부틸',
#   '스코',
#   '라민',
#   '환당의정개',
#   '당의',
#   '정개',
#   '반품신청요청'],
#  ['단풍',
#   '단풍약국이혜',
#   '이혜',
#   '백광',
#   '백광의약품',
#   '의약품',
#   '둘코락스에스',
#   '락스',
#   '에스',
#   '핑크',
#   '반품요청사유',
#   '재고과다',
#   '과다',
#   '반품가능',
#   '연락주기',
#   '주기'],
#  ['행복',
#   '이소',
#   '이소현주문',
#   '현주',
#   '거래처',
#   '로컬',
#   '로컬사업부',
#   '사업부',
#   '편승',
#   '주문이력',
#   '해당거래처',
#   '월주문건',
#   '전경진님',
#   '경진',
#   '인계'],
#  ['백광', '백광의약품', '의약품', '둘코락스에스', '락스', '에스', '핑크', '반품요청사유', '재고과다', '과다'],
#  ['사용방법문의', '반품하면', '하면', '주문결제', '진행시', '할인정보', '대웅마이너스잔고'],
#  ['임팩',
#   '케어',
#   '등록후',
#   '개이상',
#   '권장',
#   '권장소비자',
#   '준수',
#   '지윤님상담',
#   '상담',
#   '처리후',
#   '내용임',
#   '확인햇으',
#   '지속',
#   '전상담원',
#   '상담원',
#   '통화요청',
#   '지윤님',
#   '통화중',
#   '대신',
#   '사과',
#   '거냐',
#   '짜증',
#   '짜증불만제기',
#   '불만',
#   '제기',
#   '해당내용',
#   '응대',
#   '양해안내드림',
#   '페이지대웅',
#   '특별공급관',
#   '확인가능',
#   '그것',
#   '했냐',
#   '주의',
#   '안내케어',
#   '등록요청',
#   '최소',
#   '제품임',
#   '건의'],
#  ['그린', '백지', '백지흔승인요청', '면허증', '영메일'],
#  ['비말',
#   '비말마스크',
#   '마스크',
#   '마스크가격',
#   '냐며',
#   '시중',
#   '판매중인',
#   '중인',
#   '건의',
#   '건의요청',
#   '편의점',
#   '기함',
#   '기함운영팀',
#   '운영',
#   '요청드림양해'],
#  ['카톡으', '환불요청', '폐업예정', '차주', '금요일', '환급', '성희', '성희님', '이번주', '화요일'],
#  ['클럽', '이처', '구연산', '식용', '식용구연산', '스푼', '스푼포함', '포함', '오늘출고요청', '오늘출고'],
#  ['종로',
#   '종로당온누리약국',
#   '기승',
#   '기승호결제완료',
#   '클럽',
#   '이처',
#   '구연산',
#   '식용',
#   '식용구연산',
#   '스푼',
#   '스푼포함',
#   '포함',
#   '오늘출고요청',
#   '주신다심',
#   '다심'],
#  ['클럽', '이처', '구연산', '식용', '식용구연산', '스푼', '스푼포함', '포함', '오늘출고요청'],
#  ['대웅서울',
#   '덤씬가위포함',
#   '가위',
#   '포함',
#   '매입',
#   '개매매',
#   '매매',
#   '이번주중',
#   '주중',
#   '권장',
#   '권장소비자가격',
#   '천원',
#   '천원만원'],
#  ['도매몰문의', '매몰', '내선'],
#  ['마트온누리약국', '김종', '용마', '용마임팩', '민케어', '케어', '공장출고분', '용마배송'],
#  ['내역문의', '도매부외품반품', '부외품', '진행현황', '현황'],
#  ['분포', '아신', '반품가능', '이내', '때문', '반품불가하다'],
#  ['삼일', '삼일약국', '김영민여', '분포', '아신', '반품가능', '개월이내', '이내', '반품불가'],
#  ['감약국감경전', '감경', '세화', '세화약품테넬', '엠서방정', '서방', '배송예정확인안내'],
#  ['분포', '아신', '반품가능'],
#  ['수정요청톡으'],
#  ['렌품절문의',
#   '대웅바이오',
#   '렌정',
#   '말경',
#   '예정이엇으',
#   '미정',
#   '미정상태',
#   '월말',
#   '정확',
#   '정확치가',
#   '치가',
#   '전고객',
#   '품절양해안내드림'],
#  ['제약공장', '락피더스아이', '더스', '아이', '공장출고분', '오늘주문건', '이번달', '거라'],
#  ['새물',
#   '새물약국',
#   '김수진',
#   '수진',
#   '씨엠랩',
#   '멀티',
#   '멀티체온계',
#   '체온계',
#   '접촉',
#   '접촉비접촉생활온도',
#   '비접촉',
#   '생활',
#   '온도',
#   '년무상',
#   '무상',
#   '반품쿠폰사용',
#   '회수지연',
#   '전달완료',
#   '현서',
#   '재인',
#   '재인입',
#   '운수',
#   '운수트레이드남',
#   '트레이드',
#   '독촉'],
#  ['대웅복산약품', '배송예정시간'],
#  ['이화', '이화온누리약국', '임강현', '오영', '록신', '반품회수지연', '회수요청완료'],
#  ['지오영', '오영', '록신', '반품회수지연', '회수요청'],
#  ['다이아', '다이아벡스', '벡스', '재고문의', '미차장', '내선', '내선안내'],
#  ['약국몰',
#   '병원',
#   '병원몰',
#   '리브',
#   '리브레',
#   '도매상',
#   '구입가능',
#   '도매몰',
#   '매몰',
#   '가입조건',
#   '조건',
#   '사업자등록증',
#   '등록증',
#   '종목',
#   '의약품',
#   '가입가능',
#   '구입시',
#   '입시',
#   '실적',
#   '실적여부',
#   '구입가능가입시',
#   '추천',
#   '이름',
#   '실적인정가능리브',
#   '인정',
#   '의료기',
#   '의료기상사',
#   '상사'],
#  ['부외품', '부외품할인쿠폰사용법'],
#  ['생명',
#   '생명사랑약국',
#   '사랑',
#   '임순하',
#   '삭제요청',
#   '하기',
#   '통화당시',
#   '당시',
#   '출하',
#   '출하정지',
#   '문의옴',
#   '결제취소완료',
#   '오더',
#   '오더삭제되있',
#   '되있',
#   '납품',
#   '대전지오영제',
#   '전지',
#   '영제',
#   '양해안내드림',
#   '출고정지삭제요청',
#   '담당',
#   '담당부서',
#   '부서',
#   '답변',
#   '인터페이스',
#   '납품삭제',
#   '안내드렷으',
#   '우리',
#   '안됬다',
#   '영업팀',
#   '통화종료'],
#  ['비용',
#   '비용할인',
#   '합계',
#   '합계금액',
#   '결제금액',
#   '안내드림오상담',
#   '상담',
#   '재안내',
#   '주문금액',
#   '합산',
#   '우루',
#   '우루사연질캡슐',
#   '연질',
#   '캡슐',
#   '하나',
#   '주문이력있으심',
#   '있으'],
#  ['카드정보', '마스크', '전화주신다심', '다심', '지윤님', '신용', '신용카드', '사전', '사전등록'],
#  ['비용', '비용할인', '합계', '합계금액', '결제금액', '안내드림오상담', '상담', '재안내'],
#  ['패밀리',
#   '패밀리존',
#   '사용방법문의',
#   '경로',
#   '경로안내',
#   '생활기',
#   '생활기프트부외품할인',
#   '프트',
#   '부외품',
#   '등등'],
#  ['안전',
#   '안전보호',
#   '보호',
#   '일회용',
#   '마스크',
#   '중필터',
#   '필터',
#   '성인',
#   '성인청색',
#   '제일',
#   '제일헬스케어',
#   '헬스',
#   '케어',
#   '회수요청'],
#  ['씨엠랩',
#   '멀티',
#   '멀티체온계',
#   '체온계',
#   '접촉',
#   '접촉비접촉생활온도',
#   '비접촉',
#   '생활',
#   '온도',
#   '년무상',
#   '무상',
#   '반품쿠폰사용',
#   '회수지연',
#   '전달완료',
#   '현서',
#   '재인'],
#  ['조은', '조은약국', '지현', '주문취소', '음약', '음약국과', '국과', '소통완료'],
#  ['카드정보', '마스크', '전화주신다심', '다심'],
#  ['가입관련', '배정문', '배정원', '정원'],
#  ['메디',
#   '메디타운',
#   '타운',
#   '최윤미',
#   '러브',
#   '러브러브',
#   '러브러브초코케익',
#   '케익',
#   '유효기간연장',
#   '연장',
#   '재발송요청'],
#  ['엔제이', '제이', '출고해'],
#  ['약국변혜경'],
#  ['엔제이', '제이'],
#  ['부외품',
#   '부외품업체',
#   '할인쿠폰사용',
#   '사라',
#   '월드',
#   '월드비젼',
#   '비젼',
#   '신규',
#   '신규업체라',
#   '업데이트',
#   '완료시',
#   '전달완료',
#   '유미',
#   '유미선님',
#   '반영',
#   '쿠폰적용가능하다'],
#  ['사용방법', '분기', '롯데', '발신', '발신번호', '롯데백화점', '백화점'],
#  ['한올', '한올바이오파마', '파마', '단순', '지윤님언제', '언제', '환급'],
#  [],
#  ['어린이',
#   '일회용',
#   '부직포',
#   '마스크',
#   '흰색',
#   '흰색벌크형',
#   '벌크',
#   '인천약품',
#   '반품수량',
#   '개로',
#   '수정완료'],
#  ['세계', '세계약국박재완결', '박재', '완결', '인천약품', '한신', '한신약품', '출고정지완료'],
#  ['응답'],
#  ['세계', '세계약국박재완결', '박재', '완결', '인천약품', '한신', '한신약품', '출고정지완료'],
#  ['인천약품', '한신', '한신약품'],
#  ['가나',
#   '가나약국허유정',
#   '허유',
#   '공지사항',
#   '사항',
#   '대로',
#   '백색',
#   '주문결제오류',
#   '주문결제',
#   '원격',
#   '원격지원',
#   '지원'],
#  ['수약국',
#   '헬스',
#   '헬스케어',
#   '케어',
#   '에스엠',
#   '에스엠스왑',
#   '스왑',
#   '알파',
#   '알파알콜스왑매',
#   '알콜',
#   '개개',
#   '연락주신'],
#  ['다음분기', '분기', '패밀리', '패밀리등급', '분기매출', '원로'],
#  ['화면', '백색', '백색오류', '샵공지사항', '사항', '파일', '다운로드'],
#  ['사용방법', '패밀리', '패밀리존', '통해'],
#  ['아침', '아침약국', '호종', '호종결제완료', '대웅대전', '대전', '출고정지'],
#  ['판촉물미신청',
#   '차처',
#   '안내마일리지',
#   '주유',
#   '주유할인',
#   '파리',
#   '파리바게트',
#   '바게트',
#   '천원',
#   '천원권투',
#   '권투',
#   '아메리카',
#   '아메리카노',
#   '청해',
#   '청해드림',
#   '만유',
#   '월매출',
#   '부족금액',
#   '미애님통화',
#   '스타',
#   '스타벅스',
#   '벅스',
#   '카페',
#   '변경신청요청',
#   '변경신청'],
#  ['복산나이스', '나이스', '부산', '문의글루코', '글루코', '서방', '서방정', '전화요청'],
#  ['대웅공장', '덤씬가위포함', '가위', '포함', '매입', '개매매', '매매', '김현규'],
#  ['동국', '동국약국유미라', '미라', '플러스', '반품취소'],
#  ['주문번호',
#   '샵플러스',
#   '플러스',
#   '황실',
#   '황실유기공방',
#   '유기',
#   '공방',
#   '황실유기',
#   '수저',
#   '수저세트',
#   '세트',
#   '출고해'],
#  ['반품접수', '택배비', '왕복', '왕복적용', '운영', '운영팀', '장지', '장지윤님'],
#  ['덤플러스', '플러스', '낱알', '기입', '예상', '예상금액', '실제', '환입가', '입가', '무관함'],
#  ['로제',
#   '로제피부과의원',
#   '피부과',
#   '의원',
#   '정병',
#   '정병철',
#   '한백',
#   '한백엠트레이드세금',
#   '트레이드',
#   '신고',
#   '신고건',
#   '오늘자',
#   '선발',
#   '요청담당자',
#   '함사라',
#   '사라',
#   '통화건일자로',
#   '건일',
#   '자로',
#   '고함',
#   '병원',
#   '동일',
#   '이메일',
#   '요청드림'],
#  ['오창약국김진태', '김진태', '출고정지'],
#  ['도매몰', '매몰', '주문관련문의', '미차장', '내선', '내선안내'],
#  ['국산',
#   '황사',
#   '흰색',
#   '황사방역',
#   '용마스크',
#   '마스크',
#   '푸른',
#   '방역',
#   '대형',
#   '대형매매',
#   '매매',
#   '개배송문의'],
#  ['월부족금액',
#   '만유',
#   '차처',
#   '미안내',
#   '스타',
#   '스타벅스',
#   '벅스',
#   '캬라멜',
#   '캬라멜마끼',
#   '청해',
#   '청해드림',
#   '낱알',
#   '낱알반품',
#   '사용방법',
#   '신진',
#   '신진선님',
#   '낱알반품방법',
#   '선생님'],
#  ['신한', '신한카드', '재등록', '재등록문의', '페이지회원정보', '신한카드설정', '설정'],
#  ['국민은행', '은행', '주문요청', '가상계좌', '엠서클', '서클'],
#  ['대웅대전', '대전', '진행중'],
#  ['플러스'],
#  ['햇살',
#   '약국구영태',
#   '구영',
#   '대웅원주',
#   '원주',
#   '문의주심',
#   '주심',
#   '유미',
#   '유미선님통화',
#   '햇살약국',
#   '오배송',
#   '아침',
#   '아침편'],
#  ['약국명과',
#   '명과',
#   '주소전화번호',
#   '변경문의',
#   '팩스발송요청',
#   '전번은',
#   '번은',
#   '임팩케어',
#   '케어',
#   '렛잇비',
#   '구매위',
#   '배정요청',
#   '특별공급관',
#   '구매가능',
#   '불가함'],
#  ['오창약국김진태', '김진태', '시이후', '연락요청'],
#  [],
#  ['가입관련', '배정문', '일단', '본사'],
#  ['사업자번호변경', '사업자번호', '기준', '때문'],
#  ['가입관련', '배정문의', '시정도', '요청하심'],
#  ['메디',
#   '신약국',
#   '오옥',
#   '오옥주반품',
#   '복산나이스',
#   '나이스',
#   '부산',
#   '문의글루코',
#   '글루코',
#   '서방',
#   '서방정',
#   '제조사',
#   '제조사회수대상',
#   '대상',
#   '한올',
#   '처리때문',
#   '때문',
#   '순차적',
#   '순차적처리'],
#  ['용마',
#   '지스',
#   '지스처방전박스',
#   '수거요청',
#   '고객센터',
#   '센터',
#   '직접',
#   '일이내공휴일제외',
#   '이내',
#   '공휴일',
#   '제외',
#   '수거예정'],
#  ['영님', '연결요청', '연결완료'],
#  ['햇살', '약국구영태', '구영', '대웅원주', '원주', '문의주심', '주심'],
#  ['테라이트', '라이트', '정관련'],
#  ['가입관련', '배정문', '정문'],
#  ['대웅공장', '덤씬가위포함', '가위', '포함', '매입', '개매매', '매매'],
#  ['가입관련', '배정문의'],
#  ['제이', '입체', '극세사', '방한', '블랙', '방한대', '블랙반품', '개회수', '미처리', '처리요청'],
#  ['주문번호',
#   '샵플러스',
#   '플러스',
#   '황실',
#   '황실유기공방',
#   '유기',
#   '공방',
#   '황실유기',
#   '수저',
#   '수저세트',
#   '세트'],
#  ['주병'],
#  ['방금', '방금가입', '반나절', '하루', '안내드림승인완료', '문자발송', '안내완료'],
#  ['가입관련', '배정문의'],
#  ['생명',
#   '생명사랑약국',
#   '사랑',
#   '임순하',
#   '삭제요청',
#   '하기',
#   '통화당시',
#   '당시',
#   '출하',
#   '출하정지',
#   '문의옴',
#   '결제취소완료',
#   '오더',
#   '오더삭제되있',
#   '되있',
#   '납품',
#   '대전지오영제',
#   '전지',
#   '영제',
#   '양해안내드림',
#   '출고정지삭제요청',
#   '담당',
#   '담당부서',
#   '부서',
#   '답변'],
#  ['메디',
#   '신약국',
#   '오옥',
#   '오옥주반품',
#   '복산나이스',
#   '나이스',
#   '부산',
#   '문의글루코',
#   '글루코',
#   '서방',
#   '서방정',
#   '제조사',
#   '제조사회수대상',
#   '대상',
#   '한올',
#   '처리때문',
#   '때문',
#   '순차적',
#   '순차적처리'],
#  ['임팩', '프리미엄', '제외', '구매희망', '김민우담당자', '번호안내'],
#  ['로제',
#   '로제피부과의원',
#   '피부과',
#   '의원',
#   '정병',
#   '정병철',
#   '한백',
#   '한백엠트레이드세금',
#   '트레이드',
#   '신고',
#   '신고건',
#   '오늘자',
#   '선발',
#   '요청담당자'],
#  ['복산나이스', '나이스', '부산', '문의글루코', '글루코', '서방', '서방정', '전화요청'],
#  ['요양', '요양기관번호', '기관', '임의', '임의숫자', '숫자', '자리', '기입', '변경요청'],
#  ['헬스', '헬스케어', '케어', '에스엠', '에스엠스왑', '스왑', '알파', '알파알콜스왑매', '알콜', '개개', '고함'],
#  ['나우',
#   '나우약국',
#   '이경',
#   '이경목',
#   '제일',
#   '제일헬스케어',
#   '헬스',
#   '케어',
#   '건강일회용마스크',
#   '일회용',
#   '마스크',
#   '처리요청',
#   '전달완료'],
#  ['제일', '제일헬스케어', '헬스', '케어', '건강일회용마스크', '일회용', '마스크', '처리요청'],
#  ['대성', '메디', '케어', '케어주문취소', '요청사유단순취소', '단순'],
#  ['천사',
#   '천사약국',
#   '광열',
#   '대성',
#   '메디',
#   '케어',
#   '케어주문취소',
#   '요청사유단순취소',
#   '단순',
#   '출하',
#   '출하정지',
#   '카드취소'],
#  ['공동', '공동구매'],
#  ['대성', '메디', '케어', '케어주문취소', '요청사유단순취소', '단순'],
#  ['금성', '금성약국', '돌고래', '돌고래약국', '승인요청', '주문급하심'],
#  ['월부족금액',
#   '만유',
#   '차처',
#   '월매출',
#   '부족금액',
#   '신진',
#   '신진선님',
#   '어디',
#   '얼마',
#   '재확인',
#   '재확인요청',
#   '이달',
#   '이달말일',
#   '말일',
#   '추가구매',
#   '이벤트전화',
#   '휴대폰',
#   '메모',
#   '메모완료'],
#  ['솔트', '솔트액', '반품문의', '반품신청가능', '결과', '자로', '신청하심'],
#  ['반품회수지연',
#   '불만',
#   '제일',
#   '제일헬스케어',
#   '헬스',
#   '케어',
#   '수거요청',
#   '신청건',
#   '데일리',
#   '필터',
#   '일회용',
#   '마스크',
#   '필터사용',
#   '개별',
#   '개별포장백색개',
#   '백색',
#   '중구조',
#   '구조',
#   '데일리세이프',
#   '세이프',
#   '부직포',
#   '개별포장검정색',
#   '검정색',
#   '단순',
#   '단순반품',
#   '부직포마스크검정색',
#   '사유단순반품',
#   '택배박스'],
#  ['돔정',
#   '최저가',
#   '최저가연동',
#   '연동',
#   '약정',
#   '약정금액',
#   '천만',
#   '천만원',
#   '연동혜택',
#   '전종우',
#   '종우',
#   '설정',
#   '언제',
#   '계속',
#   '도달',
#   '월일',
#   '월일자로',
#   '자로',
#   '사전',
#   '사전안내',
#   '패밀리',
#   '패밀리존',
#   '분기',
#   '시기',
#   '코로나',
#   '때문',
#   '최저',
#   '최저가가',
#   '가가',
#   '겠다',
#   '겠다라',
#   '보통',
#   '최저가보상차액',
#   '보상',
#   '차액',
#   '예외',
#   '부외품',
#   '부외품할인쿠폰',
#   '내하'],
#  ['대웅전', '대웅전주백제', '정아', '클라', '목시', '정아목시', '부란', '부란산칼륨', '칼륨', '대웅제약취소건'],
#  ['사업자변경', '가입문의', '기존정보', '삭제완료', '사용권', '사용권장', '저녁'],
#  ['잔고이동문의주문', '잔고이동', '방법안내드림'],
#  ['생활기', '생활기프트신청', '프트', '커피', '커피쿠폰', '차주중', '주중'],
#  ['케어', '케어등록요청', '월개이상', '권장', '권장소비자', '만원준수', '준수', '구글시트접수', '시트'],
#  ['반품번호', '월일', '회수지연문의', '반려', '정상적', '안내드림기사님'],
#  ['부외품',
#   '부외품업체',
#   '할인쿠폰사용',
#   '사라',
#   '월드',
#   '월드비젼',
#   '비젼',
#   '신규',
#   '신규업체라',
#   '업데이트',
#   '완료시',
#   '전달완료'],
#  ['반품번호', '월일', '회수지연문의'],
#  ['송강', '태평양', '박상', '방금'],
#  ['세화',
#   '세화헬스케어',
#   '헬스',
#   '케어',
#   '비접촉',
#   '식체온계',
#   '체온계',
#   '반품신청요청',
#   '청해',
#   '청해드림세화헬스',
#   '반품처리',
#   '회수일로',
#   '일로',
#   '일주일',
#   '일주일정도',
#   '최소',
#   '이번주',
#   '금요일',
#   '헬스케어',
#   '해당건',
#   '함지',
#   '윤님통화',
#   '재인',
#   '재인입전화통화',
#   '선되',
#   '재문의',
#   '후연락'],
#  ['크롬', '크롬결제', '농협', '주문요청', '가상계좌', '농협중앙회', '중앙회', '엠서클', '서클'],
#  ['역대급이벤트',
#   '레주르',
#   '선택',
#   '이주',
#   '님통화참고',
#   '참고',
#   '선택하라',
#   '하라',
#   '거보',
#   '거냐며',
#   '냐며',
#   '예외',
#   '예외요청',
#   '중순',
#   '중순안',
#   '발급예정',
#   '월안',
#   '사은품',
#   '유미',
#   '유미선님',
#   '통화건월',
#   '레쥬르',
#   '안됬다',
#   '처리지연',
#   '천점',
#   '대체',
#   '차주',
#   '휴대폰',
#   '복귀',
#   '말씀',
#   '약국장',
#   '국장',
#   '한수',
#   '님답변',
#   '답변',
#   '주안',
#   '언제',
#   '끌거냐',
#   '이것',
#   '누군지',
#   '군지',
#   '직접',
#   '전화오고가게',
#   '오고',
#   '가게',
#   '적립완료',
#   '양해드림'],
#  ['패밀리',
#   '패밀리존',
#   '샵플러스',
#   '플러스',
#   '사용방법',
#   '전부',
#   '파리',
#   '파리바게트',
#   '바게트',
#   '기프티콘',
#   '청해',
#   '청해드림',
#   '꿀조합',
#   '조합',
#   '런치',
#   '런치세트',
#   '세트',
#   '아이스',
#   '아메리카',
#   '아메리카노',
#   '차주',
#   '수요일',
#   '모바일'],
#  ['패밀리',
#   '패밀리존',
#   '샵플러스',
#   '플러스',
#   '사용방법',
#   '전부',
#   '파리',
#   '파리바게트',
#   '바게트',
#   '기프티콘',
#   '청해',
#   '청해드림'],
#  ['조은',
#   '조은약국',
#   '이진',
#   '이진규결제완료',
#   '대웅전',
#   '대웅전주백제',
#   '정아',
#   '클라',
#   '목시',
#   '정아목시',
#   '부란',
#   '부란산칼륨',
#   '칼륨',
#   '요청드림',
#   '방금',
#   '확정',
#   '고함'],
#  ['새천년약국', '천년', '예치금적립요청', '응답', '종료세화', '세화', '헬스', '헬스케어', '케어', '해당건'],
#  ['세화',
#   '세화헬스케어',
#   '헬스',
#   '케어',
#   '비접촉',
#   '식체온계',
#   '체온계',
#   '반품신청요청',
#   '청해',
#   '청해드림세화헬스',
#   '반품처리',
#   '회수일로',
#   '일로',
#   '일주일',
#   '일주일정도',
#   '최소',
#   '이번주',
#   '금요일',
#   '예치금적립요청',
#   '응답',
#   '통화종료'],
#  ['월부족금액',
#   '만유',
#   '차처',
#   '미안내',
#   '스타',
#   '스타벅스',
#   '벅스',
#   '캬라멜',
#   '캬라멜마끼',
#   '청해',
#   '청해드림',
#   '낱알',
#   '낱알반품',
#   '사용방법',
#   '신진',
#   '신진선님',
#   '낱알반품방법'],
#  ['생명',
#   '생명사랑약국',
#   '사랑',
#   '임순하',
#   '삭제요청',
#   '하기',
#   '통화당시',
#   '당시',
#   '출하',
#   '출하정지',
#   '문의옴',
#   '결제취소완료',
#   '오더',
#   '오더삭제되있',
#   '되있',
#   '납품',
#   '대전지오영제',
#   '전지',
#   '영제',
#   '양해안내드림'],
#  [],
#  ['역대급이벤트',
#   '레주르',
#   '선택',
#   '이주',
#   '님통화참고',
#   '참고',
#   '선택하라',
#   '하라',
#   '거보',
#   '거냐며',
#   '냐며',
#   '예외',
#   '예외요청',
#   '중순',
#   '중순안',
#   '발급예정',
#   '월안',
#   '사은품',
#   '유미',
#   '유미선님',
#   '통화건월',
#   '레쥬르',
#   '안됬다',
#   '처리지연',
#   '천점',
#   '대체',
#   '차주',
#   '휴대폰',
#   '복귀',
#   '말씀',
#   '약국장',
#   '국장',
#   '한수',
#   '님답변',
#   '답변',
#   '주안',
#   '언제',
#   '끌거냐',
#   '이것',
#   '누군지',
#   '군지',
#   '직접',
#   '전화오고가게',
#   '오고',
#   '가게',
#   '불만'],
#  ['메디칼',
#   '데이',
#   '일회용',
#   '부직포',
#   '마스크',
#   '소형',
#   '백색',
#   '꼬마',
#   '꼬마자동차',
#   '자동차',
#   '매입',
#   '반품처리요청',
#   '해당제품',
#   '쿠팡',
#   '메디칼이름',
#   '이름',
#   '신뢰를깨뜨렷다',
#   '반품처리',
#   '운영',
#   '운영팀',
#   '전달요청',
#   '세이',
#   '손소',
#   '손소독티슈매',
#   '티슈',
#   '캡형',
#   '반품신청예정',
#   '실수',
#   '입고',
#   '후약국',
#   '전달드림'],
#  ['생명',
#   '생명사랑약국',
#   '사랑',
#   '임순하',
#   '삭제요청',
#   '하기',
#   '통화당시',
#   '당시',
#   '출하',
#   '출하정지',
#   '문의옴',
#   '결제취소완료',
#   '오더',
#   '오더삭제되있',
#   '되있',
#   '납품',
#   '대전지오영제',
#   '전지',
#   '영제',
#   '양해안내드림'],
#  ['아이', '아이사랑', '사랑', '세이', '손소', '손소독티슈매', '티슈', '캡형', '후약국'],
#  ['아이',
#   '아이사랑',
#   '사랑',
#   '메디칼',
#   '데이',
#   '일회용',
#   '부직포',
#   '마스크',
#   '소형',
#   '백색',
#   '꼬마',
#   '꼬마자동차',
#   '자동차',
#   '매입',
#   '반품처리요청'],
#  ['생명',
#   '생명사랑약국',
#   '사랑',
#   '임순하',
#   '삭제요청',
#   '하기',
#   '통화당시',
#   '당시',
#   '출하',
#   '출하정지',
#   '문의옴',
#   '결제취소완료',
#   '오더',
#   '오더삭제되있',
#   '되있',
#   '납품',
#   '대전지오영제',
#   '전지',
#   '영제',
#   '양해안내드림'],
#  ['지윤', '연결요청', '호전환완료', '전환'],
#  ['아이',
#   '아이사랑',
#   '사랑',
#   '메디칼',
#   '데이',
#   '일회용',
#   '부직포',
#   '마스크',
#   '소형',
#   '백색',
#   '꼬마',
#   '꼬마자동차',
#   '자동차',
#   '매입',
#   '반품처리요청',
#   '해당건',
#   '연락주시기',
#   '시기'],
#  ['임팩케어', '케어', '구매요청'],
#  ['카드등록문의', '삼성', '신한', '우리', '비씨', '신한카드등록문의', '손님'],
#  ['아이', '아이사랑', '사랑', '세이', '손소', '손소독티슈매', '티슈', '캡형'],
#  ['천지인', '모아이', '아이', '비접촉', '비접촉식', '적외선', '체온계'],
#  ['샵마일리지',
#   '사용방법',
#   '계속',
#   '신청요청',
#   '패밀리',
#   '패밀리존',
#   '생활기',
#   '생활기프트신청',
#   '프트',
#   '파리',
#   '파리바게트',
#   '바게트',
#   '차주중',
#   '주중'],
#  ['중앙',
#   '중앙약국',
#   '양정',
#   '양정환결제완료',
#   '천지인',
#   '모아이',
#   '아이',
#   '비접촉',
#   '비접촉식',
#   '적외선',
#   '체온계',
#   '출고정지요청완료'],
#  ['천지인', '모아이', '아이', '비접촉', '비접촉식', '적외선', '체온계'],
#  ['약구매시', '사용기한', '상품권할인쿠폰', '적립일로', '일로'],
#  ['메일주소'],
#  ['대웅전',
#   '대웅전주백제',
#   '정아',
#   '클라',
#   '목시',
#   '정아목시',
#   '부란',
#   '부란산칼륨',
#   '칼륨',
#   '취소가능',
#   '시간소요',
#   '양해드림'],
#  ['부외품', '부외품업체', '할인쿠폰사용'],
#  ['케어', '에이', '에이플러스', '플러스', '등록요청', '내일모레', '모레', '확인가능'],
#  ['아이', '아이사랑', '사랑', '세이', '손소', '손소독티슈매', '티슈', '캡형'],
#  ['메디',
#   '메디크린',
#   '크린',
#   '살균',
#   '살균소독제분무',
#   '소독제',
#   '분무',
#   '재고과다사유',
#   '과다',
#   '제일',
#   '제일헬스케어',
#   '헬스',
#   '케어',
#   '회수지연'],
#  ['레쥬르', '교환권', '교환권신청', '청일', '차주', '차주후', '모바일'],
#  ['마이너스잔고사용방법', '장바구니상품', '결제시'],
#  ['메디칼',
#   '데이',
#   '일회용',
#   '부직포',
#   '마스크',
#   '소형',
#   '백색',
#   '꼬마',
#   '꼬마자동차',
#   '자동차',
#   '매입',
#   '반품처리요청',
#   '해당제품',
#   '쿠팡',
#   '메디칼이름',
#   '이름',
#   '신뢰를깨뜨렷다',
#   '반품처리',
#   '운영',
#   '운영팀',
#   '전달요청',
#   '세이',
#   '손소',
#   '손소독티슈매',
#   '티슈',
#   '캡형'],
#  ['천지인', '쥐매트골드', '매트', '골드', '결제완료상태', '부분취소해드림'],
#  ['사용가능', '사용가능여부', '예전', '사용불가'],
#  ['화성',
#   '화성스마일약국박동혁',
#   '스마일',
#   '박동혁',
#   '백광',
#   '백광의약품배송예정',
#   '의약품',
#   '거래처',
#   '오배송',
#   '재배',
#   '재배송요청',
#   '재배송예정',
#   '수있음'],
#  ['용약국방', '약국방', '코엔', '아이스', '스카프', '스카프핑크', '핑크', '자외선', '차단', '마스크', '오배송'],
#  ['규화',
#   '스마일',
#   '약국유',
#   '스마일약국',
#   '박동혁',
#   '백광',
#   '백광의약품',
#   '의약품',
#   '거래처',
#   '오배송',
#   '재배',
#   '재배송요청',
#   '배송사',
#   '얘기',
#   '재배송'],
#  ['헬스', '헬스인', '주문취소요청', '취소가능', '즉시취소', '안내완료'],
#  ['샵포인트몰', '접속', '접속가능', '결과', '휴대폰', '휴대폰버전', '버전', '컴퓨터'],
#  ['정혜', '우정', '우정약국', '헬스', '헬스인', '주문취소요청', '취소가능', '즉시취소'],
#  ['새롬',
#   '새롬약국신지섭',
#   '지섭',
#   '오케이',
#   '일회용',
#   '마스크',
#   '마스크소형백색매',
#   '소형',
#   '백색',
#   '오배송',
#   '재출고'],
#  ['헬스', '헬스인', '주문취소요청'],
#  ['조은',
#   '조은약국',
#   '이진',
#   '이진규결제완료',
#   '대웅전',
#   '대웅전주백제',
#   '정아',
#   '클라',
#   '목시',
#   '정아목시',
#   '부란',
#   '부란산칼륨',
#   '칼륨',
#   '출고정지'],
#  ['화성',
#   '화성스마일약국박동혁',
#   '스마일',
#   '박동혁',
#   '백광',
#   '백광의약품배송예정',
#   '의약품',
#   '거래처',
#   '오배송',
#   '재배',
#   '재배송요청'],
#  ['대웅전', '대웅전주백제', '정아', '클라', '목시', '정아목시', '부란', '부란산칼륨', '칼륨'],
#  ['리제정', '제정'],
#  ['돔정',
#   '최저가',
#   '최저가연동',
#   '연동',
#   '약정',
#   '약정금액',
#   '천만',
#   '천만원',
#   '연동혜택',
#   '전종우',
#   '종우',
#   '설정',
#   '언제',
#   '계속',
#   '도달',
#   '월일',
#   '월일자로',
#   '자로',
#   '사전',
#   '사전안내',
#   '패밀리',
#   '패밀리존',
#   '분기',
#   '시기',
#   '코로나',
#   '때문',
#   '최저',
#   '최저가가',
#   '가가',
#   '겠다',
#   '겠다라'],
#  ['결제변경요청', '우혜연님', '결제카드', '신한', '신한카드', '일시', '일시불로', '불로', '위내', '약국통화완료'],
#  ['성민', '약국박종', '열결제완료', '결제카드', '삼성', '신한', '변경요청', '우혜연님'],
#  ['파리', '파리바게트만원건', '바게트', '스타', '스타벅스카페라', '벅스', '카페', '요청하심', '해드림'],
#  ['대웅서울', '결제변경요청'],
#  ['돔정',
#   '최저가',
#   '최저가연동',
#   '연동',
#   '약정',
#   '약정금액',
#   '천만',
#   '천만원',
#   '연동혜택',
#   '전종우',
#   '종우',
#   '설정',
#   '언제',
#   '계속'],
#  ['퍼펙트',
#   '손소독제에탄올',
#   '소독제',
#   '에탄올',
#   '크린',
#   '크린투크린',
#   '핸드',
#   '타이',
#   '겔손소독',
#   '소독',
#   '제일',
#   '제일헬스케어',
#   '헬스',
#   '케어',
#   '반품쿠폰',
#   '회수택배비',
#   '택배비',
#   '안내차',
#   '품건당',
#   '재신',
#   '재신청해드림',
#   '청해'],
#  ['거래원장', '원장', '연동', '동기화', '확인가능안내'],
#  ['씨콜드', '콜드', '처리문의', '사용하심', '역대급이벤트', '해당월', '만원이상'],
#  ['통화번호',
#   '전화드림',
#   '렛잇비정',
#   '비정',
#   '정정개',
#   '정개',
#   '렛잇비',
#   '해외',
#   '선주문',
#   '예약',
#   '예약손님',
#   '손님',
#   '시사이',
#   '사이',
#   '권익',
#   '권익환',
#   '메일확인',
#   '예상',
#   '예상시간',
#   '시경',
#   '토요일',
#   '해당지역',
#   '연착',
#   '발생',
#   '지역내',
#   '코스',
#   '코스변경',
#   '배송건',
#   '시간내',
#   '배송팀',
#   '최대한',
#   '감사',
#   '위내',
#   '통화안내'],
#  ['상호명', '제민', '제민약국', '연락드림사업자'],
#  ['주문번호', '샵플러스', '플러스', '아디다스', '남성', '트렁크', '택일', '재고부족'],
#  ['생명', '생명사랑약국', '사랑', '임순하', '대전', '주문취소요청', '사유오주문취소'],
#  ['회복', '회복약국', '김자영약가인', '영약', '가인', '하보', '하보상', '오늘자로', '자로'],
#  ['프로', '전용관안내'],
#  ['시리즈', '구매문의등록완료', '대웅전', '구매가능', '구매가능하다'],
#  ['돔정', '최저가', '최저가연동', '연동', '약정', '약정금액', '천만', '천만원', '연동혜택'],
#  ['사은품', '신청방법'],
#  ['생명', '생명사랑약국', '사랑', '임순하', '삭제요청'],
#  ['패밀리', '패밀리존', '낱알', '낱알반품포인트', '어디', '도매부외품', '부외품', '낱알반품신청', '소멸기한'],
#  ['시리즈', '구매문의'],
#  ['통화번호',
#   '전화드림',
#   '렛잇비정',
#   '비정',
#   '정정개',
#   '정개',
#   '렛잇비',
#   '해외',
#   '선주문',
#   '예약',
#   '예약손님',
#   '손님',
#   '시사이',
#   '사이'],
#  ['범어', '기약', '기약국장세윤거점', '국장', '세윤', '올등록'],
#  ['태전', '태전약품', '반품처리건', '어디', '사용하심', '아신'],
#  ['통화번호'],
#  ['생명', '생명사랑약국', '사랑', '임순하', '대전', '주문취소요청', '사유오주문'],
#  ['담양종로약국', '종로', '박찬', '박찬식결제완료', '태전', '태전약품', '덤뷰티매', '뷰티', '시출고'],
#  ['담양종로약국', '종로', '박찬', '박찬식결제완료', '태전', '태전약품', '덤뷰티매', '뷰티'],
#  ['코큐터', '연질', '연질캡슐', '캡슐', '합산', '시스템상', '자재', '리뉴얼', '월월건', '월건', '사은품'],
#  ['담양종로약국', '종로', '박찬', '박찬식결제완료', '태전', '태전약품', '덤뷰티매', '뷰티', '후연락'],
#  ['결제건', '고함', '해당주문건', '한번', '정확', '카드사', '듯하다'],
#  ['지난달',
#   '계심',
#   '계심대',
#   '채팅',
#   '채팅상담',
#   '상담',
#   '문의주심패밀리존',
#   '주심',
#   '패밀리',
#   '역대급혜택',
#   '지윤님통화',
#   '지가',
#   '언제냐',
#   '연락안주',
#   '안주',
#   '하냐',
#   '불만',
#   '재인',
#   '재인입',
#   '비용',
#   '비용마감일',
#   '마감일',
#   '반영',
#   '반영안됨',
#   '미수긍',
#   '수긍',
#   '요청협의중',
#   '협의',
#   '가능여부',
#   '협의중',
#   '결과',
#   '결과확인후',
#   '양해안내',
#   '오늘안',
#   '조바심',
#   '할거',
#   '장담'],
#  [],
#  ['치경치과용',
#   '경치',
#   '과용',
#   '탐침치석제거기',
#   '치석',
#   '제거기',
#   '의료',
#   '스케일',
#   '러치석',
#   '제거기개',
#   '반품신청요청',
#   '기억',
#   '반품쿠폰사용',
#   '청해',
#   '청해드림'],
#  ['부외품', '부외품쿠폰사용', '상품중', '부외품상품', '선택', '적용가능'],
#  ['층건강약국', '박태'],
#  ['샵플러스포인트',
#   '플러스',
#   '처방전보관서비스취소',
#   '주문번호',
#   '주문일',
#   '용마',
#   '지스',
#   '처방전보관서비스신규',
#   '신규',
#   '유주',
#   '유주희더샵',
#   '희더',
#   '메일답변',
#   '답변',
#   '카드사',
#   '기준별',
#   '평일',
#   '일이내',
#   '이내',
#   '승인취소',
#   '감사',
#   '위내',
#   '통화안내완료'],
#  ['등록완료', '구매가능', '구매가능하다'],
#  ['반품거부', '고함', '변경요청', '운영', '운영팀'],
#  [],
#  ['운수',
#   '운수트레이드',
#   '트레이드',
#   '선출',
#   '케이',
#   '케이에이',
#   '에이',
#   '황사',
#   '황사마스크',
#   '마스크',
#   '대형',
#   '대형국내산',
#   '국내산',
#   '특가',
#   '운수트레이드남',
#   '선출하',
#   '출하',
#   '위내용안내',
#   '내상담건',
#   '상담',
#   '운송장',
#   '배달',
#   '배달중',
#   '도로',
#   '도로명',
#   '충청남',
#   '충청남도',
#   '천안',
#   '천안시',
#   '동남구',
#   '남구',
#   '쉼길',
#   '삼룡동',
#   '천안',
#   '외필지',
#   '천안삼거리',
#   '필지',
#   '삼거리',
#   '휴게소',
#   '휴게소약국',
#   '충남',
#   '배당',
#   '배당중',
#   '삼룡동',
#   '대리점',
#   '배달지역',
#   '부성',
#   '부성대리점',
#   '배송사전달',
#   '전달입력당시',
#   '당시',
#   '충남천안행운대리점',
#   '행운',
#   '배송기사',
#   '위내용',
#   '통화전달완료'],
#  ['대웅제약오산', '임팩', '프리미엄', '정개', '취소요청임팩', '케어', '등록요청', '시간소요', '양해드림'],
#  ['마이너스잔고개념문의', '개념'],
#  ['부외품', '종수', '종수약품', '저녁', '저녁시마감인업체', '시마', '감인'],
#  ['엔젯오리진',
#   '오리진',
#   '남극',
#   '크릴',
#   '크릴오일국내최대',
#   '오일',
#   '국내',
#   '최대',
#   '인지질',
#   '인지질함량남극',
#   '함량',
#   '크릴오일개',
#   '제일',
#   '제일헬스케어',
#   '헬스',
#   '케어',
#   '단순',
#   '단순반품',
#   '청해',
#   '청해드림포장',
#   '요청드림'],
#  ['대웅제품',
#   '입가',
#   '입가대',
#   '반품금액문의',
#   '완제품',
#   '낱알',
#   '임팩',
#   '프리미엄',
#   '정개',
#   '반품처리',
#   '잔고반영금액',
#   '반영',
#   '임인숙',
#   '인숙',
#   '메일답변',
#   '답변',
#   '단가',
#   '단가조정처리',
#   '조정',
#   '원장',
#   '거래원장',
#   '반영내용',
#   '통화안내완료'],
#  ['가입관련', '배정문의'],
#  ['역대급이벤트',
#   '레주르',
#   '선택',
#   '이주',
#   '님통화참고',
#   '참고',
#   '선택하라',
#   '하라',
#   '거보',
#   '거냐며',
#   '냐며',
#   '예외',
#   '예외요청',
#   '중순',
#   '중순안',
#   '발급예정',
#   '월안',
#   '사은품',
#   '유미',
#   '유미선님',
#   '통화건월',
#   '레쥬르',
#   '안됬다',
#   '처리지연',
#   '천점',
#   '대체',
#   '차주',
#   '휴대폰',
#   '복귀',
#   '말씀',
#   '약국장',
#   '국장'],
#  ['프로', '구매문의', '거점상품관', '확인가능'],
#  ['마일리지사용방법문의',
#   '경로',
#   '경로안내',
#   '천원',
#   '어치',
#   '기프티콘',
#   '추천',
#   '추천요청',
#   '베이커리',
#   '커피',
#   '커피쿠폰'],
#  ['약가',
#   '약가인하',
#   '인하',
#   '처리관련',
#   '자동',
#   '자동보상',
#   '보상',
#   '약가인하건',
#   '복산나이스',
#   '나이스',
#   '보상처리'],
#  ['운영', '운영팀번호문', '이정', '이정민', '내선', '내선안내드림'],
#  ['주문번호', '샵플러스', '플러스', '아디다스', '남성', '트렁크', '택일', '재고부족'],
#  ['회원가입오류', '가입어려움', '작성', '작성후', '서류', '서류종', '발송요청'],
#  ['간편', '간편카드등록요청', '일반', '일반신용카드', '신용', '간편결제카드정보'],
#  ['구재', '구재오', '미배송건문의', '지오', '배송완료', '거로', '확인전화드림'],
#  ['반월', '반월당자연사', '당자', '연사', '약국김수원', '수원', '출고정지', '연락주기', '주기'],
#  ['반월', '반월당자연사', '당자', '연사', '약김수원', '수원', '출고정지'],
#  ['천안',
#   '삼거리',
#   '휴게소',
#   '휴게소약국',
#   '양선아결제완료',
#   '선아',
#   '운수',
#   '운수트레이드',
#   '트레이드',
#   '케이',
#   '케이에이',
#   '에이',
#   '황사',
#   '황사마스크',
#   '마스크',
#   '대형',
#   '대형국내산',
#   '국내산',
#   '운송장',
#   '배달',
#   '배달중',
#   '도로',
#   '도로명',
#   '충청남',
#   '충청남도',
#   '천안',
#   '천안시',
#   '동남구',
#   '남구',
#   '쉼길',
#   '삼룡동',
#   '외필지',
#   '천안삼거리',
#   '필지',
#   '충남',
#   '배당',
#   '배당중',
#   '삼룡동',
#   '대리점',
#   '배달지역',
#   '부성',
#   '부성대리점',
#   '배송사전달',
#   '전달입력당시',
#   '당시',
#   '충남천안행운대리점',
#   '행운',
#   '위내용',
#   '택배사',
#   '운수트레이드남',
#   '배송기사담당대리점',
#   '담당',
#   '천안삼거리휴게소',
#   '까닭',
#   '까닭확인후',
#   '심도',
#   '명주',
#   '네이버',
#   '명주소사이트',
#   '사이트',
#   '검색시',
#   '구성',
#   '구성동',
#   '삼룡동번지',
#   '번지',
#   '전산',
#   '변경요청',
#   '약국안내후',
#   '정보변경요청'],
#  ['우루', '우루사정우루소', '사정', '데스', '데스옥시콜린산', '옥시', '콜린', '전문', '전문약'],
#  ['반월', '반월당자연사', '당자', '연사', '약국김수원', '수원', '출고정지'],
#  ['천안', '삼거리', '건호', '건호전환', '전환', '성희', '성희님전달완료'],
#  ['반월', '반월당자연사', '당자', '연사', '약국김수원', '수원', '출고정지', '물류', '연락주기', '주기'],
#  ['비전', '비전가취소완료'],
#  ['신명', '신명약국', '이경화', '서울약업', '주문취소요청'],
#  ['렛잇비',
#   '구매문의',
#   '지역담당자',
#   '박주',
#   '박주환님',
#   '소통완료',
#   '대웅제품담당자',
#   '등록요청',
#   '재연',
#   '제품등록완료',
#   '마이페이지',
#   '특별공급관',
#   '준수',
#   '고안',
#   '고안내'],
#  ['공급사별보기', '사별', '보기', '상세보', '세보', '공급사', '선택', '검색방법'],
#  ['레스',
#   '레스큐약국정화',
#   '정화',
#   '사입건',
#   '입건',
#   '개월내',
#   '도매부외품상품',
#   '부외품',
#   '대성',
#   '대성메디케어',
#   '메디',
#   '케어',
#   '반품신청함',
#   '신청함',
#   '변심',
#   '변심반품',
#   '반품쿠폰사용',
#   '컴배트파워',
#   '배트',
#   '파워',
#   '프로페셔널',
#   '파워형',
#   '단계',
#   '바퀴',
#   '단계작',
#   '자기',
#   '유통기한',
#   '임박',
#   '임박제품',
#   '반려',
#   '연락요청',
#   '선종료',
#   '대성메디케어여',
#   '됬으',
#   '옆에',
#   '듯이',
#   '반품처리',
#   '해주지않냐',
#   '주지',
#   '않냐',
#   '문제냐',
#   '불만',
#   '불만제기',
#   '제기',
#   '얘기',
#   '실제',
#   '반품상품',
#   '착불',
#   '왕복',
#   '왕복택배비',
#   '택배비',
#   '지불',
#   '반송',
#   '연락주라심',
#   '주라',
#   '약국전화',
#   '반품어려움',
#   '반송안',
#   '폐기함',
#   '샵내',
#   '쿠폰발급안내드림',
#   '신청시',
#   '무료',
#   '무료반품',
#   '전달드림양해'],
#  ['천안',
#   '삼거리',
#   '휴게소',
#   '휴게소약국',
#   '양선아결제완료',
#   '선아',
#   '운수',
#   '운수트레이드',
#   '트레이드',
#   '케이',
#   '케이에이',
#   '에이',
#   '황사',
#   '황사마스크',
#   '마스크',
#   '대형',
#   '대형국내산',
#   '국내산',
#   '운송장',
#   '배달',
#   '배달중',
#   '도로',
#   '도로명',
#   '충청남',
#   '충청남도',
#   '천안',
#   '천안시',
#   '동남구',
#   '남구',
#   '쉼길',
#   '삼룡동',
#   '외필지',
#   '천안삼거리',
#   '필지',
#   '충남',
#   '배당',
#   '배당중',
#   '삼룡동',
#   '대리점',
#   '배달지역',
#   '부성',
#   '부성대리점',
#   '배송사전달',
#   '전달입력당시',
#   '당시',
#   '충남천안행운대리점',
#   '행운',
#   '위내용',
#   '택배사',
#   '운수트레이드남',
#   '배송기사담당대리점',
#   '담당'],
#  ['정성희님', '성희', '호전환', '전환'],
#  ['마일리지사용방법문의', '경로', '경로안내'],
#  ['다이아', '다이아벡스', '벡스', '주문시', '경기', '경기도', '김포', '김포시'],
#  ['반품승인처리', '전산', '전산처리방법문의', '운영', '운영팀'],
#  ['지난달', '계심', '계심대', '채팅', '채팅상담', '상담', '문의주심패밀리존', '주심', '패밀리', '역대급혜택'],
#  ['미차장', '내선'],
#  ['운수',
#   '운수트레이드',
#   '트레이드',
#   '케이',
#   '케이에이',
#   '에이',
#   '황사',
#   '황사마스크',
#   '마스크',
#   '대형',
#   '대형국내산',
#   '국내산',
#   '운송장',
#   '배달',
#   '배달중',
#   '도로',
#   '도로명',
#   '충청남',
#   '충청남도',
#   '천안',
#   '천안시',
#   '동남구',
#   '남구',
#   '쉼길',
#   '삼룡동',
#   '천안',
#   '외필지',
#   '천안삼거리',
#   '필지',
#   '삼거리',
#   '휴게소',
#   '휴게소약국',
#   '충남',
#   '배당',
#   '배당중',
#   '삼룡동',
#   '대리점',
#   '배달지역',
#   '부성',
#   '부성대리점',
#   '배송사전달',
#   '전달입력당시',
#   '당시',
#   '충남천안행운대리점',
#   '행운',
#   '위내용',
#   '택배사'],
#  ['일회용',
#   '부직포',
#   '마스크',
#   '성인',
#   '중구조',
#   '구조',
#   '백색',
#   '백색상품코드',
#   '규격',
#   '매입',
#   '매입제조사',
#   '제조사',
#   '엠코리아',
#   '코리아',
#   '국산',
#   '중국산',
#   '기획',
#   '기획전'],
#  ['대웅계열사', '계열사', '판매마감문의', '마지막'],
#  ['대웅제약공장',
#   '캡슐',
#   '이브',
#   '이브연질캡슐',
#   '연질',
#   '주문취소요청',
#   '김현규',
#   '김현규남',
#   '전화요청',
#   '어려움안내'],
#  ['디트림메이트산', '트림', '메이트', '입고문', '고문', '아신', '약사신협', '신협', '생산', '생산중단'],
#  ['케어', '제약공장임팩', '정정', '정정정개', '정개', '거래명세서', '명세서', '팩스발송요청', '발송해드리곘다'],
#  ['나무', '트림', '약국신봉기디', '봉기', '메이트', '메이트산', '입고문', '고문', '생산', '생산중단'],
#  ['월부족금액',
#   '만유',
#   '차처',
#   '국장님',
#   '장님',
#   '그전',
#   '엔스트롱',
#   '스트롱',
#   '접수요청하심시',
#   '통화가능',
#   '월매출',
#   '부족금액',
#   '반품신청요청하심',
#   '삼흥',
#   '삼흥약국',
#   '윤종',
#   '사업자번호',
#   '고함',
#   '구매이력'],
#  ['나무', '트림', '약국신봉기디', '봉기', '메이트', '메이트산', '입고문', '고문', '입고', '입고계획', '계획'],
#  ['디트림메이트산', '트림', '메이트', '입고문', '고문'],
#  ['아신', '구조대', '불빛', '불빛귀이개', '귀이개', '불이', '물류', '물류팀', '직접'],
#  ['세종',
#   '세종약국하용우',
#   '하용',
#   '아신',
#   '구조대',
#   '불빛',
#   '불빛귀이개',
#   '귀이개',
#   '불이',
#   '물류',
#   '물류팀',
#   '직접'],
#  ['아신', '구조대', '불빛', '불빛귀이개', '귀이개', '불이'],
#  ['민장용', '장용', '반품신청법'],
#  ['운수',
#   '운수트레이드',
#   '트레이드',
#   '선출',
#   '케이',
#   '케이에이',
#   '에이',
#   '황사',
#   '황사마스크',
#   '마스크',
#   '대형',
#   '대형국내산',
#   '국내산',
#   '특가',
#   '운수트레이드남',
#   '선출하',
#   '출하',
#   '위내용안내',
#   '내상담건',
#   '상담',
#   '하심확인요청'],
#  ['구재', '구재오', '미배송건문의', '지오', '배송완료', '거로', '확인전화'],
#  ['소독',
#   '에탄올',
#   '스프레이',
#   '스프레이손소독제에탄올',
#   '소독제',
#   '개중',
#   '파손',
#   '내용물',
#   '고함',
#   '처리해드림',
#   '회수안'],
#  ['튼튼',
#   '튼튼약국',
#   '정영진',
#   '영진',
#   '소독',
#   '에탄올',
#   '스프레이',
#   '스프레이손소독제에탄올',
#   '소독제',
#   '개중',
#   '파손',
#   '내용물',
#   '고함'],
#  ['더블유',
#   '스토어',
#   '스토어하이약국',
#   '하이',
#   '윤영수일회용',
#   '영수',
#   '일회용',
#   '부직포',
#   '마스크',
#   '성인',
#   '중구조',
#   '구조',
#   '백색',
#   '백색상품코드',
#   '규격',
#   '매입',
#   '매입제조사',
#   '제조사',
#   '엠코리아',
#   '코리아',
#   '국산',
#   '중국산'],
#  ['일회용',
#   '부직포',
#   '마스크',
#   '성인',
#   '중구조',
#   '구조',
#   '백색',
#   '백색상품코드',
#   '규격',
#   '매입',
#   '매입제조사',
#   '제조사',
#   '엠코리아',
#   '코리아',
#   '국산'],
#  ['창생',
#   '창생당약국',
#   '현미',
#   '현미배송건',
#   '사라',
#   '대신',
#   '메일회신',
#   '대신전화',
#   '하기',
#   '하기약국',
#   '배송완료',
#   '물류',
#   '거래명세서직인',
#   '명세서',
#   '직인'],
#  ['미소',
#   '미소약국',
#   '변성',
#   '부산',
#   '해운대',
#   '해운대구',
#   '재송',
#   '재송동',
#   '개봉',
#   '개봉후',
#   '코튼',
#   '스킨',
#   '탈지면',
#   '알콜',
#   '알콜혼합제',
#   '혼합제',
#   '반품처리',
#   '용마',
#   '물류',
#   '물류이동중',
#   '입고시',
#   '고시',
#   '미처리',
#   '처리예정'],
#  ['이지듀', '화장품', '구매문의', '디엔', '디엔씨몰', '개인적', '개인적구매'],
#  ['이지듀', '리페어컨트롤', '페어', '컨트롤', '리차징', '차징', '크림', '병원', '병원몰', '전용제품'],
#  ['이천', '시민', '시민약국', '오배송', '교육', '재배', '재배송'],
#  ['창생', '창생당약국', '현미', '현미배송건'],
#  ['반품건임',
#   '프리미엄',
#   '정개',
#   '단가',
#   '단가처리',
#   '임인숙님',
#   '인숙',
#   '환입단가',
#   '조정',
#   '조정전표',
#   '전표',
#   '금일오후',
#   '원장',
#   '반영',
#   '반영예정',
#   '문자발송',
#   '임팩',
#   '거래원장',
#   '불편'],
#  ['임팩', '민케어', '케어', '특별공급관', '통해'],
#  ['겔손소독제에탄올',
#   '소독제',
#   '에탄올',
#   '제이',
#   '제품하자',
#   '하자',
#   '회수후',
#   '반품처리',
#   '적립지연',
#   '약국전화',
#   '예치금적립'],
#  ['제약오산', '중복', '중복결제'],
#  ['임팩', '민케어', '케어'],
#  ['임팩', '민케어', '케어', '특별공급관', '통해', '구매가능'],
#  ['김치',
#   '김치냉장고',
#   '냉장고',
#   '배송조회',
#   '설치',
#   '설치상품',
#   '평균',
#   '주말',
#   '공휴일',
#   '공휴일제외',
#   '제외'],
#  ['샵플러스', '플러스', '전환', '전환방법'],
#  ['월드',
#   '월드비젼팜뽑아쓰',
#   '비젼',
#   '팜뽑아쓰',
#   '오케이',
#   '일회용',
#   '마스크',
#   '마스크대형백색매',
#   '대형',
#   '백색',
#   '개취소요청'],
#  ['마더스약국',
#   '더스',
#   '최소',
#   '최소영결제완료',
#   '월드',
#   '월드비젼팜뽑아쓰',
#   '비젼',
#   '팜뽑아쓰',
#   '오케이',
#   '일회용',
#   '마스크',
#   '마스크대형백색매',
#   '대형',
#   '백색',
#   '개취소요청'],
#  ['오전시전', '시전', '익일배송', '도착시간', '가도', '시반', '수긍'],
#  ['약국김태우비', '우비', '직판', '직판처', '렛잇비정', '비정', '차용', '약정', '약정제품', '불가하다'],
#  ['호전환완료', '전환'],
#  ['약국김태우비', '우비', '직판', '직판처', '렛잇비정', '비정', '차용'],
#  ['렛잇비등록', '관련문의', '환자', '등록요청하심'],
#  ['다이아', '다이아폴민폴', '민엑스알', '엑스', '신청요청', '함소', '함소영', '님전달완료'],
#  ['상원',
#   '상원메드',
#   '메드',
#   '트랜스포',
#   '트랜스포외과',
#   '외과',
#   '공간',
#   '반품가능',
#   '상원메',
#   '답변',
#   '사진',
#   '반품기한',
#   '원래',
#   '불가지'],
#  ['명광',
#   '약국황',
#   '승희',
#   '승희결제완료',
#   '헬스',
#   '헬스인',
#   '무통사',
#   '통사',
#   '혈기',
#   '혈기스텐',
#   '스텐',
#   '예치금처리'],
#  [],
#  ['나스', '나스약국', '대웅반품신청요청', '코큐터', '에이스', '에이스연질외', '연질'],
#  ['운수', '운수트레이드', '트레이드'],
#  ['수완', '수완건강약국김', '혜련', '혜련대웅', '환불요청사유', '폐업톡으'],
#  ['메디칼', '카드취소건'],
#  ['대성', '부분카드취소'],
#  ['마더스약국',
#   '더스',
#   '최소',
#   '최소영결제완료',
#   '월드',
#   '월드비젼팜뽑아쓰',
#   '비젼',
#   '팜뽑아쓰',
#   '오케이',
#   '일회용',
#   '마스크',
#   '마스크대형백색매',
#   '대형',
#   '백색',
#   '개취소요청'],
#  ['대성',
#   '대성메디케어',
#   '메디',
#   '케어',
#   '적립요청금요일',
#   '금요일',
#   '전달드림',
#   '지윤님통화',
#   '불만',
#   '적립요청',
#   '대성메디여',
#   '지금적립',
#   '통화안내완료'],
#  ['결제하기', '제하기', '대신', '결제해드림결제', '제해', '종수', '종수약품'],
#  ['솔벗약국황진',
#   '황진',
#   '대성',
#   '대성메디케어',
#   '메디',
#   '케어',
#   '적립요청금요일',
#   '금요일',
#   '전달드림',
#   '지윤님통화',
#   '불만',
#   '적립요청',
#   '대성메디여',
#   '지금적립'],
#  ['대성', '대성메디케어', '메디', '케어', '적립요청금요일', '금요일', '전달드림', '지윤님통화', '불만', '적립요청'],
#  ['마더스약국',
#   '더스',
#   '최소',
#   '최소영결제완료',
#   '월드',
#   '월드비젼팜뽑아쓰',
#   '비젼',
#   '팜뽑아쓰',
#   '오케이',
#   '일회용',
#   '마스크',
#   '마스크대형백색매',
#   '대형',
#   '백색',
#   '개취소요청'],
#  ['월드',
#   '월드비젼팜뽑아쓰',
#   '비젼',
#   '팜뽑아쓰',
#   '오케이',
#   '일회용',
#   '마스크',
#   '마스크대형백색매',
#   '대형',
#   '백색',
#   '개취소요청'],
#  ['한올', '한올바이오파마', '파마', '당시', '회수기사님', '방문시', '재방문'],
#  [],
#  ['별내해밀약국', '내해', '정화', '정화영', '문의기사님'],
#  [],
#  ['운수',
#   '운수트레이드케이에이',
#   '트레이드',
#   '케이',
#   '에이',
#   '황사',
#   '황사마스크',
#   '마스크',
#   '대형',
#   '대형국내산',
#   '국내산',
#   '금융',
#   '금융할인',
#   '할인적용',
#   '외품',
#   '할인불가',
#   '세화',
#   '공적',
#   '공적마스크',
#   '원래',
#   '부외품',
#   '부외품업체',
#   '도매업체',
#   '재안내드림'],
#  ['상원',
#   '상원메드',
#   '메드',
#   '트랜스포',
#   '트랜스포외과',
#   '외과',
#   '공간',
#   '반품가능',
#   '상원메',
#   '답변',
#   '사진',
#   '반품기한',
#   '원래',
#   '불가지'],
#  ['김치', '김치냉장고', '냉장고', '배송조회'],
#  ['메디',
#   '피아',
#   '피아노약국황',
#   '동진',
#   '상원',
#   '상원메드',
#   '메드',
#   '트랜스포',
#   '트랜스포외과',
#   '외과',
#   '공간',
#   '반품가능',
#   '사진',
#   '반품기한',
#   '원래',
#   '불가지'],
#  ['배송기사님', '회수기사님', '방문하시기때문', '문하', '시기', '때문'],
#  ['대웅제약원주백제', '원주', '다이아', '다이아벡스정', '벡스', '출고지가', '지가', '때문', '배송시간'],
#  ['전체취소요청', '사유카드오결', '오결'],
#  ['오전시전', '시전'],
#  ['상원', '상원메드', '메드', '트랜스포', '트랜스포외과', '외과', '공간', '반품가능'],
#  ['삼성',
#   '삼성열린내과',
#   '열린',
#   '내과',
#   '한올',
#   '파인',
#   '파인비',
#   '디주',
#   '구매희망',
#   '직거래잔고',
#   '수금',
#   '수금요청점심시간',
#   '점심시간'],
#  ['폴민',
#   '다이아',
#   '엑스',
#   '엑스알서방정',
#   '서방',
#   '사입이',
#   '입이',
#   '반품가능수량',
#   '연락주시',
#   '회수확인서',
#   '확인서',
#   '동봉'],
#  ['패밀리', '패밀리존', '플러스', '플러스포인트몰', '엔터테인먼트'],
#  ['헬스', '헬스인', '무통사', '통사', '혈기', '혈기스텐', '스텐', '예치금처리'],
#  ['결제창',
#   '백색',
#   '이슈',
#   '해결',
#   '방법한국정보',
#   '한국',
#   '윈도',
#   '윈도우',
#   '자동',
#   '자동업데이트',
#   '데이트',
#   '수동',
#   '수동업데이트',
#   '업데이트',
#   '샵공지사항',
#   '사항',
#   '첨부',
#   '첨부파일',
#   '파일',
#   '실행',
#   '부팅',
#   '인증서',
#   '설치',
#   '이드'],
#  ['동산',
#   '동산약국',
#   '김미숙담당자',
#   '미숙',
#   '보고',
#   '하라',
#   '전달하라',
#   '주심',
#   '문의건',
#   '코큐터',
#   '구매가능',
#   '안녕',
#   '김미숙',
#   '전화요청',
#   '메세지',
#   '해당약국',
#   '관련건',
#   '클레임',
#   '클레임주고',
#   '주고',
#   '약국과',
#   '국과'],
#  ['대웅바이오', '폐업반품신청건', '요청하심', '신청완료'],
#  ['동산',
#   '동산약국',
#   '김미숙담당자',
#   '미숙',
#   '보고',
#   '하라',
#   '전달하라',
#   '주심',
#   '문의건',
#   '코큐터',
#   '구매가능',
#   '구매가능문의'],
#  ['운수',
#   '운수트레이드케이에이',
#   '트레이드',
#   '케이',
#   '에이',
#   '황사',
#   '황사마스크',
#   '마스크',
#   '대형',
#   '대형국내산',
#   '국내산',
#   '금융',
#   '금융할인',
#   '할인적용',
#   '외품',
#   '할인불가',
#   '세화',
#   '공적',
#   '공적마스크',
#   '원래',
#   '부외품'],
#  ['샵마일리지', '사용방법문의', '패밀리', '패밀리존', '샵플러스포인트', '플러스', '경로'],
#  ['정약국정재훈',
#   '정재',
#   '제일',
#   '제일헬스케어양자',
#   '헬스',
#   '케어',
#   '양자',
#   '함침',
#   '연예인',
#   '연예인마스크',
#   '마스크',
#   '대형',
#   '대형블랙성인매입',
#   '블랙',
#   '성인',
#   '매입',
#   '흰색',
#   '오배송',
#   '교환요청',
#   '직접',
#   '블랙성인',
#   '회수요청',
#   '회수접수',
#   '고함'],
#  ['코큐',
#   '에이스',
#   '에이스구매문',
#   '품절임',
#   '절임',
#   '월주차',
#   '주차',
#   '구매가능',
#   '구매가능대체품목문',
#   '대체',
#   '대체품목',
#   '코큐터',
#   '구매가능안내',
#   '보고',
#   '하라'],
#  ['제일',
#   '제일헬스케어양자',
#   '헬스',
#   '케어',
#   '양자',
#   '함침',
#   '연예인',
#   '연예인마스크',
#   '마스크',
#   '대형',
#   '대형블랙성인매입',
#   '블랙',
#   '성인',
#   '매입',
#   '흰색',
#   '오배송'],
#  ['마스크', '비용', '비용할인', '비용할인금액'],
#  ['도매몰', '매몰', '미차장'],
#  ['역대급이벤트', '도달', '다음달', '중순', '전용관매출', '도달하심'],
#  ['역대급이벤트', '도달', '다음달', '중순'],
#  ['인천약품배송예정일',
#   '베타',
#   '베타미가서방정',
#   '미가',
#   '서방',
#   '약가',
#   '약가인하품목',
#   '인하',
#   '발송준비중',
#   '준비',
#   '출하',
#   '출하완료',
#   '상태변경요청',
#   '출하완료처리후'],
#  ['환불요청', '통장사본전송잔고', '처리중', '결제분', '제분', '계정', '오결제', '취소처리', '사과', '사과드림'],
#  ['오산거점', '탐색', '도중', '통화종료'],
#  ['가입관련', '배정문의'],
#  ['파워',
#   '제약오산임팩',
#   '이플러스',
#   '이플러스정',
#   '임팩',
#   '구매문의',
#   '특별공급관안내',
#   '않으',
#   '않으심',
#   '결제해드림',
#   '제해',
#   '안녕',
#   '선생님',
#   '확인결과',
#   '결과',
#   '최근',
#   '최근사용',
#   '결제수단',
#   '수단',
#   '불결',
#   '감사'],
#  ['인천약품배송예정일',
#   '베타',
#   '베타미가서방정',
#   '미가',
#   '서방',
#   '약가',
#   '약가인하품목',
#   '인하',
#   '발송준비중',
#   '준비',
#   '출하',
#   '출하완료',
#   '상태변경요청'],
#  ['한미',
#   '한미바이오리버큐',
#   '리버',
#   '포르테',
#   '포르테밀크씨',
#   '밀크',
#   '배송중파손',
#   '파손',
#   '신청상태',
#   '취소처리완료'],
#  ['크롬', '크롬결제', '농협', '주문요청', '가상계좌', '농협중앙회', '중앙회', '엠서클', '서클', '주문완료'],
#  ['사입건',
#   '입건',
#   '유통기한',
#   '임박',
#   '임박제품',
#   '컴배트파워',
#   '배트',
#   '파워',
#   '프로페셔널',
#   '파워형',
#   '단계',
#   '바퀴',
#   '단계작',
#   '대성',
#   '대성메디케어여',
#   '메디',
#   '케어',
#   '됬으',
#   '옆에',
#   '듯이',
#   '반품처리',
#   '해주지않냐',
#   '주지',
#   '않냐',
#   '문제냐',
#   '불만',
#   '불만제기',
#   '제기',
#   '얘기',
#   '실제',
#   '반품상품',
#   '착불',
#   '왕복',
#   '왕복택배비',
#   '택배비',
#   '지불',
#   '반송',
#   '연락주라심',
#   '주라'],
#  ['사입건',
#   '입건',
#   '개월내',
#   '도매부외품상품',
#   '부외품',
#   '대성',
#   '대성메디케어',
#   '메디',
#   '케어',
#   '반품신청함',
#   '신청함',
#   '변심',
#   '변심반품',
#   '반품쿠폰사용',
#   '컴배트파워',
#   '배트',
#   '파워',
#   '프로페셔널',
#   '파워형',
#   '단계',
#   '바퀴',
#   '단계작',
#   '자기',
#   '유통기한',
#   '임박',
#   '임박제품',
#   '반려',
#   '연락요청',
#   '선종료'],
#  ['역대급이벤트',
#   '레주르',
#   '선택',
#   '이주',
#   '님통화참고',
#   '참고',
#   '선택하라',
#   '하라',
#   '거보',
#   '거냐며',
#   '냐며',
#   '예외',
#   '예외요청',
#   '중순',
#   '중순안',
#   '발급예정',
#   '월안',
#   '사은품',
#   '유미',
#   '유미선님',
#   '통화건월',
#   '레쥬르',
#   '안됬다',
#   '처리지연',
#   '천점',
#   '대체',
#   '차주',
#   '휴대폰'],
#  ['임팩', '프리미엄', '담기', '담기요청특별공급관', '해당위치', '위치', '전용관안내'],
#  ['신규', '신규가입', '마지막', '오류문의', '수기', '수기발송'],
#  ['메디',
#   '신약국',
#   '오옥',
#   '오옥주반품',
#   '신신',
#   '신신물파스에스',
#   '물파스',
#   '에스',
#   '약사신협',
#   '신협',
#   '회수요청'],
#  ['신신', '신신물파스에스', '물파스', '에스', '약사신협', '신협', '회수요청'],
#  ['플러스', '플러스포인트', '전환', '언제', '사용가능'],
#  ['도매몰', '매몰', '취소문의', '미차장', '내선', '내선안내'],
#  ['반품건임',
#   '프리미엄',
#   '정개',
#   '단가',
#   '단가처리',
#   '임인숙님',
#   '인숙',
#   '환입단가',
#   '조정',
#   '조정전표',
#   '전표',
#   '금일오후',
#   '원장',
#   '반영',
#   '반영예정'],
#  ['환불요청', '통장사본전송'],
#  ['동인', '동인약국', '임팩타민파워에이플러스등록문의월구매수량개', '권장', '권장소비자', '준수', '필요시', '재문의'],
#  ['명성',
#   '메디',
#   '주식',
#   '주식회사',
#   '회사',
#   '세인트',
#   '세인트솔루션',
#   '솔루션',
#   '장세',
#   '장세현배송상태',
#   '출하',
#   '발송준비중',
#   '준비',
#   '변경요청',
#   '운영',
#   '운영팀'],
#  ['부재중',
#   '부재중전화',
#   '월부족금액',
#   '만유',
#   '차처',
#   '미안내',
#   '월매출',
#   '부족금액',
#   '진선',
#   '진선님통화건',
#   '위내용'],
#  ['약가',
#   '약가인하',
#   '인하',
#   '처리방법',
#   '연락요청',
#   '약가인하일직',
#   '일직',
#   '개월분',
#   '자동',
#   '자동보상',
#   '보상',
#   '개월초과건',
#   '초과',
#   '실물',
#   '실물반품진행',
#   '듯하심안내'],
#  ['직원',
#   '거냐',
#   '불만',
#   '불만제기',
#   '제기',
#   '정상',
#   '정상출하',
#   '출하',
#   '영상',
#   '물건',
#   '택배사',
#   '분실',
#   '분실확인요청',
#   '가량',
#   '얼굴',
#   '재확인',
#   '재확인후',
#   '성희',
#   '성희님통화',
#   '재인',
#   '재인입',
#   '과정',
#   '진위',
#   '진위여부',
#   '파악',
#   '전상담원',
#   '상담원',
#   '하심이사라',
#   '이사',
#   '통화건약국장',
#   '국장',
#   '통화요청하심',
#   '분뒤',
#   '안내건',
#   '처음',
#   '답변',
#   '응대',
#   '응대관련',
#   '양해드림',
#   '물류',
#   '물류측',
#   '공유',
#   '개분',
#   '양해안내약사'],
#  ['약가', '약가인하', '인하', '처리방법', '연락요청'],
#  ['회원가입방법', '샵홈페이지', '홈페이지', '회원가입', '안내드림승인될려', '될려', '반나절', '하루', '하루정도'],
#  ['사용방법', '패밀리', '패밀리존', '통해'],
#  ['세비',
#   '세비카',
#   '불가하다',
#   '안내문구',
#   '문구',
#   '공동',
#   '공동판매품목',
#   '도매상',
#   '사입건',
#   '입건',
#   '롯트',
#   '롯트번호',
#   '반송',
#   '양해낱알',
#   '낱알',
#   '냐며',
#   '구매이력',
#   '정책',
#   '불편',
#   '제조번호유통처',
#   '구분',
#   '구분불가',
#   '원인',
#   '원인파악',
#   '파악',
#   '입실',
#   '처리가능',
#   '답변',
#   '케이스',
#   '입유무',
#   '유무',
#   '안내양성호님',
#   '양성',
#   '확인건',
#   '완제품'],
#  ['대웅제약공장', '캡슐', '이브', '이브연질캡슐', '연질', '주문취소요청', '김현규', '김현규남', '전화요청'],
#  ['멸균', '멸균거즈', '거즈', '금보', '금보메디넷', '메디', '반품신청요청', '냄새', '고함'],
#  ['샵플러스포인트',
#   '플러스',
#   '처방전보관서비스취소',
#   '주문번호',
#   '주문일',
#   '용마',
#   '지스',
#   '처방전보관서비스신규',
#   '신규'],
#  ['소망',
#   '소망약국',
#   '허미경결제완료',
#   '미경',
#   '기획',
#   '지닥터',
#   '닥터',
#   '혈당',
#   '혈당측정지스트립',
#   '스트립',
#   '측정기',
#   '개매',
#   '주문혈당스트립',
#   '정상',
#   '정상배송',
#   '오출고',
#   '약국장',
#   '국장'],
#  ['기획',
#   '지닥터',
#   '닥터',
#   '혈당',
#   '혈당측정지스트립',
#   '스트립',
#   '측정기',
#   '개매',
#   '혈당스트립',
#   '정상',
#   '정상배송',
#   '오출고지닥터',
#   '지닥'],
#  ['역대급이벤트',
#   '레주르',
#   '선택',
#   '이주',
#   '님통화참고',
#   '참고',
#   '선택하라',
#   '하라',
#   '거보',
#   '거냐며',
#   '냐며',
#   '예외',
#   '예외요청',
#   '중순',
#   '중순안',
#   '발급예정',
#   '월안',
#   '사은품',
#   '유미',
#   '유미선님',
#   '통화건월',
#   '레쥬르',
#   '안됬다'],
#  ['직원',
#   '거냐',
#   '불만',
#   '불만제기',
#   '제기',
#   '정상',
#   '정상출하',
#   '출하',
#   '영상',
#   '물건',
#   '택배사',
#   '분실',
#   '분실확인요청',
#   '가량',
#   '얼굴',
#   '재확인',
#   '재확인후',
#   '성희',
#   '성희님통화',
#   '재인',
#   '재인입',
#   '과정',
#   '진위',
#   '진위여부',
#   '파악',
#   '전상담원',
#   '상담원',
#   '하심이사라',
#   '이사',
#   '통화건약국장',
#   '국장',
#   '통화요청하심'],
#  ['대풍',
#   '대풍약국',
#   '이우진',
#   '우진',
#   '직원',
#   '거냐',
#   '불만',
#   '불만제기',
#   '제기',
#   '댜융',
#   '댜융운',
#   '정상',
#   '정상출하',
#   '출하',
#   '영상',
#   '물건',
#   '택배사',
#   '분실',
#   '분실확인요청',
#   '가량',
#   '얼굴',
#   '재확인',
#   '재확인후',
#   '준희',
#   '준희팀장',
#   '팀장',
#   '개분량출고',
#   '분량'],
#  ['직원',
#   '거냐',
#   '불만',
#   '불만제기',
#   '제기',
#   '정상',
#   '정상출하',
#   '출하',
#   '영상',
#   '물건',
#   '택배사',
#   '분실',
#   '분실확인요청',
#   '가량',
#   '얼굴',
#   '재확인',
#   '재확인후',
#   '성희',
#   '성희님통화',
#   '재인',
#   '재인입',
#   '과정',
#   '진위',
#   '진위여부',
#   '파악',
#   '전상담원',
#   '상담원'],
#  ['하늘', '약국장진', '국장', '미비어현', '비어', '탁용', '탁용분말', '분말'],
#  ['이브', '추가주문시', '반영', '반영가능', '할인스케일', '스케일', '개로', '재주', '재주문'],
#  ['안산', '상록', '상록구', '임팩', '프리미엄', '판매가'],
#  ['한올', '한올반품시', '반품접수장', '상단', '상단부착요청드림', '부착'],
#  ['겔손소독제에탄올', '소독제', '에탄올', '제이', '제품하자', '하자', '회수후', '반품처리', '적립지연'],
#  ['판교',
#   '판교한솔',
#   '한솔',
#   '대웅제약공장',
#   '캡슐',
#   '이브',
#   '이브연질캡슐',
#   '연질',
#   '주문취소요청',
#   '김현규',
#   '김현규남'],
#  ['대웅제약공장', '캡슐', '이브', '이브연질캡슐', '연질', '주문취소요청'],
#  ['복산', '나이스', '서울부분카드취소'],
#  ['보건',
#   '보건약국',
#   '권우섬',
#   '복산',
#   '나이스',
#   '가드',
#   '황사',
#   '황사마스크',
#   '마스크',
#   '대형',
#   '부분카드취소',
#   '공급사'],
#  ['복산',
#   '나이스',
#   '가드',
#   '황사',
#   '황사마스크',
#   '마스크',
#   '대형',
#   '카드취소',
#   '공급사가',
#   '사가',
#   '부분취소진행',
#   '전달완료'],
#  ['리제정', '제정', '생산', '병원', '처방', '어디'],
#  ['대웅향남',
#   '덤씬거점',
#   '코큐터',
#   '락피더스아이',
#   '더스',
#   '아이',
#   '용마',
#   '정확',
#   '배송일정',
#   '일정',
#   '파악',
#   '내일받는거냐',
#   '받는거냐'],
#  ['패밀리', '패밀리존', '스타', '스타벅스', '벅스', '카페', '미수신'],
#  ['대웅향남',
#   '덤씬거점',
#   '코큐터',
#   '락피더스아이',
#   '더스',
#   '아이',
#   '배송예정미선님',
#   '미선',
#   '통화건확인후',
#   '이번호',
#   '전화요청'],
#  ['반품건임', '프리미엄', '정개', '단가', '단가처리'],
#  ['환입번호',
#   '대웅바이오',
#   '처리요청',
#   '신고',
#   '신고일',
#   '통화건전체',
#   '자로',
#   '발행완료안내',
#   '안녕',
#   '요청주신',
#   '선발',
#   '반품완료',
#   '오늘자로',
#   '잔고예치금',
#   '감사'],
#  ['으뜸',
#   '으뜸약국전혜숙',
#   '혜숙',
#   '대웅향남',
#   '덤씬거점',
#   '코큐터',
#   '락피더스아이',
#   '더스',
#   '아이',
#   '출고건',
#   '내일이후',
#   '배송확인'],
#  ['조치', '구입가능'],
#  ['코큐터', '품절문의'],
#  ['사업자번호번호', '동일', '상호명', '약국주소', '신규', '신규가입', '사업자등록증', '등록증'],
#  ['주인', '주인터파마', '파마'],
#  ['헬스',
#   '헬스인',
#   '사용여부',
#   '문의수성',
#   '수성',
#   '폴리',
#   '글러브',
#   '글러브진료',
#   '진료',
#   '장갑',
#   '장갑일회용',
#   '일회용',
#   '의료기',
#   '의료기기반품쿠폰',
#   '기반',
#   '잔여',
#   '잔여쿠폰'],
#  ['동방',
#   '동방약국',
#   '윤지',
#   '윤지영',
#   '탑헬스케어',
#   '헬스',
#   '케어',
#   '사혈침',
#   '혈침',
#   '때문',
#   '전체카드취소요청',
#   '출고정지',
#   '사라',
#   '고함'],
#  ['대웅향남', '덤씬거점', '코큐터', '락피더스아이', '더스', '아이'],
#  ['직원',
#   '거냐',
#   '불만',
#   '불만제기',
#   '제기',
#   '정상',
#   '정상출하',
#   '출하',
#   '영상',
#   '물건',
#   '택배사',
#   '분실',
#   '분실확인요청',
#   '가량',
#   '얼굴',
#   '재확인',
#   '재확인후'],
#  ['조치'],
#  ['케이',
#   '케이에이',
#   '에이',
#   '황사',
#   '황사마스크',
#   '마스크',
#   '대형',
#   '대형국내산제품',
#   '국내산',
#   '하얀색',
#   '보기'],
#  ['사랑',
#   '배한',
#   '배한금반품',
#   '에스비',
#   '에스비앤에프',
#   '에프',
#   '반품거부',
#   '문의바이오',
#   '페리',
#   '오랄반품',
#   '오더',
#   '오더마',
#   '아토',
#   '아토덤',
#   '밤대용량오일',
#   '대용량',
#   '오일',
#   '증정',
#   '증정반품쿠폰사용',
#   '반품거부사유',
#   '오늘중',
#   '고함'],
#  ['에스비',
#   '에스비앤에프',
#   '에프',
#   '반품거부',
#   '문의바이오',
#   '페리',
#   '오랄반품',
#   '오더',
#   '오더마',
#   '아토',
#   '아토덤',
#   '밤대용량오일',
#   '대용량',
#   '오일',
#   '증정',
#   '증정반품쿠폰사용'],
#  ['파워', '임팩', '이플러스', '정마이페이지', '특별공급관', '가능하다'],
#  ['반품건임', '프리미엄', '정개', '단가', '단가처리'],
#  ['동방',
#   '동방약국',
#   '윤지',
#   '윤지영',
#   '탑헬스케어',
#   '헬스',
#   '케어',
#   '사혈침',
#   '혈침',
#   '때문',
#   '전체카드취소요청',
#   '출고정지',
#   '요청완료'],
#  ['존슨',
#   '존슨앤존슨',
#   '존슨즈',
#   '베이비',
#   '파우더',
#   '헬스',
#   '헬스인',
#   '주문이력',
#   '뉴스',
#   '반품배상처리',
#   '배상',
#   '저희',
#   '위내용안내'],
#  ['파워',
#   '제약오산임팩',
#   '정조제',
#   '조제',
#   '확인요청출고지에',
#   '지에',
#   '정상',
#   '정상출고',
#   '출고지에',
#   '영상',
#   '이메일',
#   '이메일주소',
#   '분뒤',
#   '재연',
#   '재연락주시곘',
#   '다심'],
#  ['탑헬스케어', '헬스', '케어', '미배송건문', '의사', '의사혈침', '혈침', '때문', '전체카드취소', '요청하심'],
#  ['라비', '라비수정', '낱알', '사입이', '입이', '오늘중', '회수확인서', '확인서', '동봉', '동봉요청'],
#  ['중앙',
#   '중앙약국',
#   '사입건',
#   '입건',
#   '대웅반품신청요청',
#   '에스',
#   '넥시움정',
#   '에스오메프',
#   '라졸',
#   '마그네슘',
#   '움정',
#   '개넥시',
#   '반품취소요청'],
#  ['동방',
#   '동방약국',
#   '윤지',
#   '윤지영',
#   '탑헬스케어',
#   '헬스',
#   '케어',
#   '건문의사',
#   '의사',
#   '침란셋',
#   '란셋',
#   '물류',
#   '물류센터',
#   '센터',
#   '혈침',
#   '출고가능여부',
#   '직접'],
#  ['국산',
#   '국산메디플러스',
#   '메디',
#   '플러스',
#   '일회용',
#   '일회용마스크',
#   '마스크',
#   '통개',
#   '통개변심반품',
#   '변심',
#   '회수후',
#   '반품예치금',
#   '적립지연문의',
#   '김중',
#   '메일확인',
#   '하기',
#   '하기건',
#   '용마',
#   '저희',
#   '대로',
#   '실물',
#   '위내'],
#  ['임팩', '프리미엄', '거점상품', '안녕', '선생님', '구매가능', '감사'],
#  ['탑헬스케어', '헬스', '케어'],
#  ['처리방법무느이',
#   '법무',
#   '느이',
#   '일이내',
#   '이내',
#   '회수회수일로',
#   '일로',
#   '일이내',
#   '처리완료',
#   '샵연락후',
#   '요청일로',
#   '차주',
#   '금요일'],
#  ['중앙',
#   '중앙약국',
#   '사입건',
#   '입건',
#   '대웅반품신청요청',
#   '에스',
#   '넥시움정',
#   '에스오메프',
#   '라졸',
#   '마그네슘',
#   '움정',
#   '개넥시',
#   '청해',
#   '청해드림'],
#  ['화명',
#   '화명메디칼약국',
#   '메디칼',
#   '박경수',
#   '어캅',
#   '일회용',
#   '마스크',
#   '마스크백색매',
#   '백색',
#   '반품불가',
#   '건강약국',
#   '윤영',
#   '큐첵',
#   '액티브',
#   '혈당',
#   '스트립',
#   '측정지',
#   '글루',
#   '글루코트랜드',
#   '코트',
#   '랜드',
#   '겸용',
#   '양평포',
#   '평포',
#   '나무',
#   '나무약국',
#   '허진서',
#   '진서',
#   '보령',
#   '그린',
#   '그린세이프액체',
#   '세이프',
#   '액체',
#   '전자',
#   '전자모기향',
#   '모기향',
#   '훈증기세트',
#   '증기',
#   '세트',
#   '접수건',
#   '수건',
#   '완료처리',
#   '종로',
#   '종로약국',
#   '임창묵',
#   '오랄케어',
#   '케어',
#   '치간칫솔',
#   '칫솔',
#   '자형',
#   '약국장',
#   '국장'],
#  ['김윤지', '윤지', '그린', '그린솔트에프액', '솔트', '에프', '집하', '집하완료', '접수상태'],
#  ['중동',
#   '우리',
#   '우리약국',
#   '봉유니',
#   '유니',
#   '글루코',
#   '글루코카드',
#   '제로',
#   '제로원',
#   '센서',
#   '스트립',
#   '스트립매반품신청',
#   '접수처리'],
#  ['대웅제품',
#   '입가',
#   '입가대',
#   '반품금액문의',
#   '완제품',
#   '낱알',
#   '임팩',
#   '프리미엄',
#   '정개',
#   '반품처리',
#   '잔고반영금액',
#   '반영'],
#  ['반품접수'],
#  ['세영',
#   '세영약국',
#   '왕무상',
#   '무상',
#   '성광',
#   '스노',
#   '스노제트스프레이',
#   '제트',
#   '스프레이',
#   '성광티눈액',
#   '티눈',
#   '회수접수',
#   '유한',
#   '유한약국',
#   '박영희',
#   '하루',
#   '디톡스',
#   '톡스',
#   '화이버',
#   '요구르트',
#   '요구르트맛',
#   '경과',
#   '통화후',
#   '반품거부'],
#  ['덤씬', '매입', '구매문의', '특별공급관안내드림'],
#  ['미차장'],
#  ['푸른', '푸른솔약국', '최주영결제완료', '주영', '대웅공장주문취소', '해드림'],
#  ['우리', '이행', '본정', '처리완료'],
#  ['처리확인요청자로', '자로', '대웅제약바이오', '사용가능'],
#  ['화명',
#   '화명메디칼약국',
#   '메디칼',
#   '박경수',
#   '어캅',
#   '일회용',
#   '마스크',
#   '마스크백색매',
#   '백색',
#   '건강약국',
#   '윤영',
#   '큐첵',
#   '액티브',
#   '혈당',
#   '스트립',
#   '측정지',
#   '글루',
#   '글루코트랜드',
#   '코트',
#   '랜드',
#   '겸용',
#   '평포도나무약국',
#   '포도나무',
#   '허진서',
#   '진서',
#   '보령',
#   '그린',
#   '그린세이프액체',
#   '세이프',
#   '액체',
#   '전자',
#   '전자모기향',
#   '모기향',
#   '훈증기세트',
#   '증기',
#   '세트',
#   '종로',
#   '종로약국',
#   '임창묵',
#   '오랄케어',
#   '케어',
#   '치간칫솔',
#   '칫솔',
#   '자형',
#   '호반품신청건',
#   '통화중',
#   '분후',
#   '재통화'],
#  ['바른',
#   '바른약국',
#   '새론',
#   '소독',
#   '에탄올',
#   '휴대용',
#   '휴대용에탄올',
#   '통화후',
#   '우리',
#   '오영민',
#   '중필터',
#   '필터',
#   '일회용',
#   '마스크',
#   '개별',
#   '개별포장매',
#   '반품불가품목',
#   '반품불가'],
#  ['전관식',
#   '관식',
#   '건전지',
#   '불량',
#   '회사',
#   '회사것',
#   '문제',
#   '노바',
#   '노바첵',
#   '비접촉',
#   '체온계',
#   '체온계듀얼타입',
#   '듀얼',
#   '타입',
#   '약국직접',
#   '직접',
#   '전화요청',
#   '고함'],
#  ['건전지',
#   '불량',
#   '회사',
#   '회사것',
#   '문제',
#   '노바',
#   '노바첵',
#   '비접촉',
#   '체온계',
#   '체온계듀얼타입',
#   '듀얼',
#   '타입',
#   '약국직접',
#   '직접',
#   '전화요청'],
#  ['현대', '현대약국', '병철', '로드', '로드정', '예치금적립', '처리완료'],
#  ['수동',
#   '수동약국',
#   '금주',
#   '금주결제완료',
#   '복산',
#   '나이스',
#   '경남',
#   '경남해당',
#   '차주',
#   '차주출고요청',
#   '월요일출고요청'],
#  ['복산', '나이스', '경남', '경남해당', '차주', '차주출고요청'],
#  ['역대급',
#   '안왔따심월초',
#   '왔따',
#   '월초',
#   '발송확인',
#   '정성희',
#   '성희',
#   '지난번',
#   '치킨',
#   '치킨이랑',
#   '이랑',
#   '레주르',
#   '피자',
#   '피자마루안내',
#   '마루',
#   '취합',
#   '취합리스트',
#   '리스트',
#   '확인됬으',
#   '부외품',
#   '나머지',
#   '재발송요청',
#   '일산',
#   '일산백마점',
#   '백마',
#   '사용완료',
#   '피자마루'],
#  ['우리', '이행', '본정', '분후', '재통화'],
#  ['프라졸캡슐',
#   '라졸',
#   '캡슐',
#   '한올',
#   '한올바이오파마',
#   '파마',
#   '보험',
#   '보험코드',
#   '반품신청관련',
#   '문의사입이',
#   '의사',
#   '입이',
#   '반품처리',
#   '심확인후',
#   '한올강태석차장',
#   '태석',
#   '입근거',
#   '근거',
#   '생산',
#   '위내용'],
#  ['진주', '진주약국', '박경난', '경난', '익스프레스', '바디', '바디로션', '로션'],
#  ['파워', '제약오산임팩', '정조제', '조제'],
# ...
#   '코큐터',
#   '연질',
#   '연질캡슐',
#   '캡슐',
#   '신제품',
#   '자재',
#   '자재마스터',
#   '마스터',
#   '오더',
#   '생성',
#   '실물',
#   '실물재고',
#   '주문취소',
#   '방안',
#   '출고요청'],
#  ['슬기', '슬기약국', '경희', '대웅담당자', '배정요청', '시간소요', '양해드림'],
#  ['햇빛', '박유나', '유나', '케이디', '케이디상사', '상사', '카드취소', '하심카드취소', '문의주심확인', '주심'],
#  ['장바구니상품', '주문결제요청', '주문완료', '농협', '농협중앙회', '중앙회', '엠서클', '서클'],
#  ['월부족금액',
#   '만유',
#   '만유도처',
#   '도처',
#   '월매출',
#   '부족금액',
#   '주란',
#   '주란님',
#   '통화건얼마',
#   '얼마',
#   '남으심'],
#  ['주문시',
#   '결제창',
#   '백색',
#   '오류화면문',
#   '화면',
#   '수동',
#   '수동업데이트',
#   '업데이트',
#   '가이드',
#   '파일',
#   '다운로드',
#   '부팅',
#   '시도'],
#  ['배송업체', '조회법', '배송안내위치', '위치', '확인법'],
#  ['마트상품권', '휴대폰', '휴대폰번호', '거로', '확인됬다'],
#  ['신동원',
#   '미미청년',
#   '동원',
#   '청년',
#   '마스크',
#   '일회용',
#   '필터',
#   '필터성인',
#   '성인',
#   '개별',
#   '개별포장',
#   '국내산',
#   '중국산'],
#  ['마트상품권', '재발송요청'],
#  ['마트상품권', '재발송요청'],
#  ['마산', '마산역육일', '김의용폐업', '의용', '티제이', '제이', '발행요청', '선발행완료'],
#  ['결제취소요청', '업체소통', '약품남', '취소가능', '약국안내완료'],
#  ['시장', '시장약국최'],
#  ['천사', '천사약국', '정윤', '정윤경결제완료', '결제취소요청', '업체소통', '약품남', '취소가능'],
#  ['월부족금액',
#   '만원유도처',
#   '유도',
#   '안내마일리지',
#   '점마일리지',
#   '무료',
#   '무료반품쿠폰',
#   '장부외',
#   '장부외품할인',
#   '천원',
#   '청해',
#   '청해드림',
#   '만유',
#   '월매출',
#   '부족금액',
#   '미애님통화',
#   '신청건',
#   '파리',
#   '파리바게트',
#   '바게트',
#   '부외품',
#   '변경요청',
#   '이디',
#   '커피',
#   '약국부재',
#   '문자안내',
#   '전날',
#   '요청주신',
#   '파리바게트만원권장',
#   '권장',
#   '부외품쿠폰',
#   '천원장천원',
#   '원장',
#   '예외',
#   '예외처리',
#   '불가능'],
#  ['구매가능'],
#  ['결제취소요청', '업체소통'],
#  ['샵이용', '가이드', '파일', '파일문의', '가이드파일', '양해드림'],
#  ['월부족금액', '만원유도처', '유도', '주유', '천원', '스타', '스타벅스', '벅스'],
#  ['카톡으', '환불요청', '폐업예정', '차주', '금요일', '환급'],
#  ['서울약사신협배송',
#   '신협',
#   '리팔',
#   '정마이크로그램',
#   '마이크로',
#   '마이크로그램',
#   '그램',
#   '수량변경요청',
#   '재주',
#   '재주문'],
#  ['마산', '마산역육일', '김의용', '의용', '대웅바이오', '회수중지요청완료', '중지'],
#  ['우루', '우루사정우루소', '사정', '데스', '데스옥시', '옥시', '콜린', '콜린산', '오배송', '것안내드림'],
#  ['자동',
#   '자동조제기관련',
#   '제기',
#   '부품',
#   '년전',
#   '유관',
#   '유관부서',
#   '부서',
#   '박혜영님',
#   '메일확인',
#   '국장',
#   '자동조제기',
#   '구매건',
#   '카세트',
#   '요청양식',
#   '양식',
#   '내상',
#   '박혜영',
#   '전달드림',
#   '내상담건',
#   '상담',
#   '변경약품관련',
#   '박혜영담당자',
#   '연락요청'],
#  ['패밀리', '패밀리등급', '기준'],
#  ['가입관련', '배정문의'],
#  ['환입번호', '대웅바이오', '처리요청', '신고', '신고일'],
#  ['씨엠랩',
#   '멀티',
#   '멀티체온계',
#   '체온계',
#   '접촉',
#   '접촉비접촉생활온도',
#   '비접촉',
#   '생활',
#   '온도',
#   '년무상',
#   '무상',
#   '수량개',
#   '운수',
#   '운수트레이드업체',
#   '트레이드',
#   '제품작동불량',
#   '작동',
#   '불량',
#   '반품신청요청',
#   '청하',
#   '청하랬다',
#   '청해',
#   '청해드림'],
#  ['사용문의', '패밀리', '패밀리존안내'],
#  ['샵관리자',
#   '관리자',
#   '사이트',
#   '구매건',
#   '뉴영업사원매출',
#   '실적',
#   '거냐며',
#   '냐며',
#   '사번',
#   '사번앞',
#   '숫자'],
#  ['코큐터', '입고문', '고문', '전날', '입고', '월말', '입고예정안내'],
#  ['부틴', '부틴정말레인산', '말레인', '트리', '트리메부틴', '통개', '청란'],
#  ['금사참약국',
#   '사참',
#   '여주',
#   '하나',
#   '우루',
#   '우루사정',
#   '사정',
#   '복합우루사연',
#   '사연',
#   '거래명세서',
#   '명세서',
#   '약국게',
#   '담김확인후',
#   '처리요청'],
#  ['회원가입중',
#   '요양',
#   '요양기관번호',
#   '기관',
#   '발급전',
#   '가입신청문',
#   '임의',
#   '임의숫자자리',
#   '숫자',
#   '자리',
#   '입력후',
#   '주심'],
#  ['개업',
#   '신규',
#   '신규가입안내',
#   '요양',
#   '요양기관번호',
#   '기관',
#   '임의',
#   '임의숫자',
#   '숫자',
#   '자리',
#   '입력후',
#   '뒤변경요청'],
#  ['개업', '신규', '신규가입안내드림'],
#  ['마트상품권', '재발송요청', '바코드', '휴대폰', '신세계', '신세계쪽', '엠서클건', '서클', '한번'],
#  ['말일',
#   '말일자로',
#   '자로',
#   '전문',
#   '전문약과',
#   '약과',
#   '일반',
#   '일반약',
#   '구분',
#   '구분여부',
#   '구분요청',
#   '혼재'],
#  ['헬스', '헬스인', '확인요청운송장', '운송장', '배달', '배달완료', '통화완료'],
#  ['한마음',
#   '한마음약국',
#   '주영남',
#   '코큐터',
#   '영남',
#   '연질',
#   '연질캡슐',
#   '캡슐',
#   '주문시',
#   '재고수량부족',
#   '연락요청해당건',
#   '담당',
#   '담당부서',
#   '부서',
#   '확인중',
#   '시간정도',
#   '최대한',
#   '재연',
#   '품절상태',
#   '연동',
#   '발생'],
#  ['태약국강', '출고정지'],
#  ['낱알',
#   '낱알반품신청포인트',
#   '사용방법문의',
#   '낱알반품',
#   '일이내',
#   '이내',
#   '패밀리',
#   '패밀리존',
#   '신청시',
#   '문제',
#   '공급사',
#   '최소',
#   '협력',
#   '동시',
#   '수도권',
#   '일부',
#   '인천약품',
#   '제외',
#   '전지역',
#   '조건',
#   '신청가능금액',
#   '초과',
#   '비보험오남용',
#   '보험',
#   '남용',
#   '향정',
#   '마약',
#   '액상',
#   '과립',
#   '분말',
#   '시럽',
#   '현탁액',
#   '위내용안내'],
#  ['월부족금액',
#   '만원유도처',
#   '유도',
#   '안내홈페이지',
#   '홈페이지',
#   '직접',
#   '월매출',
#   '부족금액',
#   '판촉물신청',
#   '경로'],
#  ['사랑',
#   '약국황홍주',
#   '대웅대전',
#   '대전',
#   '전체취소요청',
#   '사유재고과다',
#   '과다',
#   '출고정지완료',
#   '취소확정요청',
#   '확정'],
#  ['월부족금액',
#   '만원유도처',
#   '유도',
#   '안내마일리지',
#   '점마일리지',
#   '무료',
#   '무료반품쿠폰',
#   '장부외',
#   '장부외품할인',
#   '천원',
#   '청해',
#   '청해드림',
#   '만유',
#   '월매출',
#   '부족금액',
#   '미애님통화',
#   '신청건',
#   '파리',
#   '파리바게트',
#   '바게트',
#   '부외품',
#   '변경요청',
#   '이디',
#   '커피'],
#  ['월부족금액',
#   '만원유도처',
#   '유도',
#   '미안',
#   '미안내부',
#   '내부',
#   '만유',
#   '월매출',
#   '부족금액',
#   '미애님통화',
#   '위내용안내'],
#  ['냉온',
#   '찜질',
#   '수면',
#   '수면안대',
#   '안대',
#   '구매상품',
#   '판매중',
#   '액체',
#   '반품교환문의',
#   '불량',
#   '통화안내완료'],
#  ['사용방법',
#   '패밀리',
#   '패밀리존',
#   '통해',
#   '생활기',
#   '생활기프트',
#   '프트',
#   '차주',
#   '수요일',
#   '모바일',
#   '발송예정'],
#  ['대웅바이오',
#   '채널매',
#   '베아크라듀오시럽',
#   '아크라',
#   '듀오',
#   '시럽',
#   '병대웅',
#   '바이오베',
#   '정밀',
#   '정밀리그램',
#   '그램',
#   '정대웅바이오',
#   '함박',
#   '오류발생',
#   '발생',
#   '메일확인',
#   '아래',
#   '거래처',
#   '보류',
#   '지하',
#   '구매가능',
#   '구매가능안내드림'],
#  ['소망',
#   '소망약국손인기',
#   '인기',
#   '헬스',
#   '헬스인',
#   '확인요청운송장',
#   '운송장',
#   '배달',
#   '배달완료',
#   '송장',
#   '배송완료',
#   '모주',
#   '모주문건',
#   '자주',
#   '자주문건',
#   '거라심'],
#  ['로사',
#   '로사마이드정',
#   '이드',
#   '문의코로나',
#   '코로나',
#   '백신',
#   '심해',
#   '동물인증',
#   '인증',
#   '인체',
#   '인체인증',
#   '해당제품',
#   '실제',
#   '소요시간',
#   '제품발매여부',
#   '발매',
#   '양해요청드림'],
#  ['글루코', '오알서방정', '서방', '낱알', '반품신청방법', '회수확인서', '확인서', '동봉', '신청완료'],
#  ['약국박애경', '박애', '글루코', '오알서방정', '서방', '낱알', '반품신청방법', '회수확인서', '확인서', '동봉'],
#  ['헬스', '헬스인', '확인요청운송장', '운송장', '배달', '배달완료'],
#  ['세화',
#   '세화약국',
#   '카드등록',
#   '주소오류',
#   '윈도우',
#   '수동',
#   '수동업데이트',
#   '업데이트',
#   '공지사항',
#   '사항',
#   '부팅'],
#  ['글루코', '오알서방정', '서방', '낱알', '반품신청방법'],
#  ['코큐터', '연질', '연질캡슐', '캡슐', '일정', '일정문의', '문자예정안내'],
#  ['행복',
#   '행복약국',
#   '김민숙포인트',
#   '민숙',
#   '기본',
#   '기본배송지',
#   '송지',
#   '변경요청',
#   '경남',
#   '남해',
#   '남해군',
#   '남해읍',
#   '망운'],
#  ['사랑', '약국황홍주', '대웅대전', '대전', '전체취소요청', '사유재고과다', '과다', '출고정지완료'],
#  ['프라자약국', '라자', '영주', '영주월', '말일', '말일자로', '자로'],
#  ['대웅대전', '대전', '전체취소요청', '사유재고과다', '과다'],
#  ['기본', '기본배송지', '송지', '변경요청', '경남', '남해', '남해군', '남해읍', '망운'],
#  ['홍약국',
#   '영선',
#   '영선결제완료',
#   '세화',
#   '세화헬스케어',
#   '헬스',
#   '케어',
#   '청폐탕',
#   '재고부족',
#   '연락주기',
#   '주기',
#   '카드취소',
#   '헬스케어',
#   '전화요청',
#   '물류',
#   '물류팀',
#   '직접'],
#  ['서울메디칼약국', '메디칼', '전체취소요청', '사유재고부족', '결제완료상태'],
#  ['푸른', '푸른약국', '김경선', '경선', '몰코드', '구매예정', '채널매', '약국안내완료'],
#  ['세화',
#   '세화헬스케어',
#   '헬스',
#   '케어',
#   '청폐탕',
#   '재고부족',
#   '연락주기',
#   '주기',
#   '카드취소',
#   '헬스케어',
#   '전화요청'],
#  ['생활기', '생활기프트', '프트', '사용방법문의', '신청경로', '경로'],
#  ['소망',
#   '소망약국',
#   '허미경',
#   '미경',
#   '제이',
#   '일회용',
#   '부직포',
#   '마스크',
#   '마스크백색개',
#   '백색',
#   '반품처리',
#   '해당제품',
#   '자로',
#   '클레임',
#   '클레임제기',
#   '제기',
#   '문제'],
#  ['제이',
#   '일회용',
#   '부직포',
#   '마스크',
#   '마스크백색개',
#   '백색',
#   '반품처리',
#   '업체전달',
#   '예치금처리',
#   '요청드리고',
#   '드리고',
#   '문제',
#   '전달드림'],
#  ['소망',
#   '소망약국',
#   '허미경',
#   '미경',
#   '제이',
#   '일회용',
#   '부직포',
#   '마스크',
#   '마스크백색개',
#   '백색',
#   '반품처리',
#   '해당제품'],
#  ['우리',
#   '우리서울약국',
#   '일회용',
#   '부직포',
#   '마스크',
#   '마스크대형백색',
#   '대형',
#   '백색',
#   '대성',
#   '대성메디케어',
#   '메디',
#   '케어',
#   '제품불량',
#   '불량',
#   '반품회수지연',
#   '재회',
#   '재회수요',
#   '수요'],
#  ['샵마일리지',
#   '사용요청',
#   '롯데',
#   '롯데마트',
#   '천원권잔액관리',
#   '원권',
#   '잔액',
#   '잔액관리형',
#   '청해',
#   '청해드림안내'],
#  ['제이', '일회용', '부직포', '마스크', '마스크백색개', '백색', '반품처리'],
#  ['사용방법문의', '부외품', '다운', '생활기', '생활기프트', '프트', '아래쪽', '확인안내드림'],
#  ['롯데', '롯데마트', '천원권잔액관리', '원권', '잔액', '다음주', '수금', '모바일', '모바일상품권', '수신예정'],
#  ['사입건',
#   '입건',
#   '반품문의안국',
#   '안국',
#   '골드',
#   '루테인',
#   '골드안심',
#   '안심',
#   '캡슐',
#   '캡슐쇼핑백증정개',
#   '쇼핑백',
#   '증정',
#   '건강식품',
#   '입일로',
#   '일로',
#   '반품어려움'],
#  ['마트상품권', '샵플러스', '플러스', '전환'],
#  ['코큐텐를',
#   '텐를',
#   '오신청함',
#   '신청함',
#   '도매상',
#   '대웅환입실',
#   '입실',
#   '반송',
#   '어디',
#   '구매했엇',
#   '했엇',
#   '한신',
#   '한신약품',
#   '타사',
#   '타사반송건',
#   '월회',
#   '반송처리',
#   '수령',
#   '수령후',
#   '고안',
#   '고안내해드림',
#   '내해'],
#  ['정은', '정은주', '종수', '종수약품월', '이메일', '이메일재발송요청', '종수약품여', '이메일재발송'],
#  ['사용법문의', '패밀리', '패밀리존가', '존가', '고안', '고안내해드림', '내해'],
#  ['사용방법'],
#  ['마트상품권', '재발송요청', '이마트재발송', '원권', '수신확인차'],
#  ['스타',
#   '스타벅스',
#   '벅스',
#   '방금',
#   '신청함',
#   '수령',
#   '다음주',
#   '수금',
#   '수금요일사이',
#   '요일',
#   '사이',
#   '모바일',
#   '수령예정'],
#  ['마트상품권', '재발송요청', '원권'],
#  ['만점', '패밀리', '패밀리존', '고안', '고안내'],
#  ['마트상품권', '재발송요청'],
#  ['약국사정', '사정', '폐업예정', '나중'],
#  ['엠서클',
#   '서클',
#   '제일',
#   '제일헬스케어',
#   '헬스',
#   '케어',
#   '세금계산서임',
#   '영님',
#   '통화건자로',
#   '자로',
#   '만원어치라심',
#   '어치',
#   '해당건',
#   '샵이용금액'],
#  ['푸른', '푸른약국', '김경선', '경선', '몰코드', '구매예정', '채널매'],
#  ['헬스', '헬스인', '처리문의비접촉', '비접촉', '적외선', '적외선체온계', '체온계', '온도계', '예치금적립'],
#  ['코큐텐를',
#   '텐를',
#   '오신청함',
#   '신청함',
#   '도매상',
#   '대웅환입실',
#   '입실',
#   '반송',
#   '어디',
#   '구매했엇',
#   '했엇',
#   '한신',
#   '한신약품'],
#  ['엠서클', '서클', '제일', '제일헬스케어', '헬스', '케어', '세금계산서임'],
#  ['제일',
#   '제일헬스케어',
#   '헬스',
#   '케어',
#   '젯오리진',
#   '오리진',
#   '남극',
#   '크릴',
#   '크릴오일국내최대',
#   '오일',
#   '국내',
#   '최대',
#   '인지질',
#   '인지질함량남극',
#   '함량',
#   '크릴오일개',
#   '미회수',
#   '회수후연락요청',
#   '일이내',
#   '이내',
#   '회수기사님',
#   '미방문시',
#   '재연'],
#  ['헬스',
#   '헬스케어클린산소',
#   '케어',
#   '클린',
#   '산소',
#   '휴대용',
#   '산소캔',
#   '도착교환희망',
#   '재연',
#   '일이내',
#   '이내',
#   '기사님방문',
#   '교환처리'],
#  ['종수', '종수약품월', '이메일', '이메일재발송요청'],
#  ['송옥례결제',
#   '헬스',
#   '헬스케어클린산소',
#   '케어',
#   '클린',
#   '산소',
#   '휴대용',
#   '산소캔',
#   '도착교환희망',
#   '교환신청',
#   '모레',
#   '모레정도',
#   '교환가능'],
#  ['헬스', '헬스케어클린산소', '케어', '클린', '산소', '휴대용', '산소캔', '도착교환희망', '재연'],
#  ['도매부외품', '부외품', '확인가능곳', '안내요청', '반품진행현황', '현황', '반품처리프로세스', '프로세스'],
#  ['라성', '정왕', '라성약국', '김용하이', '하이', '마트상품권', '재발송요청', '바코드'],
#  ['샵플러스포인트', '플러스', '사용방법'],
#  ['마트상품권', '재발송요청', '바코드'],
#  ['임팩', '프리미엄', '정개', '회수지연', '전달완료'],
#  ['반품신청방법문의', '낱알', '통수량', '입력방법', '젠가드캡슐캡슐', '가드', '캡슐', '등등'],
#  ['새물',
#   '새물약국',
#   '김수진',
#   '수진',
#   '씨엠랩',
#   '멀티',
#   '멀티체온계',
#   '체온계',
#   '접촉',
#   '접촉비접촉생활온도',
#   '비접촉',
#   '생활',
#   '온도',
#   '년무상',
#   '무상',
#   '반품쿠폰사용',
#   '회수지연',
#   '택배접수',
#   '요청드림'],
#  ['나비',
#   '나비약국',
#   '임미라',
#   '미라',
#   '제이',
#   '제이스피앤티',
#   '스피앤',
#   '처리요청',
#   '발효',
#   '발효진액',
#   '진액',
#   '선물',
#   '선물세트',
#   '세트'],
#  ['씨엠랩',
#   '멀티',
#   '멀티체온계',
#   '체온계',
#   '접촉',
#   '접촉비접촉생활온도',
#   '비접촉',
#   '생활',
#   '온도',
#   '년무상반품쿠폰',
#   '무상',
#   '회수지연',
#   '전달완료'],
#  ['칠원제일',
#   '제일',
#   '오현석반품',
#   '더존',
#   '개미',
#   '액바퀴',
#   '개미파리',
#   '바퀴',
#   '파리',
#   '개월지속성',
#   '지속성',
#   '저번'],
#  ['샵플러스포인트',
#   '플러스',
#   '사용가능',
#   '천점',
#   '부외품',
#   '부외품할인쿠폰',
#   '반품쿠폰',
#   '등등',
#   '의약품',
#   '주문시',
#   '안내해드림',
#   '내해'],
#  ['제이',
#   '제이스피앤티',
#   '스피앤',
#   '처리요청',
#   '발효',
#   '발효진액',
#   '진액',
#   '선물',
#   '선물세트',
#   '세트',
#   '회수요청',
#   '반품절차',
#   '절차'],
#  ['배정여부', '배정요청'],
#  ['제일',
#   '헬스',
#   '케어',
#   '젯오리진',
#   '오리진',
#   '남극',
#   '크릴',
#   '크릴오일국내최대',
#   '오일',
#   '국내',
#   '최대',
#   '인지질',
#   '인지질함량남극',
#   '함량',
#   '크릴오일캡슐개',
#   '캡슐',
#   '회수품목',
#   '개월지나도',
#   '나도',
#   '반품신청가능',
#   '여부확인요청',
#   '유통기한',
#   '월일자',
#   '반품가능',
#   '불만',
#   '불만표출하심',
#   '출하',
#   '샵측',
#   '임의',
#   '제일헬스케어'],
#  ['건강약국',
#   '덕현반품',
#   '헬스',
#   '헬스퓨어',
#   '퓨어',
#   '중필터',
#   '필터',
#   '일회용',
#   '부직포',
#   '백색',
#   '마스크',
#   '마스크성인',
#   '성인',
#   '반품쿠폰사용',
#   '반품처리',
#   '적립요청',
#   '전화결제완료',
#   '제일',
#   '제일헬스케어',
#   '케어',
#   '엔젯오리진',
#   '오리진',
#   '남극',
#   '크릴',
#   '크릴오일국내최대',
#   '오일',
#   '국내',
#   '최대',
#   '인지질',
#   '인지질함량남극',
#   '함량',
#   '캡슐',
#   '크릴오일',
#   '캡슐개회수',
#   '개월지나도',
#   '나도',
#   '반품신청가능',
#   '반품가능여부확인'],
#  ['월부족금액',
#   '만유',
#   '만유도처미안내',
#   '도처',
#   '월매출',
#   '부족금액',
#   '신진',
#   '신진선님',
#   '부재중',
#   '부재중전화',
#   '부족금액안내'],
#  ['가입관련', '배정문의'],
#  ['마음',
#   '마음편',
#   '울산',
#   '남구',
#   '화합',
#   '다이아',
#   '다이아벡스엑스알',
#   '벡스',
#   '엑스',
#   '서방',
#   '서방정',
#   '거래처',
#   '오배송',
#   '수거요청하심'],
#  ['한마음',
#   '한마음약국',
#   '주영남',
#   '코큐터',
#   '영남',
#   '연질',
#   '연질캡슐',
#   '캡슐',
#   '주문시',
#   '재고수량부족',
#   '연락요청해당건',
#   '담당',
#   '담당부서',
#   '부서',
#   '확인중',
#   '시간정도',
#   '최대한',
#   '재연',
#   '안내함담당자',
#   '함담',
#   '당자',
#   '있음운영팀',
#   '운영',
#   '팀물류팀',
#   '물류',
#   '오늘안',
#   '재안내드림'],
#  ['세화',
#   '세화약품',
#   '금보',
#   '금보메디넷',
#   '메디',
#   '오주문취소완료',
#   '문자발송',
#   '선생님',
#   '문자보',
#   '자보',
#   '모두',
#   '참고',
#   '감사'],
#  ['북약국', '일이지', '이브', '올등록요청'],
#  ['대웅바이오',
#   '채널매',
#   '베아크라듀오시럽',
#   '아크라',
#   '듀오',
#   '시럽',
#   '병대웅',
#   '바이오베',
#   '정밀',
#   '정밀리그램',
#   '그램',
#   '정대웅바이오',
#   '오류발생',
#   '발생'],
#  ['주문완료', '통장입금', '주문결제시', '프로그램', '설치', '팝업', '하나', '무엇', '키보드', '보안'],
#  ['세화', '세화약품', '금보', '금보메디넷', '메디', '오주문취소완료'],
#  ['청구', '청구약국', '이용남'],
#  ['마이페이지',
#   '부외품',
#   '반품신청방법',
#   '성인',
#   '중필터',
#   '필터',
#   '일회용',
#   '마스크',
#   '개별',
#   '개별포장백색',
#   '백색',
#   '게일헬스케어',
#   '헬스',
#   '케어',
#   '반품신청완료'],
#  ['청구', '청구약국', '이용남', '고함'],
#  ['세화', '세화약품', '금보', '금보메디넷', '메디'],
#  ['보험', '보험코드', '확인중', '원인', '해당건', '처방'],
#  ['세화', '세화헬스케어', '헬스', '케어'],
#  ['브리',
#   '브리데이',
#   '데이',
#   '소형',
#   '일회용',
#   '마스크',
#   '개별',
#   '개별포장백색',
#   '백색',
#   '제일',
#   '제일헬스케어',
#   '헬스',
#   '케어',
#   '연락주신',
#   '반품쿠폰',
#   '청해',
#   '청해드림'],
#  ['정약국',
#   '정재',
#   '정재훈',
#   '냉온',
#   '찜질',
#   '수면',
#   '수면안대',
#   '안대',
#   '구매상품',
#   '판매중',
#   '액체',
#   '반품교환문의',
#   '불량'],
#  ['약국김',
#   '르네상스',
#   '미화',
#   '미화약사',
#   '공동',
#   '공동대표',
#   '대표',
#   '로그',
#   '로그인문의사업자',
#   '인문',
#   '의사',
#   '업자',
#   '재가',
#   '재가입후',
#   '입후'],
#  ['유정', '유정약국', '병일', '병일아이디'],
#  ['냉온', '찜질', '수면', '수면안대', '안대', '구매상품', '판매중', '액체', '반품교환문의'],
#  ['제일',
#   '제일헬스케어',
#   '헬스',
#   '케어',
#   '엔젯오리진',
#   '오리진',
#   '남극',
#   '크릴',
#   '크릴오일국내최대',
#   '오일',
#   '국내',
#   '최대',
#   '인지질',
#   '인지질함량남극',
#   '함량',
#   '크릴오일캡슐개',
#   '캡슐',
#   '회수품목',
#   '개월지나도',
#   '나도',
#   '반품신청가능',
#   '여부확인요청'],
#  ['자동',
#   '자동조제기',
#   '제기',
#   '유비',
#   '유비케어',
#   '케어',
#   '사이트',
#   '이거',
#   '식이',
#   '수도',
#   '대표',
#   '대표번호'],
#  ['대웅반품내역', '조회방법문의', '거래원장', '원장', '달력', '체크', '해주심', '주심'],
#  ['마미',
#   '마미송에프크림',
#   '에프',
#   '크림',
#   '구매상품',
#   '상세보기가',
#   '세보',
#   '기가',
#   '대웅생명과학',
#   '생명',
#   '과학',
#   '수급',
#   '수급중인',
#   '중인'],
#  ['샵마일리지사용', '마트상품권', '차주', '수요일', '수요일이후', '휴대폰'],
#  ['모두', '결제취소', '사유카드변경원', '경원', '카드변경', '불가함', '설명', '양해드림'],
#  ['닥터',
#   '프리미엄',
#   '손소독제',
#   '소독제',
#   '종수',
#   '종수약품',
#   '반품관련신청',
#   '제품관련',
#   '곤란',
#   '곤란하다',
#   '짜증',
#   '고함',
#   '공급업체',
#   '불만',
#   '기함',
#   '운영',
#   '운영팀',
#   '전달드림'],
#  ['윤기',
#   '윤기봉남',
#   '조메가',
#   '메가',
#   '스프레이',
#   '유통기한문의',
#   '금년',
#   '금년월',
#   '가용',
#   '지윤님지금',
#   '주문하려',
#   '하려',
#   '정영호님답변',
#   '영호',
#   '답변'],
#  ['태약국',
#   '정대전',
#   '대전',
#   '동구',
#   '가오',
#   '가오동',
#   '그린',
#   '그린타워',
#   '타워',
#   '캡슐',
#   '캡슐캡슐',
#   '납품',
#   '제함',
#   '삭제요청'],
#  ['크린', '크린크림', '크림'],
#  ['생활기', '생활기프트신청방법', '프트', '샵마일리지', '신청가능', '사용경로', '경로', '샵사이트내', '사이트'],
#  ['복산나이스', '나이스', '티제이', '제이', '출고요청'],
#  ['조메가', '메가', '스프레이', '유통기한문의', '금년', '금년월', '가용', '지윤님지금', '주문하려', '하려'],
#  ['햇빛', '햇빛약국', '정동', '정동훈결제완료', '복산나이스', '나이스', '평택오늘', '출고요청'],
#  ['티제이', '제이', '정동', '정동훈결제완료', '출고요청', '담당자분'],
#  ['난곡',
#   '난곡프라자약국',
#   '라자',
#   '라온',
#   '라온약국',
#   '신규',
#   '신규가입안내',
#   '입시',
#   '계속',
#   '가입신청서',
#   '신청서',
#   '신청서양식',
#   '양식',
#   '팩스발송'],
#  ['다이아',
#   '다이아벡스엑스알',
#   '벡스',
#   '엑스',
#   '서방',
#   '서방정',
#   '처리지연',
#   '자로',
#   '안내드림마이너스잔고',
#   '사용시',
#   '금액변경',
#   '정상',
#   '정상사용',
#   '쿠폰사용방법요청',
#   '펫비즈',
#   '비즈',
#   '장과',
#   '무료',
#   '무료반품쿠폰',
#   '공급사',
#   '주문시',
#   '사용가능',
#   '사용가능안내드림'],
#  ['솔약국',
#   '선영',
#   '일양',
#   '일양약품',
#   '슈가롱',
#   '가롱',
#   '시트',
#   '열냉각',
#   '시트시간',
#   '냉각',
#   '지속',
#   '지속매입',
#   '매입',
#   '얼마',
#   '뒷면',
#   '갈색',
#   '갈색검정',
#   '검정',
#   '곰팡이',
#   '나머지',
#   '불량',
#   '동일',
#   '하자',
#   '하자건',
#   '클레임',
#   '한번',
#   '반품기한',
#   '경과'],
#  ['솔약국',
#   '선영',
#   '일양',
#   '일양약품',
#   '슈가롱',
#   '가롱',
#   '시트',
#   '열냉각',
#   '시트시간',
#   '냉각',
#   '지속',
#   '지속매입',
#   '매입',
#   '얼마',
#   '뒷면',
#   '갈색',
#   '갈색검정',
#   '검정',
#   '곰팡이',
#   '나머지'],
#  ['다이아', '다이아벡스엑스알', '벡스', '엑스', '서방', '서방정', '처리지연'],
#  ['태약국',
#   '정대전',
#   '대전',
#   '동구',
#   '가오',
#   '가오동',
#   '그린',
#   '그린타워',
#   '타워',
#   '캡슐',
#   '캡슐캡슐',
#   '납품',
#   '납품삭제'],
#  ['사등',
#   '발송요청',
#   '통합처',
#   '본사',
#   '본사관리',
#   '예정미선님통화',
#   '미선',
#   '시리즈',
#   '대웅상품',
#   '거점등록확인',
#   '문의함',
#   '발송이후',
#   '미회신',
#   '시간양해',
#   '처리시',
#   '재연락드림',
#   '양해안내',
#   '연락요청하심',
#   '정성희님',
#   '성희',
#   '구매가능'],
#  ['난곡', '난곡프라자약국', '라자', '라온', '라온약국', '신규', '신규가입안내'],
#  ['브리',
#   '브리데이',
#   '데이',
#   '소형',
#   '일회용',
#   '마스크',
#   '개별',
#   '개별포장백색',
#   '백색',
#   '제일',
#   '제일헬스케어',
#   '헬스',
#   '케어',
#   '연락주신'],
#  ['제일',
#   '제일헬스케어',
#   '헬스',
#   '케어',
#   '젯오리진',
#   '오리진',
#   '남극',
#   '크릴',
#   '크릴오일국내최대',
#   '오일',
#   '국내',
#   '최대',
#   '인지질',
#   '인지질함량남극',
#   '함량',
#   '크릴오일개',
#   '미회수',
#   '회수후연락요청'],
#  ['도매부외품',
#   '부외품',
#   '낱알',
#   '낱알반품가능여부',
#   '도매업체',
#   '구매제품',
#   '반품어려움안내현재',
#   '패밀리',
#   '패밀리존마일리지'],
#  ['백색',
#   '백색오류때문',
#   '때문',
#   '설치',
#   '국세청',
#   '어디',
#   '짜증',
#   '불만',
#   '수동',
#   '수동업데이트',
#   '업데이트',
#   '안내후',
#   '파일',
#   '압축',
#   '압축풀기',
#   '풀기',
#   '안내중',
#   '손님'],
#  ['하이',
#   '하이노우',
#   '노우',
#   '티슈',
#   '세트',
#   '개별',
#   '항균',
#   '손소독',
#   '개별포장',
#   '항균반품',
#   '소독',
#   '제일',
#   '제일헬스케어',
#   '헬스',
#   '케어',
#   '반품신청요청',
#   '구글시트접수',
#   '시트',
#   '회수요청드림'],
#  ['지윤님', '호전환', '전환'],
#  ['산도스에스시', '도스', '에스', '탈로', '탈로프람정밀리그램', '프람', '밀리그램', '주문시', '배송가능', '공급사'],
#  ['복산나이스', '나이스', '티제이', '제이', '출고요청'],
#  ['메디칼', '컴배트파워', '배트', '파워', '프로페셔널', '파워형', '단계', '바퀴', '미배송문의', '파업'],
#  ['미래',
#   '미래약국',
#   '박승',
#   '메디칼',
#   '컴배트파워',
#   '배트',
#   '파워',
#   '프로페셔널',
#   '파워형',
#   '단계',
#   '바퀴',
#   '미배송문의',
#   '배송예정일오늘',
#   '안내요청주심',
#   '주심'],
#  ['예성', '관구', '관구한올', '한올', '환불기안상신', '기안', '상신', '기안상신', '프로세스', '공유'],
#  ...]

# %%
len(gensim_corpus)
# Out:
# 29170

# %%
# 토픽 개수, 키워드 개수를 정해주는 변수를 추가.
NUM_TOPICS = 2

NUM_TOPIC_WORDS = 30


def build_doc_term_mat(documents):
    # 문서-단어 행렬 만들어주는 함수.
    print("Building document-term matrix.")
    dictionary = corpora.Dictionary(documents)
    corpus = [dictionary.doc2bow(document) for document in documents]
        
    return corpus, dictionary


def print_topic_words(model):

    # 토픽 모델링 결과를 출력해 주는 함수.
    print("\nPrinting topic words.\n")
    
    for topic_id in range(model.num_topics):
        topic_word_probs = model.show_topic(topic_id, NUM_TOPIC_WORDS)
        print("Topic ID: {}".format(topic_id))
        
        for topic_word, prob in topic_word_probs:
            print("\t{}\t{}".format(topic_word, prob))
            
        print("\n")

def word_cloud(model):
    for topic_id in range(model.num_topics):
        wordcloud = WordCloud(font_path='Font/applegothic.ttf',
                          relative_scaling = 0.2,
                          # stopwords=STOPWORDS,
                          background_color='white',
                          ).generate_from_frequencies(dict(model.show_topic(topic_id,NUM_TOPIC_WORDS)))
        plt.figure(figsize=(16,8))
        plt.imshow(wordcloud)
        plt.axis("off")
        plt.show()
        print("\n\n")
        
        
# document-term matrix를 만들고,
corpus, dictionary = build_doc_term_mat(gensim_corpus)
# LDA를 실행.
model = models.ldamodel.LdaModel(corpus, num_topics=NUM_TOPICS, id2word=dictionary)
# 결과를 출력.
print_topic_words(model)
#워드 클라우드 출력
word_cloud(model)
# Out:
# Building document-term matrix.
#
# Printing topic words.
#
# Topic ID: 0
# 	이브	0.004373439587652683
# 	플러스	0.003809964284300804
# 	고함	0.0034992219880223274
# 	한올	0.0034941737540066242
# 	품절문의	0.0030971255619078875
# 	엑스	0.0030572526156902313
# 	메디	0.002880427986383438
# 	다이아	0.0027917164843529463
# 	벡스	0.0027633209247142076
# 	인천약품	0.0025838296860456467
# 	임팩	0.0024469492491334677
# 	낱알	0.002380230464041233
# 	제이	0.002360482234507799
# 	대웅바이오	0.002024245448410511
# 	양해드림	0.0020154365338385105
# 	주심	0.0019945399835705757
# 	메디칼	0.001993971411138773
# 	부탁	0.0019909574184566736
# 	티제이	0.0019562591332942247
# 	다이아벡스엑스알	0.00191050476860255
# 	불만	0.0018173749558627605
# 	월일	0.0017991981003433466
# 	대전	0.0017910815076902509
# 	일정	0.0017889972077682614
# 	유미	0.0017870126757770777
# 	서방	0.0017127010505646467
# 	고문	0.0017098162788897753
# 	입고문	0.0016796727431938052
# 	특별공급관	0.0016736998222768307
# 	상황	0.0016593211330473423
#
#
# Topic ID: 1
# 	헬스	0.01395476795732975
# 	케어	0.013950238935649395
# 	마스크	0.007690072525292635
# 	소독	0.0062794857658445835
# 	소독제	0.0052969749085605145
# 	제일	0.005267787724733353
# 	상원	0.004996905568987131
# 	메디	0.0047794487327337265
# 	헬스인	0.004619883373379707
# 	고함	0.004539585672318935
# 	출하	0.004153716377913952
# 	상원메드	0.004062442574650049
# 	메드	0.003951275255531073
# 	핸드	0.003929269500076771
# 	에탄올	0.003814792027696967
# 	타이	0.0033914311788976192
# 	천지인	0.0031777156982570887
# 	제이	0.0031751340720802546
# 	개중	0.002877549035474658
# 	프로	0.002832075348123908
# 	손소독제	0.0027079670690000057
# 	코리	0.002663855906575918
# 	나이스	0.00262886262498796
# 	세이	0.002409712877124548
# 	크린	0.002398155862465501
# 	황사	0.0023907418362796307
# 	카드취소	0.0023844249080866575
# 	제일헬스케어	0.0023460465017706156
# 	그린	0.0023224095348268747
# 	수령	0.0022979415953159332

# %%
# pyLDAvis 불러오기
import pyLDAvis
import pyLDAvis.gensim_models as gensimvis

# pyLDAvis를 jupyter notebook에서 실행할 수 있게 활성화.
pyLDAvis.enable_notebook()

# pyLDAvis 실행.
data = gensimvis.prepare(model, corpus, model.id2word)
pyLDAvis.display(data)
# Out:
# C:\Users\manue\anaconda3\lib\site-packages\sklearn\decomposition\_lda.py:28: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   EPS = np.finfo(np.float).eps
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.3.1/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el1708425057485491845111596114"></div>
# <script type="text/javascript">
#
# var ldavis_el1708425057485491845111596114_data = {"mdsDat": {"x": [0.13305807003514852, -0.13305807003514852], "y": [0.0, 0.0], "topics": [1, 2], "cluster": [1, 1], "Freq": [51.13961977929728, 48.86038022070273]}, "tinfo": {"Term": ["\ud5ec\uc2a4", "\ucf00\uc5b4", "\uc18c\ub3c5", "\uc18c\ub3c5\uc81c", "\uc81c\uc77c", "\uc0c1\uc6d0", "\ub9c8\uc2a4\ud06c", "\uc0c1\uc6d0\uba54\ub4dc", "\uba54\ub4dc", "\ud578\ub4dc", "\uc5d0\ud0c4\uc62c", "\ud0c0\uc774", "\uc5d1\uc2a4", "\ud55c\uc62c", "\ud5ec\uc2a4\uc778", "\ud50c\ub7ec\uc2a4", "\uc190\uc18c\ub3c5\uc81c", "\ub2e4\uc774\uc544", "\ubca1\uc2a4", "\ucd9c\ud558", "\uc774\ube0c", "\ub0b1\uc54c", "\ucf54\ub9ac", "\uc81c\uc77c\ud5ec\uc2a4\ucf00\uc5b4", "\uc138\uc774", "\uc138\uc815\uc81c", "\uadf8\ub9b0", "\ud0d1\ud5ec\uc2a4\ucf00\uc5b4", "\uac1c\uc911", "\ub2e4\uc774\uc544\ubca1\uc2a4\uc5d1\uc2a4\uc54c", "\uc18c\ub3c5", "\ud578\ub4dc", "\uba54\ub4dc", "\uc0c1\uc6d0\uba54\ub4dc", "\uc138\uc815\uc81c", "\ubc30\uc815\ubb38\uc758", "\uc18c\ub3c5\uc81c", "\uc190\uc18c\ub3c5\uc81c", "\uc190\uc18c\ub3c5", "\uba74\ud5c8\uc99d", "\uc190\uccad\uacb0\uc81c", "\ud0d1\ud5ec\uc2a4\ucf00\uc5b4", "\uc190\uc18c\ub3c5\uc138\uc815\uc81c", "\uac1c\uc124", "\uc0c1\uc6d0", "\uc0c1\uc6d0\uba54", "\uc5d0\ud0c4\uc62c", "\uac80\uc815", "\uac00\uc785\uad00\ub828", "\uccad\uacb0\uc81c", "\ud4e8\uc5b4", "\uac94\uc190\uc18c\ub3c5", "\ubc18\ub098\uc808", "\ucca8\ubd80", "\uc0bc\ud604", "\uc784\uc2dc", "\uc0b4\uade0", "\uc81c\uc77c\ud5ec\uc2a4\ucf00\uc5b4", "\uc784\uc2dc\ube44\ubc88", "\uc138\uc815", "\uc81c\uc77c", "\ud5ec\uc2a4", "\ud0c0\uc774", "\ucf00\uc5b4", "\ub4f1\ub85d\uc99d", "\uadf8\ub9b0", "\uc720\uc9c4\ube44", "\uc138\uc774", "\ucf54\ub9ac", "\ubc29\uc5ed", "\ud074\ub9b0", "\ud5ec\uc2a4\ucf00\uc5b4", "\uc900\ube44", "\ub9c8\uc2a4\ud06c", "\ud669\uc0ac", "\ud5ec\uc2a4\uc778", "\uac1c\uc911", "\uc5f0\uc9c8", "\ucd9c\ud558", "\ud06c\ub9b0", "\ucc9c\uc9c0\uc778", "\uce74\ub4dc\ucde8\uc18c", "\uba54\ub514", "\ud504\ub85c", "\uace0\ud568", "\ub098\uc774\uc2a4", "\uc81c\uc774", "\uc218\ub839", "\uc5d1\uc2a4", "\ub2e4\uc774\uc544\ubca1\uc2a4\uc5d1\uc2a4\uc54c", "\uc11c\ubc29\uc815", "\uc11c\ubc29", "\uc0f5\ud50c\ub7ec\uc2a4", "\ubc31\uad11", "\uac70\uc810\uc0c1\ud488", "\ud655\uc778\uc11c", "\ud68c\uc218\ud655\uc778\uc11c", "\ub0b1\uc54c\ubc18\ud488", "\uc57d\uac00\uc778\ud558", "\uc0ac\uc785\uc774", "\ub77c\ub2c8\ud2f0\ub518", "\ubc31\uad11\uc758\uc57d\ud488", "\ube44\uc2a4", "\uc785\uc774", "\ud0a4\ub098", "\uc57d\uac00", "\uc2dc\uacbd", "\uc7ac\ubc1c\uc1a1\uc644\ub8cc", "\ud30c\ub9c8", "\uc785\uac00", "\ud55c\uc62c\ubc14\uc774\uc624\ud30c\ub9c8", "\ud328\ubc00\ub9ac\uc874", "\ub300\uc6c5\ub300\uc804", "\uc0bc\uc131\uce74\ub4dc", "\ubcf4\ub958", "\uae30\ud504\ud2f0\ucf58", "\ub0b1\uc54c", "\uc138\ube44", "\uc2e0\ud55c", "\ub2e4\uc774\uc544", "\uace0\ubb38", "\ud0dc\uc804", "\uc785\uace0\ubb38", "\ub300\uc6c5\ubc14\uc774\uc624", "\ubca1\uc2a4", "\ud55c\uc62c", "\uc778\ud558", "\uc0c1\ud669", "\ub300\uc804", "\ud55c\uc2e0", "\uc758\uc57d\ud488", "\ud50c\ub7ec\uc2a4", "\ud558\uae30", "\ud1b5\ud574", "\ud2b9\ubcc4\uacf5\uae09\uad00", "\uc774\ube0c", "\uc720\ubbf8", "\ud30c\uc6cc", "\ubcf4\ub355\uba54\ub514", "\ud06c\ub9bc", "\ub0b4\ud574", "\ud488\uc808\ubb38\uc758", "\ubd80\ud0c1", "\uc784\ud329", "\uc591\ud574\ub4dc\ub9bc", "\uc6d4\uc77c", "\uc778\ucc9c\uc57d\ud488", "\uace0\ud568", "\uba54\ub514\uce7c", "\uba54\ub514", "\ud2f0\uc81c\uc774", "\uc81c\uc774", "\uc77c\uc815", "\uc8fc\uc2ec", "\ubd88\ub9cc"], "Freq": [2283.0, 2292.0, 1006.0, 849.0, 849.0, 802.0, 1361.0, 651.0, 633.0, 629.0, 612.0, 547.0, 468.0, 549.0, 804.0, 621.0, 434.0, 435.0, 431.0, 739.0, 773.0, 367.0, 436.0, 377.0, 391.0, 349.0, 376.0, 328.0, 493.0, 292.0, 1004.8238022603872, 628.7494973948524, 632.2707900120719, 650.0594390272194, 348.9990168575593, 205.36990817167424, 847.6054674807865, 433.32047688821007, 190.1271491734425, 204.83093215069317, 157.79557357136582, 327.19769481246493, 188.85331931512474, 128.0293639973318, 799.5893040599053, 240 ...

# %%
pyLDAvis.save_html(data,'202001-06_kkma_lda.html')
# Out:
# C:\Users\manue\AppData\Roaming\Python\Python38\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# # 월별 문의사항 데이터 KR-wordrank 분석

# %% [markdown]
# 참조 사이트: https://pypi.org/project/krwordrank/

# %%
from krwordrank.word import KRWordRank
# Out:
# /Users/hyunkyungwoo/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
min_count = 5   # 단어의 최소 출현 빈도수 (그래프 생성 시)
max_length = 10 # 단어의 최대 길이
wordrank_extractor = KRWordRank(min_count=min_count, max_length=max_length)
# Out:
# /Users/hyunkyungwoo/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
beta = 0.85    # PageRank의 decaying factor beta
max_iter = 10
texts = tfidf_corpus #1차원인 list가 필요해 tfidf에서 쓰인 corpus를 그대로 사용함.
keywords, rank, graph = wordrank_extractor.extract(texts, beta, max_iter)
# Out:
# /Users/hyunkyungwoo/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
for word, r in sorted(keywords.items(), key=lambda x:x[1], reverse=True)[:30]:
        print('%8s:\t%.4f' % (word, r))
# Out:
#       플러:	2.7769
#      마일리:	2.7054
#       이벤:	2.5283
#       포인:	2.4820
#       담당:	2.2132
#       주문:	1.5727
#       이마:	1.5708
#       바이:	1.5707
#       제이:	1.5478
#       예치:	1.5256
#       국민:	1.4880
#       어려:	1.4270
#       전용:	1.3967
#      스트로:	1.3859
#       프로:	1.3499
#       신용:	1.2902
#       상품:	1.2789
#       나이:	1.2669
#       연락:	1.2028
#       마이:	1.1553
#       된다:	1.1308
#       메디:	1.0780
#       계산:	1.0664
#       종이:	1.0651
#      프리미:	1.0367
#       판촉:	1.0312
#       스위:	1.0000
#       현금:	1.0000
#       카라:	1.0000
#       장바:	1.0000
# /Users/hyunkyungwoo/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
SW
# Out:
# /Users/hyunkyungwoo/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# {'가\n',
#  '가까스로\n',
#  '가령\n',
#  '각\n',
#  '각각\n',
#  '각자\n',
#  '각종\n',
#  '갖고말하자면\n',
#  '같다\n',
#  '같이\n',
#  '개의치않고\n',
#  '거니와\n',
#  '거바\n',
#  '거의\n',
#  '것\n',
#  '것과 같이\n',
#  '것들\n',
#  '게다가\n',
#  '게우다\n',
#  '겨우\n',
#  '견지에서\n',
#  '결과에 이르다\n',
#  '결국\n',
#  '결론을 낼 수 있다\n',
#  '겸사겸사\n',
#  '고려하면\n',
#  '고로\n',
#  '곧\n',
#  '공동으로\n',
#  '과\n',
#  '과연\n',
#  '관계가 있다\n',
#  '관계없이\n',
#  '관련이 있다\n',
#  '관하여\n',
#  '관한\n',
#  '관해서는\n',
#  '구\n',
#  '구체적으로\n',
#  '구토하다\n',
#  '그\n',
#  '그들\n',
#  '그때\n',
#  '그래\n',
#  '그래도\n',
#  '그래서\n',
#  '그러나\n',
#  '그러니\n',
#  '그러니까\n',
#  '그러면\n',
#  '그러므로\n',
#  '그러한즉\n',
#  '그런 까닭에\n',
#  '그런데\n',
#  '그런즉\n',
#  '그럼\n',
#  '그럼에도 불구하고\n',
#  '그렇게 함으로써\n',
#  '그렇지\n',
#  '그렇지 않다면\n',
#  '그렇지 않으면\n',
#  '그렇지만\n',
#  '그렇지않으면\n',
#  '그리고\n',
#  '그리하여\n',
#  '그만이다\n',
#  '그에 따르는\n',
#  '그위에\n',
#  '그저\n',
#  '그중에서\n',
#  '그치지 않다\n',
#  '근거로\n',
#  '근거하여\n',
#  '기대여\n',
#  '기점으로\n',
#  '기준으로\n',
#  '기타\n',
#  '까닭으로\n',
#  '까악\n',
#  '까지\n',
#  '까지 미치다\n',
#  '까지도\n',
#  '꽈당\n',
#  '끙끙\n',
#  '끼익\n',
#  '나\n',
#  '나머지는\n',
#  '남들\n',
#  '남짓\n',
#  '너\n',
#  '너희\n',
#  '너희들\n',
#  '네\n',
#  '넷\n',
#  '년\n',
#  '논하지 않다\n',
#  '놀라다\n',
#  '누가 알겠는가\n',
#  '누구\n',
#  '다른\n',
#  '다른 방면으로\n',
#  '다만\n',
#  '다섯\n',
#  '다소\n',
#  '다수\n',
#  '다시 말하자면\n',
#  '다시말하면\n',
#  '다음\n',
#  '다음에\n',
#  '다음으로\n',
#  '단지\n',
#  '답다\n',
#  '당신\n',
#  '당장\n',
#  '대로 하다\n',
#  '대하면\n',
#  '대하여\n',
#  '대해 말하자면\n',
#  '대해서\n',
#  '댕그\n',
#  '더구나\n',
#  '더군다나\n',
#  '더라도\n',
#  '더불어\n',
#  '더욱더\n',
#  '더욱이는\n',
#  '도달하다\n',
#  '도착하다\n',
#  '동시에\n',
#  '동안\n',
#  '된바에야\n',
#  '된이상\n',
#  '두번째로\n',
#  '둘\n',
#  '둥둥\n',
#  '뒤따라\n',
#  '뒤이어\n',
#  '든간에\n',
#  '들\n',
#  '등\n',
#  '등등\n',
#  '딩동\n',
#  '따라\n',
#  '따라서\n',
#  '따위\n',
#  '따지지 않다\n',
#  '딱\n',
#  '때\n',
#  '때가 되어\n',
#  '때문에\n',
#  '또\n',
#  '또한\n',
#  '뚝뚝\n',
#  '라 해도\n',
#  '령\n',
#  '로\n',
#  '로 인하여\n',
#  '로부터\n',
#  '로써\n',
#  '륙\n',
#  '를\n',
#  '마음대로\n',
#  '마저\n',
#  '마저도\n',
#  '마치\n',
#  '막론하고\n',
#  '만 못하다\n',
#  '만약\n',
#  '만약에\n',
#  '만은 아니다\n',
#  '만이 아니다\n',
#  '만일\n',
#  '만큼\n',
#  '말하자면\n',
#  '말할것도 없고\n',
#  '매\n',
#  '매번\n',
#  '메쓰겁다\n',
#  '몇\n',
#  '모\n',
#  '모두\n',
#  '무렵\n',
#  '무릎쓰고\n',
#  '무슨\n',
#  '무엇\n',
#  '무엇때문에\n',
#  '물론\n',
#  '및\n',
#  '바꾸어말하면\n',
#  '바꾸어말하자면\n',
#  '바꾸어서 말하면\n',
#  '바꾸어서 한다면\n',
#  '바꿔 말하면\n',
#  '바로\n',
#  '바와같이\n',
#  '밖에 안된다\n',
#  '반대로\n',
#  '반대로 말하자면\n',
#  '반드시\n',
#  '버금\n',
#  '보는데서\n',
#  '보다더\n',
#  '보드득\n',
#  '본대로\n',
#  '봐\n',
#  '봐라\n',
#  '부류의 사람들\n',
#  '부터\n',
#  '불구하고\n',
#  '불문하고\n',
#  '붕붕\n',
#  '비걱거리다\n',
#  '비교적\n',
#  '비길수 없다\n',
#  '비로소\n',
#  '비록\n',
#  '비슷하다\n',
#  '비추어 보아\n',
#  '비하면\n',
#  '뿐만 아니라\n',
#  '뿐만아니라\n',
#  '뿐이다\n',
#  '삐걱\n',
#  '삐걱거리다\n',
#  '사\n',
#  '삼\n',
#  '상대적으로 말하자면\n',
#  '생각한대로\n',
#  '설령\n',
#  '설마\n',
#  '설사\n',
#  '셋\n',
#  '소생\n',
#  '소인\n',
#  '솨\n',
#  '쉿\n',
#  '습니까\n',
#  '습니다\n',
#  '시각\n',
#  '시간\n',
#  '시작하여\n',
#  '시초에\n',
#  '시키다\n',
#  '실로\n',
#  '심지어\n',
#  '아\n',
#  '아니\n',
#  '아니나다를가\n',
#  '아니라면\n',
#  '아니면\n',
#  '아니었다면\n',
#  '아래윗\n',
#  '아무거나\n',
#  '아무도\n',
#  '아야\n',
#  '아울러\n',
#  '아이\n',
#  '아이고\n',
#  '아이구\n',
#  '아이야\n',
#  '아이쿠\n',
#  '아하\n',
#  '아홉\n',
#  '안 그러면\n',
#  '않기 위하여\n',
#  '않기 위해서\n',
#  '알 수 있다\n',
#  '알았어\n',
#  '앗\n',
#  '앞에서\n',
#  '앞의것\n',
#  '야\n',
#  '약간\n',
#  '양자\n',
#  '어\n',
#  '어기여차\n',
#  '어느\n',
#  '어느 년도\n',
#  '어느것\n',
#  '어느곳\n',
#  '어느때\n',
#  '어느쪽\n',
#  '어느해\n',
#  '어디\n',
#  '어때\n',
#  '어떠한\n',
#  '어떤\n',
#  '어떤것\n',
#  '어떤것들\n',
#  '어떻게\n',
#  '어떻해\n',
#  '어이\n',
#  '어째서\n',
#  '어쨋든\n',
#  '어쩔수 없다\n',
#  '어찌\n',
#  '어찌됏든\n',
#  '어찌됏어\n',
#  '어찌하든지\n',
#  '어찌하여\n',
#  '언제\n',
#  '언젠가\n',
#  '얼마\n',
#  '얼마 안 되는 것\n',
#  '얼마간\n',
#  '얼마나\n',
#  '얼마든지\n',
#  '얼마만큼\n',
#  '얼마큼\n',
#  '엉엉\n',
#  '에\n',
#  '에 가서\n',
#  '에 달려 있다\n',
#  '에 대해\n',
#  '에 있다\n',
#  '에 한하다\n',
#  '에게\n',
#  '에서\n',
#  '여\n',
#  '여기\n',
#  '여덟\n',
#  '여러분\n',
#  '여보시오\n',
#  '여부\n',
#  '여섯\n',
#  '여전히\n',
#  '여차\n',
#  '연관되다\n',
#  '연이서\n',
#  '영\n',
#  '영차\n',
#  '옆사람\n',
#  '예\n',
#  '예를 들면\n',
#  '예를 들자면\n',
#  '예컨대\n',
#  '예하면\n',
#  '오\n',
#  '오로지\n',
#  '오르다\n',
#  '오자마자\n',
#  '오직\n',
#  '오호\n',
#  '오히려\n',
#  '와\n',
#  '와 같은 사람들\n',
#  '와르르\n',
#  '와아\n',
#  '왜\n',
#  '왜냐하면\n',
#  '외에도\n',
#  '요만큼\n',
#  '요만한 것\n',
#  '요만한걸\n',
#  '요컨대\n',
#  '우르르\n',
#  '우리\n',
#  '우리들\n',
#  '우선\n',
#  '우에 종합한것과같이\n',
#  '운운\n',
#  '월\n',
#  '위에서 서술한바와같이\n',
#  '위하여\n',
#  '위해서\n',
#  '윙윙\n',
#  '육\n',
#  '으로\n',
#  '으로 인하여\n',
#  '으로서\n',
#  '으로써\n',
#  '을\n',
#  '응\n',
#  '응당\n',
#  '의\n',
#  '의거하여\n',
#  '의지하여\n',
#  '의해\n',
#  '의해되다\n',
#  '의해서\n',
#  '이\n',
#  '이 되다\n',
#  '이 때문에\n',
#  '이 밖에\n',
#  '이 외에\n',
#  '이 정도의\n',
#  '이것\n',
#  '이곳\n',
#  '이때\n',
#  '이라면\n',
#  '이래\n',
#  '이러이러하다\n',
#  '이러한\n',
#  '이런\n',
#  '이럴정도로\n',
#  '이렇게 많은 것\n',
#  '이렇게되면\n',
#  '이렇게말하자면\n',
#  '이렇구나\n',
#  '이로 인하여\n',
#  '이르기까지\n',
#  '이리하여\n',
#  '이만큼\n',
#  '이번\n',
#  '이봐\n',
#  '이상\n',
#  '이어서\n',
#  '이었다\n',
#  '이와 같다\n',
#  '이와 같은\n',
#  '이와 반대로\n',
#  '이와같다면\n',
#  '이외에도\n',
#  '이용하여\n',
#  '이유만으로\n',
#  '이젠\n',
#  '이지만\n',
#  '이쪽\n',
#  '이천구\n',
#  '이천육\n',
#  '이천칠\n',
#  '이천팔\n',
#  '인 듯하다\n',
#  '인젠\n',
#  '일\n',
#  '일것이다\n',
#  '일곱\n',
#  '일단\n',
#  '일때\n',
#  '일반적으로\n',
#  '일지라도\n',
#  '임에 틀림없다\n',
#  '입각하여\n',
#  '입장에서\n',
#  '잇따라\n',
#  '있다\n',
#  '자\n',
#  '자기\n',
#  '자기집\n',
#  '자마자\n',
#  '자신\n',
#  '잠깐\n',
#  '잠시\n',
#  '저\n',
#  '저것\n',
#  '저것만큼\n',
#  '저기\n',
#  '저쪽\n',
#  '저희\n',
#  '전부\n',
#  '전자\n',
#  '전후\n',
#  '점에서 보아\n',
#  '정도에 이르다\n',
#  '제\n',
#  '제각기\n',
#  '제외하고\n',
#  '조금\n',
#  '조차\n',
#  '조차도\n',
#  '졸졸\n',
#  '좀\n',
#  '좋아\n',
#  '좍좍\n',
#  '주룩주룩\n',
#  '주저하지 않고\n',
#  '줄은 몰랏다\n',
#  '줄은모른다\n',
#  '중에서\n',
#  '중의하나\n',
#  '즈음하여\n',
#  '즉\n',
#  '즉시\n',
#  '지든지\n',
#  '지만\n',
#  '지말고\n',
#  '진짜로\n',
#  '쪽으로\n',
#  '차라리\n',
#  '참\n',
#  '참나\n',
#  '첫번째로\n',
#  '쳇\n',
#  '총적으로\n',
#  '총적으로 말하면\n',
#  '총적으로 보면\n',
#  '칠\n',
#  '콸콸\n',
#  '쾅쾅\n',
#  '쿵\n',
#  '타다\n',
#  '타인\n',
#  '탕탕\n',
#  '토하다\n',
#  '통하여\n',
#  '툭\n',
#  '퉤\n',
#  '틈타\n',
#  '팍\n',
#  '팔\n',
#  '퍽\n',
#  '펄렁\n',
#  '하\n',
#  '하게될것이다\n',
#  '하게하다\n',
#  '하겠는가\n',
#  '하고 있다\n',
#  '하고있었다\n',
#  '하곤하였다\n',
#  '하구나\n',
#  '하기 때문에\n',
#  '하기 위하여\n',
#  '하기는한데\n',
#  '하기만 하면\n',
#  '하기보다는\n',
#  '하기에\n',
#  '하나\n',
#  '하느니\n',
#  '하는 김에\n',
#  '하는 편이 낫다\n',
#  '하는것도\n',
#  '하는것만 못하다\n',
#  '하는것이 낫다\n',
#  '하는바\n',
#  '하더라도\n',
#  '하도다\n',
#  '하도록시키다\n',
#  '하도록하다\n',
#  '하든지\n',
#  '하려고하다\n',
#  '하마터면\n',
#  '하면 할수록\n',
#  '하면된다\n',
#  '하면서\n',
#  '하물며\n',
#  '하여금\n',
#  '하여야\n',
#  '하자마자\n',
#  '하지 않는다면\n',
#  '하지 않도록\n',
#  '하지마\n',
#  '하지마라\n',
#  '하지만\n',
#  '하하\n',
#  '한 까닭에\n',
#  '한 이유는\n',
#  '한 후\n',
#  '한다면\n',
#  '한다면 몰라도\n',
#  '한데\n',
#  '한마디\n',
#  '한적이있다\n',
#  '한켠으로는\n',
#  '한항목\n',
#  '할 따름이다\n',
#  '할 생각이다\n',
#  '할 줄 안다\n',
#  '할 지경이다\n',
#  '할 힘이 있다\n',
#  '할때\n',
#  '할만하다\n',
#  '할망정\n',
#  '할뿐\n',
#  '할수있다\n',
#  '할수있어\n',
#  '할줄알다\n',
#  '할지라도\n',
#  '할지언정\n',
#  '함께\n',
#  '해도된다\n',
#  '해도좋다\n',
#  '해봐요\n',
#  '해서는 안된다\n',
#  '해야한다\n',
#  '해요\n',
#  '했어요\n',
#  '향하다\n',
#  '향하여\n',
#  '향해서\n',
#  '허\n',
#  '허걱\n',
#  '허허\n',
#  '헉\n',
#  '헉헉\n',
#  '헐떡헐떡\n',
#  '형식으로 쓰여\n',
#  '혹시\n',
#  '혹은\n',
#  '혼자\n',
#  '훨씬\n',
#  '휘익\n',
#  '휴\n',
#  '흐흐\n',
#  '흥\n',
#  '힘입어'}

# %%
stopwords = SW
passwords = {word:score for word, score in sorted(
    keywords.items(), key=lambda x:-x[1])[:300] if not (word in stopwords)}
# Out:
# /Users/hyunkyungwoo/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
krwordrank_cloud = WordCloud(
    font_path = '/Library/Fonts/AppleGothic.ttf',
    width = 800,
    height = 800,
    background_color="white"
)
krwordrank_cloud = krwordrank_cloud.generate_from_frequencies(passwords)
# Out:
# /Users/hyunkyungwoo/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
fig = plt.figure(figsize=(10, 10))
plt.imshow(krwordrank_cloud, interpolation="bilinear")
plt.show()
# Out:
# /Users/hyunkyungwoo/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
fig.savefig('./lalaland_wordcloud.png') #그림 저장
