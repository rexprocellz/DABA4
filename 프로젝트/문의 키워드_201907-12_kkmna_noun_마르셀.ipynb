# %%
import nltk
import numpy as np
import pandas as pd
from konlpy.tag import Okt
from konlpy.tag import Komoran
from konlpy.tag import Hannanum
from konlpy.tag import Kkma
from keras.models import load_model
from tqdm import tqdm
from tqdm import tqdm_notebook
from gensim import corpora
from gensim import models
from time import time
from wordcloud import WordCloud
import seaborn as sns
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'Malgun Gothic'
# %matplotlib inline
import warnings
warnings.filterwarnings(action='ignore') 

# mecab = Mecab()
# okt = Okt()
# komoran=Komoran()
# hannanum=Hannanum()
kkma=Kkma()
# Out:
# C:\Users\manue\anaconda3\lib\site-packages\gensim\similarities\__init__.py:15: UserWarning: The gensim.similarities.levenshtein submodule is disabled, because the optional Levenshtein package <https://pypi.org/project/python-Levenshtein/> is unavailable. Install Levenhstein (e.g. `pip install python-Levenshtein`) to suppress this warning.
#   warnings.warn(msg)

# %% [markdown]
# # 데이터 불러오기

# %%
df = pd.read_excel('Raw Data/(공유) 더샵약국몰_상담내역_2019.07-12.xlsx')
#(공유) 더샵약국몰_상담내역_2019.04-06.xlsx
#(공유) 더샵약국몰_상담내역_2019.07-12.xlsx
#(공유) 더샵약국몰_상담내역_2020.01-06.xlsx
#(공유) 더샵약국몰_상담내역_2020.07-12.xlsx
#(공유) 더샵약국몰_상담내역_2021.01-05.xlsx

# %%
df.head(3)
# Out:
#                   상담일시 통화유형 상담구분  상담유형       상담상세 상담결과  \
# 0  2019-12-31 18:35:03   발신  약국몰  결제관련       주문결제  VOC
# 1  2019-12-31 18:13:55   발신  약국몰  결제관련  결제취소(미사용)  미완결
# 2  2019-12-31 18:12:50   발신  약국몰  결제관련  결제취소(미사용)   완결
#
#                                                 문의사항
# 0  \n해피톡  \nPO1019220534    결제완료(2019-12-31 11:43...
# 1  \n\n김포종로약국 (한의순)     PO1019220534     결제완료(201...
# 2  \n해피톡  \nPO1019220534    결제완료(2019-12-31 11:43...

# %%
df.shape
# Out:
# (30106, 7)

# %% [markdown]
# # 문의사항 중 null 데이터 개수 확인

# %%
df['문의사항'].isnull().sum()
# Out:
# 722

# %% [markdown]
# # 본문 중 null 데이터 제외

# %%
temp_idx = df[df['문의사항'].isnull()].index

# %%
df = df.drop(temp_idx)

# %%
df['문의사항'].isnull().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (29384, 7)

# %% [markdown]
# # 상담 내용 데이터 정제

# %%
import re
# from pykospacing import spacing

def define_stopwords(path):
    
    SW = set()
    # 불용어를 추가하는 방법 1.
    #for i in string.punctuation:
        #SW.add(i)
    SW.update(["요청", "완료", "안내", "확인", "반품", "결제", "약국", "신청", "배송", "취소", "가능", "문의", "주문", "구매"])
    SW.update(['예정', '연락', '처리', '대웅', '제품', '사용', '더샵', '발송', '업체', '변경', '방법', '안내드림', '쿠폰', '이벤트', '등록', '문자'])
    SW.update(['대웅제약', '상품', '적립', '이상', '카드', '금일', '승인', '해당', '전달', '거점', '수정', '담당자', '전화', '통화', '팩스'])
    SW.update(['다함', '진행', '오후', '사업자', '잔고', '할인', '금액', '오늘', '회수', '오산', '약사', '번호', '검색', '판매', '도착', '주소'])
    SW.update(['메일', '관리', '환불', '페이', '기간', '유효', '사유', '기사', '불가', '출고', '약품', '약속', '영업', '세금', '발행', '전체'])
    SW.update(['사원', '방문', '재고', '제조', '이오', '부분', '포장', '주문건', '관련', '박스', '공장', '반품건', '수량', '정지', '배송문', '제약'])
    SW.update(['즉시', '통장', '처방전', '포인트', '전용', '서비스', '보관', '복원', '대웅바이', '사용법', '선구매', '소멸', '적용', '개선', '오후시'])
    SW.update(['포인트몰', '선발행', '마감', '환입실', '등급', '지급', '서울지점', '삭제', '안내함', '구입', '연락처', '마일리지', '마이너스', '연락드림'])
    SW.update(['차장', '드림', '바이오', '이력', '어려움', '판촉물', '코드', '본인', '품절', '혜택', '직거래', '사입', '인천', '가입', '내일', '통화건'])
    SW.update(['예치금', '양해', '지연', '시간', '이후', '부재', '폐업', '오전', '내역', '여부', '연락드리', '교환', '접수', '이마트', '추가', '소비자'])
    SW.update(['특별', '경우', '수신', '공급관', '품목', '월요일', '중단', '상품권', '내용', '배정', '추후', '익일', '서울', '정보', '오류', '택배'])
    SW.update(['기존', '일자', '미배송', '시스템', '새벽', '당첨', '입금', '시분', '계좌', '국민', '통합', '복합', '이동', '오결재', '매핑', '향남'])
    SW.update(['참여', '역대', '성규', '가상', '채널', '스마', '김선', '산서', '이번', '상태', '공지', '어제', '입력', '매출', '전송', '장바구니'])
    SW.update(['소통', '사본', '지문', '소요', '기재', '조회', '다음', '고객', '발급', '도매', '부족', '연결', '오주문', '지역', '정도', '건강'])
    SW.update(['핸드폰', '가격', '종료', '인천약', '이용', '인수', '기한', '오주문', '부천시', '유통', '작업', '동물', '확인차', '알반품', '노출', '종료'])
    SW.update(['공급', '예정일', '건지', '송문', '품건', '현재', '거래', '계산서', '하심', '환입', '페이지', '전용관', '아이디', '지점', '카톡', '만우절'])
    SW.update(['필요', '결제완료', '반품신청', '확인요청', '만원', '취소요청', '영업사원', '있음', '기사님', '배송예정일', '배송예정', '문건', '유효기간', '취소완료','반품신청건', '주신', '백제'])
    SW.update(['수거', '통장사본', '구입문의', '명세표', '민정', '회원', '마트', '이전', '거래명세표', '배송문의', '희망', '누락', '이관', '거부', '회신', '확인후', '재연락', '이지'])
    SW.update(['마이너스잔고', '주시길', '안됨', '마이', '취소요청사유', '하다', '개월', '반품요청', '쿠폰사용', '지금', '개가', '인수', '인수인계', '주시', '온누리', '지금', '구매시', '당일', '세금계산서', '재발', '문의확인후', '바구니', '재발송'])
    #SW.update(["안내", "프로슈머", "요청", "긴급", "문의", "수정", "리스트", "감사", "관련", "부탁", "재문", "재문의", "추가", "제목", "등록", "정보"])
    #SW.update(['입니다', '또는', '추가', '드립니다', '드려요', '드릴게요', '가격', '합니다', '바랍니다', '부탁드립니다', '습니다', '지역', '급급', '월일'])
    #SW.update(['병원', '박일', '모두', '월호', '게시물', '위주', '드림', '의원', '투명', '이야기', '연세', '이비인후과', '에서'])
    #SW.update(['제공', '추천', '원내', '제작', '주력', '견적', '일정', '분석', '제작', '관리', '실장', '선생', '메일', '파일', '방법', '하나', '우리'])
    #SW.update(['구매', '후기', '테일', '구입', '이것저것', '이거', '직구', '추천', '가지', '오바', '성공', '주문', '오늘', '여러분', '하세', '오랜만','기타'])
    # 불용어를 추가하는 방법 2.
    # stopwords-ko.txt에 직접 추가
    
    with open(path, encoding='utf-8') as f:
        for word in f:
            SW.add(word)

    return SW


def list_of_list(docs):
    temp_list = []
    
    for doc in docs:
        temp = doc.split(', ')
        temp_list.append(temp)
        
    return temp_list


def text_cleaning(docs):
    """
        1. 한글만 추출.
        
        2. 자음/모음 표현 처리방법.
        
            1) "ㅇㅇ" ,"ㅋㅋㅋㅋㅋ" 같은 자음만 존재하는 표현이나, "ㅡㅡ", "ㅠㅠ" 같은 모음만 존재하는 표현들은
            의미는 있으나 중요한 의미를 가지고 있지 않다고 판단하여 제거.
            
            2) 이러한 표현들도 전부 emoticon 같은 감정 표현의 의성어로 쓰거나, 단축 표현이므로 제거하지 않음. 
            
        3. http:// 로 시작하는 hyperlink 제거.
        
        4. 특수문자 제거.
        
        5. 이메일 주소 제거.
    
    """
    # Series의 object를 str로 변경.
    #docs = [str(doc) for doc in docs]
    
    # 1
    pattern1 = re.compile('[^ ㄱ-ㅣ가-힣]+')
    docs = [pattern1.sub("", docs)] 
    #print(docs)
    
    # 2
    pattern2 = re.compile("[ㄱ-ㅎ]*[ㅏ-ㅢ]*")
    docs = [pattern2.sub("", doc) for doc in docs]
    #print(docs)
    
    # 3
    #pattern3 = re.compile(r"\b(https?:\/\/)?([\w.]+){1,2}(\.[\w]{2,4}){1,2}(.*)")
    #docs = pattern3.sub("", docs) 
    
    # 4
    pattern4 = re.compile("[\{\}\[\]\/?.,;:|\)*~`!^\-_+<>@\#$%&\\\=\(\'\"]")
    docs = pattern4.sub("", str(docs))
    #print(docs)
    
    # 5
    pattern5 = re.compile('\S*@\S*\s?')
    docs = pattern5.sub("", docs)
    #print(docs)
    
    # 띄어쓰기 다시하기
    # docs = spacing(docs)
    #print(docs)
    
    print('Done!')
        
    return docs


def slicing_time_str(time_str):
    return time_str[0:10]

# %% [markdown]
# # 본문 데이터 정제 후 본문클리닝에 저장

# %%
df['문의사항_클리닝'] = df['문의사항'].apply(text_cleaning)
# Out:
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# ...
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!

# %%
df.head()
# Out:
#         상담일시 통화유형 상담구분  상담유형       상담상세 상담결과  \
# 0 2019-12-31   발신  약국몰  결제관련       주문결제  VOC
# 1 2019-12-31   발신  약국몰  결제관련  결제취소(미사용)  미완결
# 2 2019-12-31   발신  약국몰  결제관련  결제취소(미사용)   완결
# 3 2019-12-31   발신  약국몰  이용문의      더샵플러스   완결
# 4 2019-12-31   발신  약국몰  회원정보       회원가입   완결
#
#                                                 문의사항  \
# 0  \n해피톡  \nPO1019220534    결제완료(2019-12-31 11:43...
# 1  \n\n김포종로약국 (한의순)     PO1019220534     결제완료(201...
# 2  \n해피톡  \nPO1019220534    결제완료(2019-12-31 11:43...
# 3  \n\n미소약국 새로 약국장님 1월 2일부로 오셔서 가입하려고 하는데 액티브 설치가...
# 4  \n\n미소약국 새로 약국장님 1월 2일부로 오셔서 가입하려고 하는데 액티브 설치가...
#
#                                             문의사항_클리닝
# 0  해피톡      결제완료   취소요청건  모르고  다른 주문건을  취소해버림   죄...
# 1        김포종로약국 한의순          결제완료    인천약품    취소문의해야함
# 2  해피톡      결제완료   취소요청건  모르고  다른 주문건을  취소해버림   죄...
# 3  미소약국 새로 약국장님 월 일부로 오셔서 가입하려고 하는데 액티브 설치가 안됨 설치...
# 4  미소약국 새로 약국장님 월 일부로 오셔서 가입하려고 하는데 액티브 설치가 안됨 설치...

# %% [markdown]
# ## 혹시 모를 상황에 대비해서 전처리된 데이터 프레임을 저장

# %%
df.to_csv('Data/2019.07-12_상담내역.csv', index = False, encoding = 'utf-8')

# %%
temp = pd.read_csv('Data/2019.07-12_상담내역.csv', encoding='utf-8')
temp.head()
# Out:
#          상담일시 통화유형 상담구분  상담유형       상담상세 상담결과  \
# 0  2019-12-31   발신  약국몰  결제관련       주문결제  VOC
# 1  2019-12-31   발신  약국몰  결제관련  결제취소(미사용)  미완결
# 2  2019-12-31   발신  약국몰  결제관련  결제취소(미사용)   완결
# 3  2019-12-31   발신  약국몰  이용문의      더샵플러스   완결
# 4  2019-12-31   발신  약국몰  회원정보       회원가입   완결
#
#                                                 문의사항  \
# 0  \n해피톡  \nPO1019220534    결제완료(2019-12-31 11:43...
# 1  \n\n김포종로약국 (한의순)     PO1019220534     결제완료(201...
# 2  \n해피톡  \nPO1019220534    결제완료(2019-12-31 11:43...
# 3  \n\n미소약국 새로 약국장님 1월 2일부로 오셔서 가입하려고 하는데 액티브 설치가...
# 4  \n\n미소약국 새로 약국장님 1월 2일부로 오셔서 가입하려고 하는데 액티브 설치가...
#
#                                             문의사항_클리닝
# 0  해피톡      결제완료   취소요청건  모르고  다른 주문건을  취소해버림   죄...
# 1        김포종로약국 한의순          결제완료    인천약품    취소문의해야함
# 2  해피톡      결제완료   취소요청건  모르고  다른 주문건을  취소해버림   죄...
# 3  미소약국 새로 약국장님 월 일부로 오셔서 가입하려고 하는데 액티브 설치가 안됨 설치...
# 4  미소약국 새로 약국장님 월 일부로 오셔서 가입하려고 하는데 액티브 설치가 안됨 설치...

# %% [markdown]
# # 상담일시 판다스 포멧에 맞게 전환

# %%
df = pd.read_csv('Data/2019.07-12_상담내역.csv', encoding='utf-8')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29260 entries, 0 to 29259
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   상담일시      29260 non-null  object
#  1   통화유형      29260 non-null  object
#  2   상담구분      29260 non-null  object
#  3   상담유형      29260 non-null  object
#  4   상담상세      29260 non-null  object
#  5   상담결과      29260 non-null  object
#  6   문의사항      29260 non-null  object
#  7   문의사항_클리닝  29260 non-null  object
# dtypes: object(8)
# memory usage: 1.8+ MB

# %%
df['상담일시'] = df['상담일시'].apply(slicing_time_str)
df['상담일시'] = pd.to_datetime(df['상담일시'], format='%Y/%m/%d')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29260 entries, 0 to 29259
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   상담일시      29260 non-null  datetime64[ns]
#  1   통화유형      29260 non-null  object
#  2   상담구분      29260 non-null  object
#  3   상담유형      29260 non-null  object
#  4   상담상세      29260 non-null  object
#  5   상담결과      29260 non-null  object
#  6   문의사항      29260 non-null  object
#  7   문의사항_클리닝  29260 non-null  object
# dtypes: datetime64[ns](1), object(7)
# memory usage: 1.8+ MB

# %%
df.head(3)
# Out:
#         상담일시 통화유형 상담구분  상담유형       상담상세 상담결과  \
# 0 2019-12-31   발신  약국몰  결제관련       주문결제  VOC
# 1 2019-12-31   발신  약국몰  결제관련  결제취소(미사용)  미완결
# 2 2019-12-31   발신  약국몰  결제관련  결제취소(미사용)   완결
#
#                                                 문의사항  \
# 0  \n해피톡  \nPO1019220534    결제완료(2019-12-31 11:43...
# 1  \n\n김포종로약국 (한의순)     PO1019220534     결제완료(201...
# 2  \n해피톡  \nPO1019220534    결제완료(2019-12-31 11:43...
#
#                                             문의사항_클리닝
# 0  해피톡      결제완료   취소요청건  모르고  다른 주문건을  취소해버림   죄...
# 1        김포종로약국 한의순          결제완료    인천약품    취소문의해야함
# 2  해피톡      결제완료   취소요청건  모르고  다른 주문건을  취소해버림   죄...

# %% [markdown]
# # 월별 문의사항 데이터 TF-IDF 분석

# %%
df['문의사항_클리닝'].isnull().sum()
# Out:
# 0

# %%
idx = df[df['문의사항_클리닝'].isnull()].index
df = df.drop(idx)

# %%
SW = define_stopwords("stopwords-ko.txt")

# %%
def list_of_list(docs):
    temp_list = []
    
    for doc in docs:
        temp = doc.split(', ')
        temp_list.append(temp)
        
    return temp_list

# %%
def month_context_extract_tfidf(df, month_start, month_end):
    
    # 시간정보 열 datetime 정보로 변환
    df['상담일시'] = pd.to_datetime(df['상담일시'], format='%Y/%m/%d')
    #연도, 월 데이터 dataframe 받음
    year_month_df = df.loc[(df['상담일시'] > month_start) & (df['상담일시'] < month_end)]
    #제목 데이터 프레임 슬라이싱
    corpus = year_month_df['문의사항_클리닝']
    #리스트화
    cleaned_corpus = corpus.tolist() #--> list of str
    
    #okt를 이용한 형태소 분석
    temp_list = []
    for i in tqdm_notebook(cleaned_corpus):
        #temp_list.append(okt.morphs(i)) #temp_list.append(okt.nouns(i)) #명사형 
        #temp_list.append(mecab.morphs(i)) #temp_list.append(mecab.nouns(i))
        #temp_list.append(komoran.morphs(i)) #temp_list.append(komoran.nouns(i))
        #temp_list.append(hannanum.morphs(i)) #temp_list.append(hannanum.nouns(i))
        temp_list.append(kkma.nouns(i)) #temp_list.append(kkma.nouns(i))
    #2차원 리스트를 1차원으로    
    single_de_list = sum(temp_list, [])
    #불용어 제거
    final_list = [word for word in single_de_list if word not in SW and len(word) > 1]
    return final_list

# %%
# vectorizer 내에서 높은 순위로 고려되는 단어들을 불러오는 함수를 생성 
def rank_words(terms, feature_matrix):
    sums = feature_matrix.sum(axis=0) # 문서마다 단어의 tfidf 합산
    data = []
    for col, term in enumerate(terms): 
        data.append( (term, sums[0,col])) # 단어의 tfidf 값 매핑하여 리스트에 추가
    ranked = pd.DataFrame(data, columns=['term','rank']).sort_values('rank',ascending=False) 
    #ranked = pd.DataFrame(data, columns=['term','rank']).sort_values('rank',ascending=False) 
    # tfidf 내림차순으로 정렬하여 데이터프레임 생성  
    return ranked

# %%
df.head(3)
# Out:
#         상담일시 통화유형 상담구분  상담유형       상담상세 상담결과  \
# 0 2019-12-31   발신  약국몰  결제관련       주문결제  VOC
# 1 2019-12-31   발신  약국몰  결제관련  결제취소(미사용)  미완결
# 2 2019-12-31   발신  약국몰  결제관련  결제취소(미사용)   완결
#
#                                                 문의사항  \
# 0  \n해피톡  \nPO1019220534    결제완료(2019-12-31 11:43...
# 1  \n\n김포종로약국 (한의순)     PO1019220534     결제완료(201...
# 2  \n해피톡  \nPO1019220534    결제완료(2019-12-31 11:43...
#
#                                             문의사항_클리닝
# 0  해피톡      결제완료   취소요청건  모르고  다른 주문건을  취소해버림   죄...
# 1        김포종로약국 한의순          결제완료    인천약품    취소문의해야함
# 2  해피톡      결제완료   취소요청건  모르고  다른 주문건을  취소해버림   죄...

# %%
tfidf_corpus = month_context_extract_tfidf(df,'2019-07-01', '2019-12-31') #2019년 4월에서 6월까지 하려면 (df,'2019-04-01', '2019-06-30')로 작성하면 됨.
tfidf_corpus
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=28752.0), HTML(value='')))
# ['탑헬스케어',
#  '헬스',
#  '케어',
#  '포장엘란바이탈',
#  '바이탈',
#  '프리미엄',
#  '프로',
#  '프로폴리스',
#  '폴리스',
#  '보덕',
#  '보덕탑',
#  '포장엘란',
#  '배송확인요청',
#  '시간양해차',
#  '전화드림약국',
#  '우슬',
#  '우슬닭발',
#  '일건',
#  '양해전화드림',
#  '양해안내',
#  '샵플러스',
#  '플러스',
#  '운영',
#  '운영지원서비스',
#  '지원',
#  '포인트샵',
#  '기프트콘',
#  '사용가능내일',
#  '낱알',
#  '낱알반품쿠폰',
#  '재적',
#  '재적립',
#  '부외품',
#  '부외품쿠폰',
#  '미래',
#  '소멸처리',
#  '예외',
#  '전환',
#  '안내완료',
#  '한올',
#  '한올바이오파마',
#  '파마',
#  '가능여부',
#  '배송비',
#  '만원정도',
#  '부과',
#  '부과예정임',
#  '분경',
#  '예정임',
#  '경원',
#  '오메',
#  '크린',
#  '크린크림',
#  '크림',
#  '구입문',
#  '바구니',
#  '월최대수량',
#  '최대',
#  '즉시할인',
#  '일정',
#  '카특',
#  '사용문의',
#  '생활',
#  '기프',
#  '부외품',
#  '다운',
#  '만이',
#  '판촉물신청처',
#  '미안내',
#  '판촉물신청',
#  '미신청처',
#  '신진',
#  '신진선님',
#  '통화건스타벅스',
#  '스타',
#  '벅스',
#  '신청요청',
#  '청해',
#  '청해드림',
#  '만이',
#  '판촉물신청처',
#  '미안내',
#  '판촉물신청',
#  '하기',
#  '재인',
#  '재인입',
#  '역대급이벤트',
#  '판촉물신청안내차',
#  '전화드림',
#  '선택',
#  '청해',
#  '청해드림안내',
#  '이마트상품권',
#  '원권',
#  '청해드림',
#  '이너',
#  '김수진',
#  '이너힐즈약국',
#  '수진',
#  '사업자면허서류',
#  '면허',
#  '서류',
#  '종목',
#  '화장품',
#  '화장품비누',
#  '비누',
#  '방향제',
#  '소매업',
#  '오선택',
#  '선택',
#  '예정임',
#  '상호명',
#  '사업자번호',
#  '동일',
#  '조은',
#  '조은제이앤피',
#  '제이',
#  '연말',
#  '확인후금일',
#  '익일오전중',
#  '조은제이',
#  '위내용',
#  '안내완료',
#  '호생',
#  '호생약국',
#  '정인수',
#  '조은',
#  '조은제이앤피',
#  '제이',
#  '연말',
#  '익일오전중',
#  '조은제이',
#  '한올',
#  '한올바이오파마',
#  '파마',
#  '가능여부',
#  '배송비',
#  '만원정도',
#  '부과',
#  '부과예정임',
#  '분경',
#  '예정임',
#  '한올',
#  '한올바이오파마',
#  '파마',
#  '가능여부',
#  '배송비',
#  '만원정도',
#  '부과',
#  '부과예정임',
#  '분경',
#  '예정임정',
#  '임정',
#  '배송기사님',
#  '조은',
#  '조은제이앤피',
#  '제이',
#  '연말',
#  '확인후금일',
#  '익일오전중',
#  '메디',
#  '신약국',
#  '오옥',
#  '오옥주핸드폰',
#  '재발송요청',
#  '재발송완료',
#  '재발송요청',
#  '재발송완료',
#  '선약국김혜',
#  '영약국',
#  '부재여',
#  '혜님',
#  '반품건과',
#  '건과',
#  '모두',
#  '미처리',
#  '월내',
#  '처리요청',
#  '환불문의',
#  '발행예정',
#  '헬스',
#  '헬스인',
#  '발송요청',
#  '소요안내',
#  '판촉물신청방법문의',
#  '패밀리',
#  '패밀리존',
#  '안내해드림',
#  '내해',
#  '해오름',
#  '해오름약국홍',
#  '미처리',
#  '폐업예정',
#  '월안',
#  '지금',
#  '내일안',
#  '메모',
#  '메모전달',
#  '대웅오산',
#  '이브',
#  '이브연질캡슐',
#  '연질',
#  '캡슐',
#  '미배송문의',
#  '부외품',
#  '부외품쿠폰',
#  '천원',
#  '신청완료',
#  '개월',
#  '개월내',
#  '저번',
#  '재발',
#  '재발송요청',
#  '재발송완료',
#  '중림',
#  '중림약국김수생',
#  '수생',
#  '최근',
#  '재발송문의',
#  '재발',
#  '재발송',
#  '주문번호상품번호',
#  '교보',
#  '교보문고',
#  '문고',
#  '실시간',
#  '실시간발송',
#  '모바일',
#  '교보문고상품권',
#  '프트',
#  '프트카드',
#  '만원핸드폰번호',
#  '요청하심',
#  '부외품',
#  '부외품쿠폰',
#  '천원',
#  '신청완료',
#  '개월',
#  '개월내',
#  '저번',
#  '재발송요청',
#  '대웅향남',
#  '배송예정시간',
#  '분시경',
#  '시경',
#  '낱알',
#  '낱알반품쿠폰장',
#  '재적',
#  '재적립',
#  '부외품',
#  '부외품쿠폰',
#  '변경요청',
#  '재연락드림',
#  '폴민',
#  '다이아',
#  '엑스',
#  '엑스알서방정정',
#  '서방',
#  '정정',
#  '대웅바이오',
#  '샵플러스포인트',
#  '플러스',
#  '전환',
#  '전환후',
#  '부외품',
#  '부외품할인쿠폰',
#  '발급요청',
#  '샵플러스',
#  '무엇',
#  '미래',
#  '나머지',
#  '제공',
#  '전환불가',
#  '파리',
#  '파리바게트',
#  '바게트',
#  '기프티콘',
#  '청해',
#  '청해드림',
#  '럭키',
#  '럭키약국안승부',
#  '승부',
#  '복산공장',
#  '전체취소요청',
#  '사유오주문',
#  '부외품',
#  '부외품쿠폰',
#  '신청요청',
#  '만원장',
#  '원장',
#  '신청완료',
#  '차주',
#  '모바일',
#  '모바일발송',
#  '대웅향남',
#  '배송예정시간',
#  '세화',
#  '세화헬스케어',
#  '헬스',
#  '케어',
#  '주문취소요청',
#  '세화여',
#  '취소가능',
#  '메디',
#  '메디약국',
#  '김혜란',
#  '혜란',
#  '세화',
#  '세화헬스케어',
#  '헬스',
#  '케어',
#  '주문취소요청',
#  '재통화예정',
#  '세화여',
#  '취소가능',
#  '도매몰',
#  '매몰',
#  '크롬',
#  '용하',
#  '신용',
#  '신용카드사전등록',
#  '사전',
#  '할부',
#  '선택',
#  '아래',
#  '아래화면',
#  '화면',
#  '부가',
#  '마우스',
#  '하면',
#  '불편',
#  '할부선택',
#  '하심월일',
#  '월일',
#  '오전시경',
#  '시경',
#  '천만',
#  '천만원',
#  '개월',
#  '할부결제',
#  '세화',
#  '세화헬스케어',
#  '헬스',
#  '케어',
#  '주문취소요청',
#  '재통화예정',
#  '탈프로',
#  '프로',
#  '치간칫솔자형',
#  '칫솔',
#  '자형',
#  '개입',
#  '개가',
#  '생활기프트',
#  '포인트전환',
#  '전환',
#  '내일안',
#  '한올',
#  '한올노르믹스',
#  '믹스',
#  '보임',
#  '주문가능',
#  '익일이후',
#  '임팩',
#  '민파워',
#  '파워',
#  '구매문의',
#  '마이',
#  '마이페이지',
#  '특별공급관',
#  '통해',
#  '근처',
#  '병원',
#  '준거',
#  '사용방법',
#  '호환',
#  '불가함',
#  '처리해라',
#  '비타민',
#  '라도',
#  '연락요청주심',
#  '주심',
#  '이정',
#  '이정효담당자',
#  '휴가',
#  '한올',
#  '한올바이오파마',
#  '파마',
#  '가능여부',
#  '배송비',
#  '만원정도',
#  '부과',
#  '부과예정임',
#  '분경',
#  '김태',
#  '근처',
#  '병원',
#  '준거',
#  '사용방법',
#  '호환',
#  '불가함',
#  '처리해라',
#  '비타민',
#  '라도',
#  '연락요청주심위',
#  '주심',
#  '자문',
#  '구함',
#  '일단',
#  '지금',
#  '휴가',
#  '휴가라',
#  '목욜',
#  '목욜이후',
#  '비디',
#  '마이크로',
#  '마이크로파인',
#  '파인',
#  '헬스',
#  '헬스인',
#  '반품가능',
#  '오래전',
#  '반품불가',
#  '인천약품',
#  '주문시',
#  '만원이상',
#  '만원이하',
#  '이하',
#  '하면',
#  '착불',
#  '최소',
#  '최소주문',
#  '최소주문금액',
#  '배송비',
#  '말일',
#  '말일자로',
#  '자로',
#  '마트내약국',
#  '지금',
#  '오전중',
#  '고객센터',
#  '센터',
#  '진행요청',
#  '차주',
#  '월화',
#  '회수요청',
#  '약국회수',
#  '직접',
#  '보건소',
#  '폐업일자',
#  '언제쯤',
#  '하면',
#  '환불가능',
#  '세금계산서',
#  '발행문제',
#  '문제',
#  '보건소처리',
#  '최대',
#  '여유',
#  '중순',
#  '통화건도매반품',
#  '정리',
#  '안됨',
#  '리스트',
#  '카톡으',
#  '신청요청',
#  '반품기한',
#  '정책상',
#  '월로',
#  '년이내건',
#  '이내',
#  '최대한',
#  '내일이후',
#  '건물',
#  '오늘내',
#  '전달주시길',
#  '주시',
#  '유미',
#  '유미선',
#  '개인',
#  '개인번호',
#  '산타',
#  '산타홍의원',
#  '의원',
#  '홍종',
#  '병원',
#  '발송완료',
#  '부분취소요청',
#  '유선',
#  '테일',
#  '나이론',
#  '유선리',
#  '봉합사',
#  '미출고분',
#  '유선리테일',
#  '업체측',
#  '반품예치금적립',
#  '직접',
#  '부분취소',
#  '단계',
#  '무상',
#  '무상반품',
#  '신청가능',
#  '세화',
#  '세화약품',
#  '실과',
#  '실과립',
#  '카드취소',
#  '반품쿠폰',
#  '신청해',
#  '청해',
#  '반품시',
#  '환급',
#  '일행복',
#  '행복',
#  '김선영',
#  '선영',
#  '대웅전',
#  '대웅전주백제',
#  '주문취소요청',
#  '회신예정',
#  '한올',
#  '한올바이오',
#  '대전',
#  '대전지방식품의약품',
#  '지방',
#  '식품',
#  '의약품',
#  '안전',
#  '안전청',
#  '실시',
#  '정기',
#  '정기약사감시',
#  '감시',
#  '업무',
#  '개월',
#  '위반',
#  '위반사항',
#  '사항',
#  '지적',
#  '품질',
#  '품질관리기준',
#  '기준',
#  '적합',
#  '적합판정',
#  '판정',
#  '갱신',
#  '보류',
#  '구입어려움처분사항',
#  '처분',
#  '확정',
#  '판매재개',
#  '재개',
#  '패밀리',
#  '패밀리존',
#  '사용방법',
#  '만점',
#  '파리',
#  '파리바게트',
#  '바게트',
#  '기프티콘',
#  '나머지',
#  '부외품',
#  '할인쿠폰',
#  '다운',
#  '환급',
#  '환급요청',
#  '카톡으',
#  '내츄럴라이즈',
#  '츄럴',
#  '이즈',
#  '플래',
#  '플래티',
#  '오메가',
#  '탑헬스케어',
#  '헬스',
#  '케어',
#  '제대',
#  '반품쿠폰',
#  '재신청',
#  '반품기한일',
#  '건기',
#  '건기식',
#  '개월',
#  '경과',
#  '메모',
#  '대웅생명과학',
#  '생명',
#  '과학',
#  '비타민',
#  '토린정',
#  '구매내역',
#  '가입일현재',
#  '조회시',
#  '대웅공장',
#  '배송안내드림',
#  '탑헬스케어',
#  '헬스',
#  '케어',
#  '배송지연',
#  '물류',
#  '문제',
#  '약국안내완료',
#  '정성희님',
#  '성희',
#  '택배사',
#  '도착예정',
#  '글루코',
#  '서방',
#  '서방정',
#  '주문시',
#  '재고노출안됨문의',
#  '안됨',
#  '약품명',
#  '영어',
#  '입력안내',
#  '주문노출확인',
#  '상담',
#  '상담완료',
#  '솔빛약국김',
#  '탑헬스케어',
#  '헬스',
#  '케어',
#  '배송지연',
#  '물류',
#  '문제',
#  '약국안내완료',
#  '정성희님',
#  '성희',
#  '택배사',
#  '도착예정',
#  '김태',
#  '근처',
#  '병원',
#  '준거',
#  '사용방법',
#  '호환',
#  '불가함',
#  '처리해라',
#  '비타민',
#  '라도',
#  '연락요청주심위',
#  '주심',
#  '자문',
#  '패밀리',
#  '패밀리존',
#  '파리',
#  '파리바게트',
#  '바게트',
#  '스타',
#  '스타벅스',
#  '벅스',
#  '아메리카',
#  '아메리카노',
#  '차주',
#  '수요일',
#  '모바일',
#  '발송예정',
#  '웅지',
#  '웅지오',
#  '다이아',
#  '다이아벡스엑스알',
#  '벡스',
#  '엑스',
#  '서방',
#  '서방정',
#  '나머지',
#  '나머지약품',
#  '탑헬스케어',
#  '헬스',
#  '케어',
#  '배송지연',
#  '물류',
#  '문제',
#  '약국안내완료',
#  '정성희님',
#  '성희',
#  '샵플러스포인트',
#  '플러스',
#  '전환',
#  '전환후',
#  '부외품',
#  '부외품할인쿠폰',
#  '발급요청',
#  '샵플러스',
#  '무엇',
#  '한올',
#  '한올바이오파마',
#  '파마',
#  '가능여부',
#  '생활기',
#  '생활기프트',
#  '프트',
#  '쿠폰신청방법문의',
#  '패밀리',
#  '패밀리존',
#  '약국전화',
#  '동일',
#  '동일문의',
#  '재인',
#  '재인입',
#  '확인재촉요청',
#  '재촉',
#  '확인처리',
#  '대웅측확인중',
#  '양해안내드림',
#  '연락요청',
#  '금일확인가능여부',
#  '언제',
#  '사용가능',
#  '조치',
#  '조치중',
#  '대웅바이오',
#  '성희',
#  '성희님',
#  '안됨',
#  '처리요청',
#  '문제',
#  '전달완료',
#  '만점',
#  '구매시',
#  '사용문의',
#  '사용불가',
#  '생활기',
#  '생활기프트커피쿠폰',
#  '프트',
#  '커피',
#  '교환안내',
#  '필로',
#  '필로젠겔',
#  '젠겔',
#  '판매원',
#  '샵대웅',
#  '직접',
#  '판매유통',
#  '약국전화',
#  '동일',
#  '동일문의',
#  '재인',
#  '재인입',
#  '확인재촉요청',
#  '재촉',
#  '확인처리',
#  '대웅측확인중',
#  '양해안내드림',
#  '연락요청',
#  '금일확인가능여부',
#  '언제',
#  '사용가능',
#  '조치',
#  '조치중',
#  '대웅바이오',
#  '가스',
#  '정구',
#  '가스모',
#  '정구연산모사',
#  '연산',
#  '모사',
#  '프리드',
#  '개봉',
#  '어디',
#  '기억',
#  '제조번호',
#  '오상준',
#  '상준',
#  '하나',
#  '하나온누리약국',
#  '온누리',
#  '최원석',
#  '원석',
#  '창원',
#  '주문전',
#  '체취',
#  '회신예정',
#  '창원백제',
#  '동일',
#  '정보변경',
#  '스타',
#  '스타벅스',
#  '벅스',
#  '생활기',
#  '생활기프트',
#  '프트',
#  '신청방법',
#  '겔포스엠현탁액',
#  '포스',
#  '현탁액',
#  '공급가차이왼쪽',
#  '차이',
#  '왼쪽',
#  '단가',
#  '오른쪽',
#  '가지',
#  '경우중',
#  '하나',
#  '하나일수',
#  '일수',
#  '해당지역',
#  '판매중',
#  '특가',
#  '실시간',
#  '연동',
#  '일때',
#  '상계',
#  '마음',
#  '마음약국',
#  '요양',
#  '요양기관번호',
#  '기관',
#  '삭제요청',
#  '새부산약국',
#  '부산',
#  '가입예정',
#  '동물약국개설등록증',
#  '개설',
#  '등록증',
#  '요청소비자가',
#  '소비',
#  '자가',
#  '백광',
#  '백광의약품',
#  '의약품',
#  '출하',
#  '하나',
#  '하나온누리약국',
#  '온누리',
#  '최원석',
#  '원석',
#  '창원',
#  '주문전',
#  '체취',
#  '회신예정',
#  '안락',
#  '고려',
#  '수민',
#  '수민거점',
#  '올등록요청',
#  '이노첵',
#  '장현순',
#  '현순',
#  '특별공급관',
#  '등록요청',
#  '안락',
#  '고려',
#  '수민',
#  '수민거점',
#  '올등록요청',
#  '샵플러스',
#  '플러스',
#  '사용방법',
#  '패밀리',
#  '패밀리존',
#  '기프트콘',
#  '신청방법',
#  '코메키나캡슐',
#  '키나',
#  '캡슐',
#  '마이',
#  '마이페이지',
#  '대웅특별공급관',
#  '사용문의',
#  '생활기프트',
#  '부외품',
#  '부외품쿠폰',
#  '안내중',
#  '포인트전환',
#  '전환',
#  '포인트몰내',
#  '내일안',
#  '말일',
#  '말일자로',
#  '자로',
#  '마트내약국',
#  '지금',
#  '오전중',
#  '고객센터',
#  '센터',
#  '진행요청',
#  '차주',
#  '월화',
#  '회수요청',
#  '약국회수',
#  '직접',
#  '보건소',
#  '폐업일자',
#  '언제쯤',
#  '하면',
#  '환불가능',
#  '세금계산서',
#  '발행문제',
#  '문제',
#  '보건소처리',
#  '최대',
#  '여유',
#  '중순',
#  '통화건도매반품',
#  '약국전화',
#  '동일',
#  '동일문의',
#  '재인',
#  '재인입',
#  '확인재촉요청',
#  '재촉',
#  '확인처리',
#  '대웅측확인중',
#  '양해안내드림',
#  '연락요청',
#  '금일확인가능여부',
#  '언제',
#  '사용가능',
#  '사직',
#  '천안',
#  '천안종합',
#  '종합',
#  '약국황태윤',
#  '황태',
#  '전체취소요청',
#  '사유재고부족',
#  '발송준비중',
#  '준비',
#  '인천약품',
#  '노스판패취',
#  '스판',
#  '부프레노',
#  '르핀매',
#  '향정',
#  '반품문의',
#  '직배송처',
#  '지금',
#  '경과',
#  '폐기',
#  '주문시',
#  '약국이형복',
#  '이형',
#  '인천약품',
#  '노스판패취',
#  '스판',
#  '부프레노',
#  '르핀매',
#  '향정',
#  '반품문의',
#  '직배송처',
#  '지금',
#  '경과',
#  '폐기',
#  '주문시',
#  '으뜸',
#  '으뜸약국',
#  '미숙',
#  '미숙노르믹스',
#  '믹스',
#  '보임',
#  '통화요청',
#  '인천약품',
#  '노스판패취',
#  '스판',
#  '부프레노',
#  '르핀매',
#  '향정',
#  '반품문의',
#  '직배송처',
#  '지금',
#  '약국전화',
#  '동일',
#  '동일문의',
#  '재인',
#  '재인입',
#  '확인재촉요청',
#  '재촉',
#  '약국전화',
#  '모범',
#  '모범약국약사',
#  '성함',
#  '모름',
#  '경기',
#  '경기도',
#  '양주',
#  '소재',
#  '한올',
#  '노르믹스정',
#  '믹스',
#  '한올채널',
#  '생성',
#  '생성후',
#  '구입가능',
#  '사용문의',
#  '부외품',
#  '천원',
#  '개월',
#  '개월안',
#  '임팩',
#  '민파워',
#  '파워',
#  '안내차',
#  '부재여',
#  '말일',
#  '말일자로',
#  '자로',
#  '마트내약국',
#  '지금',
#  ...]

# %%
len(tfidf_corpus)
# Out:
# 279058

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer(
                            use_idf=True,
                            ngram_range=(1,1)) #오직 1-grams만 고려함
#                             min_df = 0.01,     #1% 미만으로 문서에서 출현하는 단어들은 삭제
#                             max_df = 0.05)      #5% 이상으로 문서에서 존재하는 단어들은 삭제(너무 흔함)

t0=time() 


tfidf = vectorizer.fit_transform(tfidf_corpus)

print("완료시간 : %0.3f초" % (time() - t0))
# Out:
# 완료시간 : 1.828초

# %%
ranked = rank_words(terms=vectorizer.get_feature_names(), feature_matrix=tfidf)

fix, ax = plt.subplots(figsize=(6,10), ncols=1, nrows=1)
sns.barplot(x='rank',y='term',data=ranked[:20], palette="Reds_r", ax=ax)
# Out:
# C:\Users\manue\AppData\Roaming\Python\Python38\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <AxesSubplot:xlabel='rank', ylabel='term'>

# %% [markdown]
# # 월별 문의사항 데이터 Gensim 분석

# %%
def text_tokenizing(corpus, tokenizer):
    
    # okt = Okt()
    kkma=Kkma()
    token_corpus = []
    

    if tokenizer == "noun":
        for n in tqdm_notebook(range(len(corpus)), desc="Preprocessing"):
            # token_text = okt.nouns(corpus[n])
            #token_text = mecab.nouns(corpus[n])
            token_text = kkma.nouns(corpus[n])
            #token_text = komoran.nouns(corpus[n])
            #token_text = hannanum.nouns(corpus[n])
            token_text = [word for word in token_text if word not in SW and len(word) > 1]
            token_corpus.append(token_text)
            
    elif tokenizer == "morph":
        for n in tqdm_notebook(range(len(corpus)), desc="Preprocessing"):
            # token_text = okt.morphs(corpus[n])
            #token_text = mecab.morphs(corpus[n])
            token_text = kkma.morphs(corpus[n])
            #token_text = komoran.morphs(corpus[n])
            #token_text = hannanum.morphs(corpus[n])
            token_text = [word for word in token_text if word not in SW and len(word) > 1]
            token_corpus.append(token_text)
            

    return token_corpus

# %%
def month_context_extract_gensim(df, month_start, month_end):
    
    # 시간정보 열 datetime 정보로 변환
    df['상담일시'] = pd.to_datetime(df['상담일시'], format='%Y/%m/%d')
    #연도, 월 데이터 dataframe 받음
    year_month_df = df.loc[(df['상담일시'] > month_start) & (df['상담일시'] < month_end)]
    #텍스트 정제
    corpus = year_month_df[['문의사항_클리닝']].values.tolist()
    #corpus --> list of list
    temp_list = sum(corpus, [])
    #okt 형태소 추출
    per_month_keyword = text_tokenizing(temp_list, "noun")
    
    
    return per_month_keyword

# %%
#2019년 4월에서 6월까지 하려면 (df,'2019-04-01', '2019-06-30')로 작성하면 됨.
gensim_corpus = month_context_extract_gensim(df, '2019-07-01', '2019-12-31')
# Out:
# HBox(children=(HTML(value='Preprocessing'), FloatProgress(value=0.0, max=28752.0), HTML(value='')))

# %%
gensim_corpus
# Out:
# [['탑헬스케어',
#   '헬스',
#   '케어',
#   '포장엘란바이탈',
#   '바이탈',
#   '프리미엄',
#   '프로',
#   '프로폴리스',
#   '폴리스',
#   '보덕',
#   '보덕탑',
#   '포장엘란',
#   '배송확인요청',
#   '시간양해차',
#   '전화드림약국',
#   '우슬',
#   '우슬닭발',
#   '일건',
#   '양해전화드림',
#   '양해안내'],
#  ['샵플러스', '플러스', '운영', '운영지원서비스', '지원', '포인트샵', '기프트콘', '사용가능내일'],
#  ['낱알',
#   '낱알반품쿠폰',
#   '재적',
#   '재적립',
#   '부외품',
#   '부외품쿠폰',
#   '미래',
#   '소멸처리',
#   '예외',
#   '전환',
#   '안내완료'],
#  ['한올', '한올바이오파마', '파마', '가능여부', '배송비', '만원정도', '부과', '부과예정임', '분경', '예정임'],
#  ['경원', '오메', '크린', '크린크림', '크림', '구입문', '바구니', '월최대수량', '최대'],
#  ['즉시할인', '일정', '카특'],
#  ['사용문의', '생활', '기프', '부외품', '다운'],
#  ['만이',
#   '판촉물신청처',
#   '미안내',
#   '판촉물신청',
#   '미신청처',
#   '신진',
#   '신진선님',
#   '통화건스타벅스',
#   '스타',
#   '벅스',
#   '신청요청',
#   '청해',
#   '청해드림'],
#  ['만이',
#   '판촉물신청처',
#   '미안내',
#   '판촉물신청',
#   '하기',
#   '재인',
#   '재인입',
#   '역대급이벤트',
#   '판촉물신청안내차',
#   '전화드림',
#   '선택',
#   '청해',
#   '청해드림안내',
#   '이마트상품권',
#   '원권',
#   '청해드림'],
#  ['이너',
#   '김수진',
#   '이너힐즈약국',
#   '수진',
#   '사업자면허서류',
#   '면허',
#   '서류',
#   '종목',
#   '화장품',
#   '화장품비누',
#   '비누',
#   '방향제',
#   '소매업',
#   '오선택',
#   '선택',
#   '예정임',
#   '상호명',
#   '사업자번호',
#   '동일'],
#  ['조은', '조은제이앤피', '제이', '연말', '확인후금일', '익일오전중', '조은제이', '위내용', '안내완료'],
#  ['호생', '호생약국', '정인수', '조은', '조은제이앤피', '제이', '연말', '익일오전중', '조은제이'],
#  ['한올', '한올바이오파마', '파마', '가능여부', '배송비', '만원정도', '부과', '부과예정임', '분경', '예정임'],
#  ['한올',
#   '한올바이오파마',
#   '파마',
#   '가능여부',
#   '배송비',
#   '만원정도',
#   '부과',
#   '부과예정임',
#   '분경',
#   '예정임정',
#   '임정',
#   '배송기사님'],
#  ['조은', '조은제이앤피', '제이', '연말', '확인후금일', '익일오전중'],
#  ['메디', '신약국', '오옥', '오옥주핸드폰', '재발송요청', '재발송완료'],
#  ['재발송요청', '재발송완료'],
#  ['선약국김혜', '영약국', '부재여'],
#  ['혜님'],
#  ['반품건과',
#   '건과',
#   '모두',
#   '미처리',
#   '월내',
#   '처리요청',
#   '환불문의',
#   '발행예정',
#   '헬스',
#   '헬스인',
#   '발송요청',
#   '소요안내'],
#  ['판촉물신청방법문의', '패밀리', '패밀리존', '안내해드림', '내해'],
#  ['해오름', '해오름약국홍', '미처리', '폐업예정', '월안', '지금', '내일안', '메모', '메모전달'],
#  ['대웅오산', '이브', '이브연질캡슐', '연질', '캡슐', '미배송문의'],
#  ['부외품', '부외품쿠폰', '천원', '신청완료', '개월', '개월내', '저번', '재발', '재발송요청', '재발송완료'],
#  ['중림', '중림약국김수생', '수생', '최근', '재발송문의', '재발', '재발송'],
#  ['주문번호상품번호',
#   '교보',
#   '교보문고',
#   '문고',
#   '실시간',
#   '실시간발송',
#   '모바일',
#   '교보문고상품권',
#   '프트',
#   '프트카드',
#   '만원핸드폰번호',
#   '요청하심'],
#  ['부외품', '부외품쿠폰', '천원', '신청완료', '개월', '개월내', '저번', '재발송요청'],
#  ['대웅향남', '배송예정시간', '분시경', '시경'],
#  ['낱알', '낱알반품쿠폰장', '재적', '재적립', '부외품', '부외품쿠폰', '변경요청', '재연락드림'],
#  ['폴민', '다이아', '엑스', '엑스알서방정정', '서방', '정정', '대웅바이오'],
#  ['샵플러스포인트',
#   '플러스',
#   '전환',
#   '전환후',
#   '부외품',
#   '부외품할인쿠폰',
#   '발급요청',
#   '샵플러스',
#   '무엇',
#   '미래',
#   '나머지',
#   '제공',
#   '전환불가',
#   '파리',
#   '파리바게트',
#   '바게트',
#   '기프티콘',
#   '청해',
#   '청해드림'],
#  ['럭키',
#   '럭키약국안승부',
#   '승부',
#   '복산공장',
#   '전체취소요청',
#   '사유오주문',
#   '부외품',
#   '부외품쿠폰',
#   '신청요청',
#   '만원장',
#   '원장',
#   '신청완료',
#   '차주',
#   '모바일',
#   '모바일발송'],
#  ['대웅향남', '배송예정시간'],
#  ['세화', '세화헬스케어', '헬스', '케어', '주문취소요청', '세화여', '취소가능'],
#  [],
#  ['메디',
#   '메디약국',
#   '김혜란',
#   '혜란',
#   '세화',
#   '세화헬스케어',
#   '헬스',
#   '케어',
#   '주문취소요청',
#   '재통화예정',
#   '세화여',
#   '취소가능'],
#  ['도매몰',
#   '매몰',
#   '크롬',
#   '용하',
#   '신용',
#   '신용카드사전등록',
#   '사전',
#   '할부',
#   '선택',
#   '아래',
#   '아래화면',
#   '화면',
#   '부가',
#   '마우스',
#   '하면',
#   '불편',
#   '할부선택',
#   '하심월일',
#   '월일',
#   '오전시경',
#   '시경',
#   '천만',
#   '천만원',
#   '개월',
#   '할부결제'],
#  [],
#  ['세화', '세화헬스케어', '헬스', '케어', '주문취소요청', '재통화예정'],
#  ['탈프로', '프로', '치간칫솔자형', '칫솔', '자형', '개입', '개가'],
#  ['생활기프트', '포인트전환', '전환', '내일안'],
#  ['한올', '한올노르믹스', '믹스', '보임', '주문가능', '익일이후'],
#  ['임팩', '민파워', '파워', '구매문의', '마이', '마이페이지', '특별공급관', '통해'],
#  ['근처',
#   '병원',
#   '준거',
#   '사용방법',
#   '호환',
#   '불가함',
#   '처리해라',
#   '비타민',
#   '라도',
#   '연락요청주심',
#   '주심',
#   '이정',
#   '이정효담당자',
#   '휴가'],
#  ['한올', '한올바이오파마', '파마', '가능여부', '배송비', '만원정도', '부과', '부과예정임', '분경'],
#  ['김태',
#   '근처',
#   '병원',
#   '준거',
#   '사용방법',
#   '호환',
#   '불가함',
#   '처리해라',
#   '비타민',
#   '라도',
#   '연락요청주심위',
#   '주심',
#   '자문',
#   '구함',
#   '일단',
#   '지금',
#   '휴가',
#   '휴가라',
#   '목욜',
#   '목욜이후'],
#  ['비디', '마이크로', '마이크로파인', '파인', '헬스', '헬스인', '반품가능', '오래전', '반품불가'],
#  ['인천약품',
#   '주문시',
#   '만원이상',
#   '만원이하',
#   '이하',
#   '하면',
#   '착불',
#   '최소',
#   '최소주문',
#   '최소주문금액',
#   '배송비'],
#  ['말일',
#   '말일자로',
#   '자로',
#   '마트내약국',
#   '지금',
#   '오전중',
#   '고객센터',
#   '센터',
#   '진행요청',
#   '차주',
#   '월화',
#   '회수요청',
#   '약국회수',
#   '직접',
#   '보건소',
#   '폐업일자',
#   '언제쯤',
#   '하면',
#   '환불가능',
#   '세금계산서',
#   '발행문제',
#   '문제',
#   '보건소처리',
#   '최대',
#   '여유',
#   '중순',
#   '통화건도매반품',
#   '정리',
#   '안됨',
#   '리스트',
#   '카톡으',
#   '신청요청',
#   '반품기한',
#   '정책상',
#   '월로',
#   '년이내건',
#   '이내',
#   '최대한',
#   '내일이후',
#   '건물',
#   '오늘내',
#   '전달주시길',
#   '주시',
#   '유미',
#   '유미선',
#   '개인',
#   '개인번호'],
#  ['산타',
#   '산타홍의원',
#   '의원',
#   '홍종',
#   '병원',
#   '발송완료',
#   '부분취소요청',
#   '유선',
#   '테일',
#   '나이론',
#   '유선리',
#   '봉합사',
#   '미출고분',
#   '유선리테일',
#   '업체측',
#   '반품예치금적립',
#   '직접',
#   '부분취소',
#   '단계',
#   '무상',
#   '무상반품',
#   '신청가능'],
#  ['세화', '세화약품', '실과', '실과립', '카드취소', '반품쿠폰', '신청해', '청해', '반품시', '환급'],
#  ['일행복', '행복', '김선영', '선영', '대웅전', '대웅전주백제', '주문취소요청', '회신예정'],
#  ['한올',
#   '한올바이오',
#   '대전',
#   '대전지방식품의약품',
#   '지방',
#   '식품',
#   '의약품',
#   '안전',
#   '안전청',
#   '실시',
#   '정기',
#   '정기약사감시',
#   '감시',
#   '업무',
#   '개월',
#   '위반',
#   '위반사항',
#   '사항',
#   '지적',
#   '품질',
#   '품질관리기준',
#   '기준',
#   '적합',
#   '적합판정',
#   '판정',
#   '갱신',
#   '보류',
#   '구입어려움처분사항',
#   '처분',
#   '확정',
#   '판매재개',
#   '재개'],
#  ['패밀리',
#   '패밀리존',
#   '사용방법',
#   '만점',
#   '파리',
#   '파리바게트',
#   '바게트',
#   '기프티콘',
#   '나머지',
#   '부외품',
#   '할인쿠폰',
#   '다운'],
#  ['환급', '환급요청', '카톡으'],
#  ['내츄럴라이즈',
#   '츄럴',
#   '이즈',
#   '플래',
#   '플래티',
#   '오메가',
#   '탑헬스케어',
#   '헬스',
#   '케어',
#   '제대',
#   '반품쿠폰',
#   '재신청',
#   '반품기한일',
#   '건기',
#   '건기식',
#   '개월',
#   '경과',
#   '메모',
#   '대웅생명과학',
#   '생명',
#   '과학',
#   '비타민',
#   '토린정',
#   '구매내역',
#   '가입일현재',
#   '조회시'],
#  ['대웅공장', '배송안내드림'],
#  ['탑헬스케어',
#   '헬스',
#   '케어',
#   '배송지연',
#   '물류',
#   '문제',
#   '약국안내완료',
#   '정성희님',
#   '성희',
#   '택배사',
#   '도착예정'],
#  ['글루코',
#   '서방',
#   '서방정',
#   '주문시',
#   '재고노출안됨문의',
#   '안됨',
#   '약품명',
#   '영어',
#   '입력안내',
#   '주문노출확인',
#   '상담',
#   '상담완료'],
#  ['솔빛약국김',
#   '탑헬스케어',
#   '헬스',
#   '케어',
#   '배송지연',
#   '물류',
#   '문제',
#   '약국안내완료',
#   '정성희님',
#   '성희',
#   '택배사',
#   '도착예정'],
#  ['김태',
#   '근처',
#   '병원',
#   '준거',
#   '사용방법',
#   '호환',
#   '불가함',
#   '처리해라',
#   '비타민',
#   '라도',
#   '연락요청주심위',
#   '주심',
#   '자문'],
#  ['패밀리',
#   '패밀리존',
#   '파리',
#   '파리바게트',
#   '바게트',
#   '스타',
#   '스타벅스',
#   '벅스',
#   '아메리카',
#   '아메리카노',
#   '차주',
#   '수요일',
#   '모바일',
#   '발송예정'],
#  ['웅지', '웅지오', '다이아', '다이아벡스엑스알', '벡스', '엑스', '서방', '서방정', '나머지', '나머지약품'],
#  ['탑헬스케어', '헬스', '케어', '배송지연', '물류', '문제', '약국안내완료', '정성희님', '성희'],
#  ['샵플러스포인트', '플러스', '전환', '전환후', '부외품', '부외품할인쿠폰', '발급요청', '샵플러스', '무엇'],
#  ['한올', '한올바이오파마', '파마', '가능여부'],
#  ['생활기', '생활기프트', '프트', '쿠폰신청방법문의', '패밀리', '패밀리존'],
#  ['약국전화',
#   '동일',
#   '동일문의',
#   '재인',
#   '재인입',
#   '확인재촉요청',
#   '재촉',
#   '확인처리',
#   '대웅측확인중',
#   '양해안내드림',
#   '연락요청',
#   '금일확인가능여부',
#   '언제',
#   '사용가능',
#   '조치',
#   '조치중',
#   '대웅바이오',
#   '성희',
#   '성희님',
#   '안됨',
#   '처리요청',
#   '문제',
#   '전달완료'],
#  ['만점', '구매시', '사용문의', '사용불가', '생활기', '생활기프트커피쿠폰', '프트', '커피', '교환안내'],
#  ['필로', '필로젠겔', '젠겔', '판매원', '샵대웅', '직접', '판매유통'],
#  ['약국전화',
#   '동일',
#   '동일문의',
#   '재인',
#   '재인입',
#   '확인재촉요청',
#   '재촉',
#   '확인처리',
#   '대웅측확인중',
#   '양해안내드림',
#   '연락요청',
#   '금일확인가능여부',
#   '언제',
#   '사용가능',
#   '조치',
#   '조치중',
#   '대웅바이오'],
#  ['가스', '정구', '가스모', '정구연산모사', '연산', '모사', '프리드', '개봉', '어디', '기억', '제조번호'],
#  ['오상준',
#   '상준',
#   '하나',
#   '하나온누리약국',
#   '온누리',
#   '최원석',
#   '원석',
#   '창원',
#   '주문전',
#   '체취',
#   '회신예정',
#   '창원백제'],
#  ['동일', '정보변경'],
#  ['스타', '스타벅스', '벅스', '생활기', '생활기프트', '프트', '신청방법'],
#  ['겔포스엠현탁액',
#   '포스',
#   '현탁액',
#   '공급가차이왼쪽',
#   '차이',
#   '왼쪽',
#   '단가',
#   '오른쪽',
#   '가지',
#   '경우중',
#   '하나',
#   '하나일수',
#   '일수',
#   '해당지역',
#   '판매중',
#   '특가',
#   '실시간',
#   '연동',
#   '일때'],
#  ['상계', '마음', '마음약국', '요양', '요양기관번호', '기관', '삭제요청', '새부산약국', '부산', '가입예정'],
#  ['동물약국개설등록증', '개설', '등록증', '요청소비자가', '소비', '자가', '백광', '백광의약품', '의약품', '출하'],
#  ['하나', '하나온누리약국', '온누리', '최원석', '원석', '창원', '주문전', '체취', '회신예정'],
#  ['안락', '고려', '수민', '수민거점', '올등록요청', '이노첵', '장현순', '현순', '특별공급관', '등록요청'],
#  ['안락', '고려', '수민', '수민거점', '올등록요청'],
#  ['샵플러스', '플러스', '사용방법', '패밀리', '패밀리존', '기프트콘', '신청방법'],
#  ['코메키나캡슐', '키나', '캡슐', '마이', '마이페이지', '대웅특별공급관'],
#  ['사용문의', '생활기프트', '부외품', '부외품쿠폰', '안내중', '포인트전환', '전환', '포인트몰내', '내일안'],
#  ['말일',
#   '말일자로',
#   '자로',
#   '마트내약국',
#   '지금',
#   '오전중',
#   '고객센터',
#   '센터',
#   '진행요청',
#   '차주',
#   '월화',
#   '회수요청',
#   '약국회수',
#   '직접',
#   '보건소',
#   '폐업일자',
#   '언제쯤',
#   '하면',
#   '환불가능',
#   '세금계산서',
#   '발행문제',
#   '문제',
#   '보건소처리',
#   '최대',
#   '여유',
#   '중순',
#   '통화건도매반품'],
#  ['약국전화',
#   '동일',
#   '동일문의',
#   '재인',
#   '재인입',
#   '확인재촉요청',
#   '재촉',
#   '확인처리',
#   '대웅측확인중',
#   '양해안내드림',
#   '연락요청',
#   '금일확인가능여부',
#   '언제',
#   '사용가능'],
#  ['사직', '천안', '천안종합', '종합', '약국황태윤', '황태', '전체취소요청', '사유재고부족', '발송준비중', '준비'],
#  ['인천약품',
#   '노스판패취',
#   '스판',
#   '부프레노',
#   '르핀매',
#   '향정',
#   '반품문의',
#   '직배송처',
#   '지금',
#   '경과',
#   '폐기',
#   '주문시'],
#  ['약국이형복',
#   '이형',
#   '인천약품',
#   '노스판패취',
#   '스판',
#   '부프레노',
#   '르핀매',
#   '향정',
#   '반품문의',
#   '직배송처',
#   '지금',
#   '경과',
#   '폐기',
#   '주문시'],
#  ['으뜸', '으뜸약국', '미숙', '미숙노르믹스', '믹스', '보임', '통화요청'],
#  ['인천약품', '노스판패취', '스판', '부프레노', '르핀매', '향정', '반품문의', '직배송처', '지금'],
#  ['약국전화', '동일', '동일문의', '재인', '재인입', '확인재촉요청', '재촉'],
#  ['약국전화'],
#  ['모범',
#   '모범약국약사',
#   '성함',
#   '모름',
#   '경기',
#   '경기도',
#   '양주',
#   '소재',
#   '한올',
#   '노르믹스정',
#   '믹스',
#   '한올채널',
#   '생성',
#   '생성후',
#   '구입가능'],
#  ['사용문의', '부외품', '천원', '개월', '개월안'],
#  ['임팩', '민파워', '파워', '안내차', '부재여'],
#  ['말일',
#   '말일자로',
#   '자로',
#   '마트내약국',
#   '지금',
#   '오전중',
#   '고객센터',
#   '센터',
#   '진행요청',
#   '차주',
#   '월화',
#   '회수요청',
#   '약국회수',
#   '직접',
#   '보건소',
#   '폐업일자',
#   '언제쯤',
#   '하면',
#   '환불가능',
#   '세금계산서',
#   '발행문제',
#   '문제',
#   '보건소처리',
#   '최대',
#   '여유',
#   '중순',
#   '통화건도매반품'],
#  ['도매부외품', '부외품', '리스트', '아까', '상담원', '아가', '통화요청유미선', '유미', '통화중임', '중임'],
#  ['임팩', '프리미엄', '이브', '주문요청', '삼성', '삼성간편결제', '간편', '주문결제완료', '해드림', '안내완료'],
#  ['만점',
#   '사용문의',
#   '생활기',
#   '생활기프트',
#   '프트',
#   '스벅으',
#   '전부',
#   '스벅',
#   '모두',
#   '신청완료',
#   '차주',
#   '수금',
#   '모바일',
#   '모바일발송'],
#  ['정산', '정산관련', '확인문의', '확인시', '전종우님', '종우', '휴무', '재문'],
#  ['공장배송문의'],
#  ['폐업예정', '잔고예치금', '환불문의', '발송요청', '소요안내'],
#  ['코끼리',
#   '코끼리약국',
#   '가입중',
#   '요양',
#   '요양기관번호',
#   '기관',
#   '미발급',
#   '가입문',
#   '임의',
#   '임의숫자',
#   '숫자',
#   '중복',
#   '자리',
#   '가입후',
#   '회원정보수정'],
#  ['캡슐', '판매문의', '슈넬', '슈넬생명과학', '생명', '과학', '생산', '아너스팜', '판매중', '너스'],
#  ['임팩', '민케어', '케어', '할증', '가능하심', '내년'],
#  ['다이아',
#   '다이아벡스엑스알',
#   '벡스',
#   '엑스',
#   '서방',
#   '서방정',
#   '하루',
#   '개로',
#   '구매수량제한',
#   '제한',
#   '중순',
#   '해소',
#   '수량증대',
#   '증대',
#   '거래처'],
#  ['다이아', '다이아벡스엑스알', '벡스', '엑스', '채널매'],
#  ['도매부외품', '부외품', '신청시', '선택', '대상', '알럿', '선택추가', '버튼', '클릭'],
#  ['삼성', '삼성연합약국', '연합', '사용방법', '문의주심', '주심'],
#  ['무등', '무등약품남', '주문접수', '마이너스잔고', '익일재확인안내드림', '재확인'],
#  ['사용방법', '패밀리', '패밀리존', '통해'],
#  ['주문접수', '입금전', '개더', '취소요청드림', '재주', '재주문안내', '정성희님', '성희', '연락요청'],
#  ['기산', '기산약국', '영재', '탑헬스케어', '헬스', '케어', '집화', '집화처리'],
#  ['가정', '가정약국방명신', '방명', '결제취소', '발송완료'],
#  ['크린',
#   '수량증대',
#   '증대',
#   '소량',
#   '최대',
#   '개개입월구매',
#   '개입',
#   '문의후',
#   '크린증대',
#   '김병주',
#   '바구니',
#   '안내완료'],
#  ['금보',
#   '금보메디넷',
#   '메디',
#   '로키티',
#   '아이스',
#   '아이스겔밴드년형',
#   '밴드',
#   '년형',
#   '매입',
#   '요청사유',
#   '과다',
#   '과다제조번호',
#   '조일',
#   '반품불가시',
#   '불가시',
#   '반품불가하다',
#   '하다',
#   '신청건'],
#  ['유성',
#   '유성미래약국임',
#   '미래',
#   '유비',
#   '금보',
#   '금보메디넷',
#   '메디',
#   '로키티',
#   '아이스',
#   '아이스겔밴드년형',
#   '밴드',
#   '년형',
#   '매입',
#   '요청사유',
#   '과다',
#   '과다제조번호',
#   '조일',
#   '반품불가하다',
#   '하다',
#   '신청건'],
#  ['금보',
#   '금보메디넷',
#   '메디',
#   '로키티',
#   '아이스',
#   '아이스겔밴드년형',
#   '밴드',
#   '년형',
#   '매입',
#   '요청사유',
#   '과다',
#   '과다제조번호',
#   '조일',
#   '반품불가시',
#   '불가시'],
#  ['사은품'],
#  ['주문접수', '입금전', '개더', '취소요청드림', '재주', '재주문안내'],
#  ['마이너스잔고'],
#  ['연질', '연질캡슐', '캡슐', '연락드림반품불가', '표기', '체크'],
#  ['선사',
#   '프라임',
#   '프라임약국',
#   '김수경',
#   '수경',
#   '대웅공장다이아벡스',
#   '다이아',
#   '벡스',
#   '엑스',
#   '엑스알서방정',
#   '서방',
#   '미배송문의',
#   '예정서문',
#   '서문',
#   '세환',
#   '대웅공장',
#   '다이아벡스엑스알',
#   '서방정',
#   '도착예정'],
#  ['이지에프새살연고',
#   '에프',
#   '새살',
#   '연고',
#   '개봉',
#   '사용기한',
#   '냉장',
#   '냉장보관',
#   '개월',
#   '상온',
#   '개월임',
#   '님상담',
#   '상담',
#   '건사용기한',
#   '개봉전',
#   '개봉일로',
#   '일로'],
#  ['이지에프새살연고', '에프', '새살', '연고', '개봉', '사용기한', '냉장', '냉장보관', '개월', '상온', '개월임'],
#  ['회원가입승인문', '주심', '주심양해드림'],
#  ['한올',
#   '한올바이오파마',
#   '파마',
#   '카드사',
#   '카드사측',
#   '가맹점',
#   '취소데이터',
#   '데이터',
#   '것임',
#   '기준',
#   '기준일로',
#   '일로',
#   '휴무일',
#   '제외',
#   '최소'],
#  ['인천약품', '결제완료상태', '출고문의'],
#  ['천일', '천일온누리약국', '온누리', '김경주', '경주', '제약공장', '배송일정문의', '일정', '용마', '지스'],
#  ['한올', '결제당일', '당일', '취소건', '카드사', '수있음', '대웅바이오', '취소안', '정정'],
#  ['우리', '약국김성진', '성진', '출하', '출하정지', '카드취소'],
#  ['우리', '약국김성진', '성진', '티제이', '제이', '카드취소'],
#  ['한올', '결제당일', '당일', '취소건', '카드사'],
#  ['바구니',
#   '우루',
#   '결제요청',
#   '우루사잔고',
#   '주문금액원',
#   '마이너스잔고사용원',
#   '비용',
#   '인원',
#   '주문완료',
#   '해드림'],
#  ['라니티딘', '제제', '이후분'],
#  ['조회자체',
#   '자체',
#   '안됨',
#   '년이상',
#   '경과',
#   '사유유효기간',
#   '임박',
#   '임박초과',
#   '초과',
#   '반품기한',
#   '개월',
#   '예외',
#   '예외확인',
#   '양해담당자',
#   '처음',
#   '퇴사면',
#   '사면',
#   '잘못',
#   '연락요청',
#   '개내외',
#   '내외',
#   '우선',
#   '정책',
#   '최대',
#   '하곘음',
#   '업체건',
#   '경동',
#   '현탁액',
#   '아세트',
#   '경동사수원',
#   '수원',
#   '토펜',
#   '아미노',
#   '아미노펜',
#   '예외신청',
#   '샵전산',
#   '전산',
#   '쿠폰사용',
#   '배송비',
#   '차감',
#   '수있음',
#   '거랑',
#   '메모',
#   '반품정책',
#   '말씀',
#   '말씀주시',
#   '주시',
#   '최대한',
#   '드릴',
#   '완강히',
#   '재양'],
#  ['온누리',
#   '현약국',
#   '황은희',
#   '은희',
#   '세금계산서',
#   '금융',
#   '금융할인',
#   '하심원원원원',
#   '원원',
#   '공급사별',
#   '사별',
#   '주문조회',
#   '마이',
#   '마이페이지',
#   '거래원장',
#   '원장',
#   '금액일치',
#   '일치',
#   '판매마감',
#   '이월'],
#  ['박진',
#   '수원',
#   '현탁액',
#   '아세트',
#   '등약국',
#   '박진아경동사',
#   '아경',
#   '토펜',
#   '동사',
#   '아미노',
#   '아미노펜',
#   '반품가능',
#   '주라'],
#  ['행복',
#   '나눔',
#   '병무',
#   '노르믹스',
#   '믹스',
#   '재고부족',
#   '해당약국',
#   '중복',
#   '중복취소',
#   '부분취소예치금적립',
#   '개값임',
#   '착각'],
#  ['말일',
#   '말일자로',
#   '자로',
#   '마트내약국',
#   '지금',
#   '오전중',
#   '고객센터',
#   '센터',
#   '진행요청',
#   '차주',
#   '월화',
#   '회수요청',
#   '약국회수',
#   '직접',
#   '보건소',
#   '폐업일자',
#   '언제쯤',
#   '하면',
#   '환불가능',
#   '세금계산서',
#   '발행문제',
#   '문제',
#   '보건소처리',
#   '최대',
#   '여유',
#   '중순',
#   '통화건도매반품'],
#  ['프로', '입고문', '고문'],
#  ['다이아', '다이아벡스엑스알', '벡스', '엑스', '채널매'],
#  ['이지듀', '셜미스트', '미스트', '보임', '일문'],
#  ['느티나무', '느티나무약국김혜성', '혜성', '개랑', '거점출고', '공장출고'],
#  ['해결'],
#  ['한올', '한올바이오배송문의', '택배사', '용마', '공장출고건'],
#  ['프로', '확인부탁', '부탁'],
#  ['파주', '그린', '그린약국', '우루', '우루사가', '사가', '오배송'],
#  ['덤액티브', '액티브', '반품가능', '무료', '반품신청방법'],
#  ['제목', '도매반품', '클레임', '연락요청', '등약국', '박진', '정책상', '개월', '제조번호', '팀원'],
#  ['반품건과', '건과', '모두', '미처리', '월내', '처리요청', '환불문', '불문'],
#  ['한올',
#   '한올바이오',
#   '원래',
#   '행정',
#   '행정처분보류',
#   '처분',
#   '보류',
#   '판매중지',
#   '중지',
#   '고함',
#   '고안',
#   '고안내함',
#   '일부',
#   '일부제품',
#   '고안내'],
#  ['조회자체',
#   '자체',
#   '안됨',
#   '년이상',
#   '경과',
#   '사유유효기간',
#   '임박',
#   '임박초과',
#   '초과',
#   '반품기한',
#   '개월',
#   '예외',
#   '예외확인',
#   '양해담당자',
#   '처음',
#   '퇴사면',
#   '사면',
#   '잘못',
#   '연락요청',
#   '개내외',
#   '내외',
#   '우선',
#   '정책',
#   '최대',
#   '하곘음',
#   '업체건',
#   '경동',
#   '현탁액',
#   '아세트',
#   '경동사수원',
#   '수원',
#   '토펜',
#   '아미노',
#   '아미노펜'],
#  ['반품처리여부', '조제', '조제중', '마이', '마이페이지', '거래원장', '원장', '통해', '환입내역', '확인방법'],
#  ['온누리', '현약국', '황은희', '은희', '세금계산서', '금융', '금융할인', '하심원원원원', '원원'],
#  ['반품시', '낱알', '낱알수량', '예상', '예상금액', '수도', '규격', '제대', '처리가능', '매수', '정수'],
#  ['휴면', '휴면계정활성화', '계정', '활성화', '정보확인후', '회원정보수정', '해주심안내드림', '주심'],
#  ['금일배송',
#   '내일오전',
#   '배송원',
#   '송원',
#   '익일배송안내',
#   '확답',
#   '확답어려움',
#   '재확인',
#   '재확인후',
#   '김현규',
#   '스마일',
#   '스마일확인',
#   '담당',
#   '담당기사',
#   '오전중',
#   '전달드림',
#   '하기',
#   '안내완료'],
#  ['조회자체',
#   '자체',
#   '안됨',
#   '년이상',
#   '경과',
#   '사유유효기간',
#   '임박',
#   '임박초과',
#   '초과',
#   '반품기한',
#   '개월',
#   '예외',
#   '예외확인',
#   '양해담당자',
#   '처음',
#   '퇴사면',
#   '사면',
#   '잘못',
#   '연락요청',
#   '개내외',
#   '내외'],
#  ['우루', '우루사', '시너지', '세트', '세트관련', '지난주', '리버골드', '이벤트기간내', '주신건', '적립안내드림'],
#  ['임경',
#   '탑헬스케어',
#   '헬스',
#   '케어',
#   '포장엘란바이탈',
#   '바이탈',
#   '프리미엄',
#   '프로',
#   '프로폴리스',
#   '폴리스',
#   '보덕',
#   '보덕탑',
#   '포장엘란',
#   '배송확인요청'],
#  ['월말',
#   '월말결제액',
#   '주문관리',
#   '월말결제',
#   '도매몰',
#   '매몰',
#   '선결제',
#   '안내상담원',
#   '상담원',
#   '테스트',
#   '아이디여'],
#  ['온누리',
#   '현약국',
#   '황은희',
#   '은희',
#   '주문내역',
#   '해당시간',
#   '취소시간',
#   '서울약사신협',
#   '신협',
#   '비용',
#   '비용할인',
#   '서방',
#   '서방정'],
#  ['월말', '월말결제액', '주문관리', '월말결제'],
#  ['결제하기',
#   '제하기',
#   '반응',
#   '일반',
#   '쿠키',
#   '사이트',
#   '데이터',
#   '설정',
#   '보안',
#   '신뢰',
#   '고급',
#   '고급설정복원',
#   '기본',
#   '기본설정복원',
#   '원래',
#   '설정적용',
#   '부팅'],
#  ['박명기',
#   '명기',
#   '목청',
#   '프로',
#   '프로폴리스목캔디',
#   '폴리스',
#   '캔디',
#   '개가',
#   '마누카벌꿀',
#   '벌꿀',
#   '목청캔디',
#   '오배송'],
#  ['업체명', '낱알', '아이콘', '주문시', '낱알반품', '문구', '급여', '제공', '반품가능하심'],
#  ['상아',
#   '상아약국',
#   '유니',
#   '유니피토정',
#   '토정',
#   '경남쪽',
#   '남쪽',
#   '하나',
#   '본사',
#   '고가',
#   '필요수량',
#   '말씀'],
#  ['탑헬스케어',
#   '헬스',
#   '케어',
#   '포장엘란바이탈',
#   '바이탈',
#   '프리미엄',
#   '프로',
#   '프로폴리스',
#   '폴리스',
#   '보덕',
#   '보덕탑',
#   '포장엘란',
#   '배송확인요청',
#   '재연락예정'],
#  ['탑헬스케어', '헬스', '케어'],
#  ['한신', '한신약품', '반품방법', '도매부외품', '부외품'],
#  ['대웅라니티딘제제',
#   '라니티딘',
#   '제제',
#   '회수확인서',
#   '확인서',
#   '안와',
#   '팩스재발송',
#   '재발',
#   '이메일',
#   '마일리지사용문의',
#   '샵마일리지',
#   '만점',
#   '만점확인',
#   '패밀리',
#   '패밀리존',
#   '생활기',
#   '생활기프트신청',
#   '프트',
#   '쿠폰전환',
#   '전환'],
#  ['로수', '바스타', '스타', '영님'],
#  ['라니',
#   '라니콤정',
#   '낱알',
#   '서울약사신협',
#   '신협',
#   '라니티딘',
#   '제제',
#   '신청건',
#   '아까',
#   '회수확인서',
#   '확인서',
#   '동봉',
#   '상호'],
#  ['상아', '상아약국', '유니', '유니피토정', '토정'],
#  ['출석',
#   '출석이벤트',
#   '스탬프',
#   '응모',
#   '때제대',
#   '제대',
#   '횟수',
#   '횟수반영',
#   '반영',
#   '항의',
#   '항의하심응모횟수',
#   '회로',
#   '반영요청오류',
#   '저장',
#   '저장안됨',
#   '안됨',
#   '송두리',
#   '버튼',
#   '클릭',
#   '알럿창',
#   '구매이력',
#   '보유',
#   '카운트',
#   '방식',
#   '확인가능',
#   '개발',
#   '개발팀',
#   '담당자분',
#   '휴무',
#   '하기',
#   '응모횟수',
#   '구매횟수',
#   '할인쿠폰',
#   '발급처리'],
#  ['역대급',
#   '매출기준',
#   '기준',
#   '파일',
#   '확인시',
#   '안내판촉물',
#   '만점',
#   '부외품',
#   '부외품만원',
#   '치킨',
#   '치킨기프티'],
#  ['동물약품',
#   '구매문의',
#   '개설',
#   '개설증',
#   '어디',
#   '민원',
#   '민원개설신고',
#   '신고',
#   '서류',
#   '서류출력',
#   '출력',
#   '저희',
#   '재연',
#   '재연락주시길',
#   '주시'],
#  ['로수', '바스타', '스타', '김중흠', '시경'],
#  ['대웅서울',
#   '평소',
#   '토요일',
#   '유미',
#   '유미선님상담',
#   '상담',
#   '배송확인',
#   '재문의',
#   '이번호',
#   '주라',
#   '심미선',
#   '미선',
#   '전달드림',
#   '하기',
#   '하기건',
#   '문의한지',
#   '한지',
#   '떄문',
#   '손님',
#   '인줄',
#   '냐며',
#   '짜증',
#   '짜증불만제기',
#   '불만',
#   '제기',
#   '만큼',
#   '보상',
#   '줄거냐',
#   '불만제기',
#   '안해',
#   '안해보고',
#   '보고',
#   '독촉',
#   '양해드림',
#   '강성',
#   '차량',
#   '문제',
#   '오전내',
#   '재배',
#   '재배송예정'],
#  ['오라비',
#   '오라비수정',
#   '반품승인',
#   '우측',
#   '승인후출력가능',
#   '출력',
#   '버튼',
#   '무엇',
#   '렌드로',
#   '드로',
#   '네이트',
#   '네이트디정',
#   '금요일',
#   '시쯤',
#   '배송확인요청',
#   '실물',
#   '주시',
#   '현님',
#   '전주',
#   '전주백제거점',
#   '시반'],
#  ['가입관련', '배정문의'],
#  ['문메디칼', '메디칼', '렌드로', '드로', '네이트', '네이트디정', '금요일', '시쯤', '시반', '출고오늘안'],
#  ['한올',
#   '보류',
#   '제조판매',
#   '누군가',
#   '책임',
#   '당장',
#   '하라',
#   '클레임',
#   '클레임제기',
#   '제기',
#   '책임자',
#   '연락하라',
#   '조현',
#   '조현서',
#   '하심배송',
#   '재고확보',
#   '확보',
#   '하심팩스',
#   '라도',
#   '하심오늘중'],
#  ['금일배송', '내일오전', '배송원', '송원', '익일배송안내', '확답', '확답어려움', '재확인', '재확인후'],
#  ['한올', '한올노르믹스', '믹스', '채널매', '생성', '생성완료'],
#  ['평화', '최승', '최승유', '처음', '분전', '피드백', '항의', '답장'],
#  ['한올', '한올노르믹스', '믹스', '채널매'],
#  ['연질', '연질캡슐', '캡슐', '문의으'],
#  ['샵플러스', '플러스', '모두', '전환'],
#  ['로수', '바스타', '스타'],
#  [],
#  ['대웅서울',
#   '평소',
#   '토요일',
#   '유미',
#   '유미선님상담',
#   '상담',
#   '배송확인',
#   '재문의',
#   '이번호',
#   '주라',
#   '심미선',
#   '미선',
#   '전달드림',
#   '하기',
#   '하기건',
#   '문의한지',
#   '한지',
#   '떄문',
#   '손님',
#   '인줄',
#   '냐며',
#   '짜증',
#   '짜증불만제기',
#   '불만',
#   '제기',
#   '만큼',
#   '보상',
#   '줄거냐',
#   '불만제기',
#   '안해',
#   '안해보고',
#   '보고',
#   '독촉',
#   '양해드림',
#   '강성'],
#  ['구남약국', '지영'],
#  ['오라비',
#   '오라비수정',
#   '반품승인',
#   '우측',
#   '승인후출력가능',
#   '출력',
#   '버튼',
#   '무엇',
#   '렌드로',
#   '드로',
#   '네이트',
#   '네이트디정',
#   '금요일',
#   '시쯤',
#   '배송확인요청'],
#  ['약국박주현', '박주', '취소확정', '확정'],
#  ['대웅서울',
#   '평소',
#   '토요일',
#   '유미',
#   '유미선님상담',
#   '상담',
#   '배송확인',
#   '재문의',
#   '이번호',
#   '주라',
#   '심미선',
#   '미선',
#   '전달드림'],
#  ['처방전보관서비스',
#   '어디',
#   '운영',
#   '운영지원서비스',
#   '지원',
#   '포인트샵상단',
#   '상단',
#   '상품쇼핑',
#   '쇼핑',
#   '전용서비스처방전보관'],
#  ['라니',
#   '라니콤정',
#   '낱알',
#   '서울약사신협',
#   '신협',
#   '라니티딘',
#   '제제',
#   '회수확인서',
#   '확인서',
#   '낱알수량',
#   '연락주시기',
#   '시기'],
#  ['비스', '비스정', '반품후', '잔고처리', '거래원장', '원장', '확인가능안내', '손님', '이상있음', '재문의'],
#  ['마이크로', '마이크로파인', '파인', '펜니들', '니들', '오배송', '교환요청금일', '출고해드림', '교환안내완료'],
#  ['조은',
#   '조은약국',
#   '박혜',
#   '마이크로',
#   '마이크로파인',
#   '파인',
#   '펜니들',
#   '니들',
#   '오배송',
#   '교환요청금일',
#   '출고해드림'],
#  ['패밀리', '패밀리약국', '길자', '대웅반품', '오늘내', '회수요청', '사유폐업'],
#  ['한올',
#   '한올바이오파마',
#   '파마',
#   '출고불가',
#   '카드취소',
#   '승인시',
#   '카드사',
#   '기준',
#   '기준일로',
#   '일로',
#   '휴무',
#   '제외'],
#  ['장태',
#   '장태훈님',
#   '통화요청월중',
#   '월중',
#   '폐업예정',
#   '약국운영',
#   '운영',
#   '대웅반품',
#   '회수요청',
#   '내일중',
#   '세금계산서',
#   '문제',
#   '반품처리완료',
#   '연락주신'],
#  ['뷰티',
#   '개개',
#   '개개매개향남',
#   '매개',
#   '출고분',
#   '예정임',
#   '엔프로',
#   '프로',
#   '대웅바이오',
#   '구매시',
#   '제품군',
#   '전액',
#   '입고시',
#   '고시',
#   '바구니'],
#  ['크린'],
#  ['크린', '크림', '구매문의', '거점상품', '바구니', '최대', '개입', '개입개'],
#  ['메디', '메디원', '약국이광수', '이광수', '약국통화요청'],
#  ['대웅바이오',
#   '거래중단',
#   '안됨',
#   '콕시브캡슐',
#   '시브',
#   '캡슐',
#   '네버',
#   '네버펜',
#   '웅코나졸정',
#   '나졸',
#   '웅코나졸캡슐',
#   '프라캡슐',
#   '클래',
#   '리트',
#   '마이',
#   '마이신정',
#   '신정',
#   '클로버',
#   '클로버정',
#   '대웅라',
#   '티민정',
#   '개베아크라정',
#   '아크라'],
#  ['약가', '약가인하', '인하', '공지사항', '사항', '등록시', '대웅제약관련', '공지등록', '안내완료'],
#  ['약가', '약가인하관련', '인하', '공지사항', '사항', '반품신청시', '약가인하'],
#  ['김재인남', '재인', '약가', '약가인하', '인하', '후약국', '연락요청', '등록안내드림'],
#  ['월일',
#   '사업자번호대표자명',
#   '대표자',
#   '변경예정',
#   '회원정보변경문의',
#   '사업자번호',
#   '신규',
#   '신규가입',
#   '접수후',
#   '국장',
#   '약사면허증사등',
#   '면허증',
#   '내줏'],
#  ['티제이', '제이', '전체취소요청', '사유오주문'],
#  ['약국박주현', '박주', '출하', '출하정지'],
#  ['세건강약국장기원', '장기원', '티제이', '제이', '전체취소요청', '사유오주문', '출고정지완료'],
#  [],
#  ['티제이', '제이', '전체취소요청', '사유오주문'],
#  [],
#  ['출석',
#   '출석이벤트',
#   '스탬프',
#   '응모',
#   '때제대',
#   '제대',
#   '횟수',
#   '횟수반영',
#   '반영',
#   '항의',
#   '항의하심응모횟수',
#   '회로',
#   '반영요청'],
#  ['한올',
#   '바이오노르',
#   '믹스',
#   '믹스정리',
#   '정리',
#   '시민',
#   '월일',
#   '약가',
#   '약가인하',
#   '인하',
#   '대상',
#   '보상',
#   '보상방안',
#   '방안',
#   '한올측',
#   '차주',
#   '김수경님',
#   '수경',
#   '직전',
#   '개월',
#   '매출수량',
#   '금월',
#   '금월중',
#   '실물',
#   '김수경',
#   '예외적',
#   '한솔',
#   '한솔약국',
#   '리스트',
#   '노르믹스',
#   '거래처',
#   '상호',
#   '직인',
#   '날인',
#   '저희',
#   '스캔',
#   '스캔본',
#   '부탁',
#   '드립',
#   '재고수량',
#   '보상처리',
#   '작성',
#   '전화주시기',
#   '시기'],
#  ['대웅서울', '평소', '토요일'],
#  [],
#  ['인천약품',
#   '에스',
#   '세파',
#   '에스케이',
#   '케이',
#   '건조',
#   '건조시럽',
#   '시럽',
#   '제품하자',
#   '하자',
#   '하심신청방법'],
#  ['바세린',
#   '세린',
#   '립테라피',
#   '테라',
#   '오리지날',
#   '하필',
#   '손님',
#   '예약',
#   '클레임',
#   '저번',
#   '파손',
#   '파손건',
#   '곤란',
#   '곤란하다',
#   '하다',
#   '일단',
#   '출고해',
#   '보상'],
#  ['한올',
#   '한올노르믹스',
#   '믹스',
#   '바구니',
#   '코드매',
#   '팝업',
#   '팝업뜸',
#   '노르믹스',
#   '업무',
#   '업무정지',
#   '국내',
#   '국내생산',
#   '생산',
#   '수입품',
#   '확인요청약사',
#   '개명',
#   '면허증',
#   '면허증사등',
#   '팩스발송요청',
#   '시간소요',
#   '재고소진',
#   '소진',
#   '요청주심',
#   '주심',
#   '사명',
#   '주문가능',
#   '약가',
#   '약가인하',
#   '인하',
#   '예정임'],
#  ['반품신청시',
#   '불만',
#   '엑스',
#   '과립',
#   '가미',
#   '귀비탕',
#   '티제이',
#   '귀비탕반품',
#   '반품접수요청',
#   '제이',
#   '경안',
#   '경안신',
#   '쿠폰사용',
#   '판매부진',
#   '부진',
#   '접수요청',
#   '도매부외품',
#   '부외품',
#   '반품접수',
#   '해드림'],
#  ['천사', '천사약국정윤경', '정윤', '바세린', '세린', '립테라피', '테라', '오리지날', '출고해'],
#  ['약가',
#   '약가인하공지',
#   '인하',
#   '직전',
#   '개월',
#   '입건',
#   '자동',
#   '보상',
#   '보상안내',
#   '미수긍',
#   '수긍',
#   '대웅제약년월일',
#   '년월일',
#   '약가인하',
#   '보상안내관련',
#   '홈페이지',
#   '공지사항',
#   '사항',
#   '등록안내드림',
#   '한올',
#   '한올바이오',
#   '취소건',
#   '환불조치',
#   '조치'],
#  ['연질',
#   '연질캅셀',
#   '캅셀',
#   '문의확인후',
#   '재전화드림',
#   '현님',
#   '답변',
#   '답변은혜',
#   '은혜',
#   '구매내역',
#   '주문일자',
#   '월로',
#   '고함',
#   '한번',
#   '반송',
#   '함재',
#   '함재확인후',
#   '안내확인중',
#   '목요일',
#   '수님'],
#  ['가입관련', '배정여부', '본사'],
#  ['닥터',
#   '닥터체크',
#   '체크',
#   '이중',
#   '허리',
#   '허리벨트',
#   '벨트',
#   '메디',
#   '메디미',
#   '플러스',
#   '구매내역',
#   '신청되',
#   '청되',
#   '처리됬나',
#   '택배비',
#   '편도',
#   '편도비',
#   '처리됬음',
#   '일방적',
#   '처리해라',
#   '처리요청',
#   '운영',
#   '운영팀',
#   '확인중이',
#   '중이',
#   '메디미플러스건',
#   '저희',
#   '업체소통후',
#   '예외',
#   '원래',
#   '전산',
#   '전산자체',
#   '자체',
#   '반품쿠폰사용',
#   '여태',
#   '반품하면서',
#   '전산상',
#   '처리안해준거',
#   '안해',
#   '준거',
#   '처음',
#   '어깨',
#   '어깨교정벨트',
#   '교정',
#   '반품소통',
#   '나도',
#   '이거',
#   '했어도',
#   '어깨벨트',
#   '나중',
#   '쿠폰안',
#   '권한',
#   '쿠폰사용',
#   '본인권한',
#   '통해',
#   '쿠폰장',
#   '차감',
#   '차감후'],
#  ['국장',
#   '사망',
#   '환불요청',
#   '서류',
#   '서류가족관계증명서',
#   '가족',
#   '관계',
#   '증명서',
#   '자녀',
#   '사망신고서',
#   '신고서',
#   '발송안내',
#   '환불시점',
#   '시점',
#   '재안내'],
#  ['가입관련', '배정여부'],
#  ['파워', '임팩', '이플러스', '이플러스정', '특별공급관'],
#  ['비스', '비스정', '반품예정', '프린트', '고장', '회수확인서', '확인서', '팩스요청', '팩스발송완료'],
#  ['롯데', '미수', '미수신문', '신문', '텔코', '이슈', '발송지연', '발송예정'],
#  ['연질',
#   '연질캡슐',
#   '캡슐',
#   '약가',
#   '약가인하',
#   '인하',
#   '실물',
#   '실물반품신청문',
#   '마지막',
#   '입가',
#   '처리예정',
#   '계약',
#   '계약종료'],
#  ['크린', '품절문의', '예전', '메모', '정상', '주문가능'],
#  ['프로',
#   '프로연질캡슐외',
#   '연질',
#   '캡슐',
#   '폐업예정',
#   '반품신청문의',
#   '반품접수',
#   '대신',
#   '해드림',
#   '임박',
#   '임박사유',
#   '반품접수완료',
#   '폐업전',
#   '환급',
#   '환급요청시',
#   '문의안내드림',
#   '반품제한',
#   '제한',
#   '입이'],
#  ['경북', '경북약국채종태', '채종', '탑헬스케어미', '헬스', '케어', '직접'],
#  ['탑헬스케어미', '헬스', '케어'],
#  ['우리', '형석'],
#  ['한올',
#   '한올노르믹스',
#   '믹스',
#   '바구니',
#   '코드매',
#   '팝업',
#   '팝업뜸',
#   '노르믹스',
#   '업무',
#   '업무정지',
#   '국내',
#   '국내생산',
#   '생산',
#   '수입품',
#   '확인요청약사',
#   '개명',
#   '면허증',
#   '면허증사등',
#   '팩스발송요청',
#   '시간소요',
#   '재고소진',
#   '소진',
#   '요청주심',
#   '주심'],
#  ['조은', '조은약국', '박혜', '마이크로', '마이크로파인', '파인', '펜니들', '니들', '오배송', '교환요청'],
#  ['마이크로', '마이크로파인', '파인', '펜니들', '니들', '오배송', '교환요청'],
#  ['한올',
#   '바이오노르',
#   '믹스',
#   '믹스정리',
#   '정리',
#   '시민',
#   '월일',
#   '약가',
#   '약가인하',
#   '인하',
#   '대상',
#   '보상',
#   '보상방안',
#   '방안',
#   '한올측',
#   '차주',
#   '김수경님',
#   '수경',
#   '직전',
#   '개월',
#   '매출수량',
#   '금월',
#   '금월중',
#   '실물'],
#  ['마이너스잔고', '노출확인', '거래원장', '원장', '안내완료'],
#  ['한올',
#   '한올노르믹스',
#   '믹스',
#   '바구니',
#   '코드매',
#   '팝업',
#   '팝업뜸',
#   '노르믹스',
#   '업무',
#   '업무정지',
#   '국내',
#   '국내생산',
#   '생산',
#   '수입품'],
#  ['노르믹스정',
#   '믹스',
#   '한올',
#   '한올바이오',
#   '약가',
#   '약가인하',
#   '인하',
#   '보상',
#   '보상문의',
#   '재전화드림',
#   '수님',
#   '김수경님',
#   '수경',
#   '직전',
#   '개월',
#   '금월',
#   '금월중'],
#  ['사랑', '사랑약국', '김영준', '유진', '유진약품', '취소요청사유', '재고부족'],
#  ['다이아', '다이아벡스', '벡스', '입고문', '고문', '주문가능'],
#  ['다이아',
#   '다이아벡스',
#   '벡스',
#   '한올',
#   '한올전체',
#   '일부',
#   '다이아벡스',
#   '일정',
#   '정확',
#   '확인중임',
#   '중임',
#   '주문가능'],
#  ['다이아', '다이아벡스', '벡스', '품절문의', '확인부탁', '부탁', '주문가능'],
#  ['약국개설',
#   '개설',
#   '사업자상호명',
#   '상호명',
#   '신규',
#   '신규회원',
#   '카톡으',
#   '사업자등록증약사면허증',
#   '등록증',
#   '면허증',
#   '기존회원정보',
#   '재문의',
#   '주시',
#   '환불요청',
#   '수신내용',
#   '재통화양해드림'],
#  ['다이아', '다이아벡스', '벡스', '입고문', '고문', '입고', '재연락약속', '주문가능'],
#  ['다이아',
#   '다이아벡스엑스알',
#   '벡스',
#   '엑스',
#   '서방',
#   '서방정',
#   '정경진',
#   '경진',
#   '수량제한',
#   '제한',
#   '개로',
#   '염두',
#   '구입희망',
#   '지금',
#   '주문가능',
#   '고함'],
#  ['대웅바이오베',
#   '디핀에스정',
#   '에스',
#   '반품처리',
#   '확인문의',
#   '확인중',
#   '시간양해드림',
#   '금일중',
#   '대전',
#   '확인시',
#   '함약국'],
#  ['정밀',
#   '정밀리그램',
#   '리그',
#   '오르',
#   '다라',
#   '다라필',
#   '낱알',
#   '거래명세서',
#   '명세서',
#   '짜증',
#   '짜증불만제기',
#   '불만',
#   '제기',
#   '이혜',
#   '이혜주',
#   '환산',
#   '표시',
#   '표시됬음안내'],
#  ['라니티딘',
#   '라니티딘반품',
#   '신청문의',
#   '도매상',
#   '샵페이지',
#   '대웅바이오',
#   '라비',
#   '라비수정',
#   '낱알',
#   '청해',
#   '청해드림',
#   '모두',
#   '회수확인서',
#   '확인서',
#   '작성',
#   '각각',
#   '박스동봉',
#   '동봉',
#   '고안',
#   '고안내'],
#  ['영남',
#   '영남백제약품',
#   '약정',
#   '전용관내',
#   '관내',
#   '최저가',
#   '최저가보상',
#   '보상',
#   '함급여매출',
#   '급여',
#   '통합검색',
#   '크롬',
#   '쿠키',
#   '쿠키삭제방법'],
#  ['다이아',
#   '다이아벡스엑스알',
#   '벡스',
#   '엑스',
#   '서방',
#   '서방정',
#   '품절문의',
#   '계획',
#   '월일',
#   '월일다이아벡스엑스',
#   '알서방정',
#   '품절해지',
#   '해지',
#   '문자발송',
#   '선생님',
#   '약국부재',
#   '문자보',
#   '자보',
#   '감사'],
#  ['노르믹스정',
#   '믹스',
#   '한올',
#   '한올바이오',
#   '약가',
#   '약가인하',
#   '인하',
#   '보상',
#   '보상문의',
#   '재전화드림',
#   '지금',
#   '주문시',
#   '바구니',
#   '담기',
#   '참고'],
#  ['다이아', '다이아벡스엑스알', '벡스', '엑스', '서방', '서방정'],
#  ['소액',
#   '소액처',
#   '월부족금액',
#   '유도',
#   '유도처',
#   '아웃',
#   '바운드',
#   '바운드통화',
#   '건역대급이벤트',
#   '신청문의',
#   '집계',
#   '부외품',
#   '부외품쿠폰만원',
#   '제공',
#   '제공예정',
#   '월초',
#   '월초확인안내드림'],
#  ['안산', '안산백제약품김', '페이몰', '픽스', '픽스정', '연동'],
#  ['한올',
#   '보류',
#   '제조판매',
#   '누군가',
#   '책임',
#   '당장',
#   '하라',
#   '클레임',
#   '클레임제기',
#   '제기',
#   '책임자',
#   '연락하라'],
#  ['근처', '병원', '준거', '사용방법', '호환', '불가함', '처리해라', '비타민', '라도', '연락요청주심', '주심'],
#  ['한올',
#   '바이오노르',
#   '믹스',
#   '믹스정리',
#   '정리',
#   '시민',
#   '월일',
#   '약가',
#   '약가인하',
#   '인하',
#   '대상',
#   '보상',
#   '보상방안',
#   '방안',
#   '한올측',
#   '차주'],
#  ['대전',
#   '연질',
#   '연질캡슐',
#   '캡슐',
#   '약가',
#   '약가인하',
#   '인하',
#   '월말',
#   '반품완료',
#   '상품구매',
#   '처방',
#   '구매계획',
#   '계획'],
#  ['한올', '보류', '제조판매'],
#  ['누리', '필름', '필름밀리그램', '밀리그램', '공급가문', '가문', '누리그라정', '리그'],
#  ['문의알레', '언제', '확인어려움'],
#  ['다이아', '다이아벡스엑스알', '벡스', '엑스', '서방', '서방정'],
#  ['안산', '안산백제약국김은기팜페이몰', '김은기팜페이몰', '픽스', '픽스정', '반영'],
#  ['패드', '결제중', '안됨', '대웅세비카', '세비', '바구니', '삼성', '삼성개월', '개월', '대신', '대신결제요청'],
#  ['한올', '보류', '제조판매', '취소하라', '하라'],
#  ['역대급', '신청방법문의', '경로'],
#  ['한올', '보류', '제조판매', '알파', '본연', '본연질캡슐', '캡슐', '알파칼시돌', '취소하라', '하라'],
#  ['주영',
#   '주영호담당자',
#   '전화요청',
#   '전화드림',
#   '환불요청',
#   '대웅바이오',
#   '마이너스잔고',
#   '환불접수',
#   '주안',
#   '안내팩스',
#   '수신확인',
#   '완료예정',
#   '사업자등록증',
#   '등록증',
#   '첨부',
#   '첨부안'],
#  ['기분', '약국안지', '안지', '임팩', '프리미엄', '캡슐', '연락주기', '주기', '함김정', '안내김정', '전달완료'],
#  ['삼원',
#   '약국정',
#   '하연',
#   '거점등록요청',
#   '통합처',
#   '코드이관',
#   '영업사원본사',
#   '본사',
#   '배정여부',
#   '본사관리',
#   '거점상품등록요청',
#   '하루',
#   '하루정도',
#   '문치',
#   '문치호님',
#   '기안',
#   '기안상신',
#   '상신',
#   '소장',
#   '승인요청'],
#  ['구름',
#   '구름약국신유진',
#   '유진',
#   '헬스',
#   '헬스인',
#   '뽀로',
#   '황사',
#   '황사방역용마스크',
#   '방역',
#   '마스크',
#   '소형',
#   '개타',
#   '황사마스크',
#   '소형세미',
#   '세미',
#   '개미',
#   '개미배송문의',
#   '넥스',
#   '넥스케어',
#   '케어',
#   '방수',
#   '방수밴드투명',
#   '밴드',
#   '투명',
#   '일반',
#   '일반형',
#   '모두',
#   '중형',
#   '제품오배송',
#   '직접'],
#  ['클렌징', '클렌징오일제품', '오일', '직접', '제약사', '제약사상품', '확인안내드림'],
#  ['기분', '약국안지', '안지', '임팩', '프리미엄', '캡슐', '연락주기', '주기'],
#  ['대웅오산내일', '오전중', '배송요청주심', '주심', '시시안', '시안', '스마일', '스마일로지', '로지'],
#  ['패밀리', '길자', '대웅반품'],
#  ['로타리', '로타리약국', '김호길', '웅지', '웅지오', '취소요청사유', '중복', '중복주문'],
#  ['말일',
#   '말일자로',
#   '자로',
#   '마트내약국',
#   '지금',
#   '오전중',
#   '고객센터',
#   '센터',
#   '진행요청',
#   '차주',
#   '월화',
#   '회수요청',
#   '약국회수',
#   '직접',
#   '보건소',
#   '폐업일자',
#   '언제쯤',
#   '하면',
#   '환불가능',
#   '세금계산서',
#   '발행문제',
#   '문제',
#   '보건소처리',
#   '최대',
#   '여유',
#   '중순'],
#  ['시네',
#   '시네츄라시럽',
#   '라시',
#   '오영영남',
#   '영남',
#   '약가',
#   '약가인하',
#   '인하',
#   '청해',
#   '청해드림',
#   '최대',
#   '안내드림정',
#   '통화건어',
#   '건어',
#   '통화시',
#   '회수기사님',
#   '미회수',
#   '약가인',
#   '가인',
#   '일안',
#   '선생님',
#   '회수접수',
#   '방문예정',
#   '감사',
#   '유미',
#   '유미선님',
#   '상담',
#   '재인',
#   '재인입',
#   '한번',
#   '전달드림약속',
#   '약가인하반품건',
#   '하반',
#   '방문확인완료'],
#  ['이형',
#   '이형복',
#   '반품가능',
#   '크레산트',
#   '크레산트정개',
#   '정개',
#   '젠트',
#   '젠트점안액',
#   '점안',
#   '반품접수',
#   '회수요청완료'],
#  ['구름',
#   '구름약국신유진',
#   '유진',
#   '헬스',
#   '헬스인',
#   '뽀로',
#   '황사',
#   '황사방역용마스크',
#   '방역',
#   '마스크',
#   '소형',
#   '개타',
#   '황사마스크',
#   '소형세미',
#   '세미',
#   '개미',
#   '개미배송문의',
#   '넥스',
#   '넥스케어',
#   '케어',
#   '방수',
#   '방수밴드투명',
#   '밴드',
#   '투명',
#   '일반',
#   '일반형',
#   '모두',
#   '중형',
#   '제품오배송'],
#  ['헬스',
#   '헬스인',
#   '뽀로',
#   '황사',
#   '황사방역용마스크',
#   '방역',
#   '마스크',
#   '소형',
#   '개타',
#   '황사마스크',
#   '소형세미',
#   '세미',
#   '개미',
#   '개미배송문의',
#   '넥스',
#   '넥스케어',
#   '케어',
#   '방수',
#   '방수밴드투명',
#   '밴드',
#   '투명',
#   '일반',
#   '일반형',
#   '모두',
#   '중형',
#   '제품오배송'],
#  ['주영',
#   '주영호담당자',
#   '전화요청',
#   '전화드림',
#   '환불요청',
#   '대웅바이오',
#   '마이너스잔고',
#   '환불접수',
#   '주안',
#   '안내팩스'],
#  ['약국백선영', '백선', '문의약국', '전화요청'],
#  ['소액',
#   '소액처',
#   '월부족금액',
#   '유도',
#   '유도처안내',
#   '이주',
#   '부족금액',
#   '안내함구',
#   '함구',
#   '도달',
#   '도달하심'],
#  ['반품쿠폰', '반품비', '무료'],
#  ['안산', '안산백제약품김', '페이몰', '픽스', '픽스정', '연동', '체크'],
#  ['모바렌', '구매요청', '사이트', '안보임', '보임', '거점등록완료', '확인안내', '프로'],
#  ['당일',
#   '당일반품신청',
#   '보령',
#   '구강',
#   '구강청결',
#   '청결',
#   '멸균',
#   '멸균티슈',
#   '티슈',
#   '제품하자',
#   '하자',
#   '두시',
#   '회수기사',
#   '회수예정',
#   '완료후',
#   '적립예정임'],
#  ['대웅복산주문건', '산주', '복산약품', '배송완료'],
#  ['안산',
#   '안산백제약국김은기팜페이몰',
#   '김은기팜페이몰',
#   '픽스',
#   '픽스정',
#   '오등록',
#   '약국이형',
#   '이형',
#   '나머지',
#   '크레산트',
#   '크레산트정',
#   '정개',
#   '옵타젠트',
#   '옵타젠트점안액',
#   '점안',
#   '가능여부',
#   '연락주기',
#   '주기'],
#  ['모바렌', '구매요청', '사이트', '안보'],
#  ['복산나이스',
#   '나이스',
#   '예치금적립',
#   '문의릴렉스정',
#   '스정',
#   '근육',
#   '완제',
#   '라라',
#   '프라믹',
#   '연고',
#   '연고튜브',
#   '튜브',
#   '재전화드림',
#   '복산',
#   '부산',
#   '부산지점',
#   '부산지점해당약국',
#   '전체적',
#   '한번',
#   '시간양해요청',
#   '업체라',
#   '예치금처리',
#   '주신다'],
#  ['샵마일리지', '패밀리', '패밀리존', '생활기', '생활기프트콘', '프트', '부외품', '부외품반품쿠폰신청', '방법안내드림'],
#  ['라니티딘',
#   '라니티딘반품',
#   '신청문의',
#   '도매상',
#   '샵페이지',
#   '대웅바이오',
#   '라비',
#   '라비수정',
#   '낱알',
#   '청해',
#   '청해드림',
#   '모두',
#   '회수확인서',
#   '확인서',
#   '작성',
#   '각각',
#   '동봉',
#   '고안',
#   '내해',
#   '나중',
#   '연락하라',
#   '하라'],
#  ['복산나이스',
#   '나이스',
#   '예치금적립',
#   '문의릴렉스정',
#   '스정',
#   '근육',
#   '완제',
#   '라라',
#   '프라믹',
#   '연고',
#   '연고튜브',
#   '튜브',
#   '해당약국',
#   '전체적',
#   '한번',
#   '시간양해요청'],
#  ['임팩', '프리미엄', '파워', '파워정', '오배송문의', '파워정정', '정정', '오주문하심'],
#  ['복산나이스',
#   '나이스',
#   '예치금적립',
#   '문의릴렉스정',
#   '스정',
#   '근육',
#   '완제',
#   '라라',
#   '프라믹',
#   '연고',
#   '연고튜브',
#   '튜브',
#   '재전화드림'],
#  ['천희', '물류'],
#  ['사은품',
#   '신청문의',
#   '파리',
#   '파리바게트',
#   '바게트',
#   '기프티콘',
#   '구매금액',
#   '청해',
#   '청해드림',
#   '스타',
#   '스타벅스',
#   '벅스',
#   '카페'],
#  ['전체취소요청', '추가품목', '신청예정', '신청상태', '취소처리완료'],
#  ['예치금마이너스', '잔고환불요청', '차주', '금요일', '환불안', '불안'],
#  ['프로', '문의대웅', '중간', '검색창이', '창이', '거기', '입력후', '시리즈', '정상'],
#  ['태전',
#   '태전약품해소민',
#   '해소',
#   '캡슐',
#   '안내개',
#   '취소후',
#   '재주',
#   '재주문요청',
#   '재주문',
#   '주시',
#   '주시길'],
#  ['제민', '제민회보약국윤', '회보', '태준', '태전', '태전약품해소민', '해소', '캡슐', '출하'],
#  ['대웅오산내일', '오전중', '배송요청주심', '주심'],
#  ['영님'],
#  ['대림',
#   '대림약국',
#   '새부산약국',
#   '부산',
#   '가입안내사업자',
#   '환불요청환불',
#   '시이후',
#   '환불예정폐업일자',
#   '이달',
#   '이달말'],
#  ['제민', '제민회보약국윤', '회보', '태준', '태전', '태전약품해소민', '해소', '캡슐', '창고'],
#  ['약가', '약가인하', '인하', '공지사항', '사항', '등록시', '대웅제약관련'],
#  ['헬스',
#   '헬스인',
#   '상아',
#   '상아전자',
#   '전자',
#   '조은',
#   '맥반석',
#   '황토',
#   '황토찜질기분',
#   '찜질',
#   '기분',
#   '자동',
#   '자동타이머기능',
#   '타이머',
#   '기능',
#   '개중',
#   '반품요청',
#   '온도',
#   '레버',
#   '레버불량확인후',
#   '불량',
#   '재전화드림',
#   '제품하자',
#   '하자',
#   '청하',
#   '인터넷'],
#  ['햇님',
#   '햇님약국',
#   '이종량',
#   '종량',
#   '헬스',
#   '헬스인',
#   '상아',
#   '상아전자',
#   '전자',
#   '조은',
#   '맥반석',
#   '황토',
#   '황토찜질기분',
#   '찜질',
#   '기분',
#   '자동',
#   '자동타이머기능',
#   '타이머',
#   '기능',
#   '개중',
#   '반품요청',
#   '온도',
#   '레버',
#   '레버불량제품하자',
#   '불량',
#   '하자',
#   '청하'],
#  ['헬스',
#   '헬스인',
#   '상아',
#   '상아전자',
#   '전자',
#   '조은',
#   '맥반석',
#   '황토',
#   '황토찜질기분',
#   '찜질',
#   '기분',
#   '자동',
#   '자동타이머기능',
#   '타이머',
#   '기능',
#   '개중',
#   '반품요청',
#   '온도',
#   '레버',
#   '레버불량확인후',
#   '불량',
#   '재전화드림'],
#  ['실비', '발송요청', '팩스오류남', '재발', '재발송', '요청드리고', '드리고', '연락확인', '전화드림'],
#  ['한올',
#   '바이오노르',
#   '믹스',
#   '믹스정리',
#   '정리',
#   '시민',
#   '월일',
#   '약가',
#   '약가인하',
#   '인하',
#   '대상',
#   '보상',
#   '보상방안',
#   '방안'],
#  ['경남', '경남약국', '정회', '정회철', '대웅복산주문건', '산주'],
#  ['태창', '태창약국김애', '임팩케어', '케어', '보임', '소분', '소분분배', '분배', '품절임', '절임', '직접'],
#  ['실비', '발송요청', '팩스오류남', '재발', '재발송요청', '요청드리고', '드리고'],
#  ['마이너스잔고', '원격', '숫자', '숫자입력', '고침', '고침후', '정상', '정상입력'],
#  ['럭시',
#   '주문시',
#   '카드일시불',
#   '일시불',
#   '결제창',
#   '로딩',
#   '쇼핑몰',
#   '정상',
#   '정상결제',
#   '결제문의',
#   '처음',
#   '화면',
#   '캡처',
#   '전달주시',
#   '주시',
#   '재연락약속',
#   '유미',
#   '유미선',
#   '개인',
#   '개인전화',
#   '개발',
#   '개발팀',
#   '확인결과',
#   '결과',
#   '삼성',
#   '삼성브라우저',
#   '브라우저',
#   '대신',
#   '동일',
#   '기계',
#   '시도',
#   '소요예정',
#   '결제건',
#   '우선',
#   '해주시길',
#   '양해드림'],
#  ['부일',
#   '약국송',
#   '열호',
#   '열호님',
#   '향정',
#   '허은성담당자',
#   '은성',
#   '부재고',
#   '문의드림',
#   '휴가',
#   '정상',
#   '정상업무중',
#   '업무'],
#  ['임팩', '프리미엄', '정정개대웅제약', '정개', '주문전', '문의상품', '바구니', '오후시전', '시전'],
#  ['도매부외품', '부외품', '반품신청방법문', '직접', '쿠폰적용', '경로', '경로안내드림'],
#  ['시네',
#   '시네츄라시럽',
#   '라시',
#   '오영영남',
#   '영남',
#   '약가',
#   '약가인하',
#   '인하',
#   '청해',
#   '청해드림',
#   '최대',
#   '안내드림정',
#   '통화건어',
#   '건어',
#   '통화시',
#   '회수기사님',
#   '미회수',
#   '약가인',
#   '가인',
#   '일안',
#   '선생님',
#   '회수접수',
#   '방문예정',
#   '감사',
#   '유미',
#   '유미선님',
#   '상담',
#   '재인',
#   '재인입',
#   '한번',
#   '전달드림약속'],
#  ['태전', '태전약품해소민', '해소', '캡슐'],
#  ['가입신청',
#   '샵프렌즈',
#   '렌즈',
#   '서류',
#   '문의카카오톡에',
#   '카카오',
#   '톡에',
#   '친구',
#   '친구추가',
#   '사업자등록증',
#   '등록증',
#   '약사면허증',
#   '면허증',
#   '가입승인'],
#  ['가입신청',
#   '샵프렌즈',
#   '렌즈',
#   '서류',
#   '문의카카오톡에',
#   '카카오',
#   '톡에',
#   '친구',
#   '친구추가',
#   '사업자등록증',
#   '등록증',
#   '약사면허증',
#   '면허증'],
#  ['시네',
#   '시네츄라시럽',
#   '라시',
#   '오영영남',
#   '영남',
#   '약가',
#   '약가인하',
#   '인하',
#   '청해',
#   '청해드림',
#   '최대',
#   '안내드림정',
#   '통화건어',
#   '건어',
#   '통화시',
#   '회수기사님',
#   '미회수',
#   '약가인',
#   '가인',
#   '일안',
#   '선생님',
#   '회수접수',
#   '방문예정',
#   '감사'],
#  ['상호', '상호가입자명', '가입자', '단선'],
#  ['대웅제약상품', '마이너스잔고', '최대', '최대일'],
#  ['라니티딘',
#   '라니티딘반품',
#   '신청문의',
#   '도매상',
#   '샵페이지',
#   '대웅바이오',
#   '라비',
#   '라비수정',
#   '낱알',
#   '청해',
#   '청해드림',
#   '모두',
#   '회수확인서',
#   '확인서',
#   '작성',
#   '각각',
#   '동봉',
#   '고안',
#   '내해'],
#  ['소액',
#   '소액처',
#   '월부족금액',
#   '유도',
#   '유도처',
#   '파리',
#   '파리바게트',
#   '바게트',
#   '청해',
#   '청해드림',
#   '만유',
#   '어디',
#   '얼마',
#   '재확인',
#   '우측',
#   '우측상단',
#   '상단',
#   '만원정도',
#   '추가구매',
#   '부외품',
#   '부외품쿠폰',
#   '추가발급예정'],
#  ['석초약국', '디핀에스정', '에스', '반품처리', '확인문의'],
#  ['우리',
#   '수정구매',
#   '시네',
#   '시네츄라시럽',
#   '라시',
#   '오영영남',
#   '영남',
#   '약가',
#   '약가인하',
#   '인하',
#   '청해',
#   '청해드림',
#   '최대',
#   '안내드림정',
#   '통화건어',
#   '건어',
#   '통화시',
#   '회수기사님',
#   '미회수',
#   '약가인',
#   '가인',
#   '일안'],
#  ['역대급이벤트', '신청요청', '죠스떡볶', '세트', '청해', '청해드림'],
#  ['패밀리',
#   '패밀리존',
#   '통해',
#   '현대',
#   '현대상품권',
#   '일전',
#   '재발송',
#   '미수신',
#   '재발송완료',
#   '발송번호',
#   '스팸',
#   '차단',
#   '요청드림',
#   '대비',
#   '선생님',
#   '핸드폰번호',
#   '지금',
#   '재발',
#   '카페',
#   '아메리카',
#   '아메리카노',
#   '기프티콘',
#   '기억',
#   '현대상품권커피',
#   '커피',
#   '기프티콘'],
#  ['월전용관', '역대급', '신청건', '발송문의', '신청발송', '차주', '수요일', '익월', '발송예정임'],
#  ['시네',
#   '시네츄라시럽',
#   '라시',
#   '오영영남',
#   '영남',
#   '약가',
#   '약가인하',
#   '인하',
#   '청해',
#   '청해드림',
#   '최대',
#   '안내드림정',
#   '통화건어',
#   '건어',
#   '통화시',
#   '회수기사님',
#   '미회수',
#   '약가인',
#   '가인',
#   '일안'],
#  ['태창', '태창약국김애', '임팩케어', '케어', '보임'],
#  ['포주', '대학당', '포주문', '문의등록', '휴대폰', '휴대폰번호', '변경해드림', '변경완료'],
#  ['한우', '최현철임', '현철', '민케어', '케어'],
#  ['임팩케어', '케어', '보임'],
#  ['이천', '대웅대전', '대전', '미배송문의'],
#  ['인천수요양병원',
#   '수요',
#   '병원',
#   '과산화',
#   '과산화수소',
#   '수소',
#   '소독',
#   '에탄올',
#   '에탄올알콜',
#   '알콜',
#   '개가'],
#  ['연락주신'],
#  [],
#  [],
#  ['처리문의', '잔고처리완료', '거래원장', '원장', '확인가능', '환불요청', '오후시이후', '환불예정'],
#  ['경남', '경남약국', '정회', '정회철', '대웅복산주문건', '산주'],
#  ['정문', '혜림', '에프', '정문약국김', '새살', '새살연고', '연고', '처방', '거점등록'],
#  ['업원',
#   '서울약',
#   '러캅셀',
#   '캅셀',
#   '세파',
#   '러관병',
#   '관병',
#   '개자모',
#   '자모',
#   '재전화드림',
#   '서울약업취소',
#   '전체취소'],
#  ['남영',
#   '남영약국',
#   '김숙',
#   '김숙귀',
#   '업원',
#   '서울약',
#   '러캅셀',
#   '캅셀',
#   '세파',
#   '러관병',
#   '관병',
#   '개자모',
#   '자모',
#   '취소가능',
#   '전체취소'],
#  ['하기',
#   '미처리',
#   '메디',
#   '팜유',
#   '팜유일약국',
#   '일약',
#   '선애반품',
#   '스티렌',
#   '스티렌정',
#   '인화',
#   '인화당약국',
#   '우숙',
#   '우숙반품',
#   '테시움정',
#   '연락주기',
#   '주기'],
#  ['업원', '서울약', '러캅셀', '캅셀', '세파', '러관병', '관병', '개자모', '자모', '재전화드림'],
#  ['확인방법문의', '거래원장', '원장', '확인방법', '안내완료'],
#  ['테시움정', '보덕', '보덕메디', '메디', '미처리'],
#  ['다정',
#   '다정약국',
#   '유혜',
#   '유혜옥',
#   '성심',
#   '일회용',
#   '일회용주사기',
#   '주사기',
#   '반품쿠폰사용',
#   '헬스',
#   '헬스인',
#   '변심',
#   '변심반품',
#   '쿠폰사용',
#   '회수접수요청',
#   '회수접수완료'],
#  ['구매시', '사은품', '주차', '모바일', '발송예정'],
#  ['노르믹스정리',
#   '믹스',
#   '정리',
#   '시민',
#   '한올',
#   '한올바이오파마',
#   '파마',
#   '확인중',
#   '담당',
#   '담당부서',
#   '부서',
#   '확인가능예상',
#   '예상',
#   '주문가능',
#   '주문가능시점약국',
#   '시점',
#   '주문가능안내완료'],
#  ['성심',
#   '일회용',
#   '일회용주사기',
#   '주사기',
#   '반품쿠폰사용',
#   '헬스',
#   '헬스인',
#   '변심',
#   '변심반품',
#   '쿠폰사용',
#   '회수접수요청'],
#  ['공동', '공동구매', '제이', '취소요청사유'],
#  ['약품새',
#   '동신',
#   '동신약국',
#   '고정숙후콘',
#   '정숙',
#   '투락투벡스겔',
#   '벡스겔',
#   '인천약품',
#   '도매몰',
#   '매몰',
#   '입이력',
#   '문의인천약품',
#   '사입이',
#   '입이'],
#  ['약국개설',
#   '개설',
#   '사업자상호명',
#   '상호명',
#   '신규',
#   '신규회원',
#   '카톡으',
#   '사업자등록증약사면허증',
#   '등록증',
#   '면허증',
#   '기존회원정보',
#   '예치금문의',
#   '문의주시',
#   '주시',
#   '환불요청',
#   '가능안내드림'],
#  ['반품쿠폰'],
#  ['변경요청', '팩스요청', '완료전', '주문어려움', '변경완료'],
#  ['광주',
#   '광주약국',
#   '재개',
#   '재개업',
#   '사업자번호',
#   '신세계',
#   '신세계백화점',
#   '백화점',
#   '스타',
#   '스타벅스',
#   '벅스',
#   '카페'],
#  ['정명',
#   '원포',
#   '임신',
#   '정명약국',
#   '테스트',
#   '테스트기',
#   '도매부외품업체',
#   '부외품',
#   '복산나이스',
#   '나이스',
#   '반품기한',
#   '개월',
#   '최대',
#   '내년',
#   '내년월'],
#  ['월부', '약가', '약가인하', '인하', '대웅제품', '사입이', '입이', '인하가로', '가로'],
#  ['탑헬스케어', '헬스', '케어', '배송지연금일', '배송안됨', '안됨', '인수거부', '무상', '수취', '수취거부요청'],
#  ['성모',
#   '중약국',
#   '탑헬스케어',
#   '헬스',
#   '케어',
#   '배송지연금일',
#   '배송안됨',
#   '안됨',
#   '인수거부',
#   '무상',
#   '수취',
#   '수취거부요청'],
#  ['탑헬스케어', '헬스', '케어', '배송지연금일', '배송안됨', '안됨', '인수거부', '무상'],
#  ['주문번호', '선택', '하단', '인쇄'],
#  ['주문완료', '서울약사신협', '신협', '입금계좌번호문', '직접', '국민은행', '은행'],
#  ['구매시', '채널매', '확정', '주문가능', '주문가능시점', '시점', '채널확장', '확장', '안민정님', '구매안내완료'],
#  ['구매금액',
#   '마이',
#   '마이페이지',
#   '공급사별',
#   '사별',
#   '주문조회',
#   '통해',
#   '안내드림김정',
#   '통화건위내용',
#   '건위',
#   '문의대웅전',
#   '대웅전',
#   '관역대급',
#   '마트상품권',
#   '선택',
#   '혜택선택',
#   '이마트상품권',
#   '신청완료만원이상',
#   '구매시',
#   '매일',
#   '매일이벤트'],
#  ['역대급', '문자안옴', '재발송요청', '수신확인완료'],
#  ['김혜경여월', '여월', '급이벤트', '이마트상품권', '문자안옴', '재발송요청', '재발', '재발송완료'],
#  ['월역대급이벤트', '이마트상품권', '문자안옴', '재발송요청', '재발'],
#  ['다이아',
#   '다이아벡스',
#   '벡스',
#   '문의품절안내',
#   '예정임',
#   '문의확인후',
#   '재전화드림',
#   '현님',
#   '답변',
#   '답변다이아벡',
#   '중이',
#   '저녁',
#   '입고시',
#   '고시',
#   '중미',
#   '중미여'],
#  ['소액',
#   '소액처',
#   '부족금액',
#   '유도',
#   '유도처',
#   '안내파리바게뜨',
#   '파리',
#   '게뜨',
#   '교환권',
#   '미애님',
#   '통화건상품권',
#   '종료후',
#   '초중순',
#   '중순'],
#  ['웅지', '웅지오'],
#  ['타약',
#   '타약국정명진',
#   '국정',
#   '명진',
#   '창원',
#   '키나',
#   '백제코메',
#   '캡슐',
#   '캡슐캡슐',
#   '약사님',
#   '수취',
#   '수취거절',
#   '거절',
#   '창원백제',
#   '예전',
#   '인수거절',
#   '주문취소',
#   '자료',
#   '임인숙님',
#   '인숙',
#   '당일',
#   '휴무',
#   '대체',
#   '대체자',
#   '안민정',
#   '안내통화',
#   '전화부탁드림',
#   '부탁',
#   '안민정님',
#   '확인해보',
#   '해보',
#   '재전화드림',
#   '사진',
#   '영업관리팀',
#   '수거래명세표',
#   '하심임인숙님',
#   '환입등록',
#   '회신후',
#   '환입오더',
#   '오더',
#   '소통후',
#   '확정',
#   '확정처리'],
#  ['구매시', '채널매', '확정', '주문가능', '주문가능시점', '시점'],
#  ['회원가입', '언제쯤'],
#  ['약가',
#   '약가인하',
#   '인하',
#   '보상',
#   '보상관련',
#   '약가인하일',
#   '가인',
#   '하일',
#   '직전',
#   '개월',
#   '자동',
#   '실물',
#   '최근',
#   '입가',
#   '단가',
#   '재주',
#   '재주문',
#   '연락주시',
#   '주시',
#   '입가대'],
#  ['다이아', '다이아벡스', '벡스', '문의품절안내', '예정임', '문의확인후', '재전화드림'],
#  ['마이너스잔고', '사용문의장바구니', '의장', '바구니', '주문시', '사용금액'],
#  ['반품거래명세서',
#   '명세서',
#   '메일요청',
#   '정밀',
#   '정밀리그램',
#   '리그',
#   '오르',
#   '다라',
#   '다라필',
#   '낱알',
#   '필름',
#   '밀리그램',
#   '매매',
#   '완제품',
#   '완제품서울',
#   '실비',
#   '이메일',
#   '점심시간',
#   '관계',
#   '시전',
#   '환입실과',
#   '실과',
#   '반품거래명세표',
#   '요청드림',
#   '안녕',
#   '안녕하세',
#   '하세',
#   '이혜',
#   '이혜주입',
#   '주입',
#   '입실',
#   '스캔',
#   '스캔기',
#   '고장',
#   '송부',
#   '팩스번호',
#   '주세',
#   '전화드림',
#   '환입실전달서울',
#   '김중흠',
#   '통화완료',
#   '송부하',
#   '부하',
#   '수고'],
#  ['구매금액', '마이', '마이페이지', '공급사별', '사별', '주문조회', '통해'],
#  ['정명',
#   '원포',
#   '임신',
#   '정명약국',
#   '테스트',
#   '테스트기',
#   '도매부외품업체',
#   '부외품',
#   '복산나이스',
#   '나이스',
#   '반품기한',
#   '개월',
#   '최대'],
#  ['노르믹스정리',
#   '믹스',
#   '정리',
#   '시민',
#   '한올',
#   '한올바이오파마',
#   '파마',
#   '확인중',
#   '담당',
#   '담당부서',
#   '부서',
#   '확인가능예상',
#   '예상',
#   '주문가능',
#   '주문가능시점약국',
#   '시점'],
#  ['패밀리',
#   '패밀리존',
#   '통해',
#   '현대',
#   '현대상품권',
#   '일전',
#   '재발송',
#   '미수신',
#   '재발송완료',
#   '발송번호',
#   '스팸',
#   '차단',
#   '요청드림',
#   '대비',
#   '선생님',
#   '핸드폰번호',
#   '지금',
#   '재발',
#   '카페',
#   '아메리카',
#   '아메리카노',
#   '기프티콘',
#   '기억',
#   '현대상품권커피',
#   '커피',
#   '기프티콘'],
#  ['배송지연문의', '지오', '담당', '배송기사님'],
#  ['태전', '태전약품', '변경요청누리그', '리그', '라정', '개실물', '실물', '고함'],
#  ['구남약국',
#   '지영',
#   '내츄럴플러스',
#   '츄럴',
#   '플러스',
#   '오메가',
#   '울트라',
#   '울트라맥스',
#   '맥스',
#   '장용성',
#   '용성',
#   '캡슐',
#   '개가',
#   '오배송',
#   '차주'],
#  ['황사',
#   '황사마스크',
#   '마스크',
#   '주문시도시',
#   '도시',
#   '안됨',
#   '안됨대웅제품',
#   '구매시도안내',
#   '시도',
#   '결제확인',
#   '상담',
#   '상담완료'],
#  ['주문도'],
#  ['누리그라정', '리그', '착오', '주문상태값', '배송중', '표기', '반품시', '신청방법'],
#  ['노르믹스정리',
#   '믹스',
#   '정리',
#   '시민',
#   '한올',
#   '한올바이오파마',
#   '파마',
#   '오더',
#   '오더유형',
#   '유형',
#   '팝업',
#   '팝업창',
#   '오류팝업'],
#  ['듀아비브정',
#   '아비',
#   '브정',
#   '특가',
#   '아이콘',
#   '색인',
#   '안내드림다이아벡스',
#   '다이아',
#   '벡스',
#   '엑스',
#   '엑스알',
#   '입고시',
#   '고시'],
#  ['원당',
#   '원당약국',
#   '조태원',
#   '태원',
#   '메디',
#   '메디미플러스발송',
#   '플러스',
#   '발송준비중',
#   '준비',
#   '주문서',
#   '변경요청',
#   '변경완료',
#   '해드림'],
#  [],
#  ['배송지연문의', '용마', '배송건', '분류', '과정', '고함', '대약', '시예정', '약국통화'],
#  ['버튼', '버튼문의', '배송관련', '대웅배송시간문', '주문시', '금일저녁', '저녁', '냉장', '냉장제외', '제외'],
#  ['크린', '크린크림', '크림', '입고시', '고시', '재안내'],
#  ['하늘', '하늘샘약국', '젠가드캡슐캡슐', '가드', '캡슐', '삭제요청', '회신예정'],
#  ['연질',
#   '연질캡슐',
#   '캡슐',
#   '월일자',
#   '약가',
#   '약가인하',
#   '인하',
#   '실물',
#   '처리문의직전',
#   '직전',
#   '개월',
#   '실물반품',
#   '연락주시',
#   '주시',
#   '입가',
#   '인하전단가',
#   '단가',
#   '처리요청'],
#  ['한올', '바이오탑디캡슐', '캡슐', '인증', '개월간', '월간', '판매유통', '금지'],
#  ['노르믹스정리', '믹스', '정리', '시민', '한올', '한올바이오파마', '파마'],
#  ['다이아', '다이아벡스엑스알', '벡스', '엑스', '서방', '서방정'],
#  ['기획',
#   '노즈',
#   '노즈큐',
#   '코세정',
#   '세정',
#   '리필',
#   '분말',
#   '분말코',
#   '세척',
#   '세척포',
#   '소독',
#   '소독파우더',
#   '파우더',
#   '포함',
#   '기획노즈큐',
#   '세척노즈큐',
#   '코세척기',
#   '세척기',
#   '천연',
#   '천연소독파우더코',
#   '바구니',
#   '담아드',
#   '아드',
#   '반품쿠폰',
#   '청해',
#   '청해드림'],
#  ['노르믹스정리',
#   '믹스',
#   '정리',
#   '시민',
#   '한올',
#   '한올바이오파마',
#   '파마',
#   '오더',
#   '오더유형',
#   '유형',
#   '팝업',
#   '팝업창'],
#  ['품절문의'],
#  ['예치금선구매'],
#  ['배송지연문의'],
#  ['다이아', '다이아벡스엑스알', '벡스', '엑스', '서방', '서방정'],
#  ['가입관련', '배정문의'],
#  ['이브', '해지', '주문하', '문하'],
#  ['이브',
#   '라더',
#   '보이',
#   '보이냐며',
#   '냐며',
#   '지금',
#   '고객센터',
#   '센터',
#   '바구니',
#   '전용관이벤트',
#   '추가구매',
#   '자동',
#   '자동발급'],
#  ['오산거점', '취소요청취소완료'],
#  ['임팩프리미엄', '프리미엄'],
#  ['수현', '온누리', '온누리약국', '선알레', '입고문', '고문', '입고', '입고예정'],
#  ['라니티딘', '라니티딘반품', '신청문의', '도매상', '샵페이지', '대웅바이오', '라비', '라비수정', '낱알'],
#  ['이브', '라더', '보이', '보이냐며', '냐며', '지금', '고객센터', '센터', '바구니', '전용관이벤트', '추가구매'],
#  ['한우',
#   '현철',
#   '대구',
#   '대구북구',
#   '북구',
#   '침산',
#   '침산동',
#   '번지',
#   '임팩',
#   '민케어정',
#   '케어',
#   '구매희망하심'],
#  ['레쥬르',
#   '재발',
#   '재발송',
#   '안내안녕하세',
#   '안녕',
#   '하세',
#   '사업',
#   '사업기획팀',
#   '기획',
#   '운영',
#   '운영파트',
#   '파트',
#   '김혜원',
#   '하기',
#   '재발송처리',
#   '감사'],
#  ['한신', '한신약품올', '과립', '쿠폰사용', '대신', '신청요청', '재신청완료'],
#  ['한우',
#   '현철',
#   '대구',
#   '대구북구',
#   '북구',
#   '침산',
#   '침산동',
#   '번지',
#   '임팩',
#   '민케어정',
#   '케어',
#   '구매희망하심'],
#  ['반품거래명세서',
#   '명세서',
#   '메일요청',
#   '정밀',
#   '정밀리그램',
#   '리그',
#   '오르',
#   '다라',
#   '다라필',
#   '낱알',
#   '필름',
#   '밀리그램',
#   '매매',
#   '완제품',
#   '완제품서울',
#   '실비',
#   '이메일',
#   '점심시간',
#   '관계',
#   '시전',
#   '환입실과',
#   '실과',
#   '반품거래명세표',
#   '요청드림'],
#  ['약국이전', '주소상호명', '상호명', '변경요청', '팩스발송요청', '완료전', '주문어려움'],
#  ['이브', '품절해지안내', '해지'],
#  ['케토',
#   '케토톱',
#   '검색시',
#   '왼쪽',
#   '오른쪽',
#   '최저가',
#   '최저가보상',
#   '보상',
#   '공급가',
#   '상승',
#   '색인',
#   '표기',
#   '해당지역',
#   '미판매라',
#   '우측',
#   '미노출'],
#  ['이브', '해지', '주문하', '문하'],
#  ['이브'],
#  ['이브',
#   '품절해지완료',
#   '해지',
#   '다이아',
#   '다이아벡스엑스알',
#   '벡스',
#   '엑스',
#   '서방',
#   '서방정',
#   '품절문의',
#   '계획',
#   '월일',
#   '예상'],
#  ['연결후', '단선'],
#  ['이브', '품절해지', '해지'],
#  ['이브', '드릴', '드릴순', '재연락약속', '삼성', '삼성일시불', '일시불', '대신'],
#  ['프로', '이브', '일경', '예정입고시', '고시', '품절해지', '해지', '품절해지안내'],
#  ['태남',
#   '태남약국',
#   '미래',
#   '온누리',
#   '가입예정인증',
#   '인증',
#   '프로그램',
#   '설치',
#   '도구',
#   '도구인터넷옵션보안',
#   '인터넷',
#   '옵션',
#   '보안',
#   '사용자',
#   '사용자지정수준',
#   '지정',
#   '수준',
#   '컨트롤',
#   '자동',
#   '체크'],
#  ['이브',
#   '입고문',
#   '고문',
#   '고침',
#   '고침후',
#   '상품검색',
#   '보시',
#   '주문가능',
#   '역대급이벤트',
#   '만점',
#   '만원이상',
#   '구매시',
#   '부외품',
#   '부외품쿠폰',
#   '원권',
#   '치킨',
#   '이마트상품권',
#   '제공'],
#  ['환불요청문',
#   '요청문',
#   '처방',
#   '대웅바이오부외품도매상',
#   '부외품',
#   '도매상',
#   '확인방법',
#   '환급',
#   '환급리스트',
#   '리스트',
#   '사별',
#   '주문조회'],
#  ['이브', '입고', '스트롱'],
#  ['약국정경희', '국정', '경희', '인천약품', '사유오주문'],
#  ['누리',
#   '누리약국',
#   '조윤정',
#   '캡슐',
#   '엔티스',
#   '캡슐비티스',
#   '티스',
#   '페라엽',
#   '엑스',
#   '엑스정반품',
#   '인천약품',
#   '한군데',
#   '나머지',
#   '회수전',
#   '거래처',
#   '배송기사',
#   '방문시',
#   '말씀',
#   '센터',
#   '동일',
#   '이번주중',
#   '주중',
#   '직접',
#   '전화드림',
#   '휴가',
#   '목요일',
#   '전화주시기',
#   '시기',
#   '당일',
#   '반품불가',
#   '용지'],
#  ['장바구니상품결제', '바구니', '안됨', '주문결제요청', '결제해드림', '대웅인천약품'],
#  ['인천약품', '사유오주문'],
#  ['누리',
#   '누리약국',
#   '조윤정',
#   '캡슐',
#   '엔티스',
#   '캡슐비티스',
#   '티스',
#   '페라엽',
#   '엑스',
#   '엑스정반품',
#   '인천약품',
#   '한군데',
#   '나머지',
#   '회수전',
#   '거래처',
#   '배송기사',
#   '방문시',
#   '말씀',
#   '센터',
#   '동일',
#   '이번주중',
#   '주중',
#   '직접',
#   '전화드림',
#   '휴가',
#   '목요일',
#   '전화주시기',
#   '시기',
#   '당일',
#   '반품불가'],
#  ['건강약국', '대웅달력', '달력', '연락요청', '문의하심', '전해', '전해드림'],
#  ['대웅달력', '달력', '영업사원전화연락', '전함'],
#  ['삼원', '약국정', '하연', '하연통합처', '소액', '소액처'],
#  ['마일리',
#   '일리',
#   '전환',
#   '마일리지부외품쿠폰',
#   '부외품',
#   '원복',
#   '원복요청',
#   '예외',
#   '예외원복',
#   '백화점',
#   '부외품쿠폰'],
#  ['탑헬스케어', '헬스', '케어', '배송지연', '물류', '문제', '약국안내완료'],
#  ['이브', '주문가능', '주문가능시간', '문의금일'],
#  ['마이너스잔고', '환불문', '환급', '환급리스트', '리스트', '약국확인'],
#  ['마일리', '일리', '전환', '마일리지부외품쿠폰', '부외품', '원복', '원복요청'],
#  ['문메디칼', '메디칼', '렌드로', '드로', '네이트', '네이트디정', '대웅바이오', '방금', '방금주문', '휴대폰'],
#  ['변경요청', '팩스요청', '완료전', '주문어려움'],
#  ['석초약국', '디핀에스정', '에스', '반품처리', '확인문의'],
#  ['대웅바이오베', '디핀에스정', '에스', '반품처리', '확인문의', '확인중', '시간양해드림', '금일중'],
#  ['동건',
#   '동건약국문',
#   '탑헬스케어',
#   '헬스',
#   '케어',
#   '울금',
#   '미수령',
#   '수령',
#   '취소요청확인',
#   '전화주시기',
#   '시기',
#   '직송',
#   '직송처리',
#   '취소불가',
#   '고려',
#   '고려택배',
#   '직접',
#   '통해주',
#   '통해주시기',
#   '오늘시'],
#  ['대웅바이오베',
#   '디핀에스정',
#   '에스',
#   '반품처리',
#   '확인문',
#   '환입실문의확인',
#   '입실',
#   '재연',
#   '연락요청',
#   '성희',
#   '전달완료'],
#  ['전용관매출원', '도달', '청해', '청해드림'],
#  ['이지듀보습크림', '보습', '크림', '약국몰', '병원', '병원몰사이트', '사이트', '구매가능', '구매가능양해'],
#  ['다이아', '다이아벡스', '벡스', '품절문의', '확인부탁', '부탁', '주문가능'],
#  ['우황',
#   '우황청심원액영묘향',
#   '청심',
#   '원액',
#   '영묘향',
#   '선택',
#   '최저',
#   '이거',
#   '전산',
#   '전산오류',
#   '최저가',
#   '최저가판매',
#   '도매상',
#   '최소',
#   '판매가격',
#   '우측',
#   '표기',
#   '근처',
#   '도매상가격임안내',
#   '공급사별',
#   '사별',
#   '주문가능'],
#  ['대웅바이오라비수', '비수', '샵구매', '라니티딘', '반품요청', '년이내', '이내', '구입이력'],
#  ['임팩', '프리미엄'],
#  ['한성', '신규', '신규처', '거점등록관련', '오전내', '배영', '배영훈님', '방문요청'],
#  ['솔빛약국', '탑헬스케어', '헬스', '케어', '배송안옴', '물류', '문제', '안내요청'],
#  ['국이정행알', '이정', '입고문', '고문', '입고', '입고예정', '공급사', '급사'],
#  ['거점등록관련', '오전내', '배영', '배영훈님', '방문요청'],
#  ['다이아', '다이아벡스엑스알', '벡스', '엑스', '서방', '서방정', '품절문의'],
#  ['시리즈', '검색방법', '문의마이', '마이', '거점상품관', '상품검색', '이브', '주문가능', '주문가능일'],
#  ['우황', '우황청심원액영묘향', '청심', '원액', '영묘향', '선택', '최저', '이거', '전산', '전산오류'],
#  ['이브',
#   '드릴',
#   '드릴순',
#   '재연락약속',
#   '유미',
#   '유미선님',
#   '지엔',
#   '주문요청',
#   '주문가능',
#   '전상담사가',
#   '상담',
#   '사가',
#   '전화드림',
#   '유미선',
#   '전달완료'],
#  ['이브', '입고문', '고문', '에이스', '차이점', '생리통', '통증', '해열', '해열추천', '추천', '재안내드림'],
#  ['조현', '조현서', '통화요청'],
#  ['바구니', '기능'],
#  ['품절문의', '예정안내드림'],
#  ['크린',
#   '수량증대',
#   '증대',
#   '소량',
#   '최대',
#   '개개입월구매',
#   '개입',
#   '문의후',
#   '가능확답어려움',
#   '확답',
#   '재안내예정'],
#  ['메디', '열린', '열린약국', '민기옥', '제약창원', '백제주문', '창원'],
#  ['인천약품',
#   '리스트',
#   '김정',
#   '통화건이후',
#   '가지',
#   '반품품목',
#   '가지',
#   '회수기사',
#   '어제접수',
#   '하심김정',
#   '전달완료'],
#  ['쿠폰적용', '쿠폰번호', '등록문의', '스크롤', '맨하단', '하단', '적용하기', '하기', '클릭', '클릭안내'],
#  ['국약국신상희', '상희', '전체취소요청사유', '약사요청'],
#  ['다이아',
#   '다이아벡스엑스알',
#   '벡스',
#   '엑스',
#   '서방',
#   '서방정',
#   '정경진',
#   '경진',
#   '수량제한',
#   '제한',
#   '개로',
#   '염두',
#   '구입희망'],
#  ['제일',
#   '제일종합약국',
#   '종합',
#   '김윤천',
#   '이소',
#   '이소메릭정',
#   '설피',
#   '설피리드',
#   '리드',
#   '처방',
#   '처방중단',
#   '복산나이스',
#   '나이스',
#   '반품환불지연문의',
#   '복산',
#   '함대',
#   '함대변약국',
#   '김태규',
#   '우황',
#   '우황청심원원방',
#   '청심원',
#   '원방',
#   '재고과다사유',
#   '과다',
#   '부산',
#   '부산지점',
#   '환불지연문의'],
#  ['동건',
#   '동건약국문',
#   '탑헬스케어',
#   '헬스',
#   '케어',
#   '울금',
#   '미수령',
#   '수령',
#   '취소요청확인',
#   '전화주시기',
#   '시기',
#   '직송',
#   '직송처리',
#   '취소불가',
#   '고려',
#   '고려택배',
#   '직접',
#   '통해주',
#   '통해주시기'],
#  ['이소',
#   '이소메릭정',
#   '설피',
#   '설피리드',
#   '리드',
#   '처방',
#   '처방중단사유',
#   '복산나이스',
#   '나이스',
#   '반품환불지연문의'],
#  ['제이', '간편', '간편결제', '변경등록', '결제버튼', '버튼', '문의예치금', '대신'],
#  ['패밀리',
#   '패밀리존',
#   '통해',
#   '현대',
#   '현대상품권',
#   '일전',
#   '재발송',
#   '미수신',
#   '재발송완료',
#   '발송번호',
#   '스팸',
#   '차단',
#   '요청드림',
#   '대비',
#   '선생님',
#   '핸드폰번호',
#   '지금',
#   '재발',
#   '카페',
#   '아메리카',
#   '아메리카노',
#   '기프티콘',
#   '기억'],
#  ['수령',
#   '박스포장',
#   '바코드',
#   '매입',
#   '재전화드림',
#   '이정식',
#   '정식',
#   '전화부탁드림',
#   '부탁',
#   '은수',
#   '휴대폰',
#   '휴대폰번호',
#   '안됨',
#   '재연락요청'],
#  ['반품완료후',
#   '문의반품완료후',
#   '도매부외품',
#   '부외품',
#   '오른쪽',
# ...
#   '월부족금액',
#   '유도',
#   '유도처',
#   '청해',
#   '청해드림',
#   '만유',
#   '신진',
#   '신진선님',
#   '상담',
#   '상담내용아웃권유',
#   '아웃',
#   '권유',
#   '만원정도',
#   '지금',
#   '전용관매출',
#   '우루',
#   '우루사',
#   '구매금액',
#   '포함',
#   '집계',
#   '미포함'],
#  ['수령', '박스포장', '바코드', '매입', '재전화드림'],
#  ['헬스', '헬스인', '미배송문의', '운송장', '터미널', '출발', '택배사'],
#  ['기분', '약국안지', '안지', '출하', '출하정지'],
#  ['대웅전', '우루', '우루사안', '사안', '우측', '날개', '날개배', '간편', '간편구매', '경로', '이브'],
#  ['코큐터', '에이스', '함량', '캡슐', '캡슐당', '하루', '복용'],
#  ['동양', '동양약국', '유경환', '경환', '클레임'],
#  ['동양',
#   '동양약국',
#   '유경환',
#   '경환',
#   '한올',
#   '한올제조판매중지',
#   '중지',
#   '취소안내',
#   '피해',
#   '것이냐',
#   '불만',
#   '불만제품',
#   '출하',
#   '책임',
#   '지라'],
#  ['복산나이스',
#   '나이스',
#   '미플',
#   '캡슐',
#   '예치금취소',
#   '주문시',
#   '사용가능',
#   '예전',
#   '짜증',
#   '짜증내심',
#   '내심',
#   '중부',
#   '중부센터',
#   '센터',
#   '여파',
#   '배송지연',
#   '차주',
#   '차질'],
#  ['새봄', '새봄약국김효림', '효림', '렛잇비정', '비정'],
#  ['대웅우루사연질', '우루', '연질', '캡슐', '하나', '의미'],
#  ['신대학',
#   '대학',
#   '손재',
#   '손재근대웅제약',
#   '슈펙트',
#   '약가',
#   '약가인하',
#   '인하',
#   '보상',
#   '보상관련',
#   '직전',
#   '개월',
#   '구매수량',
#   '자동',
#   '실물',
#   '실물반품',
#   '환입처리',
#   '인하가로',
#   '가로',
#   '재주',
#   '재주문',
#   '최근',
#   '입가',
#   '사전'],
#  ['유진',
#   '유진비',
#   '피오랄비',
#   '스테',
#   '스테이지스',
#   '이지스',
#   '어린이',
#   '어린이칫솔',
#   '칫솔',
#   '단계',
#   '제조년월일',
#   '년월일',
#   '처리요청',
#   '업체연락안됨',
#   '안됨',
#   '목요일',
#   '재연락약속',
#   '양해드림'],
#  ['알파',
#   '알파본연질캡슐',
#   '본연',
#   '캡슐',
#   '주문제한수량',
#   '제한',
#   '한올',
#   '판매제조정지',
#   '공급사',
#   '수급',
#   '제한있음'],
#  ['한올',
#   '보류',
#   '제조판매',
#   '금요일',
#   '한올담당자',
#   '연락하라',
#   '하라',
#   '조현',
#   '조현서',
#   '불평',
#   '하심취소완료'],
#  ['비디',
#   '마이크로',
#   '마이크로파인',
#   '파인',
#   '반품가능',
#   '가고파',
#   '가고파약국',
#   '김혜영님',
#   '약사시절',
#   '시절',
#   '햇님',
#   '약국가고파약국',
#   '모두',
#   '사입이',
#   '입이',
#   '재문',
#   '양해드림'],
#  ['한올', '보류', '제조판매'],
#  ['대웅유진약품', '유진', '취소요청사유', '유진약품', '배송기사님', '취소가능', '목요일'],
#  ['대웅바이오반품',
#   '신청시',
#   '분간격',
#   '간격',
#   '신청가능',
#   '바이오반품',
#   '사입이',
#   '입이',
#   '년이내',
#   '이내',
#   '수향',
#   '만큼',
#   '반품신청가능'],
#  ['대웅바이오', '라비', '라비수정', '완제품', '낱알', '오브젝트', '에러', '여직원', '퇴근해', '근해', '목요일'],
#  ['한동',
#   '한동약국이병순',
#   '이병',
#   '동원',
#   '동원약국배한',
#   '배한',
#   '아까',
#   '모두',
#   '출고정지완료',
#   '취소버튼',
#   '버튼',
#   '취소확정처리',
#   '확정'],
#  ['연질',
#   '연질캅셀',
#   '캅셀',
#   '문의확인후',
#   '재전화드림',
#   '현님',
#   '답변',
#   '답변은혜',
#   '은혜',
#   '구매내역',
#   '주문일자',
#   '월로',
#   '고함',
#   '한번',
#   '반송',
#   '함재',
#   '함재확인후',
#   '안내확인중',
#   '목요일'],
#  ['마감시간이후', '휴일'],
#  ['프로',
#   '품절불만제기',
#   '불만',
#   '제기',
#   '풀렷다하고',
#   '지금',
#   '주문시',
#   '나오냐',
#   '짜증',
#   '짜증불만제기',
#   '정중',
#   '사과',
#   '사과안내',
#   '재통화',
#   '통화거절누르',
#   '거절',
#   '월일',
#   '안내차',
#   '거절하심'],
#  ['한올', '보류', '제조판매'],
#  ['다이아', '다이아벡스', '벡스', '입고문', '고문', '입고', '입고예정', '주문가능'],
#  ['나무',
#   '나무약품',
#   '한올',
#   '한올바이오파마',
#   '파마',
#   '피엠',
#   '피엠믹스페리주',
#   '믹스',
#   '페리',
#   '구매문의',
#   '대체',
#   '대체상품'],
#  ['도원',
#   '도원약국이병',
#   '이병',
#   '대웅유진약품',
#   '유진',
#   '인수거절건',
#   '거절',
#   '확정',
#   '결제취소',
#   '김정',
#   '예정내일',
#   '회신주기',
#   '주기',
#   '안됨',
#   '안됨시정도',
#   '시정도',
#   '삭제완료'],
#  ['음정',
#   '음정약국',
#   '병기',
#   '연질',
#   '엔프로',
#   '프로',
#   '캡슐',
#   '캡슐제형축소형',
#   '제형',
#   '축소',
#   '년월일',
#   '예정안내'],
#  ['호이',
#   '호이스타정',
#   '스타',
#   '반품신청요청',
#   '반품접수완료',
#   '통증',
#   '통증완화수량개',
#   '완화',
#   '반품쿠폰사용',
#   '변심',
#   '변심반품요청',
#   '회수기간',
#   '금주중',
#   '주중',
#   '방문양해'],
#  ['정문', '정문약국전윤옥', '윤옥'],
#  ['한올', '보류', '제조판매'],
#  ['마이', '마이페이지생활기프트', '생활기', '프트', '안내포인트', '전환', '전환방법', '포인트몰사', '몰사'],
#  [],
#  ['문의주심',
#   '주심',
#   '역대급',
#   '만원이상',
#   '가지',
#   '가지중',
#   '선택',
#   '파리',
#   '파리바게트',
#   '바게트',
#   '교환권',
#   '신청요청',
#   '대신',
#   '청해',
#   '청해드림'],
#  ['한올', '보류', '제조판매'],
#  ['파리', '파리바게트', '바게트', '약국명', '국명'],
#  ['샵플러스',
#   '플러스',
#   '주문번호',
#   '수령',
#   '수령지변',
#   '지변',
#   '강남',
#   '강남구',
#   '일원',
#   '일원동',
#   '목련',
#   '목련마을상가호',
#   '마을',
#   '상가',
#   '결제완료상태',
#   '사이트',
#   '사이트내',
#   '변경처리',
#   '해드림'],
#  ['한올', '보류', '제조판매'],
#  ['한올', '한올바이오', '갱신', '갱신발급보류', '보류', '제조판매중지', '중지', '취소안내', '부분취소'],
#  ['한올', '보류', '제조판매', '취소하라', '하라'],
#  ['만원이상', '적립안', '오창석', '확인시', '담당', '담당개발자분', '개발자', '휴가', '확인지연', '양해드림'],
#  ['코발정',
#   '발정',
#   '판매여부',
#   '년도',
#   '생산',
#   '대체',
#   '코발라민',
#   '성분',
#   '가있',
#   '대부분',
#   '엑스',
#   '액티넘',
#   '골드',
#   '골드정이',
#   '정이'],
#  ['한올', '한올바이오', '갱신', '갱신발급보류', '보류', '제조판매중지', '중지', '취소안내', '부분카드취소'],
#  ['한올', '보류', '제조판매', '클레임', '클레임제기', '제기', '끊으', '끊으심'],
#  ['주문결제시', '메세지', '허용', '팝업', '문제', '인터넷', '설정'],
#  ['임팩', '프리미엄', '구매시', '제한', '팝업', '해지', '스타', '스타벅스', '벅스', '기프티콘', '요청하심'],
#  ['한동', '한동약국이병순', '이병', '웅지', '웅지오', '체취소요청', '사유오주문', '출고정지완료'],
#  ['음정', '음정약국', '병기', '연질', '엔프로', '프로', '캡슐', '캡슐제형축소형', '제형', '축소'],
#  ['한올', '보류', '제조판매'],
#  ['복산리버골드',
#   '리버',
#   '골드',
#   '파워',
#   '파워연질캡슐',
#   '연질',
#   '캡슐',
#   '취소문의복산',
#   '부산',
#   '부산지점',
#   '출고정지',
#   '취소가능여부',
#   '전화주시기',
#   '시기',
#   '함김정',
#   '복산약품남',
#   '콜백신약국장',
#   '백신',
#   '국장',
#   '유연',
#   '납품',
#   '함복산대웅',
#   '미회신',
#   '확인출고정지',
#   '확정'],
#  ['한올', '보류', '제조판매'],
#  [],
#  ['메디',
#   '메디코어',
#   '코어',
#   '주문건착오주문',
#   '착오',
#   '배송비',
#   '발생',
#   '업체번호문의반품',
#   '부담',
#   '드림보유',
#   '반품쿠폰',
#   '보유'],
#  ['한동', '한동약국이병순', '이병', '웅지', '웅지오', '체취소요청', '사유오주문'],
#  ['한올', '보류', '제조판매'],
#  ['상호명', '상호명주소', '요양', '요양번호등', '사등', '발송요청', '시간소요'],
#  ['한올', '한올바이오', '갱신', '갱신발급보류', '보류', '제조판매중지', '중지', '취소안내'],
#  ['한올', '보류', '제조판매'],
#  ['한올', '보류', '제조판매'],
#  ['인천약품',
#   '반품신청시',
#   '신청목록',
#   '목록',
#   '검색자체',
#   '자체',
#   '안됨',
#   '안됨확인',
#   '미차장',
#   '사이트',
#   '통해'],
#  ['금요일', '문의입금기한', '목입금기한전', '입금기한', '미결제', '취소처리'],
#  ['동원',
#   '동원약국배한성',
#   '한성',
#   '웅지',
#   '웅지오',
#   '체취소요청',
#   '사유수량재주문',
#   '재주',
#   '납품',
#   '출고정지완료'],
#  ['한올', '보류', '제조판매', '한올측', '전달하심'],
#  ['삼원',
#   '약국정',
#   '하연',
#   '거점등록요청',
#   '통합처',
#   '코드이관',
#   '영업사원본사',
#   '본사',
#   '배정여부',
#   '본사관리',
#   '거점상품등록요청',
#   '하루',
#   '하루정도',
#   '주문가능',
#   '처리중',
#   '시간소요',
#   '양해구함이번주중',
#   '구함',
#   '주중',
#   '정성희님',
#   '성희'],
#  [],
#  ['새봄', '새봄약국김효림', '효림', '렛잇비정', '비정'],
#  ['한올', '한올바이오', '갱신', '갱신발급보류', '보류', '제조판매중지', '중지', '취소안내'],
#  ['동원', '동원약국배한성', '한성', '웅지', '웅지오', '체취소요청', '사유수량재주', '재주'],
#  ['한올', '한올바이오', '갱신', '갱신발급보류', '보류', '제조판매중지', '중지', '취소안내'],
#  ['한올', '보류', '제조판매', '받아야겠으', '고함'],
#  ['옵티', '옵티프리', '프리', '익스프레스', '익스프레스액', '제이'],
#  ['초원',
#   '정숙',
#   '약국정',
#   '바이오베',
#   '거점등록하라',
#   '하라',
#   '신은',
#   '검색창',
#   '초원약국양영',
#   '폐업후',
#   '재개',
#   '재개업',
#   '환불요청',
#   '카톡으',
#   '대웅반품건',
#   '미처리',
#   '차주',
#   '차주이후',
#   '대로'],
#  ['한올',
#   '한올바이오',
#   '갱신',
#   '갱신발급보류',
#   '보류',
#   '제조판매중지',
#   '중지',
#   '취소안내',
#   '한올우',
#   '영님',
#   '상담',
#   '상담건',
#   '오늘안',
#   '불만',
#   '불만제기',
#   '제기',
#   '취소연락',
#   '기분',
#   '카드취소요청',
#   '카드사',
#   '반영',
#   '반영기간안내드림'],
#  ['한올', '한올바이오', '갱신', '갱신발급보류', '보류', '제조판매중지', '중지', '취소안내', '부분카드취소'],
#  ['한올', '보류', '제조판매', '취소하라', '하라'],
#  ['연질',
#   '연질캅셀',
#   '캅셀',
#   '문의확인후',
#   '재전화드림',
#   '현님',
#   '답변',
#   '답변은혜',
#   '은혜',
#   '구매내역',
#   '주문일자',
#   '월로',
#   '고함',
#   '한번',
#   '반송',
#   '재확인',
#   '재확인후'],
#  ['한올',
#   '한올바이오',
#   '갱신',
#   '갱신발급보류',
#   '보류',
#   '제조판매중지',
#   '중지',
#   '취소안내',
#   '한올우',
#   '영님',
#   '상담',
#   '상담건',
#   '오늘안',
#   '불만',
#   '불만제기',
#   '제기',
#   '취소연락',
#   '기분',
#   '카드취소요청'],
#  ['한올', '보류', '제조판매'],
#  ['한올', '한올바이오', '갱신', '갱신발급보류', '보류', '제조판매중지', '중지', '취소안내'],
#  ['한올', '한올바이오', '갱신', '갱신발급보류', '보류', '제조판매중지', '중지', '취소안내'],
#  ['한올', '보류', '제조판매'],
#  ['한올', '한올바이오', '갱신', '갱신발급보류', '보류', '제조판매중지', '중지', '취소안내'],
#  ['한올', '보류', '제조판매'],
#  ['약가',
#   '약가인하',
#   '인하',
#   '사이트',
#   '사이트상',
#   '안됨',
#   '안됨인천약품',
#   '통해',
#   '연질',
#   '연질캡슐',
#   '캡슐',
#   '얼마',
#   '보상',
#   '오프',
#   '오프라인',
#   '라인',
#   '안내반품신청',
#   '선택',
#   '검색시',
#   '반품목록',
#   '목록'],
#  ['대성',
#   '대성메디케어',
#   '메디',
#   '케어',
#   '구매시',
#   '천원',
#   '적립안됨',
#   '안됨',
#   '대성쪽',
#   '구매리스트',
#   '리스트',
#   '목요일',
#   '재연락약속'],
#  ['마이너스잔고',
#   '환불요청',
#   '월초',
#   '헬리오',
#   '동아',
#   '동아약국',
#   '정명',
#   '카톡으로',
#   '사진',
#   '주심',
#   '처리기간',
#   '차주',
#   '금요일'],
#  ['한올', '한올바이오', '재고부족', '클레임', '통화중동양약국유', '중동', '양약국', '경환'],
#  ['한올', '보류', '제조판매', '고함'],
#  ['티제이',
#   '제이',
#   '베나치오액',
#   '나치',
#   '내년',
#   '월로',
#   '택배비',
#   '부담',
#   '교환요청',
#   '반품후',
#   '재주',
#   '재주문',
#   '반품사유제품하자',
#   '하자',
#   '주문시'],
#  ['한올', '보류', '제조판매'],
#  ['한올', '보류', '제조판매'],
#  ['한올', '한올바이오', '갱신', '갱신발급보류', '보류', '제조판매중지', '중지', '취소안내'],
#  ['사업자등록증',
#   '등록증',
#   '가입승인처리요청',
#   '사업자번호',
#   '업체안내완료',
#   '현님확인',
#   '도매몰',
#   '매몰',
#   '가입승인',
#   '생성',
#   '최소',
#   '일정',
#   '소요안내드림'],
#  ['동안', '마트상품권스타벅스', '스타', '벅스', '기프티콘', '미사', '재발송'],
#  ['한올', '보류', '제조판매', '알파', '본연', '본연질캡슐', '캡슐', '알파칼시돌'],
#  ['계속', '상담', '상담사', '연결요청', '퇴근', '퇴근시간', '전달완료'],
#  ['한올', '보류', '제조판매'],
#  ['한올',
#   '한올바이오',
#   '갱신',
#   '갱신발급보류',
#   '보류',
#   '제조판매중지',
#   '중지',
#   '취소안내',
#   '수긍',
#   '당장',
#   '클레임',
#   '클레임제기양해',
#   '제기',
#   '책임자'],
#  ['정원',
#   '정원약국설경애',
#   '경애',
#   '엠디',
#   '키스',
#   '잇몸',
#   '매스틱',
#   '키스치약',
#   '잇몸질환',
#   '스틱',
#   '치약',
#   '질환',
#   '특허',
#   '특허치약',
#   '특가',
#   '취소요청사유',
#   '리뉴얼',
#   '약국과',
#   '국과',
#   '취소요청취소완료',
#   '한독',
#   '한독약국정순',
#   '정순',
#   '엠디일양약품',
#   '일양',
#   '청장',
#   '청장미인',
#   '미인',
#   '골드',
#   '단종',
#   '고함'],
#  ['약용',
#   '약용포장지',
#   '포장지',
#   '수출',
#   '수출업체',
#   '방글라데시',
#   '데시',
#   '수출관련',
#   '보트',
#   '타입',
#   '전화문자요청'],
#  ['사은품', '이마트상품권', '파리', '파리바게트', '바게트'],
#  ['봄약국김', '안됨'],
#  ['한올', '보류', '제조판매'],
#  ['연질', '연질캅셀', '캅셀', '문의확인후', '재전화드림'],
#  ['롯데',
#   '롯데카드',
#   '간편',
#   '간편등록건',
#   '분실',
#   '등록변경',
#   '신용',
#   '신용카드사전등록',
#   '사전',
#   '통화건등록방법'],
#  ['한올', '한올바이오', '갱신', '갱신발급보류', '보류', '제조판매중지', '중지', '취소안내'],
#  ['제대', '정상'],
#  ['한올', '보류', '제조판매', '시출근', '출근'],
#  ['한신',
#   '한신약품셀레',
#   '롬정',
#   '처리반품불가',
#   '떙처리상품반품',
#   '일부',
#   '보고',
#   '가능여부',
#   '한신약품',
#   '고함',
#   '명시',
#   '안내드림약사수긍',
#   '수긍'],
#  ['한올', '보류', '제조판매'],
#  ['한올', '한올바이오', '갱신', '갱신발급보류', '보류', '제조판매중지', '중지', '취소안내', '올측'],
#  ['스트롱', '예정임'],
#  ['한올', '보류', '제조판매', '버리심'],
#  ['역대급', '파리', '파리바게트', '바게트', '교환권', '예정임'],
#  ['한올', '보류', '제조판매'],
#  ['한올', '한올바이오', '갱신', '갱신발급보류', '보류', '제조판매중지', '중지', '취소안내'],
#  ['한올', '한올바이오', '갱신', '갱신발급보류', '보류', '제조판매중지', '중지', '취소안내'],
#  ['한올', '보류', '제조판매'],
#  ['프로', '입고됬다', '구매요청', '거냐', '인상', '단가', '단가안내'],
#  ['약국주소',
#   '충남',
#   '서산',
#   '서산시',
#   '지곡',
#   '지곡면',
#   '무장',
#   '무장길',
#   '사업자등록증',
#   '등록증',
#   '카톡으',
#   '하심사업자등록증',
#   '주문가능'],
#  ['한올', '한올바이오', '갱신', '갱신발급보류', '보류', '제조판매중지', '중지', '취소안내', '부분카드취소'],
#  ['통화중'],
#  ['우리', '김영주', '영주', '티제이', '제이', '사유수취거부', '수취', '소통건', '주문취소요청'],
#  ['한올',
#   '한올바이오',
#   '갱신',
#   '갱신발급보류',
#   '보류',
#   '제조판매중지',
#   '중지',
#   '취소안내',
#   '부분취소',
#   '전체취소가능국장',
#   '국장',
#   '연락요청'],
#  ['한올', '보류', '제조판매'],
#  ['사업자번호변경',
#   '대표자',
#   '동일',
#   '동일사업자등록증',
#   '등록증',
#   '업로드',
#   '로드',
#   '신규',
#   '신규가입',
#   '승인완료',
#   '문자전송',
#   '주문이용가능'],
#  [],
#  ['한올', '한올바이오', '갱신', '갱신발급보류', '보류', '제조판매중지', '중지', '취소안내'],
#  ['한올', '보류', '제조판매', '한올담당자', '확인안됨', '안됨', '모두', '안내드림약사'],
#  ['오예',
#   '오예시티약국허영',
#   '시티',
#   '허영',
#   '근대웅알레',
#   '입고문',
#   '고문',
#   '태전과',
#   '전과',
#   '지오',
#   '주문급',
#   '태전',
#   '메일요청',
#   '참조',
#   '확인부탁',
#   '부탁',
#   '태전약품',
#   '전주'],
#  ['한올',
#   '한올바이오',
#   '갱신',
#   '갱신발급보류',
#   '보류',
#   '제조판매중지',
#   '중지',
#   '취소안내',
#   '부분카드취소',
#   '국장',
#   '고함'],
#  ['알파', '알파우루사연질', '우루', '연질', '캡슐', '천원'],
#  ['한올', '한올바이오', '갱신', '갱신발급보류', '보류', '제조판매중지', '중지', '취소안내'],
#  ['한올', '보류', '제조판매', '약국장', '국장', '휴가', '휴가중', '금요일', '출근', '출근하심'],
#  ['한올', '한올바이오', '갱신', '갱신발급보류', '보류', '제조판매중지', '중지', '취소안내'],
#  ['국장', '나중', '연락주신'],
#  ['한올', '보류', '제조판매', '취소하라', '하라', '한올담당자', '카드취소시', '한통'],
#  ['사업자등록증', '등록증', '가입승인처리요청', '사업자번호', '재안내'],
#  [],
#  ['옵티', '옵티프리', '프리', '익스프레스', '익스프레스액', '제이', '제대', '안해', '정상'],
#  ['한올', '한올바이오', '갱신', '갱신발급보류', '보류', '제조판매중지', '중지', '취소안내'],
#  ['한올', '한올바이오', '갱신', '갱신발급보류', '보류', '제조판매중지', '중지', '취소안내', '부분취소'],
#  ['만점', '이브', '입고시', '고시'],
#  ['오예',
#   '오예시티약국허영',
#   '시티',
#   '허영',
#   '근대웅알레',
#   '입고문',
#   '고문',
#   '태전과',
#   '전과',
#   '지오',
#   '주문급',
#   '않냐'],
#  ['동문',
#   '동문약국',
#   '한올',
#   '헬스',
#   '헬스케어',
#   '바이오세화',
#   '케어',
#   '세화',
#   '복합주문건',
#   '합주',
#   '취소안내',
#   '주문건확인후',
#   '취소처리',
#   '도움',
#   '도움드림',
#   '고함'],
#  ['한올', '한올바이오', '갱신', '갱신발급보류', '보류', '제조판매중지', '중지', '취소안내'],
#  ['한올', '보류', '제조판매', '알파', '본연', '본연질캡슐', '캡슐', '알파칼시돌'],
#  ['샵마일리지',
#   '만점',
#   '사용방법',
#   '생활기',
#   '생활기프트',
#   '프트',
#   '샵플러스',
#   '플러스',
#   '사용가능',
#   '전환',
#   '전환부외품',
#   '부외품',
#   '할인쿠폰무료반품',
#   '무료',
#   '낱알',
#   '낱알반품',
#   '생활기프트',
#   '롯데',
#   '롯데상품권',
#   '만원장',
#   '원장',
#   '신청요청',
#   '대신',
#   '청해',
#   '청해드림',
#   '다음주',
#   '수요일',
#   '신정',
#   '관계',
#   '휴대',
#   '휴대폰',
#   '수있음'],
#  ['한올', '보류', '제조판매'],
#  ['한올', '한올바이오', '갱신', '갱신발급보류', '보류', '제조판매중지', '중지', '취소안내', '예치금취소'],
#  ['오예',
#   '오예시티약국허영',
#   '시티',
#   '허영',
#   '근대웅알레',
#   '입고문',
#   '고문',
#   '태전과',
#   '전과',
#   '지오',
#   '주문급'],
#  ['한올', '보류', '제조판매', '취소하라', '하라'],
#  ['성신',
#   '성신약국최신',
#   '최신',
#   '티제이',
#   '제이',
#   '베나치오액',
#   '나치',
#   '내년',
#   '월로',
#   '택배비',
#   '부담',
#   '교환요청',
#   '업체부담',
#   '함유',
#   '미선',
#   '전달드림',
#   '유미',
#   '유미선님',
#   '상담',
#   '상담건',
#   '창고',
#   '창고확인결과',
#   '결과',
#   '년월',
#   '반품처리'],
#  ['결제금액',
#   '주문완료',
#   '수건',
#   '샵프렌즈',
#   '렌즈',
#   '거랑',
#   '주문안',
#   '화면',
#   '유미',
#   '유미현님',
#   '도매몰',
#   '매몰',
#   '인천약품',
#   '만원미만',
#   '미만',
#   '불가능',
#   '결제창',
#   '발생한',
#   '조치',
#   '정상적',
#   '벨리',
#   '벨리데이션체크',
#   '데이',
#   '체크',
#   '함박',
#   '연고',
#   '공급사',
#   '치엔지',
#   '엔지',
#   '기론',
#   '바이오인천',
#   '약품꺼',
#   '고함'],
#  ['대웅바이오',
#   '품목세파',
#   '세파',
#   '년이내',
#   '이내',
#   '사입이',
#   '입이',
#   '안됨',
#   '연질',
#   '연질캡슐',
#   '캡슐',
#   '록소프',
#   '소프',
#   '보스',
#   '보스정',
#   '트라',
#   '트라콘정',
#   '구매이력',
#   '없으',
#   '없으심',
#   '반품시',
#   '수량입력',
#   '규격',
#   '완제품',
#   '매수',
#   '케이스',
#   '케이스수대',
#   '수대',
#   '낱알',
#   '입력안내',
#   '경과',
#   '경과시',
#   '구매내역',
#   '무시',
#   '재연락약속',
#   '신청완료',
#   '포장부탁',
#   '부탁',
#   '진행현황',
#   '현황',
#   '어디',
#   '목록',
#   '왼쪽',
#   '반품완료내역'],
#  ['한올', '보류', '제조판매'],
#  ['권장', '권장소비자', '만원안내'],
#  ['삼거리', '삼거리약국', '문의알레', '태전', '태전약품', '개지', '개지오'],
#  ['한올', '보류', '제조판매', '연락드', '락드', '통화종료하심'],
#  ['레그',
#   '정시',
#   '레그파라',
#   '파라',
#   '세트',
#   '세트염산염',
#   '염산염',
#   '사유재고과다',
#   '과다',
#   '복산',
#   '나이스',
#   '반품요청',
#   '업체확인후',
#   '재연락드림',
#   '우리',
#   '약국복산여',
#   '반품가능',
#   '안내완료'],
#  ['성신',
#   '성신약국최신',
#   '최신',
#   '티제이',
#   '제이',
#   '베나치오액',
#   '나치',
#   '내년',
#   '월로',
#   '택배비',
#   '부담',
#   '교환요청',
#   '업체부담'],
#  ['입고문', '고문', '다이아', '다이아벡스', '벡스', '이브', '입고', '입고예정'],
#  ['신세계', '신세계상품권', '레쥬르', '엔젤', '너스', '기프티콘', '커피', '사용여부'],
#  ['우리',
#   '우리약국',
#   '이수정',
#   '레그',
#   '정시',
#   '레그파라',
#   '파라',
#   '세트',
#   '세트염산염',
#   '염산염',
#   '재고과다',
#   '과다',
#   '복산',
#   '나이스',
#   '반품요청',
#   '업체확인후',
#   '재연락드림',
#   '복산반품'],
#  ['구입상품',
#   '반품신청요청신',
#   '마이크로',
#   '마이크로포살색',
#   '살색',
#   '종이',
#   '종이반창고',
#   '반창고',
#   '반품쿠폰사용',
#   '개헬스인',
#   '헬스',
#   '신청요청'],
#  ['한올', '보류', '제조판매'],
#  ['한올', '한올바이오', '갱신', '갱신발급보류', '보류', '제조판매중지', '중지', '취소안내'],
#  ['한올', '한올바이오', '갱신', '갱신발급보류', '보류', '제조판매중지', '중지', '취소안내'],
#  ['이브', '프로', '입고문', '고문', '확인중', '재전화', '예정임'],
#  ['낱알', '낱알반품', '오픈', '오픈해드림'],
#  ['한올', '한올바이오', '갱신', '갱신발급보류', '보류', '제조판매중지', '중지', '취소안내'],
#  ['한올', '한올바이오', '갱신', '갱신발급보류', '보류', '제조판매중지', '중지', '취소안내'],
#  ['이브', '프로', '입고문', '고문', '확인중'],
#  ['한올',
#   '보류',
#   '제조판매',
#   '스타',
#   '스타디핀정',
#   '말레인',
#   '말레인산암',
#   '디핀',
#   '하루',
#   '하루이틀전',
#   '이틀',
#   '한올측',
#   '잘못',
#   '취소안'],
#  ['우리',
#   '우리약국',
#   '이수정',
#   '레그',
#   '정시',
#   '레그파라',
#   '파라',
#   '세트',
#   '세트염산염',
#   '염산염',
#   '재고과다',
#   '과다',
#   '복산',
#   '나이스',
#   '반품요청',
#   '업체확인후'],
#  ['티제이', '제이', '베나치오액', '나치', '내년', '월로', '택배비', '부담', '교환요청'],
#  ['한올',
#   '한올바이오',
#   '갱신',
#   '갱신발급보류',
#   '보류',
#   '제조판매중지',
#   '중지',
#   '취소안내',
#   '한올측',
#   '시이후',
#   '재개',
#   '알파',
#   '알파본',
#   '구입가능'],
#  ['목요일'],
#  ['태전',
#   '태전약품',
#   '반품요청',
#   '쓰기',
#   '불편',
#   '반품태전약품',
#   '하나',
#   '반품택배비',
#   '택배비',
#   '재전화드림',
#   '약사페이지',
#   '상자',
#   '상자포장',
#   '업체부담',
#   '부담',
#   '접수하라',
#   '하라',
#   '반품접수',
#   '두시',
#   '회수기사방문'],
#  ['한올', '보류', '제조판매'],
#  ['한올', '한올바이오', '갱신', '갱신발급보류', '보류', '제조판매중지', '중지', '취소안내'],
#  ['레그',
#   '정시',
#   '레그파라',
#   '파라',
#   '세트',
#   '세트염산염',
#   '염산염',
#   '사유재고과다',
#   '과다',
#   '복산',
#   '나이스',
#   '반품요청',
#   '업체확인후',
#   '재연락드림',
#   '우리'],
#  ['한올', '한올바이오', '갱신', '갱신발급보류', '보류', '제조판매중지', '중지', '취소안내'],
#  ['주민',
#   '주민약국',
#   '윤우',
#   '태전',
#   '태전약품',
#   '반품요청',
#   '쓰기',
#   '불편',
#   '하나',
#   '반품택배비',
#   '택배비',
#   '약사페이지',
#   '상자',
#   '상자포장',
#   '업체부담',
#   '부담',
#   '접수하라',
#   '하라'],
#  ['한올', '보류', '제조판매'],
#  ['한올', '보류', '제조판매'],
#  ['성실',
#   '성실약국',
#   '이보배',
#   '보배',
#   '대성',
#   '대성메디케어',
#   '메디',
#   '케어',
#   '구매시',
#   '천원',
#   '적립안됨',
#   '안됨',
#   '유미',
#   '유미선님',
#   '상담',
#   '상담건',
#   '쿠폰적용',
#   '운영',
#   '운영팀',
#   '적립관련',
#   '고함'],
#  ['태전', '태전약품', '반품요청', '쓰기', '불편', '반품태전약품', '하나', '반품택배비', '택배비', '재전화드림'],
#  ['한올', '한올바이오', '갱신', '갱신발급보류', '보류', '제조판매중지', '중지', '취소안내'],
#  ['배송기사님',
#   '불친절',
#   '대꾸',
#   '인상',
#   '나이',
#   '개인',
#   '개인사유',
#   '익명',
#   '택배사',
#   '요구',
#   '교체',
#   '교체요청',
#   '오늘건',
#   '공장건',
#   '스마일',
#   '용마',
#   '용마기사님',
#   '추정',
#   '스마일기사님',
#   '재발',
#   '책임자',
#   '지역별',
#   '양해드림'],
#  ['한올', '보류', '제조판매'],
#  ['월일', '월일안내드림'],
#  ['한올', '한올바이오', '갱신', '갱신발급보류', '보류', '제조판매중지', '중지', '취소안내'],
#  ['한올', '보류', '제조판매'],
#  ['도원',
#   '도원약국이병',
#   '이병',
#   '대웅유진약품',
#   '유진',
#   '인수거절건',
#   '거절',
#   '확정',
#   '결제취소',
#   '김정',
#   '예정내일',
#   '회신주기',
#   '주기',
#   '안됨',
#   '안됨시정도',
#   '시정도'],
#  ['한올', '보류', '제조판매'],
#  ['한올', '보류', '제조판매'],
#  ['한올', '보류', '제조판매'],
#  ['한올', '보류', '제조판매'],
#  ...]

# %%
len(gensim_corpus)
# Out:
# 28752

# %%
# 토픽 개수, 키워드 개수를 정해주는 변수를 추가.
NUM_TOPICS = 2

NUM_TOPIC_WORDS = 30


def build_doc_term_mat(documents):
    # 문서-단어 행렬 만들어주는 함수.
    print("Building document-term matrix.")
    dictionary = corpora.Dictionary(documents)
    corpus = [dictionary.doc2bow(document) for document in documents]
        
    return corpus, dictionary


def print_topic_words(model):

    # 토픽 모델링 결과를 출력해 주는 함수.
    print("\nPrinting topic words.\n")
    
    for topic_id in range(model.num_topics):
        topic_word_probs = model.show_topic(topic_id, NUM_TOPIC_WORDS)
        print("Topic ID: {}".format(topic_id))
        
        for topic_word, prob in topic_word_probs:
            print("\t{}\t{}".format(topic_word, prob))
            
        print("\n")

def word_cloud(model):
    for topic_id in range(model.num_topics):
        wordcloud = WordCloud(font_path='Font/applegothic.ttf',
                          relative_scaling = 0.2,
                          # stopwords=STOPWORDS,
                          background_color='white',
                          ).generate_from_frequencies(dict(model.show_topic(topic_id,NUM_TOPIC_WORDS)))
        plt.figure(figsize=(16,8))
        plt.imshow(wordcloud)
        plt.axis("off")
        plt.show()
        print("\n\n")
        
        
# document-term matrix를 만들고,
corpus, dictionary = build_doc_term_mat(gensim_corpus)
# LDA를 실행.
model = models.ldamodel.LdaModel(corpus, num_topics=NUM_TOPICS, id2word=dictionary)
# 결과를 출력.
print_topic_words(model)
#워드 클라우드 출력
word_cloud(model)
# Out:
# Building document-term matrix.
#
# Printing topic words.
#
# Topic ID: 0
# 	케어	0.012189777567982674
# 	고함	0.00967722199857235
# 	헬스	0.00923934392631054
# 	임팩	0.007483057677745819
# 	메디	0.0052564977668225765
# 	제이	0.0046975878067314625
# 	플러스	0.004312952980399132
# 	헬스인	0.004002368077635765
# 	온누리	0.003635478438809514
# 	개가	0.00321824848651886
# 	티제이	0.0029858697671443224
# 	마이	0.0029274860862642527
# 	프리미엄	0.0029114738572388887
# 	메디칼	0.002892798976972699
# 	나이스	0.0028544263914227486
# 	반품요청	0.002708505606278777
# 	취소요청사유	0.002538527362048626
# 	파워	0.002504319418221712
# 	쿠폰사용	0.0021854189690202475
# 	천지인	0.0021527165081351995
# 	하다	0.0021438223775476217
# 	복산나이스	0.0021162708289921284
# 	개월	0.002039052080363035
# 	구매가능	0.0020185792818665504
# 	밴드	0.001954378793016076
# 	대성	0.0019429830135777593
# 	미선	0.0019263674039393663
# 	의약품	0.001914373366162181
# 	특별공급관	0.0018999215681105852
# 	세화	0.0018541889730840921
#
#
# Topic ID: 1
# 	대웅바이오	0.0039499974809587
# 	낱알	0.003910868428647518
# 	캡슐	0.0038781410548835993
# 	주시	0.003736908547580242
# 	고함	0.0035509876906871796
# 	한올	0.0034831056836992502
# 	소액	0.0033769498113542795
# 	마이너스잔고	0.0033600046299397945
# 	우루	0.0032630471978336573
# 	안됨	0.0032255942933261395
# 	소액처	0.003214034251868725
# 	인계	0.003165507223457098
# 	인수인계	0.0031479625031352043
# 	세금계산서	0.0030730946455150843
# 	부외품	0.0026931134052574635
# 	주시길	0.0026379225309938192
# 	재발	0.0026367444079369307
# 	미차장	0.0026079565286636353
# 	재발송	0.002575160237029195
# 	제약대웅	0.0025059995241463184
# 	당일	0.0025001936592161655
# 	문의확인후	0.002456746995449066
# 	부천	0.0024496656842529774
# 	우리	0.002378813922405243
# 	지금	0.0022875964641571045
# 	바구니	0.002201804891228676
# 	구매시	0.002184743294492364
# 	일반	0.002169686835259199
# 	바이오한올	0.002111661247909069
# 	재확인	0.002089476678520441

# %%
# pyLDAvis 불러오기
import pyLDAvis
import pyLDAvis.gensim_models as gensimvis

# pyLDAvis를 jupyter notebook에서 실행할 수 있게 활성화.
pyLDAvis.enable_notebook()

# pyLDAvis 실행.
data = gensimvis.prepare(model, corpus, model.id2word)
pyLDAvis.display(data)
# Out:
# C:\Users\manue\anaconda3\lib\site-packages\sklearn\decomposition\_lda.py:28: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   EPS = np.finfo(np.float).eps
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.3.1/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el1647617892199314082335364556"></div>
# <script type="text/javascript">
#
# var ldavis_el1647617892199314082335364556_data = {"mdsDat": {"x": [0.1313276369517678, -0.1313276369517678], "y": [0.0, 0.0], "topics": [1, 2], "cluster": [1, 1], "Freq": [51.048507693015374, 48.951492306984626]}, "tinfo": {"Term": ["\ucf00\uc5b4", "\ud5ec\uc2a4", "\uc784\ud329", "\ud5ec\uc2a4\uc778", "\ub300\uc6c5\ubc14\uc774\uc624", "\uc18c\uc561", "\ub0b1\uc54c", "\uc6b0\ub8e8", "\uc18c\uc561\ucc98", "\ub9c8\uc774\ub108\uc2a4\uc794\uace0", "\uc8fc\uc2dc", "\ucea1\uc290", "\ub9c8\uc774", "\ud30c\uc6cc", "\uc8fc\uc2dc\uae38", "\uace0\ud568", "\ubbf8\ucc28\uc7a5", "\uc548\ub428", "\uc778\uc218\uc778\uacc4", "\uc778\uacc4", "\uc628\ub204\ub9ac", "\uac1c\uac00", "\ucc9c\uc9c0\uc778", "\uc81c\uc57d\ub300\uc6c5", "\ud55c\uc62c", "\ub9e4\ubab0", "\uba54\ub514", "\ub300\uc131", "\ud2b9\ubcc4\uacf5\uae09\uad00", "\ubd80\ucc9c", "\uc18c\uc561\ucc98", "\uc9c1\uac70\ub798\uc694\uccad", "\uc6b0\ub8e8", "\ubaa8\ubc14\uc77c", "\ub3c4\ub9e4\ubab0", "\uad00\ubc30", "\uac00\uc704", "\ud61c\ud0dd\uc774\uc6a9", "\uc0c8\ubcbd\uc2dc", "\uc6b0\ub8e8\uc0ac", "\ube44\ubc88", "\uc18c\uc561", "\uc2e0\uc6a9", "\uc794\uace0\uc774\ub3d9", "\ub9e4\ubab0", "\uc120\ud76c", "\uc5e0\uc11c\ud074", "\uc11c\ud074", "\uc0c8\uc0b4", "\ud3ec\ud568", "\uc218\uae08", "\uc8fc\ubb38\uacb0\uc81c", "\ub364\uc52c", "\ub9c8\ud2b8\uc0c1\ud488\uad8c", "\uacb0\uc81c\ubc29\ubc95", "\uc2e0\uc6a9\uce74\ub4dc\uc0ac\uc804\ub4f1\ub85d", "\uad6d\ubbfc\uce74\ub4dc", "\uc124\ubb38", "\uc740\ud589", "\uc0c8\uc0b4\uc5f0\uace0", "\ub300\uc6c5\ubc14\uc774\uc624", "\ub9c8\uc774\ub108\uc2a4\uc794\uace0", "\uc5f0\uc9c8", "\uc7ac\ud655\uc778\uc694\uccad", "\uc0ac\uc804", "\uac04\ud3b8", "\uc8fc\uc2dc\uae38", "\ubcf4\ub355\uba54\ub514", "\ubbf8\ucc28\uc7a5", "\ub0b1\uc54c", "\ucc3d\uc6d0", "\ub300\uc6c5\uc804", "\uc8fc\uc2dc", "\uc81c\uc57d\ub300\uc6c5", "\uc5ed\ub300\uae09\uc774\ubca4\ud2b8", "\ucea1\uc290", "\ub0b1\uc54c\ubc18\ud488", "\uc2e0\ud55c", "\ubd80\ucc9c", "\uc778\uc218\uc778\uacc4", "\uc778\uacc4", "\uc548\ub428", "\ub300\uc6c5\uc624\uc0b0", "\ubb38\uc758\ud655\uc778\ud6c4", "\uc8fc\uae30", "\ud55c\uc62c", "\ud310\ucd09\ubb3c\ubc30", "\uc7ac\ubc1c", "\uc7ac\ubc1c\uc1a1", "\ubc14\uc774\uc624\ud55c\uc62c", "\uad6c\ub9e4\uc2dc", "\uc138\uae08\uacc4\uc0b0\uc11c", "\uc77c\ubc18", "\ubd80\uc678\ud488", "\uc2a4\ud0c0", "\uc6b0\ub9ac", "\ubc14\uad6c\ub2c8", "\ub2f9\uc77c", "\uace0\ud568", "\uc9c0\uae08", "\uc7ac\ud655\uc778", "\uac00\uc785\uad00\ub828", "\ubbfc\ucf00\uc5b4", "\ub300\uc131", "\ud2b9\ubcc4\uacf5\uae09\uad00", "\uac1c\uc124", "\ubc31\uad11", "\ub3d9\ubb3c\uc57d\uad6d\uac1c\uc124\ub4f1\ub85d\uc99d", "\ub300\uc131\uba54\ub514\ucf00\uc5b4", "\ucf00\uc5b4", "\uc784\ud329\ucf00\uc5b4", "\uc774\ud50c\ub7ec\uc2a4\uc815", "\ub9c8\uc774\ud398\uc774\uc9c0", "\ubc30\uc815\ubb38\uc758", "\ud30c\uc190", "\ubc30\uc815\uc5ec\ubd80", "\ubc31\uad11\uc758\uc57d\ud488", "\uc0dd\uc0b0\uc911\ub2e8", "\uc784\ud329", "\uc0c1\uc0ac", "\uc885\uadfc\ub2f9", "\uc774\ud50c\ub7ec\uc2a4", "\uc138\ud654\ud5ec\uc2a4\ucf00\uc5b4", "\ucf00\uc774\ub514", "\ub2e5\ud130", "\uba74\ud5c8\uc99d", "\uc81c\uc815", "\uc81c\uc77c\ud5ec\uc2a4\ucf00\uc5b4", "\ucc9c\uc9c0\uc778", "\uc13c\uc2a4", "\ud55c\uc2e0\uc57d\ud488", "\ud5ec\uc2a4", "\ud5ec\uc2a4\uc778", "\ud30c\uc6cc", "\ud55c\uc2e0", "\uc0dd\uc0b0", "\ubc34\ub4dc", "\ub9c8\uc774", "\uad6c\uc785\uac00\ub2a5", "\uc81c\uc77c", "\uc804\ud658", "\uae08\ubcf4", "\ud06c\ub9bc", "\ucfe0\ud3f0\uc0ac\uc6a9", "\ub4f1\ub85d\uc99d", "\ubbf8\uc120", "\ucde8\uc18c\uc694\uccad\uc0ac\uc720", "\uac1c\uac00", "\uc628\ub204\ub9ac", "\uad6c\ub9e4\uac00\ub2a5", "\uba54\ub514\uce7c", "\uba54\ub514", "\uace0\ud568", "\ubc18\ud488\uc694\uccad", "\ud50c\ub7ec\uc2a4", "\uc81c\uc774", "\uc138\ud654", "\uc758\uc57d\ud488", "\ud504\ub9ac\ubbf8\uc5c4", "\ud2f0\uc81c\uc774", "\ub098\uc774\uc2a4", "\ud558\ub2e4", "\uac1c\uc6d4", "\ubcf5\uc0b0\ub098\uc774\uc2a4"], "Freq": [1673.0, 1276.0, 1029.0, 553.0, 568.0, 483.0, 573.0, 466.0, 459.0, 483.0, 551.0, 585.0, 411.0, 345.0, 382.0, 1827.0, 379.0, 48 ...

# %%
pyLDAvis.save_html(data,'201907-12_kkma_lda.html')
# Out:
# C:\Users\manue\AppData\Roaming\Python\Python38\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# # 월별 문의사항 데이터 KR-wordrank 분석

# %% [markdown]
# 참조 사이트: https://pypi.org/project/krwordrank/

# %%
from krwordrank.word import KRWordRank
# Out:
# /Users/hyunkyungwoo/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
min_count = 5   # 단어의 최소 출현 빈도수 (그래프 생성 시)
max_length = 10 # 단어의 최대 길이
wordrank_extractor = KRWordRank(min_count=min_count, max_length=max_length)
# Out:
# /Users/hyunkyungwoo/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
beta = 0.85    # PageRank의 decaying factor beta
max_iter = 10
texts = tfidf_corpus #1차원인 list가 필요해 tfidf에서 쓰인 corpus를 그대로 사용함.
keywords, rank, graph = wordrank_extractor.extract(texts, beta, max_iter)
# Out:
# /Users/hyunkyungwoo/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
for word, r in sorted(keywords.items(), key=lambda x:x[1], reverse=True)[:30]:
        print('%8s:\t%.4f' % (word, r))
# Out:
#       플러:	2.7769
#      마일리:	2.7054
#       이벤:	2.5283
#       포인:	2.4820
#       담당:	2.2132
#       주문:	1.5727
#       이마:	1.5708
#       바이:	1.5707
#       제이:	1.5478
#       예치:	1.5256
#       국민:	1.4880
#       어려:	1.4270
#       전용:	1.3967
#      스트로:	1.3859
#       프로:	1.3499
#       신용:	1.2902
#       상품:	1.2789
#       나이:	1.2669
#       연락:	1.2028
#       마이:	1.1553
#       된다:	1.1308
#       메디:	1.0780
#       계산:	1.0664
#       종이:	1.0651
#      프리미:	1.0367
#       판촉:	1.0312
#       스위:	1.0000
#       현금:	1.0000
#       카라:	1.0000
#       장바:	1.0000
# /Users/hyunkyungwoo/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
SW
# Out:
# /Users/hyunkyungwoo/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# {'가\n',
#  '가까스로\n',
#  '가령\n',
#  '각\n',
#  '각각\n',
#  '각자\n',
#  '각종\n',
#  '갖고말하자면\n',
#  '같다\n',
#  '같이\n',
#  '개의치않고\n',
#  '거니와\n',
#  '거바\n',
#  '거의\n',
#  '것\n',
#  '것과 같이\n',
#  '것들\n',
#  '게다가\n',
#  '게우다\n',
#  '겨우\n',
#  '견지에서\n',
#  '결과에 이르다\n',
#  '결국\n',
#  '결론을 낼 수 있다\n',
#  '겸사겸사\n',
#  '고려하면\n',
#  '고로\n',
#  '곧\n',
#  '공동으로\n',
#  '과\n',
#  '과연\n',
#  '관계가 있다\n',
#  '관계없이\n',
#  '관련이 있다\n',
#  '관하여\n',
#  '관한\n',
#  '관해서는\n',
#  '구\n',
#  '구체적으로\n',
#  '구토하다\n',
#  '그\n',
#  '그들\n',
#  '그때\n',
#  '그래\n',
#  '그래도\n',
#  '그래서\n',
#  '그러나\n',
#  '그러니\n',
#  '그러니까\n',
#  '그러면\n',
#  '그러므로\n',
#  '그러한즉\n',
#  '그런 까닭에\n',
#  '그런데\n',
#  '그런즉\n',
#  '그럼\n',
#  '그럼에도 불구하고\n',
#  '그렇게 함으로써\n',
#  '그렇지\n',
#  '그렇지 않다면\n',
#  '그렇지 않으면\n',
#  '그렇지만\n',
#  '그렇지않으면\n',
#  '그리고\n',
#  '그리하여\n',
#  '그만이다\n',
#  '그에 따르는\n',
#  '그위에\n',
#  '그저\n',
#  '그중에서\n',
#  '그치지 않다\n',
#  '근거로\n',
#  '근거하여\n',
#  '기대여\n',
#  '기점으로\n',
#  '기준으로\n',
#  '기타\n',
#  '까닭으로\n',
#  '까악\n',
#  '까지\n',
#  '까지 미치다\n',
#  '까지도\n',
#  '꽈당\n',
#  '끙끙\n',
#  '끼익\n',
#  '나\n',
#  '나머지는\n',
#  '남들\n',
#  '남짓\n',
#  '너\n',
#  '너희\n',
#  '너희들\n',
#  '네\n',
#  '넷\n',
#  '년\n',
#  '논하지 않다\n',
#  '놀라다\n',
#  '누가 알겠는가\n',
#  '누구\n',
#  '다른\n',
#  '다른 방면으로\n',
#  '다만\n',
#  '다섯\n',
#  '다소\n',
#  '다수\n',
#  '다시 말하자면\n',
#  '다시말하면\n',
#  '다음\n',
#  '다음에\n',
#  '다음으로\n',
#  '단지\n',
#  '답다\n',
#  '당신\n',
#  '당장\n',
#  '대로 하다\n',
#  '대하면\n',
#  '대하여\n',
#  '대해 말하자면\n',
#  '대해서\n',
#  '댕그\n',
#  '더구나\n',
#  '더군다나\n',
#  '더라도\n',
#  '더불어\n',
#  '더욱더\n',
#  '더욱이는\n',
#  '도달하다\n',
#  '도착하다\n',
#  '동시에\n',
#  '동안\n',
#  '된바에야\n',
#  '된이상\n',
#  '두번째로\n',
#  '둘\n',
#  '둥둥\n',
#  '뒤따라\n',
#  '뒤이어\n',
#  '든간에\n',
#  '들\n',
#  '등\n',
#  '등등\n',
#  '딩동\n',
#  '따라\n',
#  '따라서\n',
#  '따위\n',
#  '따지지 않다\n',
#  '딱\n',
#  '때\n',
#  '때가 되어\n',
#  '때문에\n',
#  '또\n',
#  '또한\n',
#  '뚝뚝\n',
#  '라 해도\n',
#  '령\n',
#  '로\n',
#  '로 인하여\n',
#  '로부터\n',
#  '로써\n',
#  '륙\n',
#  '를\n',
#  '마음대로\n',
#  '마저\n',
#  '마저도\n',
#  '마치\n',
#  '막론하고\n',
#  '만 못하다\n',
#  '만약\n',
#  '만약에\n',
#  '만은 아니다\n',
#  '만이 아니다\n',
#  '만일\n',
#  '만큼\n',
#  '말하자면\n',
#  '말할것도 없고\n',
#  '매\n',
#  '매번\n',
#  '메쓰겁다\n',
#  '몇\n',
#  '모\n',
#  '모두\n',
#  '무렵\n',
#  '무릎쓰고\n',
#  '무슨\n',
#  '무엇\n',
#  '무엇때문에\n',
#  '물론\n',
#  '및\n',
#  '바꾸어말하면\n',
#  '바꾸어말하자면\n',
#  '바꾸어서 말하면\n',
#  '바꾸어서 한다면\n',
#  '바꿔 말하면\n',
#  '바로\n',
#  '바와같이\n',
#  '밖에 안된다\n',
#  '반대로\n',
#  '반대로 말하자면\n',
#  '반드시\n',
#  '버금\n',
#  '보는데서\n',
#  '보다더\n',
#  '보드득\n',
#  '본대로\n',
#  '봐\n',
#  '봐라\n',
#  '부류의 사람들\n',
#  '부터\n',
#  '불구하고\n',
#  '불문하고\n',
#  '붕붕\n',
#  '비걱거리다\n',
#  '비교적\n',
#  '비길수 없다\n',
#  '비로소\n',
#  '비록\n',
#  '비슷하다\n',
#  '비추어 보아\n',
#  '비하면\n',
#  '뿐만 아니라\n',
#  '뿐만아니라\n',
#  '뿐이다\n',
#  '삐걱\n',
#  '삐걱거리다\n',
#  '사\n',
#  '삼\n',
#  '상대적으로 말하자면\n',
#  '생각한대로\n',
#  '설령\n',
#  '설마\n',
#  '설사\n',
#  '셋\n',
#  '소생\n',
#  '소인\n',
#  '솨\n',
#  '쉿\n',
#  '습니까\n',
#  '습니다\n',
#  '시각\n',
#  '시간\n',
#  '시작하여\n',
#  '시초에\n',
#  '시키다\n',
#  '실로\n',
#  '심지어\n',
#  '아\n',
#  '아니\n',
#  '아니나다를가\n',
#  '아니라면\n',
#  '아니면\n',
#  '아니었다면\n',
#  '아래윗\n',
#  '아무거나\n',
#  '아무도\n',
#  '아야\n',
#  '아울러\n',
#  '아이\n',
#  '아이고\n',
#  '아이구\n',
#  '아이야\n',
#  '아이쿠\n',
#  '아하\n',
#  '아홉\n',
#  '안 그러면\n',
#  '않기 위하여\n',
#  '않기 위해서\n',
#  '알 수 있다\n',
#  '알았어\n',
#  '앗\n',
#  '앞에서\n',
#  '앞의것\n',
#  '야\n',
#  '약간\n',
#  '양자\n',
#  '어\n',
#  '어기여차\n',
#  '어느\n',
#  '어느 년도\n',
#  '어느것\n',
#  '어느곳\n',
#  '어느때\n',
#  '어느쪽\n',
#  '어느해\n',
#  '어디\n',
#  '어때\n',
#  '어떠한\n',
#  '어떤\n',
#  '어떤것\n',
#  '어떤것들\n',
#  '어떻게\n',
#  '어떻해\n',
#  '어이\n',
#  '어째서\n',
#  '어쨋든\n',
#  '어쩔수 없다\n',
#  '어찌\n',
#  '어찌됏든\n',
#  '어찌됏어\n',
#  '어찌하든지\n',
#  '어찌하여\n',
#  '언제\n',
#  '언젠가\n',
#  '얼마\n',
#  '얼마 안 되는 것\n',
#  '얼마간\n',
#  '얼마나\n',
#  '얼마든지\n',
#  '얼마만큼\n',
#  '얼마큼\n',
#  '엉엉\n',
#  '에\n',
#  '에 가서\n',
#  '에 달려 있다\n',
#  '에 대해\n',
#  '에 있다\n',
#  '에 한하다\n',
#  '에게\n',
#  '에서\n',
#  '여\n',
#  '여기\n',
#  '여덟\n',
#  '여러분\n',
#  '여보시오\n',
#  '여부\n',
#  '여섯\n',
#  '여전히\n',
#  '여차\n',
#  '연관되다\n',
#  '연이서\n',
#  '영\n',
#  '영차\n',
#  '옆사람\n',
#  '예\n',
#  '예를 들면\n',
#  '예를 들자면\n',
#  '예컨대\n',
#  '예하면\n',
#  '오\n',
#  '오로지\n',
#  '오르다\n',
#  '오자마자\n',
#  '오직\n',
#  '오호\n',
#  '오히려\n',
#  '와\n',
#  '와 같은 사람들\n',
#  '와르르\n',
#  '와아\n',
#  '왜\n',
#  '왜냐하면\n',
#  '외에도\n',
#  '요만큼\n',
#  '요만한 것\n',
#  '요만한걸\n',
#  '요컨대\n',
#  '우르르\n',
#  '우리\n',
#  '우리들\n',
#  '우선\n',
#  '우에 종합한것과같이\n',
#  '운운\n',
#  '월\n',
#  '위에서 서술한바와같이\n',
#  '위하여\n',
#  '위해서\n',
#  '윙윙\n',
#  '육\n',
#  '으로\n',
#  '으로 인하여\n',
#  '으로서\n',
#  '으로써\n',
#  '을\n',
#  '응\n',
#  '응당\n',
#  '의\n',
#  '의거하여\n',
#  '의지하여\n',
#  '의해\n',
#  '의해되다\n',
#  '의해서\n',
#  '이\n',
#  '이 되다\n',
#  '이 때문에\n',
#  '이 밖에\n',
#  '이 외에\n',
#  '이 정도의\n',
#  '이것\n',
#  '이곳\n',
#  '이때\n',
#  '이라면\n',
#  '이래\n',
#  '이러이러하다\n',
#  '이러한\n',
#  '이런\n',
#  '이럴정도로\n',
#  '이렇게 많은 것\n',
#  '이렇게되면\n',
#  '이렇게말하자면\n',
#  '이렇구나\n',
#  '이로 인하여\n',
#  '이르기까지\n',
#  '이리하여\n',
#  '이만큼\n',
#  '이번\n',
#  '이봐\n',
#  '이상\n',
#  '이어서\n',
#  '이었다\n',
#  '이와 같다\n',
#  '이와 같은\n',
#  '이와 반대로\n',
#  '이와같다면\n',
#  '이외에도\n',
#  '이용하여\n',
#  '이유만으로\n',
#  '이젠\n',
#  '이지만\n',
#  '이쪽\n',
#  '이천구\n',
#  '이천육\n',
#  '이천칠\n',
#  '이천팔\n',
#  '인 듯하다\n',
#  '인젠\n',
#  '일\n',
#  '일것이다\n',
#  '일곱\n',
#  '일단\n',
#  '일때\n',
#  '일반적으로\n',
#  '일지라도\n',
#  '임에 틀림없다\n',
#  '입각하여\n',
#  '입장에서\n',
#  '잇따라\n',
#  '있다\n',
#  '자\n',
#  '자기\n',
#  '자기집\n',
#  '자마자\n',
#  '자신\n',
#  '잠깐\n',
#  '잠시\n',
#  '저\n',
#  '저것\n',
#  '저것만큼\n',
#  '저기\n',
#  '저쪽\n',
#  '저희\n',
#  '전부\n',
#  '전자\n',
#  '전후\n',
#  '점에서 보아\n',
#  '정도에 이르다\n',
#  '제\n',
#  '제각기\n',
#  '제외하고\n',
#  '조금\n',
#  '조차\n',
#  '조차도\n',
#  '졸졸\n',
#  '좀\n',
#  '좋아\n',
#  '좍좍\n',
#  '주룩주룩\n',
#  '주저하지 않고\n',
#  '줄은 몰랏다\n',
#  '줄은모른다\n',
#  '중에서\n',
#  '중의하나\n',
#  '즈음하여\n',
#  '즉\n',
#  '즉시\n',
#  '지든지\n',
#  '지만\n',
#  '지말고\n',
#  '진짜로\n',
#  '쪽으로\n',
#  '차라리\n',
#  '참\n',
#  '참나\n',
#  '첫번째로\n',
#  '쳇\n',
#  '총적으로\n',
#  '총적으로 말하면\n',
#  '총적으로 보면\n',
#  '칠\n',
#  '콸콸\n',
#  '쾅쾅\n',
#  '쿵\n',
#  '타다\n',
#  '타인\n',
#  '탕탕\n',
#  '토하다\n',
#  '통하여\n',
#  '툭\n',
#  '퉤\n',
#  '틈타\n',
#  '팍\n',
#  '팔\n',
#  '퍽\n',
#  '펄렁\n',
#  '하\n',
#  '하게될것이다\n',
#  '하게하다\n',
#  '하겠는가\n',
#  '하고 있다\n',
#  '하고있었다\n',
#  '하곤하였다\n',
#  '하구나\n',
#  '하기 때문에\n',
#  '하기 위하여\n',
#  '하기는한데\n',
#  '하기만 하면\n',
#  '하기보다는\n',
#  '하기에\n',
#  '하나\n',
#  '하느니\n',
#  '하는 김에\n',
#  '하는 편이 낫다\n',
#  '하는것도\n',
#  '하는것만 못하다\n',
#  '하는것이 낫다\n',
#  '하는바\n',
#  '하더라도\n',
#  '하도다\n',
#  '하도록시키다\n',
#  '하도록하다\n',
#  '하든지\n',
#  '하려고하다\n',
#  '하마터면\n',
#  '하면 할수록\n',
#  '하면된다\n',
#  '하면서\n',
#  '하물며\n',
#  '하여금\n',
#  '하여야\n',
#  '하자마자\n',
#  '하지 않는다면\n',
#  '하지 않도록\n',
#  '하지마\n',
#  '하지마라\n',
#  '하지만\n',
#  '하하\n',
#  '한 까닭에\n',
#  '한 이유는\n',
#  '한 후\n',
#  '한다면\n',
#  '한다면 몰라도\n',
#  '한데\n',
#  '한마디\n',
#  '한적이있다\n',
#  '한켠으로는\n',
#  '한항목\n',
#  '할 따름이다\n',
#  '할 생각이다\n',
#  '할 줄 안다\n',
#  '할 지경이다\n',
#  '할 힘이 있다\n',
#  '할때\n',
#  '할만하다\n',
#  '할망정\n',
#  '할뿐\n',
#  '할수있다\n',
#  '할수있어\n',
#  '할줄알다\n',
#  '할지라도\n',
#  '할지언정\n',
#  '함께\n',
#  '해도된다\n',
#  '해도좋다\n',
#  '해봐요\n',
#  '해서는 안된다\n',
#  '해야한다\n',
#  '해요\n',
#  '했어요\n',
#  '향하다\n',
#  '향하여\n',
#  '향해서\n',
#  '허\n',
#  '허걱\n',
#  '허허\n',
#  '헉\n',
#  '헉헉\n',
#  '헐떡헐떡\n',
#  '형식으로 쓰여\n',
#  '혹시\n',
#  '혹은\n',
#  '혼자\n',
#  '훨씬\n',
#  '휘익\n',
#  '휴\n',
#  '흐흐\n',
#  '흥\n',
#  '힘입어'}

# %%
stopwords = SW
passwords = {word:score for word, score in sorted(
    keywords.items(), key=lambda x:-x[1])[:300] if not (word in stopwords)}
# Out:
# /Users/hyunkyungwoo/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
krwordrank_cloud = WordCloud(
    font_path = '/Library/Fonts/AppleGothic.ttf',
    width = 800,
    height = 800,
    background_color="white"
)
krwordrank_cloud = krwordrank_cloud.generate_from_frequencies(passwords)
# Out:
# /Users/hyunkyungwoo/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
fig = plt.figure(figsize=(10, 10))
plt.imshow(krwordrank_cloud, interpolation="bilinear")
plt.show()
# Out:
# /Users/hyunkyungwoo/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
fig.savefig('./lalaland_wordcloud.png') #그림 저장
