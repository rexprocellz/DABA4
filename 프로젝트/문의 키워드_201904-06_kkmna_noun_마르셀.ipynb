# %%
import nltk
import numpy as np
import pandas as pd
from konlpy.tag import Mecab
from konlpy.tag import Okt
from konlpy.tag import Komoran
from konlpy.tag import Hannanum
from konlpy.tag import Kkma
from keras.models import load_model
from tqdm import tqdm
from tqdm import tqdm_notebook
from gensim import corpora
from gensim import models
from time import time
from wordcloud import WordCloud
import seaborn as sns
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'Malgun Gothic'
# %matplotlib inline
import warnings
warnings.filterwarnings(action='ignore') 

mecab = Mecab()
# okt = Okt()
# komoran=Komoran()
# hannanum=Hannanum()
kkma=Kkma()
# Out:
# C:\Users\manue\anaconda3\lib\site-packages\gensim\similarities\__init__.py:15: UserWarning: The gensim.similarities.levenshtein submodule is disabled, because the optional Levenshtein package <https://pypi.org/project/python-Levenshtein/> is unavailable. Install Levenhstein (e.g. `pip install python-Levenshtein`) to suppress this warning.
#   warnings.warn(msg)
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\MeCab\__init__.py in __init__(self, rawargs)
#     132         try:
# --> 133             super(Tagger, self).__init__(args)
#     134         except RuntimeError as ee:
#
# RuntimeError:
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\konlpy\tag\_mecab.py in __init__(self, dicpath)
#     107         try:
# --> 108             self.tagger = Tagger('-d %s' % dicpath)
#     109             self.tagset = utils.read_json('%s/data/tagset/mecab.json' % utils.installpath)
#
# ~\anaconda3\lib\site-packages\MeCab\__init__.py in __init__(self, rawargs)
#     134         except RuntimeError as ee:
# --> 135             raise RuntimeError(error_info(rawargs)) from ee
#     136
#
# RuntimeError:
# ----------------------------------------------------------
#
# Failed initializing MeCab. Please see the README for possible solutions:
#
#     https://github.com/SamuraiT/mecab-python3#common-issues
#
# If you are still having trouble, please file an issue here, and include the
# ERROR DETAILS below:
#
#     https://github.com/SamuraiT/mecab-python3/issues
#
# issueを英語で書く必要はありません。
#
# ------------------- ERROR DETAILS ------------------------
# arguments: -d /usr/local/lib/mecab/dic/mecab-ko-dic
# [ifs] no such file or directory: C:\Users\manue\anaconda3\lib\site-packages\unidic\dicdir\mecabrc
# ----------------------------------------------------------
#
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# <ipython-input-1-94ded413af49> in <module>
#      21 warnings.filterwarnings(action='ignore')
#      22
# ---> 23 mecab = Mecab()
#      24 # okt = Okt()
#      25 # komoran=Komoran()
#
# ~\anaconda3\lib\site-packages\konlpy\tag\_mecab.py in __init__(self, dicpath)
#     109             self.tagset = utils.read_json('%s/data/tagset/mecab.json' % utils.installpath)
#     110         except RuntimeError:
# --> 111             raise Exception('The MeCab dictionary does not exist at "%s". Is the dictionary correctly installed?\nYou can also try entering the dictionary path when initializing the Mecab class: "Mecab(\'/some/dic/path\')"' % dicpath)
#     112         except NameError:
#     113             raise Exception('Install MeCab in order to use it: http://konlpy.org/en/latest/install/')
#
# Exception: The MeCab dictionary does not exist at "/usr/local/lib/mecab/dic/mecab-ko-dic". Is the dictionary correctly installed?
# You can also try entering the dictionary path when initializing the Mecab class: "Mecab('/some/dic/path')"

# %%
from ckonlpy.tag import Twitter

twitter = Twitter()

twitter.pos('Check')
twitter.add_dictionary(words='아이오아이', tag='Noun')
twitter.add_dictionary(['트와이스', 'tt'], tag='Noun')
# Out:
# C:\Users\manue\anaconda3\lib\site-packages\konlpy\tag\_okt.py:16: UserWarning: "Twitter" has changed to "Okt" since KoNLPy v0.4.5.
#   warn('"Twitter" has changed to "Okt" since KoNLPy v0.4.5.')

# %% [markdown]
# # 데이터 불러오기

# %%
df = pd.read_excel('Raw Data/(공유) 더샵약국몰_상담내역_2019.04-06.xlsx')
#(공유) 더샵약국몰_상담내역_2019.04-06.xlsx
#(공유) 더샵약국몰_상담내역_2019.07-12.xlsx
#(공유) 더샵약국몰_상담내역_2020.01-06.xlsx
#(공유) 더샵약국몰_상담내역_2020.07-12.xlsx
#(공유) 더샵약국몰_상담내역_2021.01-05.xlsx

# %%
df.head(3)
# Out:
#                   상담일시 통화유형 상담구분       상담유형         상담상세  \
# 0  2019-06-28 18:17:48   수신  약국몰       이용문의        이벤트관련
# 1  2019-06-28 18:04:23   발신  약국몰       회원정보       고객정보변경
# 2  2019-06-28 17:57:41   발신  약국몰  반품환불(미사용)  반품회수지연(미사용)
#
#                                                 문의사항
# 0  \n\n역대급이벤트 문의\n>15만원이상 구매하셔서 이마트 1만원상품권 선택하신걸로...
# 1  \n\n세금계산서 메일 @으로 되어있음 / 기입요청\n> shee84882000@h...
# 2  \n폐업반품으로 도매업체들 다 반품헀고 회수 모두 했는데 탑헬스케어/건강두배로만 미...

# %%
df.shape
# Out:
# (24582, 6)

# %% [markdown]
# # 문의사항 중 null 데이터 개수 확인

# %%
df['문의사항'].isnull().sum()
# Out:
# 399

# %% [markdown]
# # 본문 중 null 데이터 제외

# %%
temp_idx = df[df['문의사항'].isnull()].index

# %%
df = df.drop(temp_idx)

# %%
df['문의사항'].isnull().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (24183, 6)

# %% [markdown]
# # 상담 내용 데이터 정제

# %%
import re
# from pykospacing import spacing

def define_stopwords(path):
    
    SW = set()
    # 불용어를 추가하는 방법 1.
    #for i in string.punctuation:
        #SW.add(i)
    SW.update(["요청", "완료", "안내", "확인", "반품", "결제", "약국", "신청", "배송", "취소", "가능", "문의", "주문", "구매"])
    SW.update(['예정', '연락', '처리', '대웅', '제품', '사용', '더샵', '발송', '업체', '변경', '방법', '안내드림', '쿠폰', '이벤트', '등록', '문자'])
    SW.update(['대웅제약', '상품', '적립', '이상', '카드', '금일', '승인', '해당', '전달', '거점', '수정', '담당자', '전화', '통화', '팩스'])
    SW.update(['다함', '진행', '오후', '사업자', '잔고', '할인', '금액', '오늘', '회수', '오산', '약사', '번호', '검색', '판매', '도착', '주소'])
    SW.update(['메일', '관리', '환불', '페이', '기간', '유효', '사유', '기사', '불가', '출고', '약품', '약속', '영업', '세금', '발행', '전체'])
    SW.update(['사원', '방문', '재고', '제조', '이오', '부분', '포장', '주문건', '관련', '박스', '공장', '반품건', '수량', '정지', '배송문', '제약'])
    SW.update(['즉시', '통장', '처방전', '포인트', '전용', '서비스', '보관', '복원', '대웅바이', '사용법', '선구매', '소멸', '적용', '개선', '오후시'])
    SW.update(['포인트몰', '선발행', '마감', '환입실', '등급', '지급', '서울지점', '삭제', '안내함', '구입', '연락처', '마일리지', '마이너스', '연락드림'])
    SW.update(['차장', '드림', '바이오', '이력', '어려움', '판촉물', '코드', '본인', '품절', '혜택', '직거래', '사입', '인천', '가입', '내일', '통화건'])
    SW.update(['예치금', '양해', '지연', '시간', '이후', '부재', '폐업', '오전', '내역', '여부', '연락드리', '교환', '접수', '이마트', '추가', '소비자'])
    SW.update(['특별', '경우', '수신', '공급관', '품목', '월요일', '중단', '상품권', '내용', '배정', '추후', '익일', '서울', '정보', '오류', '택배'])
    SW.update(['기존', '일자', '미배송', '시스템', '새벽', '당첨', '입금', '시분', '계좌', '국민', '통합', '복합', '이동', '오결재', '매핑', '향남'])
    SW.update(['참여', '역대', '성규', '가상', '채널', '스마', '김선', '산서', '이번', '상태', '공지', '어제', '입력', '매출', '전송', '장바구니'])
    SW.update(['소통', '사본', '지문', '소요', '기재', '조회', '다음', '고객', '발급', '도매', '부족', '연결', '오주문', '지역', '정도', '건강'])
    SW.update(['핸드폰', '가격', '종료', '인천약', '이용', '인수', '기한', '오주문', '부천시', '유통', '작업', '동물', '확인차', '알반품', '노출', '종료'])
    SW.update(['공급', '예정일', '건지', '송문', '품건', '현재', '거래', '계산서', '하심', '환입', '페이지', '전용관', '아이디', '지점', '카톡', '만우절'])
    SW.update(['필요', '결제완료', '반품신청', '확인요청', '만원', '취소요청', '영업사원', '있음', '기사님', '배송예정일', '배송예정', '문건', '유효기간', '취소완료','반품신청건', '주신', '백제'])
    SW.update(['수거', '통장사본', '구입문의', '명세표', '민정', '회원', '마트', '이전', '거래명세표', '배송문의', '희망', '누락', '이관', '거부', '회신'])
    
    #SW.update(["안내", "프로슈머", "요청", "긴급", "문의", "수정", "리스트", "감사", "관련", "부탁", "재문", "재문의", "추가", "제목", "등록", "정보"])
    #SW.update(['입니다', '또는', '추가', '드립니다', '드려요', '드릴게요', '가격', '합니다', '바랍니다', '부탁드립니다', '습니다', '지역', '급급', '월일'])
    #SW.update(['병원', '박일', '모두', '월호', '게시물', '위주', '드림', '의원', '투명', '이야기', '연세', '이비인후과', '에서'])
    #SW.update(['제공', '추천', '원내', '제작', '주력', '견적', '일정', '분석', '제작', '관리', '실장', '선생', '메일', '파일', '방법', '하나', '우리'])
    #SW.update(['구매', '후기', '테일', '구입', '이것저것', '이거', '직구', '추천', '가지', '오바', '성공', '주문', '오늘', '여러분', '하세', '오랜만','기타'])
    # 불용어를 추가하는 방법 2.
    # stopwords-ko.txt에 직접 추가
    
    with open(path, encoding='utf-8') as f:
        for word in f:
            SW.add(word)

    return SW


def list_of_list(docs):
    temp_list = []
    
    for doc in docs:
        temp = doc.split(', ')
        temp_list.append(temp)
        
    return temp_list


def text_cleaning(docs):
    """
        1. 한글만 추출.
        
        2. 자음/모음 표현 처리방법.
        
            1) "ㅇㅇ" ,"ㅋㅋㅋㅋㅋ" 같은 자음만 존재하는 표현이나, "ㅡㅡ", "ㅠㅠ" 같은 모음만 존재하는 표현들은
            의미는 있으나 중요한 의미를 가지고 있지 않다고 판단하여 제거.
            
            2) 이러한 표현들도 전부 emoticon 같은 감정 표현의 의성어로 쓰거나, 단축 표현이므로 제거하지 않음. 
            
        3. http:// 로 시작하는 hyperlink 제거.
        
        4. 특수문자 제거.
        
        5. 이메일 주소 제거.
    
    """
    # Series의 object를 str로 변경.
    #docs = [str(doc) for doc in docs]
    
    # 1
    pattern1 = re.compile('[^ ㄱ-ㅣ가-힣]+')
    docs = [pattern1.sub("", docs)] 
    #print(docs)
    
    # 2
    pattern2 = re.compile("[ㄱ-ㅎ]*[ㅏ-ㅢ]*")
    docs = [pattern2.sub("", doc) for doc in docs]
    #print(docs)
    
    # 3
    #pattern3 = re.compile(r"\b(https?:\/\/)?([\w.]+){1,2}(\.[\w]{2,4}){1,2}(.*)")
    #docs = pattern3.sub("", docs) 
    
    # 4
    pattern4 = re.compile("[\{\}\[\]\/?.,;:|\)*~`!^\-_+<>@\#$%&\\\=\(\'\"]")
    docs = pattern4.sub("", str(docs))
    #print(docs)
    
    # 5
    pattern5 = re.compile('\S*@\S*\s?')
    docs = pattern5.sub("", docs)
    #print(docs)
    
    # 띄어쓰기 다시하기
    # docs = spacing(docs)
    #print(docs)
    
    print('Done!')
        
    return docs


def slicing_time_str(time_str):
    return time_str[0:10]
# Out:
# C:\Users\manue\AppData\Roaming\Python\Python38\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <>:90: DeprecationWarning: invalid escape sequence \{
# <>:95: DeprecationWarning: invalid escape sequence \S
# <>:90: DeprecationWarning: invalid escape sequence \{
# <>:95: DeprecationWarning: invalid escape sequence \S
# <ipython-input-80-7385eabec0a7>:90: DeprecationWarning: invalid escape sequence \{
#   pattern4 = re.compile("[\{\}\[\]\/?.,;:|\)*~`!^\-_+<>@\#$%&\\\=\(\'\"]")
# <ipython-input-80-7385eabec0a7>:95: DeprecationWarning: invalid escape sequence \S
#   pattern5 = re.compile('\S*@\S*\s?')

# %% [markdown]
# # 본문 데이터 정제 후 본문클리닝에 저장

# %%
df['문의사항_클리닝'] = df['문의사항'].apply(text_cleaning)
# Out:
# C:\Users\manue\AppData\Roaming\Python\Python38\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# ...
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!

# %%
df.head()
# Out:
# C:\Users\manue\AppData\Roaming\Python\Python38\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#          상담일시 통화유형 상담구분       상담유형         상담상세  \
# 0  2019-06-28   수신  약국몰       이용문의        이벤트관련
# 1  2019-06-28   발신  약국몰       회원정보       고객정보변경
# 2  2019-06-28   발신  약국몰  반품환불(미사용)  반품회수지연(미사용)
# 3  2019-06-28   수신  약국몰       이용문의        이벤트관련
# 4  2019-06-28   발신  약국몰  반품환불(미사용)  반품회수지연(미사용)
#
#                                                 문의사항  \
# 0  \n\n역대급이벤트 문의\n>15만원이상 구매하셔서 이마트 1만원상품권 선택하신걸로...
# 1  \n\n세금계산서 메일 @으로 되어있음 / 기입요청\n> shee84882000@h...
# 2  \n폐업반품으로 도매업체들 다 반품헀고 회수 모두 했는데 탑헬스케어/건강두배로만 미...
# 3  \n\n6월 역대급이벤트 사은품신청 문의\n-> OTC전용관-4중 택1 신청안내 /...
# 4  \n희망약국/조창희\n6/24 폐업반품건들, 아직 미회수로 빠른 회수요청\n-> 회...
#
#                                             문의사항_클리닝
# 0  역대급이벤트 문의만원이상 구매하셔서 이마트 만원상품권 선택하신걸로 확인  만유도 월...
# 1               세금계산서 메일 으로 되어있음  기입요청 월요일 처리 가능함 안내
# 2  폐업반품으로 도매업체들 다 반품헀고 회수 모두 했는데 탑헬스케어건강두배로만 미회수 ...
# 3  월 역대급이벤트 사은품신청 문의 전용관중 택 신청안내  마일리지 익월 발급예정 미선...
# 4  희망약국조창희 폐업반품건들 아직 미회수로 빠른 회수요청 회수독촉하여 차주 초까지 최...

# %% [markdown]
# ## 혹시 모를 상황에 대비해서 전처리된 데이터 프레임을 저장

# %%
df.to_csv('Data/2019.04-06_상담내역.csv', index = False, encoding = 'utf-8')
# Out:
# C:\Users\manue\AppData\Roaming\Python\Python38\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
temp = pd.read_csv('Data/2019.04-06_상담내역.csv', encoding='utf-8')
temp.head()
# Out:
# C:\Users\manue\AppData\Roaming\Python\Python38\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#          상담일시 통화유형 상담구분       상담유형         상담상세  \
# 0  2019-06-28   수신  약국몰       이용문의        이벤트관련
# 1  2019-06-28   발신  약국몰       회원정보       고객정보변경
# 2  2019-06-28   발신  약국몰  반품환불(미사용)  반품회수지연(미사용)
# 3  2019-06-28   수신  약국몰       이용문의        이벤트관련
# 4  2019-06-28   발신  약국몰  반품환불(미사용)  반품회수지연(미사용)
#
#                                                 문의사항  \
# 0  \n\n역대급이벤트 문의\n>15만원이상 구매하셔서 이마트 1만원상품권 선택하신걸로...
# 1  \n\n세금계산서 메일 @으로 되어있음 / 기입요청\n> shee84882000@h...
# 2  \n폐업반품으로 도매업체들 다 반품헀고 회수 모두 했는데 탑헬스케어/건강두배로만 미...
# 3  \n\n6월 역대급이벤트 사은품신청 문의\n-> OTC전용관-4중 택1 신청안내 /...
# 4  \n희망약국/조창희\n6/24 폐업반품건들, 아직 미회수로 빠른 회수요청\n-> 회...
#
#                                             문의사항_클리닝
# 0  역대급이벤트 문의만원이상 구매하셔서 이마트 만원상품권 선택하신걸로 확인  만유도 월...
# 1               세금계산서 메일 으로 되어있음  기입요청 월요일 처리 가능함 안내
# 2  폐업반품으로 도매업체들 다 반품헀고 회수 모두 했는데 탑헬스케어건강두배로만 미회수 ...
# 3  월 역대급이벤트 사은품신청 문의 전용관중 택 신청안내  마일리지 익월 발급예정 미선...
# 4  희망약국조창희 폐업반품건들 아직 미회수로 빠른 회수요청 회수독촉하여 차주 초까지 최...

# %% [markdown]
# # 상담일시 판다스 포멧에 맞게 전환

# %%
df = pd.read_csv('Data/2019.04-06_상담내역.csv', encoding='utf-8')
# Out:
# C:\Users\manue\AppData\Roaming\Python\Python38\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24125 entries, 0 to 24124
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   상담일시      24125 non-null  object
#  1   통화유형      24125 non-null  object
#  2   상담구분      24125 non-null  object
#  3   상담유형      24125 non-null  object
#  4   상담상세      24122 non-null  object
#  5   문의사항      24125 non-null  object
#  6   문의사항_클리닝  24125 non-null  object
# dtypes: object(7)
# memory usage: 1.3+ MB
# C:\Users\manue\AppData\Roaming\Python\Python38\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df['상담일시'] = df['상담일시'].apply(slicing_time_str)
df['상담일시'] = pd.to_datetime(df['상담일시'], format='%Y/%m/%d')
# Out:
# C:\Users\manue\AppData\Roaming\Python\Python38\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24125 entries, 0 to 24124
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   상담일시      24125 non-null  datetime64[ns]
#  1   통화유형      24125 non-null  object
#  2   상담구분      24125 non-null  object
#  3   상담유형      24125 non-null  object
#  4   상담상세      24122 non-null  object
#  5   문의사항      24125 non-null  object
#  6   문의사항_클리닝  24125 non-null  object
# dtypes: datetime64[ns](1), object(6)
# memory usage: 1.3+ MB
# C:\Users\manue\AppData\Roaming\Python\Python38\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df.head(3)
# Out:
# C:\Users\manue\AppData\Roaming\Python\Python38\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#         상담일시 통화유형 상담구분       상담유형         상담상세  \
# 0 2019-06-28   수신  약국몰       이용문의        이벤트관련
# 1 2019-06-28   발신  약국몰       회원정보       고객정보변경
# 2 2019-06-28   발신  약국몰  반품환불(미사용)  반품회수지연(미사용)
#
#                                                 문의사항  \
# 0  \n\n역대급이벤트 문의\n>15만원이상 구매하셔서 이마트 1만원상품권 선택하신걸로...
# 1  \n\n세금계산서 메일 @으로 되어있음 / 기입요청\n> shee84882000@h...
# 2  \n폐업반품으로 도매업체들 다 반품헀고 회수 모두 했는데 탑헬스케어/건강두배로만 미...
#
#                                             문의사항_클리닝
# 0  역대급이벤트 문의만원이상 구매하셔서 이마트 만원상품권 선택하신걸로 확인  만유도 월...
# 1               세금계산서 메일 으로 되어있음  기입요청 월요일 처리 가능함 안내
# 2  폐업반품으로 도매업체들 다 반품헀고 회수 모두 했는데 탑헬스케어건강두배로만 미회수 ...

# %% [markdown]
# # 월별 문의사항 데이터 TF-IDF 분석

# %%
df['문의사항_클리닝'].isnull().sum()
# Out:
# C:\Users\manue\AppData\Roaming\Python\Python38\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 0

# %%
idx = df[df['문의사항_클리닝'].isnull()].index
df = df.drop(idx)
# Out:
# C:\Users\manue\AppData\Roaming\Python\Python38\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
SW = define_stopwords("stopwords-ko.txt")
# Out:
# C:\Users\manue\AppData\Roaming\Python\Python38\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
def list_of_list(docs):
    temp_list = []
    
    for doc in docs:
        temp = doc.split(', ')
        temp_list.append(temp)
        
    return temp_list
# Out:
# C:\Users\manue\AppData\Roaming\Python\Python38\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
def month_context_extract_tfidf(df, month_start, month_end):
    
    # 시간정보 열 datetime 정보로 변환
    df['상담일시'] = pd.to_datetime(df['상담일시'], format='%Y/%m/%d')
    #연도, 월 데이터 dataframe 받음
    year_month_df = df.loc[(df['상담일시'] > month_start) & (df['상담일시'] < month_end)]
    #제목 데이터 프레임 슬라이싱
    corpus = year_month_df['문의사항_클리닝']
    #리스트화
    cleaned_corpus = corpus.tolist() #--> list of str
    
    #okt를 이용한 형태소 분석
    temp_list = []
    for i in tqdm_notebook(cleaned_corpus):
        #temp_list.append(okt.morphs(i)) #temp_list.append(okt.nouns(i)) #명사형 
        #temp_list.append(mecab.morphs(i)) #temp_list.append(mecab.nouns(i))
        #temp_list.append(komoran.morphs(i)) #temp_list.append(komoran.nouns(i))
        #temp_list.append(hannanum.morphs(i)) #temp_list.append(hannanum.nouns(i))
        temp_list.append(kkma.nouns(i)) #temp_list.append(kkma.nouns(i))
    #2차원 리스트를 1차원으로    
    single_de_list = sum(temp_list, [])
    #불용어 제거
    final_list = [word for word in single_de_list if word not in SW and len(word) > 1]
    return final_list
# Out:
# C:\Users\manue\AppData\Roaming\Python\Python38\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# vectorizer 내에서 높은 순위로 고려되는 단어들을 불러오는 함수를 생성 
def rank_words(terms, feature_matrix):
    sums = feature_matrix.sum(axis=0) # 문서마다 단어의 tfidf 합산
    data = []
    for col, term in enumerate(terms): 
        data.append( (term, sums[0,col])) # 단어의 tfidf 값 매핑하여 리스트에 추가
    ranked = pd.DataFrame(data, columns=['term','rank']).sort_values('rank',ascending=False) 
    #ranked = pd.DataFrame(data, columns=['term','rank']).sort_values('rank',ascending=False) 
    # tfidf 내림차순으로 정렬하여 데이터프레임 생성  
    return ranked
# Out:
# C:\Users\manue\AppData\Roaming\Python\Python38\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df.head(3)
# Out:
# C:\Users\manue\AppData\Roaming\Python\Python38\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#         상담일시 통화유형 상담구분       상담유형         상담상세  \
# 0 2019-06-28   수신  약국몰       이용문의        이벤트관련
# 1 2019-06-28   발신  약국몰       회원정보       고객정보변경
# 2 2019-06-28   발신  약국몰  반품환불(미사용)  반품회수지연(미사용)
#
#                                                 문의사항  \
# 0  \n\n역대급이벤트 문의\n>15만원이상 구매하셔서 이마트 1만원상품권 선택하신걸로...
# 1  \n\n세금계산서 메일 @으로 되어있음 / 기입요청\n> shee84882000@h...
# 2  \n폐업반품으로 도매업체들 다 반품헀고 회수 모두 했는데 탑헬스케어/건강두배로만 미...
#
#                                             문의사항_클리닝
# 0  역대급이벤트 문의만원이상 구매하셔서 이마트 만원상품권 선택하신걸로 확인  만유도 월...
# 1               세금계산서 메일 으로 되어있음  기입요청 월요일 처리 가능함 안내
# 2  폐업반품으로 도매업체들 다 반품헀고 회수 모두 했는데 탑헬스케어건강두배로만 미회수 ...

# %%
tfidf_corpus = month_context_extract_tfidf(df,'2019-04-01', '2019-06-30') #2019년 4월에서 6월까지 하려면 (df,'2019-04-01', '2019-06-30')로 작성하면 됨.
tfidf_corpus
# Out:
# C:\Users\manue\AppData\Roaming\Python\Python38\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <ipython-input-94-c3d1e4ba24e8>:14: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for i in tqdm_notebook(cleaned_corpus):
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=14637.0), HTML(value='')))
# ['역대급이벤트',
#  '문의만원이상',
#  '만원이상',
#  '만원상품권',
#  '선택',
#  '만유',
#  '월매출',
#  '부족금액',
#  '세금계산서',
#  '기입',
#  '기입요청',
#  '폐업반품',
#  '도매업체',
#  '반품헀고',
#  '탑헬스케어건강',
#  '헬스',
#  '케어',
#  '미회수',
#  '회수요청',
#  '월초안',
#  '초안',
#  '세무서',
#  '폐업예정',
#  '탑헬스케어업무',
#  '업무',
#  '월요일오전',
#  '요청예정',
#  '독촉',
#  '독촉완료',
#  '환불문의',
#  '예치금적립처리',
#  '환불가능',
#  '역대급이벤트',
#  '사은품',
#  '사은품신청',
#  '전용관중',
#  '관중',
#  '신청안내',
#  '익월',
#  '발급예정',
#  '미선',
#  '미선님',
#  '통화건마일리지',
#  '희망약국조창',
#  '조창',
#  '폐업반품건들',
#  '미회수',
#  '회수요청',
#  '회수독촉',
#  '독촉',
#  '차주',
#  '최대한',
#  '폐업예정',
#  '반품처리',
#  '월중',
#  '세금계산서',
#  '조정',
#  '환불가능월',
#  '전화주신',
#  '희망약국조창',
#  '조창',
#  '미회수',
#  '회수요청',
#  '소액',
#  '소액처',
#  '월매출',
#  '부족금액',
#  '유도',
#  '국장',
#  '만유',
#  '진선',
#  '진선님',
#  '통화건상기',
#  '상기',
#  '재안내',
#  '선택',
#  '폐업반품',
#  '도매업체',
#  '반품헀고',
#  '탑헬스케어건강',
#  '헬스',
#  '케어',
#  '미회수',
#  '회수요청',
#  '월초안',
#  '초안',
#  '세무서',
#  '폐업예정',
#  '임팩',
#  '프리미엄',
#  '당첨이벤트',
#  '이마트상품권',
#  '신청문의',
#  '구매자',
#  '프리미엄',
#  '프리미엄구매',
#  '프로',
#  '프로모션',
#  '모션',
#  '마트상품권',
#  '핸드폰번호',
#  '고함',
#  '임아람담당자슈',
#  '아람',
#  '글렛',
#  '반품관련',
#  '문의확인후',
#  '안내낱알반품',
#  '낱알',
#  '반품상품',
#  '낱알수량',
#  '입력후',
#  '주문취소요청처리',
#  '안내배소현님',
#  '배소',
#  '배송요청',
#  '프리미엄',
#  '프로',
#  '프로모션',
#  '모션',
#  '핸드폰번호',
#  '프리미엄',
#  '핸드폰번호',
#  '사용방법',
#  '윤약국윤미숙',
#  '미숙',
#  '슈글렛',
#  '반품관련',
#  '문의확인후',
#  '세금계산서',
#  '기입',
#  '기입요청',
#  '사용방법',
#  '문의일반',
#  '일반',
#  '의약품',
#  '구매시',
#  '사용불가',
#  '샵플러스포인트',
#  '플러스',
#  '끊으',
#  '끊으심마일리지',
#  '교환방법',
#  '안내차',
#  '않으',
#  '않으심',
#  '문자발송',
#  '헬스',
#  '헬스인',
#  '배송됬으',
#  '뉴케어',
#  '케어',
#  '곤지',
#  '곤지암',
#  '배송사',
#  '기분',
#  '중환자',
#  '바보',
#  '건의',
#  '건의요청',
#  '운영',
#  '운영팀',
#  '업체응대부분',
#  '응대',
#  '직배송',
#  '사전',
#  '사전팝업공지',
#  '팝업',
#  '의미',
#  '부외품',
#  '사용방법',
#  '문의일반',
#  '일반',
#  '의약품',
#  '구매시',
#  '사용불가',
#  '샵플러스포인트',
#  '플러스',
#  '끊으',
#  '끊으심',
#  '판매마감',
#  '배송예정일자',
#  '대웅서울',
#  '헬스',
#  '헬스인',
#  '문열기',
#  '열기',
#  '최대한',
#  '임팩프리미엄',
#  '프리미엄',
#  '대부분',
#  '부산',
#  '사하',
#  '사하구',
#  '정찬',
#  '정찬용담당자',
#  '만원선임',
#  '선임',
#  '그린',
#  '그린세이프',
#  '세이프',
#  '에프',
#  '모기향',
#  '모기향코일입',
#  '일입',
#  '물건',
#  '체크',
#  '요청하심',
#  '그린',
#  '그린세이프',
#  '세이프',
#  '에프',
#  '모기향',
#  '모기향코일입',
#  '일입',
#  '물건',
#  '체크',
#  '우리',
#  '곽현실임팩',
#  '현실',
#  '아이',
#  '프리미엄',
#  '대부분',
#  '부산',
#  '사하',
#  '사하구',
#  '전체적',
#  '소독',
#  '에탄올',
#  '당원',
#  '당원원',
#  '무료',
#  '배송가능어제',
#  '문자받으심',
#  '받으심',
#  '공동',
#  '공동구매',
#  '비스',
#  '재고부족',
#  '이슈',
#  '샵내',
#  '부외품',
#  '할인쿠폰',
#  '사용방법',
#  '티제이',
#  '제이',
#  '블레',
#  '블레파졸',
#  '제품하자',
#  '하자',
#  '반품신청도와드림',
#  '도와',
#  '제일',
#  '제일헬스케어',
#  '헬스',
#  '케어',
#  '부외품',
#  '부외품쿠폰교환',
#  '마이',
#  '마이페이지신청방법',
#  '임팩프리미엄',
#  '프리미엄',
#  '매장',
#  '그린',
#  '그린세이프',
#  '세이프',
#  '에프',
#  '모기향',
#  '모기향코일입',
#  '일입',
#  '역대급',
#  '선택',
#  '스타',
#  '스타벅스',
#  '벅스',
#  '주문취소요청처리',
#  '도담약국김',
#  '승찬',
#  '대웅유진약품',
#  '유진',
#  '대웅유진',
#  '납품',
#  '납품번호',
#  '재주',
#  '재주문',
#  '출하',
#  '출하정지',
#  '완료옥경님',
#  '옥경',
#  '출고정지완료임',
#  '민케어',
#  '케어',
#  '출고정지',
#  '임팩',
#  '탑헬스케어밴드',
#  '헬스',
#  '케어',
#  '밴드',
#  '닥터',
#  '미회수라',
#  '수라',
#  '회수요청',
#  '재회',
#  '재회수요',
#  '수요',
#  '미회수',
#  '재요청',
#  '선처리',
#  '예치금적립완료',
#  '불편',
#  '의미',
#  '부외품',
#  '부외품할인',
#  '월말',
#  '쿠폰발급',
#  '회수지연',
#  '하나',
#  '하나카드정보',
#  '문의정상적',
#  '정상적',
#  '창신용카드',
#  '신용',
#  '사전',
#  '사전등록하나카드',
#  '하나',
#  '선택',
#  '카드사의',
#  '사의',
#  '포인트제도',
#  '제도',
#  '카드사',
#  '카드사쪽',
#  '무응',
#  '임팩프리미엄',
#  '프리미엄',
#  '대부분',
#  '부산',
#  '사하',
#  '사하구',
#  '대웅제품',
#  '반품기준',
#  '기준',
#  '사입이',
#  '입이',
#  '유통기간',
#  '지났어도',
#  '났어도',
#  '낱알',
#  '반품가능',
#  '대웅바이오',
#  '년이내',
#  '이내',
#  '도매부외품',
#  '부외품',
#  '반품신청칸',
#  '내용확인',
#  '탄약',
#  '탄약국김',
#  '덕반품',
#  '메디',
#  '메디코어노즈스위퍼',
#  '코어',
#  '노즈',
#  '스위퍼',
#  '코세정분말',
#  '세정',
#  '분말',
#  '스틱',
#  '스틱형',
#  '회수택배비',
#  '택배비',
#  '차감도',
#  '감도',
#  '반품금액',
#  '미적립',
#  '통화완료수량',
#  '반품신청요청',
#  '역대급',
#  '선택',
#  '부외',
#  '부외만원',
#  '박승',
#  '박승연담당자스멕',
#  '스멕',
#  '타가',
#  '이하',
#  '아이',
#  '복용',
#  '냐며',
#  '문의약국',
#  '예정스멕',
#  '현탁액',
#  '월일',
#  '월일이후',
#  '만세',
#  '만세소아',
#  '소아',
#  '임산부',
#  '임산부임신가능성',
#  '임신',
#  '가능성',
#  '여성',
#  '여성수유부',
#  '수유',
#  '복용금지',
#  '금지',
#  '안내대',
#  '문의확인후',
#  '재연락',
#  '약속현재',
#  '유산균',
#  '제제',
#  '스멕타',
#  '대체',
#  '의약품',
#  '급여',
#  '처방',
#  '때문',
#  '복용금지대상자',
#  '대상자',
#  '가해',
#  '수도',
#  '지마켓',
#  '마켓',
#  '가전',
#  '가전업체',
#  '헬스',
#  '헬스인',
#  '배송됬으',
#  '뉴케어',
#  '케어',
#  '곤지',
#  '곤지암',
#  '배송사',
#  '기분',
#  '중환자',
#  '바보',
#  '건의',
#  '건의요청',
#  '사용방법',
#  '에스',
#  '에스비엔에프',
#  '에프',
#  '세금계산서',
#  '문의엠서클',
#  '서클',
#  '명의',
#  '사업자번호',
#  '통합발행업체',
#  '별도',
#  '별도발행업체',
#  '확인가능',
#  '경로',
#  '경로안내',
#  '서울제일약국',
#  '제일',
#  '소민',
#  '소민반품',
#  '종근당',
#  '아세틸',
#  '글루코사민',
#  '택배사',
#  '임팩프리미엄',
#  '프리미엄',
#  '아이디당',
#  '역대급이벤트',
#  '사은품',
#  '사은품신청',
#  '전용관중',
#  '관중',
#  '신청안내',
#  '익월',
#  '발급예정',
#  '연결후',
#  '단선',
#  '역대급',
#  '신청요청',
#  '대웅향남',
#  '당시',
#  '영상',
#  '물류',
#  '물류측',
#  '케이스',
#  '한번',
#  '체크',
#  '부탁',
#  '부탁드림',
#  '요청드림',
#  '동물의약품',
#  '의약품',
#  '구매승인',
#  '개설',
#  '개설등록증',
#  '등록증',
#  '주문금액',
#  '부산',
#  '부산백제약품',
#  '결제건',
#  '시스',
#  '월일',
#  '영님',
#  '연결요청',
#  '연결완료',
#  '주문금액',
#  '부산',
#  '부산백제약품',
#  '카드결제',
#  '대표',
#  '대표님',
#  '연결요청',
#  '연결중',
#  '대웅공장',
#  '꺼라',
#  '공유',
#  '사실',
#  '무지개',
#  '무지개약국',
#  '원주',
#  '취소요청사유',
#  '수령',
#  '제품하자',
#  '하자',
#  '회수택배비',
#  '택배비',
#  '부담',
#  '하심상기',
#  '상기',
#  '발송준비중',
#  '준비',
#  '상태값',
#  '제품명',
#  '안됨',
#  '지오영으',
#  '출하',
#  '출하완료',
#  '주말',
#  '카드결제',
#  '대표',
#  '대표님',
#  '연결요청',
#  '취소요청사유',
#  '수령',
#  '제품하자',
#  '하자',
#  '회수택배비',
#  '택배비',
#  '부담',
#  '하심상기',
#  '상기',
#  '발송준비중',
#  '준비',
#  '상태값',
#  '제품명',
#  '안됨',
#  '지오영으',
#  '출하',
#  '출하완료',
#  '주말',
#  '연결후',
#  '단선',
#  '구매시',
#  '실적',
#  '반영',
#  '영업기획팀',
#  '기획',
#  '김민경',
#  '민경',
#  '현금',
#  '현금충전',
#  '충전',
#  '현금인출기',
#  '인출기',
#  '현금영수증',
#  '영수증',
#  '발행가능',
#  '소득',
#  '소득공제',
#  '공제',
#  '코앱',
#  '설치',
#  '주시',
#  '주시길',
#  '새서울',
#  '전호진대웅',
#  '호진',
#  '배송시간',
#  '발송요청',
#  '대웅향남',
#  '당시',
#  '영상',
#  '물류',
#  '물류측',
#  '케이스',
#  '한번',
#  '체크',
#  '부탁',
#  '부탁드림',
#  '전자',
#  '전자세금계산서',
#  '주소변경요청',
#  '소현님',
#  '수정요청',
#  '수정완료',
#  '안내옥경님',
#  '옥경',
#  '샵사이트',
#  '사이트',
#  '반영',
#  '반영안',
#  '문의확인후',
#  '재연락',
#  '약속처리완료',
#  '전자',
#  '전자세금계산서',
#  '주소변경요청',
#  '소현님',
#  '수정요청',
#  '수정완료',
#  '안내옥경님',
#  '옥경',
#  '샵사이트',
#  '사이트',
#  '반영',
#  '반영안',
#  '문의확인후',
#  '재연락',
#  '반품절차',
#  '절차',
#  '구매시',
#  '실적',
#  '반영',
#  '영업기획팀',
#  '기획',
#  '김민경',
#  '민경',
#  '현금',
#  '현금충전',
#  '충전',
#  '현금인출기',
#  '인출기',
#  '현금영수증',
#  '영수증',
#  '발행가능',
#  '결제하기',
#  '제하기',
#  '반응',
#  '일반',
#  '쿠키',
#  '사이트',
#  '데이터',
#  '설정',
#  '보안',
#  '신뢰',
#  '고급',
#  '고급설정복원',
#  '기본',
#  '기본설정복원',
#  '원래',
#  '전자',
#  '전자세금계산서',
#  '주소변경요청',
#  '소현님',
#  '수정요청',
#  '수정완료',
#  '대웅전',
#  '대웅전주백제',
#  '임팩',
#  '프리미엄',
#  '당첨이벤트문의',
#  '비대상처',
#  '대상',
#  '아웃',
#  '성원',
#  '쇼핑백',
#  '고함',
#  '기한내',
#  '한내',
#  '소진',
#  '일경',
#  '모바일',
#  '예정안내',
#  '연두',
#  '연두약국최연도',
#  '연도',
#  '캡슐',
#  '당시',
#  '본사',
#  '도매담당',
#  '담당',
#  '이정',
#  '이정민',
#  '내선',
#  '내선안내',
#  '주문시',
#  '세금계산서',
#  '이달',
#  '판매마감',
#  '월발행',
#  '월매출',
#  '발행예정',
#  '연질',
#  '연질캡슐',
#  '캡슐',
#  '반품방법',
#  '반품기간설정',
#  '설정',
#  '선택',
#  '배송완료처리',
#  '재확인',
#  '재확인후',
#  '이지',
#  '이브',
#  '프로',
#  '경로',
#  '대웅거점상품관',
#  '백제약품',
#  '반품취소요청회수',
#  '날짜',
#  '재신청',
#  '함백제약품',
#  '택배비',
#  '차감',
#  '쿠폰적용',
#  '함취소완료',
#  '마이너스잔고예치금',
#  '환불요청',
#  '마이너스잔고',
#  '환불안됨',
#  '안됨',
#  '엠서클',
#  '서클',
#  '냐며',
#  '동오약국홍성',
#  '오약',
#  '홍성',
#  '백제약품',
#  '반품취소요청회수',
#  '재신청',
#  '함백제약품',
#  '택배비',
#  '차감',
#  '처리가능',
#  '백제약품',
#  '반품취소요청회수',
#  '날짜',
#  '재신청',
#  '함백제약품',
#  '택배비',
#  '차감',
#  '동오약국홍성',
#  '오약',
#  '홍성',
#  '백제약품',
#  '반품취소요청회수',
#  '연락주기',
#  '주기',
#  '젯트',
#  '품절문의',
#  '미차장',
#  '내선',
#  '내선안내',
#  '대웅바이오',
#  '처리현황',
#  '현황',
#  '도중',
#  '이해됬다',
#  '자체',
#  '동아당약국',
#  '아당',
#  '규영구매',
#  '센트',
#  '센트룸프로',
#  '프로',
#  '연락주기',
#  '주기',
#  '신청방법',
#  '마이',
#  '백제약품',
#  '반품취소요청회수',
#  '날짜',
#  '재신청',
#  '푸른',
#  '푸른약국차관호',
#  '차관',
#  '구지',
#  '구지오',
#  '비스',
#  '사용방법',
#  '문의마이',
#  '마이',
#  '가기',
#  '가기패밀리존등급',
#  '패밀리',
#  '상세보',
#  '세보',
#  '생활기',
#  '생활기프트',
#  '프트',
#  '신청하기',
#  '하기',
#  '경로',
#  '경로안내',
#  '마트상품권',
#  '문의다음주',
#  '다음주',
#  '수금',
#  '수금요일사이',
#  '요일',
#  '사이',
#  '지참',
#  '고객센터',
#  '센터',
#  '개월',
#  '거점등록',
#  '거점등록완료',
#  '사용문의',
#  '도중',
#  '손님',
#  '재전',
#  '한번',
#  '안됨',
#  '부서',
#  '전액',
#  '부외품',
#  '남편',
#  '남편번호',
#  '발송요청',
#  '기록',
#  '한번',
#  '안됨',
#  '부서',
#  '프라젠트라',
#  '트라',
#  '살오일',
#  '오일',
#  '유통기한',
#  '고함',
#  '고함업체',
#  '확인후',
#  '재연락',
#  '임박',
#  '임박제품하자',
#  '하자',
#  '대리',
#  '대리신청완료',
#  '분홍',
#  '분홍약국하분홍',
#  '하분',
#  '용산',
#  '용산구',
#  '이태원',
#  '이태원동',
#  '층소액처',
#  '소액',
#  '모바렌구입',
#  '이관가능',
#  '정보주면',
#  '주면',
#  '검토',
#  '검토후',
#  '피드백',
#  '피드백주기',
#  '주기',
#  '다음주',
#  '다음주중',
#  '지금',
#  '미수신',
#  '재발',
#  '재발송완료수신',
#  '샵플러스포인트',
#  '플러스',
#  '회수완료',
#  '진행현황',
#  '현황',
#  '주문번호',
#  '상품번호',
#  '반품요청',
#  '환불처리',
#  '조은',
#  '조은약국냉',
#  '미수신',
#  '재발송완료',
#  '우리',
#  '마을',
#  '마을약국정명주',
#  '명주',
#  '에스비',
#  '에스비앤에프',
#  '에프',
#  '취소요청사유',
#  '쿠폰미적',
#  '미적',
#  '재결제',
#  '출고정지',
#  '변경요청',
#  '팩스발송요청',
#  '완료전',
#  '주문어려움',
#  '변경완료',
#  '더블유',
#  '스토어',
#  '스토어대흥',
#  '대흥',
#  '덕순',
#  '프라젠트라',
#  '트라',
#  '살오일',
#  '오일',
#  '유통기한',
#  '고함',
#  '고함업체',
#  '확인후',
#  '재연락',
#  '임박',
#  '임박제품하자',
#  '하자',
#  '반품접수',
#  '에스비',
#  '에스비앤에프',
#  '에프',
#  '취소요청사유',
#  '적용취소',
#  '재결',
#  '재결제시',
#  '제시',
#  '바이오오산',
#  '컴퓨터',
#  '부실',
#  '부실뻔',
#  '프로그램',
#  '문제',
#  '장애',
#  '국민비씨',
#  '비씨',
#  '전면',
#  '전면장애',
#  '복구',
#  '복구중',
#  '미선',
#  '미선님',
#  '통화건아직',
#  '건아',
#  '결제플랫폼',
#  '플랫폼',
#  '부탁',
#  '부탁드림',
#  '완료시',
#  '통화요청',
#  '복구진행중',
#  '하루',
#  '하루종일',
#  '종일',
#  '불안정',
#  '결제방법',
#  '생각',
#  '프라젠트라',
#  '트라',
#  '살오일',
#  '오일',
#  '유통기한',
#  '고함',
#  '고함업체',
#  '확인후',
#  '재연락',
#  '복산나이스',
#  '나이스',
#  '한신',
#  '한신약품금일',
#  '출하',
#  '출하요청',
#  '천안',
#  '삼거리',
#  '휴게소',
#  '휴게소약국양선아',
#  '선아',
#  '복산나이스',
#  '나이스',
#  '한신',
#  '한신약품금일',
#  '출하',
#  '출하요청',
#  '천안',
#  '삼거리',
#  '휴게소',
#  '휴게소약국양선아',
#  '선아',
#  '복산나이스',
#  '나이스',
#  '한신',
#  '한신약품',
#  '출하',
#  '복산나이스',
#  '나이스',
#  '한신',
#  '한신약품금일',
#  '출하',
#  '출하요청',
#  '정호',
#  '선릉코',
#  '코약국',
#  ...]

# %%
len(tfidf_corpus)
# Out:
# C:\Users\manue\AppData\Roaming\Python\Python38\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 134068

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer(
                            use_idf=True,
                            ngram_range=(1,1)) #오직 1-grams만 고려함
#                             min_df = 0.01,     #1% 미만으로 문서에서 출현하는 단어들은 삭제
#                             max_df = 0.05)      #5% 이상으로 문서에서 존재하는 단어들은 삭제(너무 흔함)

t0=time() 


tfidf = vectorizer.fit_transform(tfidf_corpus)

print("완료시간 : %0.3f초" % (time() - t0))
# Out:
# C:\Users\manue\AppData\Roaming\Python\Python38\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 완료시간 : 0.945초

# %%
ranked = rank_words(terms=vectorizer.get_feature_names(), feature_matrix=tfidf)

fix, ax = plt.subplots(figsize=(6,10), ncols=1, nrows=1)
sns.barplot(x='rank',y='term',data=ranked[:14], palette="Reds_r", ax=ax)
# Out:
# C:\Users\manue\AppData\Roaming\Python\Python38\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <AxesSubplot:xlabel='rank', ylabel='term'>

# %% [markdown]
# # 월별 문의사항 데이터 Gensim 분석

# %%
def text_tokenizing(corpus, tokenizer):
    
    # okt = Okt()
    kkma=Kkma()
    token_corpus = []
    

    if tokenizer == "noun":
        for n in tqdm_notebook(range(len(corpus)), desc="Preprocessing"):
            # token_text = okt.nouns(corpus[n])
            #token_text = mecab.nouns(corpus[n])
            token_text = kkma.nouns(corpus[n])
            #token_text = komoran.nouns(corpus[n])
            #token_text = hannanum.nouns(corpus[n])
            token_text = [word for word in token_text if word not in SW and len(word) > 1]
            token_corpus.append(token_text)
            
    elif tokenizer == "morph":
        for n in tqdm_notebook(range(len(corpus)), desc="Preprocessing"):
            # token_text = okt.morphs(corpus[n])
            #token_text = mecab.morphs(corpus[n])
            token_text = kkma.morphs(corpus[n])
            #token_text = komoran.morphs(corpus[n])
            #token_text = hannanum.morphs(corpus[n])
            token_text = [word for word in token_text if word not in SW and len(word) > 1]
            token_corpus.append(token_text)
            

    return token_corpus
# Out:
# C:\Users\manue\AppData\Roaming\Python\Python38\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
def month_context_extract_gensim(df, month_start, month_end):
    
    # 시간정보 열 datetime 정보로 변환
    df['상담일시'] = pd.to_datetime(df['상담일시'], format='%Y/%m/%d')
    #연도, 월 데이터 dataframe 받음
    year_month_df = df.loc[(df['상담일시'] > month_start) & (df['상담일시'] < month_end)]
    #텍스트 정제
    corpus = year_month_df[['문의사항_클리닝']].values.tolist()
    #corpus --> list of list
    temp_list = sum(corpus, [])
    #okt 형태소 추출
    per_month_keyword = text_tokenizing(temp_list, "noun")
    
    
    return per_month_keyword
# Out:
# C:\Users\manue\AppData\Roaming\Python\Python38\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
#2019년 4월에서 6월까지 하려면 (df,'2019-04-01', '2019-06-30')로 작성하면 됨.
gensim_corpus = month_context_extract_gensim(df, '2019-04-01', '2019-06-30')
# Out:
# C:\Users\manue\AppData\Roaming\Python\Python38\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <ipython-input-104-67d508e2e341>:9: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for n in tqdm_notebook(range(len(corpus)), desc="Preprocessing"):
# HBox(children=(HTML(value='Preprocessing'), FloatProgress(value=0.0, max=14637.0), HTML(value='')))

# %%
gensim_corpus
# Out:
# C:\Users\manue\AppData\Roaming\Python\Python38\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# [['역대급이벤트', '문의만원이상', '만원이상', '만원상품권', '선택', '만유', '월매출', '부족금액'],
#  ['세금계산서', '기입', '기입요청'],
#  ['폐업반품',
#   '도매업체',
#   '반품헀고',
#   '탑헬스케어건강',
#   '헬스',
#   '케어',
#   '미회수',
#   '회수요청',
#   '월초안',
#   '초안',
#   '세무서',
#   '폐업예정',
#   '탑헬스케어업무',
#   '업무',
#   '월요일오전',
#   '요청예정',
#   '독촉',
#   '독촉완료',
#   '환불문의',
#   '예치금적립처리',
#   '환불가능'],
#  ['역대급이벤트',
#   '사은품',
#   '사은품신청',
#   '전용관중',
#   '관중',
#   '신청안내',
#   '익월',
#   '발급예정',
#   '미선',
#   '미선님',
#   '통화건마일리지'],
#  ['희망약국조창', '조창', '폐업반품건들', '미회수', '회수요청', '회수독촉', '독촉', '차주', '최대한'],
#  ['폐업예정', '반품처리', '월중', '세금계산서', '조정', '환불가능월', '전화주신'],
#  ['희망약국조창', '조창', '미회수', '회수요청'],
#  ['소액',
#   '소액처',
#   '월매출',
#   '부족금액',
#   '유도',
#   '국장',
#   '만유',
#   '진선',
#   '진선님',
#   '통화건상기',
#   '상기',
#   '재안내',
#   '선택'],
#  ['폐업반품',
#   '도매업체',
#   '반품헀고',
#   '탑헬스케어건강',
#   '헬스',
#   '케어',
#   '미회수',
#   '회수요청',
#   '월초안',
#   '초안',
#   '세무서',
#   '폐업예정'],
#  ['임팩', '프리미엄', '당첨이벤트', '이마트상품권', '신청문의', '구매자'],
#  ['프리미엄', '프리미엄구매', '프로', '프로모션', '모션', '마트상품권', '핸드폰번호', '고함'],
#  ['임아람담당자슈',
#   '아람',
#   '글렛',
#   '반품관련',
#   '문의확인후',
#   '안내낱알반품',
#   '낱알',
#   '반품상품',
#   '낱알수량',
#   '입력후'],
#  ['주문취소요청처리', '안내배소현님', '배소', '배송요청'],
#  ['프리미엄', '프로', '프로모션', '모션', '핸드폰번호'],
#  ['프리미엄', '핸드폰번호'],
#  ['사용방법'],
#  ['윤약국윤미숙', '미숙', '슈글렛', '반품관련', '문의확인후'],
#  ['세금계산서', '기입', '기입요청'],
#  ['사용방법',
#   '문의일반',
#   '일반',
#   '의약품',
#   '구매시',
#   '사용불가',
#   '샵플러스포인트',
#   '플러스',
#   '끊으',
#   '끊으심마일리지',
#   '교환방법',
#   '안내차',
#   '않으',
#   '않으심',
#   '문자발송'],
#  ['헬스',
#   '헬스인',
#   '배송됬으',
#   '뉴케어',
#   '케어',
#   '곤지',
#   '곤지암',
#   '배송사',
#   '기분',
#   '중환자',
#   '바보',
#   '건의',
#   '건의요청',
#   '운영',
#   '운영팀',
#   '업체응대부분',
#   '응대',
#   '직배송',
#   '사전',
#   '사전팝업공지',
#   '팝업',
#   '의미',
#   '부외품'],
#  ['사용방법', '문의일반', '일반', '의약품', '구매시', '사용불가', '샵플러스포인트', '플러스', '끊으', '끊으심'],
#  ['판매마감', '배송예정일자', '대웅서울'],
#  ['헬스', '헬스인', '문열기', '열기', '최대한'],
#  ['임팩프리미엄', '프리미엄', '대부분', '부산', '사하', '사하구', '정찬', '정찬용담당자', '만원선임', '선임'],
#  ['그린', '그린세이프', '세이프', '에프', '모기향', '모기향코일입', '일입', '물건', '체크', '요청하심'],
#  ['그린', '그린세이프', '세이프', '에프', '모기향', '모기향코일입', '일입', '물건', '체크'],
#  ['우리', '곽현실임팩', '현실', '아이', '프리미엄', '대부분', '부산', '사하', '사하구', '전체적'],
#  ['소독', '에탄올', '당원', '당원원', '무료', '배송가능어제', '문자받으심', '받으심', '공동', '공동구매'],
#  ['비스', '재고부족', '이슈', '샵내'],
#  ['부외품', '할인쿠폰', '사용방법'],
#  ['티제이',
#   '제이',
#   '블레',
#   '블레파졸',
#   '제품하자',
#   '하자',
#   '반품신청도와드림',
#   '도와',
#   '제일',
#   '제일헬스케어',
#   '헬스',
#   '케어'],
#  ['부외품', '부외품쿠폰교환', '마이', '마이페이지신청방법'],
#  ['임팩프리미엄', '프리미엄', '매장'],
#  ['그린', '그린세이프', '세이프', '에프', '모기향', '모기향코일입', '일입'],
#  ['역대급', '선택', '스타', '스타벅스', '벅스'],
#  ['주문취소요청처리'],
#  ['도담약국김',
#   '승찬',
#   '대웅유진약품',
#   '유진',
#   '대웅유진',
#   '납품',
#   '납품번호',
#   '재주',
#   '재주문',
#   '출하',
#   '출하정지',
#   '완료옥경님',
#   '옥경',
#   '출고정지완료임',
#   '민케어',
#   '케어',
#   '출고정지',
#   '임팩'],
#  ['탑헬스케어밴드',
#   '헬스',
#   '케어',
#   '밴드',
#   '닥터',
#   '미회수라',
#   '수라',
#   '회수요청',
#   '재회',
#   '재회수요',
#   '수요',
#   '미회수',
#   '재요청',
#   '선처리',
#   '예치금적립완료',
#   '불편',
#   '의미',
#   '부외품',
#   '부외품할인',
#   '월말',
#   '쿠폰발급',
#   '회수지연'],
#  ['하나',
#   '하나카드정보',
#   '문의정상적',
#   '정상적',
#   '창신용카드',
#   '신용',
#   '사전',
#   '사전등록하나카드',
#   '하나',
#   '선택',
#   '카드사의',
#   '사의',
#   '포인트제도',
#   '제도',
#   '카드사',
#   '카드사쪽'],
#  ['무응'],
#  ['임팩프리미엄', '프리미엄', '대부분', '부산', '사하', '사하구'],
#  ['대웅제품',
#   '반품기준',
#   '기준',
#   '사입이',
#   '입이',
#   '유통기간',
#   '지났어도',
#   '났어도',
#   '낱알',
#   '반품가능',
#   '대웅바이오',
#   '년이내',
#   '이내',
#   '도매부외품',
#   '부외품',
#   '반품신청칸',
#   '내용확인'],
#  ['탄약',
#   '탄약국김',
#   '덕반품',
#   '메디',
#   '메디코어노즈스위퍼',
#   '코어',
#   '노즈',
#   '스위퍼',
#   '코세정분말',
#   '세정',
#   '분말',
#   '스틱',
#   '스틱형',
#   '회수택배비',
#   '택배비',
#   '차감도',
#   '감도',
#   '반품금액',
#   '미적립',
#   '통화완료수량',
#   '반품신청요청'],
#  ['역대급', '선택', '부외', '부외만원'],
#  ['박승',
#   '박승연담당자스멕',
#   '스멕',
#   '타가',
#   '이하',
#   '아이',
#   '복용',
#   '냐며',
#   '문의약국',
#   '예정스멕',
#   '현탁액',
#   '월일',
#   '월일이후',
#   '만세',
#   '만세소아',
#   '소아',
#   '임산부',
#   '임산부임신가능성',
#   '임신',
#   '가능성',
#   '여성',
#   '여성수유부',
#   '수유',
#   '복용금지',
#   '금지',
#   '안내대',
#   '문의확인후',
#   '재연락',
#   '약속현재',
#   '유산균',
#   '제제',
#   '스멕타',
#   '대체',
#   '의약품',
#   '급여',
#   '처방',
#   '때문',
#   '복용금지대상자',
#   '대상자',
#   '가해',
#   '수도'],
#  ['지마켓', '마켓', '가전', '가전업체'],
#  ['헬스',
#   '헬스인',
#   '배송됬으',
#   '뉴케어',
#   '케어',
#   '곤지',
#   '곤지암',
#   '배송사',
#   '기분',
#   '중환자',
#   '바보',
#   '건의',
#   '건의요청'],
#  ['사용방법'],
#  ['에스',
#   '에스비엔에프',
#   '에프',
#   '세금계산서',
#   '문의엠서클',
#   '서클',
#   '명의',
#   '사업자번호',
#   '통합발행업체',
#   '별도',
#   '별도발행업체',
#   '확인가능',
#   '경로',
#   '경로안내'],
#  ['서울제일약국', '제일', '소민', '소민반품', '종근당', '아세틸', '글루코사민', '택배사'],
#  ['임팩프리미엄', '프리미엄', '아이디당'],
#  ['역대급이벤트', '사은품', '사은품신청', '전용관중', '관중', '신청안내', '익월', '발급예정'],
#  ['연결후', '단선'],
#  ['역대급', '신청요청'],
#  ['대웅향남', '당시', '영상', '물류', '물류측', '케이스', '한번', '체크', '부탁', '부탁드림', '요청드림'],
#  ['동물의약품', '의약품', '구매승인', '개설', '개설등록증', '등록증'],
#  ['주문금액', '부산', '부산백제약품', '결제건', '시스', '월일'],
#  ['영님', '연결요청', '연결완료'],
#  ['주문금액', '부산', '부산백제약품'],
#  ['카드결제', '대표', '대표님', '연결요청', '연결중'],
#  ['대웅공장', '꺼라', '공유', '사실'],
#  ['무지개',
#   '무지개약국',
#   '원주',
#   '취소요청사유',
#   '수령',
#   '제품하자',
#   '하자',
#   '회수택배비',
#   '택배비',
#   '부담',
#   '하심상기',
#   '상기',
#   '발송준비중',
#   '준비',
#   '상태값',
#   '제품명',
#   '안됨',
#   '지오영으',
#   '출하',
#   '출하완료',
#   '주말'],
#  ['카드결제', '대표', '대표님', '연결요청'],
#  ['취소요청사유',
#   '수령',
#   '제품하자',
#   '하자',
#   '회수택배비',
#   '택배비',
#   '부담',
#   '하심상기',
#   '상기',
#   '발송준비중',
#   '준비',
#   '상태값',
#   '제품명',
#   '안됨',
#   '지오영으',
#   '출하',
#   '출하완료',
#   '주말'],
#  ['연결후', '단선'],
#  ['구매시',
#   '실적',
#   '반영',
#   '영업기획팀',
#   '기획',
#   '김민경',
#   '민경',
#   '현금',
#   '현금충전',
#   '충전',
#   '현금인출기',
#   '인출기',
#   '현금영수증',
#   '영수증',
#   '발행가능',
#   '소득',
#   '소득공제',
#   '공제',
#   '코앱',
#   '설치',
#   '주시',
#   '주시길',
#   '새서울',
#   '전호진대웅',
#   '호진',
#   '배송시간',
#   '발송요청'],
#  ['대웅향남', '당시', '영상', '물류', '물류측', '케이스', '한번', '체크', '부탁', '부탁드림'],
#  ['전자',
#   '전자세금계산서',
#   '주소변경요청',
#   '소현님',
#   '수정요청',
#   '수정완료',
#   '안내옥경님',
#   '옥경',
#   '샵사이트',
#   '사이트',
#   '반영',
#   '반영안',
#   '문의확인후',
#   '재연락',
#   '약속처리완료'],
#  ['전자',
#   '전자세금계산서',
#   '주소변경요청',
#   '소현님',
#   '수정요청',
#   '수정완료',
#   '안내옥경님',
#   '옥경',
#   '샵사이트',
#   '사이트',
#   '반영',
#   '반영안',
#   '문의확인후',
#   '재연락'],
#  ['반품절차', '절차'],
#  ['구매시',
#   '실적',
#   '반영',
#   '영업기획팀',
#   '기획',
#   '김민경',
#   '민경',
#   '현금',
#   '현금충전',
#   '충전',
#   '현금인출기',
#   '인출기',
#   '현금영수증',
#   '영수증',
#   '발행가능'],
#  ['결제하기',
#   '제하기',
#   '반응',
#   '일반',
#   '쿠키',
#   '사이트',
#   '데이터',
#   '설정',
#   '보안',
#   '신뢰',
#   '고급',
#   '고급설정복원',
#   '기본',
#   '기본설정복원',
#   '원래'],
#  ['전자', '전자세금계산서', '주소변경요청', '소현님', '수정요청', '수정완료'],
#  ['대웅전',
#   '대웅전주백제',
#   '임팩',
#   '프리미엄',
#   '당첨이벤트문의',
#   '비대상처',
#   '대상',
#   '아웃',
#   '성원',
#   '쇼핑백',
#   '고함',
#   '기한내',
#   '한내',
#   '소진',
#   '일경',
#   '모바일',
#   '예정안내'],
#  ['연두',
#   '연두약국최연도',
#   '연도',
#   '캡슐',
#   '당시',
#   '본사',
#   '도매담당',
#   '담당',
#   '이정',
#   '이정민',
#   '내선',
#   '내선안내'],
#  ['주문시', '세금계산서', '이달', '판매마감', '월발행', '월매출', '발행예정'],
#  ['연질', '연질캡슐', '캡슐', '반품방법', '반품기간설정', '설정', '선택', '배송완료처리', '재확인', '재확인후'],
#  ['이지', '이브', '프로', '경로', '대웅거점상품관'],
#  ['백제약품', '반품취소요청회수', '날짜', '재신청', '함백제약품', '택배비', '차감', '쿠폰적용', '함취소완료'],
#  ['마이너스잔고예치금', '환불요청', '마이너스잔고', '환불안됨', '안됨', '엠서클', '서클', '냐며'],
#  ['동오약국홍성',
#   '오약',
#   '홍성',
#   '백제약품',
#   '반품취소요청회수',
#   '재신청',
#   '함백제약품',
#   '택배비',
#   '차감',
#   '처리가능'],
#  ['백제약품', '반품취소요청회수', '날짜', '재신청', '함백제약품', '택배비', '차감'],
#  ['동오약국홍성', '오약', '홍성', '백제약품', '반품취소요청회수', '연락주기', '주기'],
#  ['젯트', '품절문의', '미차장', '내선', '내선안내'],
#  ['대웅바이오', '처리현황', '현황', '도중', '이해됬다', '자체'],
#  ['동아당약국', '아당', '규영구매', '센트', '센트룸프로', '프로', '연락주기', '주기'],
#  ['신청방법', '마이'],
#  ['백제약품', '반품취소요청회수', '날짜', '재신청'],
#  ['푸른', '푸른약국차관호', '차관', '구지', '구지오', '비스'],
#  [],
#  ['사용방법',
#   '문의마이',
#   '마이',
#   '가기',
#   '가기패밀리존등급',
#   '패밀리',
#   '상세보',
#   '세보',
#   '생활기',
#   '생활기프트',
#   '프트',
#   '신청하기',
#   '하기',
#   '경로',
#   '경로안내'],
#  ['마트상품권',
#   '문의다음주',
#   '다음주',
#   '수금',
#   '수금요일사이',
#   '요일',
#   '사이',
#   '지참',
#   '고객센터',
#   '센터',
#   '개월'],
#  ['거점등록', '거점등록완료'],
#  ['사용문의', '도중', '손님', '재전'],
#  ['한번', '안됨', '부서', '전액'],
#  ['부외품', '남편', '남편번호', '발송요청', '기록'],
#  ['한번', '안됨', '부서'],
#  ['프라젠트라',
#   '트라',
#   '살오일',
#   '오일',
#   '유통기한',
#   '고함',
#   '고함업체',
#   '확인후',
#   '재연락',
#   '임박',
#   '임박제품하자',
#   '하자',
#   '대리',
#   '대리신청완료'],
#  ['분홍',
#   '분홍약국하분홍',
#   '하분',
#   '용산',
#   '용산구',
#   '이태원',
#   '이태원동',
#   '층소액처',
#   '소액',
#   '모바렌구입',
#   '이관가능',
#   '정보주면',
#   '주면',
#   '검토',
#   '검토후',
#   '피드백',
#   '피드백주기',
#   '주기',
#   '다음주',
#   '다음주중',
#   '지금'],
#  ['미수신', '재발', '재발송완료수신'],
#  ['샵플러스포인트', '플러스', '회수완료', '진행현황', '현황', '주문번호', '상품번호', '반품요청', '환불처리'],
#  ['조은', '조은약국냉', '미수신', '재발송완료'],
#  ['우리',
#   '마을',
#   '마을약국정명주',
#   '명주',
#   '에스비',
#   '에스비앤에프',
#   '에프',
#   '취소요청사유',
#   '쿠폰미적',
#   '미적',
#   '재결제',
#   '출고정지'],
#  ['변경요청', '팩스발송요청', '완료전', '주문어려움', '변경완료'],
#  ['더블유',
#   '스토어',
#   '스토어대흥',
#   '대흥',
#   '덕순',
#   '프라젠트라',
#   '트라',
#   '살오일',
#   '오일',
#   '유통기한',
#   '고함',
#   '고함업체',
#   '확인후',
#   '재연락',
#   '임박',
#   '임박제품하자',
#   '하자',
#   '반품접수'],
#  ['에스비', '에스비앤에프', '에프', '취소요청사유', '적용취소', '재결', '재결제시', '제시'],
#  ['바이오오산'],
#  ['컴퓨터',
#   '부실',
#   '부실뻔',
#   '프로그램',
#   '문제',
#   '장애',
#   '국민비씨',
#   '비씨',
#   '전면',
#   '전면장애',
#   '복구',
#   '복구중',
#   '미선',
#   '미선님',
#   '통화건아직',
#   '건아',
#   '결제플랫폼',
#   '플랫폼',
#   '부탁',
#   '부탁드림',
#   '완료시',
#   '통화요청',
#   '복구진행중',
#   '하루',
#   '하루종일',
#   '종일',
#   '불안정',
#   '결제방법',
#   '생각'],
#  ['프라젠트라', '트라', '살오일', '오일', '유통기한', '고함', '고함업체', '확인후', '재연락'],
#  ['복산나이스', '나이스', '한신', '한신약품금일', '출하', '출하요청'],
#  ['천안',
#   '삼거리',
#   '휴게소',
#   '휴게소약국양선아',
#   '선아',
#   '복산나이스',
#   '나이스',
#   '한신',
#   '한신약품금일',
#   '출하',
#   '출하요청'],
#  ['천안', '삼거리', '휴게소', '휴게소약국양선아', '선아', '복산나이스', '나이스', '한신', '한신약품', '출하'],
#  ['복산나이스', '나이스', '한신', '한신약품금일', '출하', '출하요청'],
#  ['정호', '선릉코', '코약국', '현담당자', '배재현', '재현', '실적', '함서울지역', '안민정'],
#  ['저번', '출석', '출석체크', '체크', '체크해드림'],
#  ['역대급', '선택', '선택요청'],
#  ['주문완료', '헬스', '헬스인', '결제시', '당일'],
#  ['우체', '우체국무통장', '국무', '주문요청', '가상계좌', '우체국', '엠서클', '서클'],
#  ['보근약국황지', '황지', '출하', '출하정지'],
#  ['누리', '누리약국조성', '조성', '복산', '나이스', '부산취소요청'],
#  ['컴퓨터',
#   '부실',
#   '부실뻔',
#   '프로그램',
#   '문제',
#   '장애',
#   '국민비씨',
#   '비씨',
#   '전면',
#   '전면장애',
#   '복구',
#   '복구중',
#   '미선',
#   '미선님',
#   '통화건아직',
#   '건아',
#   '결제플랫폼',
#   '플랫폼',
#   '부탁',
#   '부탁드림',
#   '완료시',
#   '통화요청'],
#  ['대웅오산', '취소요청사유', '재결제'],
#  ['샵플러스', '플러스', '전환', '전환방법'],
#  ['만점', '구매시', '일리', '일리지가', '지가', '할인쿠폰', '포인트임'],
#  ['사용방법', '구두'],
#  ['미수신'],
#  ['일반',
#   '일반신용카드',
#   '신용',
#   '광주',
#   '광주은행',
#   '은행',
#   '비씨',
#   '비씨카드',
#   '장애',
#   '안됨',
#   '김나리',
#   '나리',
#   '카드사',
#   '문제',
#   '전면',
#   '전면장애중',
#   '보시'],
#  ['거점등록', '요청임팩케어', '케어', '일단', '요청하심'],
#  ['주노약국', '환급', '차주', '금요일'],
#  ['스타', '스타벅스', '벅스', '마끼', '청해', '청해드림차주', '차주', '수령', '수령예정'],
#  ['도담약국김',
#   '승찬',
#   '대웅유진약품',
#   '유진',
#   '대웅유진',
#   '납품',
#   '납품번호',
#   '재주',
#   '재주문',
#   '출하',
#   '출하정지',
#   '완료옥경님',
#   '옥경',
#   '출고정지완료임',
#   '민케어',
#   '케어',
#   '출고정지',
#   '임팩'],
#  ['대림', '우리', '약국장', '국장', '대웅공장시'],
#  ['다정', '경희', '경희임팩', '민케어', '케어', '거점등록요청'],
#  ['탄약',
#   '탄약국김',
#   '덕반품',
#   '메디',
#   '메디코어노즈스위퍼',
#   '코어',
#   '노즈',
#   '스위퍼',
#   '코세정분말',
#   '세정',
#   '분말',
#   '스틱',
#   '스틱형',
#   '회수택배비',
#   '택배비',
#   '차감도',
#   '감도',
#   '반품금액',
#   '미적립'],
#  ['타이',
#   '타이레',
#   '공급가차이왼쪽',
#   '차이',
#   '왼쪽',
#   '단가',
#   '오른쪽',
#   '가지',
#   '경우중',
#   '하나',
#   '하나일수',
#   '일수',
#   '해당지역',
#   '판매중',
#   '특가',
#   '실시간',
#   '연동',
#   '일때'],
#  ['크림', '단가', '차이', '수금', '플러스', '정상', '사용하심'],
#  ['휴면',
#   '휴면처',
#   '해지',
#   '아이',
#   '아이디비번',
#   '비번',
#   '해제',
#   '해제완료',
#   '아이디임시',
#   '임시',
#   '메일주소',
#   '요청하심'],
#  ['에너지', '에너지약국', '김미숙', '미숙', '대웅서울', '취소요청사유', '오결'],
#  ['사용방법', '구두'],
#  ['새물', '새물약국', '김수진', '수진', '대웅복산공장', '부분취소요청', '출고정지'],
#  ['샵플러스포인트', '플러스', '전환', '확인문의처리', '왼쪽', '날개', '날개배', '경로', '경로안내'],
#  ['대성', '대성생활건강', '생활', '사별', '사별보기', '보기'],
#  ['반품가능', '낱알', '주문시', '오전예정'],
#  [],
#  ['사유재고과다', '과다'],
#  ['전자', '전자세금계산서', '수신메일주소변경'],
#  ['마이', '마이리지', '리지', '스타', '스타벅스', '벅스', '마끼', '신청완료'],
#  ['프레브이액', '브이', '지금', '구입가능', '색인', '색인시간소요', '재안내'],
#  ['임팩프리미엄', '프리미엄', '구매수량', '할인구간', '구간', '주문가능'],
#  ['전자', '전자세금계산서', '주소변경요청'],
#  ['일진', '일진사약국전', '재현', '대웅복산삼성', '삼성', '개월', '신한', '신한개월', '카드번호', '결제변경요청'],
#  ['라라',
#   '약국이유',
#   '이유',
#   '자신',
#   '조용현담당자',
#   '용현',
#   '알림문',
#   '알림문자가',
#   '자가',
#   '확인후',
#   '재연락'],
#  ['대웅복산공장', '복산', '나이스', '부산', '부산지점', '부산지점꺼', '적립예정'],
#  ['역대급이벤트우루', '우루', '사도', '포함', '전용관내', '관내', '임팩파워', '파워', '제외'],
#  ['김판주', '약국관리', '대웅전', '관배', '혜택이용'],
#  ['루사', '대웅전문약', '전문', '도매상', '대웅측', '주시', '주시길'],
#  ['아이',
#   '아이약국',
#   '조은',
#   '조은약국',
#   '안내면허번호',
#   '면허',
#   '요양',
#   '요양기관번호',
#   '기관',
#   '삭제해드림아이',
#   '폐업신고',
#   '신고',
#   '그때'],
#  ['사용방법',
#   '문의마이',
#   '마이',
#   '가기',
#   '가기패밀리존등급',
#   '패밀리',
#   '상세보',
#   '세보',
#   '생활기',
#   '생활기프트',
#   '프트',
#   '신청하기',
#   '하기',
#   '왼쪽',
#   '날개',
#   '날개배',
#   '샵플러스포인트',
#   '플러스',
#   '경로',
#   '경로안내'],
#  ['클래', '리트', '마이', '마이신정', '신정', '신청완료'],
#  ['화면'],
#  ['새대구약국허',
#   '대구',
#   '인호',
#   '임팩프리미엄',
#   '프리미엄',
#   '백만',
#   '백만얼마',
#   '얼마',
#   '제대',
#   '약사님',
#   '결제금액'],
#  ['박승',
#   '박승연담당자스멕',
#   '스멕',
#   '타가',
#   '이하',
#   '아이',
#   '복용',
#   '냐며',
#   '문의약국',
#   '예정스멕',
#   '현탁액',
#   '월일',
#   '월일이후',
#   '만세',
#   '만세소아',
#   '소아',
#   '임산부',
#   '임산부임신가능성',
#   '임신',
#   '가능성',
#   '여성',
#   '여성수유부',
#   '수유',
#   '복용금지',
#   '금지',
#   '안내대',
#   '문의확인후',
#   '재연락'],
#  ['샵플러스', '플러스', '엔터테인먼트', '메뉴', '위치'],
#  ['소나무', '김성재스멕타가', '성재', '스멕', '타가', '이하', '아이', '복용', '냐며', '문의약국'],
#  ['바구니', '시전', '주문시', '배송가능'],
#  ['플러스',
#   '플러스약국신승훈',
#   '신승',
#   '메디',
#   '메디미',
#   '플러스기획증정비',
#   '세트',
#   '기획',
#   '정비',
#   '진열',
#   '진열대비',
#   '대비',
#   '종개',
#   '스트로',
#   '스트로베리요거트증정',
#   '베리',
#   '요거트',
#   '증정',
#   '개스트로',
#   '플러스비',
#   '민트',
#   '하자',
#   '하자연기',
#   '연기',
#   '불이',
#   '낱개',
#   '사은품',
#   '동봉',
#   '스트로베리',
#   '셋트',
#   '개가',
#   '만큼',
#   '차감',
#   '개로',
#   '신청단일',
#   '단일'],
#  ['역대급', '임팩', '민파워', '파워', '구매하심', '제외', '제외대상', '대상', '미달', '미달되심', '되심'],
#  ['프레브이액', '브이', '지금', '구입가능'],
#  ['삼성', '삼성건강약국양', '미경', '전체취소요청', '사유고객요청'],
#  ['메디',
#   '플러스',
#   '메디미',
#   '플러스기획증정비',
#   '세트',
#   '기획',
#   '정비',
#   '진열',
#   '진열대비',
#   '대비',
#   '종개',
#   '스트로',
#   '스트로베리요거트증정',
#   '베리',
#   '요거트',
#   '증정',
#   '플러스비',
#   '민트',
#   '하자',
#   '하자연기',
#   '연기',
#   '불이',
#   '낱개',
#   '사은품',
#   '동봉',
#   '스트로베리',
#   '셋트',
#   '개가',
#   '만큼',
#   '차감',
#   '기획증정',
#   '분류',
#   '포장요청'],
#  ['역대급', '이마트상품권', '다음달'],
#  ['전주', '아스피린', '아스피린프로텍트정', '프로', '텍트', '장바구니담기시', '바구니', '담기', '팝업', '삭제요청'],
#  ['세계',
#   '약국정우주전주',
#   '우주',
#   '전주',
#   '아스피린',
#   '아스피린프로텍트정',
#   '프로',
#   '텍트',
#   '장바구니담기시',
#   '바구니',
#   '담기',
#   '확인후',
#   '함미선님',
#   '미선'],
#  ['세계',
#   '약국정우주전주',
#   '우주',
#   '전주',
#   '아스피린',
#   '아스피린프로텍트정',
#   '프로',
#   '텍트',
#   '장바구니담기시',
#   '바구니',
#   '담기',
#   '확인후'],
#  ['전주', '아스피린', '아스피린프로텍트정', '프로', '텍트', '장바구니담기시', '바구니', '담기'],
#  ['대성',
#   '대성생활건강시',
#   '생활',
#   '모레',
#   '건의',
#   '건의요청',
#   '최근',
#   '최근자',
#   '해당지역',
#   '사무소',
#   '매일',
#   '매일더블이벤트',
#   '더블',
#   '스탬프',
#   '응모',
#   '응모기간',
#   '도중',
#   '알럿창',
#   '기간문제',
#   '문제',
#   '실제',
#   '응모처리',
#   '별도',
#   '응모시간',
#   '설정',
#   '부외품',
#   '할인쿠폰'],
#  ['닥터', '닥터베', '수량입력', '낱알', '정수'],
#  ['플러스',
#   '플러스약국신승훈',
#   '신승',
#   '메디',
#   '메디미',
#   '플러스기획증정비',
#   '세트',
#   '기획',
#   '정비',
#   '진열',
#   '진열대비',
#   '대비',
#   '종개',
#   '스트로',
#   '스트로베리요거트증정',
#   '베리',
#   '요거트',
#   '증정',
#   '개스트로',
#   '플러스비',
#   '민트',
#   '하자',
#   '하자연기',
#   '연기',
#   '불이',
#   '낱개',
#   '사은품',
#   '동봉',
#   '스트로베리',
#   '셋트',
#   '개가',
#   '만큼',
#   '차감'],
#  ['샵플러스포인트',
#   '플러스',
#   '회수완료',
#   '진행현황',
#   '현황',
#   '주문번호',
#   '상품번호',
#   '옥경',
#   '옥경님',
#   '샵플러스측',
#   '오늘중'],
#  ['임팩케어',
#   '케어',
#   '국민카드',
#   '계속',
#   '카드사',
#   '장애',
#   '비씨',
#   '비씨국민',
#   '결제오류',
#   '복구',
#   '복구중',
#   '시간소요',
#   '양해드림'],
#  ['메디',
#   '플러스',
#   '메디미',
#   '플러스기획증정비',
#   '세트',
#   '기획',
#   '정비',
#   '진열',
#   '진열대비',
#   '대비',
#   '종개',
#   '스트로',
#   '스트로베리요거트증정',
#   '베리',
#   '요거트',
#   '증정',
#   '플러스비',
#   '민트',
#   '하자',
#   '하자연기',
#   '연기',
#   '불이'],
#  ['컴퓨터',
#   '부실',
#   '부실뻔',
#   '프로그램',
#   '문제',
#   '장애',
#   '국민비씨',
#   '비씨',
#   '전면',
#   '전면장애',
#   '복구',
#   '복구중'],
#  ['일반',
#   '일반신용카드',
#   '신용',
#   '국민카드',
#   '장애',
#   '안됨',
#   '김나리',
#   '나리',
#   '카드사',
#   '문제',
#   '비씨',
#   '전면',
#   '전면장애중',
#   '복구'],
#  ['향정',
#   '프로세스',
#   '프로세스문의',
#   '보건소',
#   '폐기',
#   '폐기서류',
#   '서류',
#   '샵반품신청',
#   '주면',
#   '현서',
#   '통화건양',
#   '건양',
#   '양수',
#   '약국대웅',
#   '직인',
#   '서류전달안내',
#   '이해',
#   '입실'],
#  ['보건소',
#   '대신',
#   '문의보건소',
#   '고객만족센터공지',
#   '만족',
#   '센터',
#   '사항',
#   '보기',
#   '보기공급업체공지',
#   '향정의약품',
#   '정의',
#   '반품절차안내',
#   '절차',
#   '첨부',
#   '첨부파일',
#   '파일',
#   '다운'],
#  ['일반',
#   '일반신용카드',
#   '신용',
#   '국민카드',
#   '장애',
#   '안됨',
#   '김나리',
#   '나리',
#   '카드사',
#   '문제',
#   '비씨',
#   '전면',
#   '전면장애중',
#   '복구'],
#  ['역대급', '경로', '구두'],
#  ['시티', '시티약국', '김연석', '연석', '대웅주문', '납품', '출고정지'],
#  ['장태',
#   '장태훈담당자',
#   '구매금액',
#   '대웅로만',
#   '로만',
#   '조회시',
#   '리버',
#   '리버골드일반약이',
#   '골드',
#   '일반',
#   '약이',
#   '포함되',
#   '함되',
#   '계산'],
#  ['도담약국김',
#   '승찬',
#   '대웅유진약품',
#   '유진',
#   '대웅유진',
#   '납품',
#   '납품번호',
#   '재주',
#   '재주문',
#   '출하',
#   '출하정지'],
#  ['일반',
#   '일반신용카드',
#   '신용',
#   '국민카드',
#   '장애',
#   '안됨',
#   '김나리',
#   '나리',
#   '카드사',
#   '문제',
#   '비씨',
#   '전면',
#   '전면장애중',
#   '복구'],
#  ['도담약국김',
#   '승찬',
#   '대웅유진약품',
#   '유진',
#   '대웅유진',
#   '납품',
#   '납품번호',
#   '재주',
#   '재주문',
#   '출하',
#   '출하정지'],
#  ['장태', '장태훈담당자', '구매금액', '대웅로만', '로만', '조회시'],
#  ['향정', '프로세스', '프로세스문의', '보건소', '폐기', '폐기서류', '서류', '샵반품신청', '주면'],
#  ['대웅전',
#   '대웅전주백제',
#   '임팩',
#   '프리미엄',
#   '당첨이벤트문의',
#   '비대상처',
#   '대상',
#   '아웃',
#   '성원',
#   '쇼핑백',
#   '고함',
#   '기한내',
#   '한내',
#   '소진'],
#  ['연락처문의', '장태', '장태훈'],
#  ['보건소', '대신', '문의보건소'],
#  ['도담약국김', '승찬', '대웅유진약품', '유진', '대웅유진', '납품', '납품번호', '재주', '재주문'],
#  ['창원', '전체취소요청', '사유카드재결제'],
#  ['옵티마', '옵티마청운약국송', '청운', '창원', '보덕', '보덕메디', '메디'],
#  ['샵플러스포인트', '플러스', '회수완료', '진행현황', '현황', '주문번호', '상품번호', '해당건'],
#  ['국민카드', '사전', '사전등록'],
#  ['역대급'],
#  ['세비', '세비카', '우루', '비스', '품절예상', '예상', '도매상', '특이', '특이사항', '사항', '공유'],
#  ['원당', '원당약국조태원', '태원', '대웅반품', '사유오신청'],
#  ['세비', '세비카', '우루', '우루사', '공장이전', '불가하다', '하다', '소문', '이슈'],
#  ['푸른', '온누리', '약국홍태훈', '십자', '십자약품', '전문', '전문약이', '약이', '월부', '예상', '지금'],
#  ['스타',
#   '스타약국',
#   '신규',
#   '신규가입중요양',
#   '요양',
#   '기관',
#   '기관번호',
#   '중복',
#   '문의수정완료',
#   '재시',
#   '입승인',
#   '요청최대한',
#   '최대한',
#   '안내정',
#   '전달완료'],
#  ['이동요청'],
#  ['현대',
#   '현대카드',
#   '무이자',
#   '무이자할부',
#   '할부',
#   '타카드',
#   '포인트적립',
#   '삼성',
#   '우리',
#   '개월',
#   '신한',
#   '신한하이',
#   '하이',
#   '할부가능',
#   '직접',
#   '카드사',
#   '정확'],
#  ['대웅전', '대웅전주백제', '임팩', '프리미엄', '당첨이벤트문의'],
#  ['임팩',
#   '민케어',
#   '케어',
#   '입고',
#   '입고라',
#   '품절임',
#   '절임',
#   '사이',
#   '월초',
#   '안내월초',
#   '하냐',
#   '연락요청',
#   '한번',
#   '주시',
#   '주시길',
#   '예상'],
#  ['온누리', '약국강규', '대웅제품', '비용', '비용할인', '동일', '할인적용', '부외품', '안내문자발송'],
#  ['메디칼',
#   '금보',
#   '금보메디넷',
#   '메디',
#   '헬스',
#   '헬스인',
#   '만원이상',
#   '최소',
#   '최소주문',
#   '최소주문금액',
#   '주묹가능'],
#  ['임팩', '프리미엄', '신규', '저변', '저변확대', '확대', '대상', '대상처', '업데이트', '업데이트관련'],
#  ['양평포',
#   '평포',
#   '나무',
#   '나무약국허진서',
#   '진서',
#   '티제이',
#   '제이',
#   '재주',
#   '재주문',
#   '전일',
#   '결제건',
#   '수취',
#   '수취거부',
#   '함약사',
#   '다시',
#   '수취거절',
#   '거절',
#   '입고시',
#   '고시',
#   '입고'],
#  ['인증',
#   '프로그램',
#   '설치',
#   '도구',
#   '도구인터넷옵션보안',
#   '인터넷',
#   '옵션',
#   '보안',
#   '사용자',
#   '사용자지정수준',
#   '지정',
#   '수준',
#   '컨트롤',
#   '자동',
#   '체크'],
#  ['승인요청사업자', '면허증', '미수신', '재발', '재발송', '함내일', '승인예정팩스번호', '재문'],
#  ['비스', '비스정', '공장이전', '품절이슈', '이슈', '정상'],
#  ['조현', '조현서', '연결요청', '연결완료'],
#  ['타이',
#   '타이레놀',
#   '주문하려',
#   '하려',
#   '공급가',
#   '실제',
#   '구입금액',
#   '차이',
#   '발생',
#   '불만',
#   '제기',
#   '기분',
#   '하루',
#   '하루이틀',
#   '이틀',
#   '반영',
#   '기만',
#   '고함',
#   '고함특가',
#   '특가',
#   '실시간',
#   '연동',
#   '일때',
#   '불만제기',
#   '정정',
#   '정정요청',
#   '최대한',
#   '안내해당지역',
#   '단가',
#   '판매중',
#   '안내지역',
#   '사람',
#   '화면',
#   '설정',
#   '설정되야',
#   '되야',
#   '지역간',
#   '위화감',
#   '조성',
#   '않겠냐',
#   '말씀',
#   '말씀하심'],
#  ['재개', '재개업', '신규', '상호명', '스타', '스타약국임재', '사등', '첨부', '예정기존', '불가함'],
#  [],
#  ['티제이',
#   '제이',
#   '재주',
#   '재주문',
#   '전일',
#   '결제건',
#   '수취',
#   '수취거부',
#   '함옥경님',
#   '옥경',
#   '통화건반',
#   '건반',
#   '수취거절',
#   '거절',
#   '카드취소요청',
#   '개로',
#   '재주문하심'],
#  ['스타', '스타약국사업자', '사용중인', '중인', '사용가능', '불가함', '탈퇴', '탈퇴처리', '함해', '안내요청'],
#  ['사용방법'],
#  ['샵플러스포인트', '플러스', '회수완료', '진행현황', '현황', '주문번호', '상품번호'],
#  ['조은',
#   '조은약국김영애',
#   '영애',
#   '탑헬스케어밴드',
#   '헬스',
#   '케어',
#   '밴드',
#   '닥터',
#   '미회수라',
#   '수라',
#   '회수요청',
#   '재회',
#   '재회수요',
#   '수요',
#   '미회수',
#   '재요청'],
#  ['등록방법', '신용', '신용카드', '사전', '사전등록'],
#  ['탑헬스케어밴드',
#   '헬스',
#   '케어',
#   '밴드',
#   '닥터',
#   '미회수라',
#   '수라',
#   '회수요청',
#   '재회',
#   '재회수요',
#   '수요',
#   '미회수',
#   '재요청'],
#  ['도매몰',
#   '매몰',
#   '영님',
#   '통화건도매몰',
#   '건도',
#   '임대',
#   '입점업체',
#   '영약국정래경',
#   '정래',
#   '씨앤케이코스',
#   '케이',
#   '코스',
#   '메디칼',
#   '반품대기',
#   '대기',
#   '상태값',
#   '다함이',
#   '클레임',
#   '제기',
#   '해결',
#   '이정',
#   '이정민님'],
#  ['프레브이액', '브이'],
#  ['부외품',
#   '반품신청방법',
#   '대성',
#   '대성생활건강',
#   '생활',
#   '녹십자',
#   '로즈',
#   '로즈맥스초체온계',
#   '맥스',
#   '체온계',
#   '개불량',
#   '불량',
#   '반품요청',
#   '불량개',
#   '무료',
#   '무료반품',
#   '재입',
#   '테스트',
#   '반송',
#   '왕복',
#   '왕복택배비',
#   '택배비',
#   '부과',
#   '내하',
#   '내하니더샵',
#   '니더',
#   '한미',
#   '한미몰'],
#  ['재고부족',
#   '취소요청바른약국',
#   '바른',
#   '송원',
#   '송원철',
#   '청십자약품취소',
#   '십자',
#   '연세',
#   '연세약국김영선',
#   '김영선'],
#  ['바렌굿', '일라', '일라카', '년월일', '세금계산서', '구매이력'],
#  ['메디',
#   '현대',
#   '약국김유정',
#   '김유정',
#   '대성',
#   '대성생활건강',
#   '생활',
#   '녹십자',
#   '로즈',
#   '로즈맥스초체온계',
#   '맥스',
#   '체온계',
#   '개불량',
#   '불량',
#   '반품요청',
#   '불량개',
#   '무료',
#   '무료반품',
#   '재입',
#   '테스트',
#   '반송',
#   '왕복',
#   '왕복택배비',
#   '택배비',
#   '부과'],
#  ['이지', '이브', '선택', '이브연질캡슐', '연질', '캡슐', '안내마이너스잔고', '대웅제품'],
#  ['대성',
#   '대성생활건강시',
#   '생활',
#   '모레',
#   '건의',
#   '건의요청',
#   '매일',
#   '매일더블이벤트',
#   '더블',
#   '스탬프',
#   '응모',
#   '응모기간'],
#  ['부외품',
#   '반품신청방법',
#   '대성',
#   '대성생활건강',
#   '생활',
#   '녹십자',
#   '로즈',
#   '로즈맥스초체온계',
#   '맥스',
#   '체온계',
#   '개불량',
#   '불량',
#   '반품요청'],
#  ['변경요청', '팩스발송요청', '완료전', '주문어려움'],
#  ['영도', '영도건강약국', '하경', '문자발송', '감사'],
#  ['중앙',
#   '중앙약국신혜',
#   '한올',
#   '한올반품처리현황',
#   '현황',
#   '조성희',
#   '성희',
#   '과장',
#   '환입명세서',
#   '명세서',
#   '출력',
#   '입실',
#   '송부',
#   '반품확정요청',
#   '확정'],
#  ['타이',
#   '타이레놀',
#   '주문하려',
#   '하려',
#   '공급가',
#   '실제',
#   '구입금액',
#   '차이',
#   '발생',
#   '불만',
#   '제기',
#   '기분',
#   '하루',
#   '하루이틀',
#   '이틀',
#   '반영',
#   '기만',
#   '고함',
#   '고함정정',
#   '정정',
#   '최대한'],
#  ['수약국심재훈',
#   '심재',
#   '거점특별공급관',
#   '개도',
#   '이지',
#   '이지덤임팩',
#   '프리',
#   '프리미엄마',
#   '엄마',
#   '보임',
#   '올등록'],
#  ['월역대급이벤트', '도달', '얼마'],
#  ['대웅바이오', '반품건아직', '건아', '원장', '원장처리', '환입마감', '둘째', '둘째주'],
#  ['중앙', '중앙약국신혜', '한올', '한올반품처리현황', '현황'],
#  ['도매몰', '매몰'],
#  ['도매몰', '매몰', '미차장'],
#  ['만점', '사용방법', '패밀리', '패밀리존', '신청방법', '신청하심', '차주', '수요일', '모바일', '발송예정'],
#  ['대웅씨콜',
#   '부가세',
#   '처리가능',
#   '양도',
#   '우선',
#   '승인상태',
#   '사이트',
#   '택배비',
#   '선불',
#   '환입실주소',
#   '경기',
#   '화성',
#   '화성시',
#   '향남면',
#   '백토리',
#   '토리',
#   '발송요청',
#   '환입서',
#   '직인',
#   '동봉',
#   '전화주시',
#   '주시',
#   '변경예정',
#   '환불예정임',
#   '안내환입서상호인',
#   '서상',
#   '호인',
#   '작성',
#   '작성후',
#   '사진',
#   '미선',
#   '미선님',
#   '톡으',
#   '고함',
#   '미수',
#   '미수신시',
#   '신시'],
#  ['가입관련', '배정문의', '함사업자상', '기재하심', '층수', '오기', '오기재'],
#  ['대웅씨콜',
#   '부가세',
#   '처리가능',
#   '양도',
#   '우선',
#   '승인상태',
#   '사이트',
#   '택배비',
#   '선불',
#   '환입실주소',
#   '경기',
#   '화성',
#   '화성시',
#   '향남면',
#   '백토리',
#   '토리',
#   '발송요청',
#   '환입서',
#   '직인',
#   '동봉',
#   '전화주시',
#   '주시',
#   '변경예정',
#   '환불예정임',
#   '안내환입서상호인',
#   '서상',
#   '호인',
#   '작성',
#   '작성후',
#   '사진'],
#  ['가입관련', '배정문', '정문'],
#  ['대웅바이오', '반품신청시', '사입이', '입이', '신청완료', '네버', '네버펜', '사입건', '입건'],
#  ['오류창',
#   '일반',
#   '쿠키',
#   '사이트',
#   '데이터',
#   '설정',
#   '보안',
#   '신뢰',
#   '고급',
#   '고급설정복원',
#   '기본',
#   '기본설정복원',
#   '원래'],
#  ['보덕',
#   '보덕메디',
#   '메디',
#   '실원스외용액',
#   '원스',
#   '용액',
#   '소통완료',
#   '조회기간',
#   '반품내역',
#   '주문내역',
#   '며칠',
#   '조회가',
#   '회가',
#   '안됬',
#   '신청완료',
#   '반품쿠폰'],
#  ['사용방법', '패밀리', '패밀리존'],
#  ['신청방법', '화면', '부외품', '천원', '청해', '청해드림'],
#  ['만점', '청해', '청해드림차주', '차주', '수금', '모바일', '수령', '수령예정'],
#  ['미래',
#   '원고',
#   '원고종하',
#   '종하',
#   '금보',
#   '금보메디넷',
#   '메디',
#   '시올',
#   '테이프',
#   '테이프박스롤',
#   '개모두',
#   '모두',
#   '제품오배송',
#   '영님',
#   '거래명세서',
#   '명세서'],
#  ['역대급', '선택'],
#  ['소액',
#   '소액처',
#   '월매출',
#   '부족금액',
#   '유도',
#   '안내만유',
#   '만유',
#   '진선',
#   '진선님',
#   '통화건위',
#   '건위',
#   '안내사항',
#   '사항',
#   '제대',
#   '안내원',
#   '추가구매',
#   '함원',
#   '구매내역확인',
#   '이마트상품권',
#   '사용방법',
#   '안내마이',
#   '마이',
#   '가기',
#   '가기패밀리존등급',
#   '패밀리',
#   '상세보',
#   '세보',
#   '생활기',
#   '생활기프트',
#   '프트',
#   '신청하기',
#   '하기',
#   '경로',
#   '경로안내',
#   '대리',
#   '대리신청',
#   '스타',
#   '스타벅스',
#   '벅스',
#   '마끼',
#   '부외품',
#   '부외품할인',
#   '천원'],
#  ['연세',
#   '내과',
#   '메디칼',
#   '최민석부재중',
#   '석부',
#   '재중',
#   '보고',
#   '통화주심',
#   '주심',
#   '신청서',
#   '신청서상',
#   '패스',
#   '패스워드',
#   '워드',
#   '자리'],
#  ['인증',
#   '프로그램',
#   '설치',
#   '도구',
#   '도구인터넷옵션보안',
#   '인터넷',
#   '옵션',
#   '보안',
#   '사용자',
#   '사용자지정수준',
#   '지정',
#   '수준',
#   '컨트롤',
#   '자동',
#   '체크'],
#  ['은진', '은진위재멸균거즈', '위재', '멸균', '거즈', '사이즈', '종수', '종수약품'],
#  ['부산', '북구', '화명', '화명동쪽', '동쪽', '병원', '누구'],
#  ['신세계', '차주'],
#  ['보덕', '보덕메디', '메디', '실원스외용액', '원스', '용액', '소통완료', '조회기간', '반품내역', '주문내역'],
#  ['부외품', '신청완료'],
#  ['금창균',
#   '요청메',
#   '코발정',
#   '발정',
#   '생산',
#   '생산중단대체상품',
#   '대체',
#   '한국',
#   '한국파마',
#   '파마',
#   '파마메코',
#   '동화',
#   '동화약품',
#   '엠코발',
#   '캅셀',
#   '캅셀안내'],
#  ['파티마', '파티마약국최선희메', '최선', '희메', '코발정', '발정', '생산', '생산중단약국', '안내요청'],
#  ['자연애',
#   '임팩',
#   '민케어',
#   '케어',
#   '구매건',
#   '기안',
#   '상신',
#   '에프',
#   '트리플',
#   '약국오정',
#   '오정',
#   '새살',
#   '새살연고',
#   '연고',
#   '거점등록',
#   '등록해드림'],
#  ['승인요청사업자', '면허증', '미수신', '재발', '재발송', '함내일', '승인예정'],
#  ['가입예정', '액티브', '액티브설치', '설치', '도구', '도구호환성보기인터넷', '호환성', '보기', '인터넷', '옵션'],
#  ['삼성', '삼성카드', '재등록', '재등록문의', '마이', '페이지회원정보', '삭제후재등록'],
#  ['보덕', '보덕메디', '메디', '배송문의배송예정일', '고윤', '약국앞', '배달'],
#  ['스타',
#   '스타벅스',
#   '벅스',
#   '신청요청',
#   '마끼',
#   '신청완료',
#   '부외품',
#   '부외품할인쿠폰해',
#   '차주',
#   '차주수금',
#   '수금',
#   '모바일',
#   '모바일발송안내'],
#  ['가지'],
#  ['크림', '단가', '차이'],
#  ['역대급이벤트',
#   '구매금액',
#   '사은',
#   '사은품',
#   '이마트만원',
#   '선택',
#   '분기',
#   '얼마',
#   '얼마이상',
#   '주고',
#   '마일리지대방출',
#   '방출'],
#  ['보덕', '보덕메디', '메디', '배송문의배송예정일'],
#  ['만점', '부외품', '부외품할인', '천원', '청해', '청해드림'],
#  ['사용방법', '구두'],
#  ['주유', '주유할인', '부외품', '부외품할인', '천원', '청해', '청해드림'],
#  ['대웅바이오', '반품건아직', '건아', '원장', '원장처리'],
#  ['정호',
#   '선릉코',
#   '코약국',
#   '정호현',
#   '폐업후',
#   '신규',
#   '신규가입',
#   '승인안내문자가',
#   '안내문',
#   '자가',
#   '문의담당자변경관련',
#   '기안',
#   '기안상신',
#   '상신',
#   '양식'],
#  ['스타', '스타벅스', '벅스', '청해', '청해드림'],
#  ['사용방법', '만원부외품', '부외품', '신청완료'],
#  ['전병', '태평양', '전병국', '태평양약국', '통화요청'],
#  ['가상계좌', '서울약사신협미', '신협', '결제요청', '예치금결제완료'],
#  ['강동', '약국장인선코드', '국장', '인선', '임수영', '수영'],
#  ['분기', '패밀리', '패밀리존', '등급문의', '다이', '다이아몬드', '아몬드', '예정반품', '포함'],
#  ['우리카드글랑블', '결제시', '사전', '사전등록', '신용', '신용카드사전등록', '하면'],
#  ['스피틴', '스피틴정', '문의확인후', '재연락', '예정내일', '저녁', '시이후', '주문가능'],
#  ['온누리', '약국박정연', '박정', '대웅향남케어', '케어', '인수증', '재확인', '재확인요청'],
#  ['스피틴', '스피틴정', '품절문의', '저녁', '시이후'],
#  ['스멕', '대웅제품', '검색시', '하단', '스틱', '포제품'],
#  ['송치',
#   '송치흥담당자약국',
#   '프로그램',
#   '연동',
#   '불만',
#   '불만제기',
#   '제기',
#   '고함',
#   '고함대웅',
#   '문제',
#   '중간',
#   '중간연계사',
#   '계사',
#   '마약',
#   '통합시스템쪽',
#   '약국쪽',
#   '직접',
#   '소통요청담당자',
#   '통합시스템'],
#  ['약국김영종',
#   '영종',
#   '공동',
#   '공동구매',
#   '메디칼',
#   '배송지연',
#   '문의업체',
#   '확인후',
#   '재연락',
#   '배송중임',
#   '중임',
#   '고함',
#   '고함소현님',
#   '시간내',
#   '조회안',
#   '이제',
#   '됬다'],
#  ['보건',
#   '프로그램',
#   '연동',
#   '불만',
#   '불만제기',
#   '제기',
#   '고함',
#   '고함대웅',
#   '문제',
#   '중간',
#   '중간연계사',
#   '계사',
#   '마약',
#   '통합시스템쪽',
#   '약국쪽',
#   '직접',
#   '소통요청'],
#  ['약국김영종',
#   '영종',
#   '공동',
#   '공동구매',
#   '메디칼',
#   '배송지연',
#   '문의업체',
#   '확인후',
#   '재연락',
#   '배송중임',
#   '중임',
#   '고함',
#   '고함소현님',
#   '시간내'],
#  ['공동',
#   '공동구매',
#   '메디칼',
#   '배송지연',
#   '문의업체',
#   '확인후',
#   '재연락',
#   '약속업체확인완료',
#   '배송중임',
#   '중임',
#   '고함',
#   '고함소현님',
#   '전화요청'],
#  ['란액',
#   '주문내역',
#   '포함',
#   '기존주문건',
#   '주문취소요청',
#   '문의확인후',
#   '취소진행',
#   '안내주문취소요청',
#   '건과',
#   '재주',
#   '재주문건',
#   '주문취소',
#   '모두',
#   '취소후',
#   '재연락',
#   '약속소현님',
#   '통화건시안',
#   '건시',
#   '하루',
#   '시안',
#   '바구니',
#   '확인후',
#   '재주문',
#   '추가처리',
#   '결제하기',
#   '제하기',
#   '클릭',
#   '안됬다'],
#  ['종근당', '패밀리', '약국이병천', '이병', '존현대상품권', '현대', '전송요청'],
#  ['이치', '수암', '앤비세', '비세', '데이즈', '이즈', '전체취소요청'],
#  ['사용방법', '이마트만원', '스타', '스타벅', '신청완료'],
#  ['취소요청사유', '오결'],
#  ['란액',
#   '주문내역',
#   '포함',
#   '기존주문건',
#   '주문취소요청',
#   '문의확인후',
#   '취소진행',
#   '안내주문취소요청',
#   '건과',
#   '재주',
#   '재주문건',
#   '주문취소',
#   '모두',
#   '취소후',
#   '재연락',
#   '약속소현님',
#   '통화건시안',
#   '건시',
#   '하루',
#   '시안',
#   '바구니',
#   '확인후',
#   '재주문'],
#  ['이층', '우리', '약국이동엽', '잔고적립', '전일', '반품처리가능'],
#  ['박용수',
#   '용수',
#   '인천약품',
#   '보령',
#   '보령토르세미',
#   '토르',
#   '세미',
#   '반품신청요청인천',
#   '고함',
#   '고함플루스타',
#   '스타',
#   '정과',
#   '엘티',
#   '반품쿠폰'],
#  ['란액',
#   '주문내역',
#   '포함',
#   '기존주문건',
#   '주문취소요청',
#   '문의확인후',
#   '취소진행',
#   '안내주문취소요청',
#   '건과',
#   '재주',
#   '재주문건',
#   '주문취소',
#   '모두',
#   '취소후',
#   '재연락',
#   '약속소현님',
#   '통화건시안',
#   '건시',
#   '하루',
#   '시안'],
#  ['대웅바이오', '반품신청시', '사입이', '입이'],
#  ['인천약품',
#   '보령',
#   '보령토르세미',
#   '토르',
#   '세미',
#   '반품신청요청인천',
#   '고함',
#   '고함플루스타',
#   '스타',
#   '정과',
#   '엘티',
#   '반품쿠폰'],
#  ['대웅바이오',
#   '셋정',
#   '네버',
#   '네버펜',
#   '셉트',
#   '세미',
#   '스타',
#   '디피',
#   '디피네스',
#   '네스',
#   '신청완료',
#   '반품잔고처리',
#   '안됨',
#   '재전'],
#  ['잔고적립', '전일', '반품처리가능'],
#  ['이메일', '변경요청'],
#  ['구남약국',
#   '지영',
#   '그린',
#   '소독',
#   '에탄올',
#   '에탄올스프레이',
#   '스프레이',
#   '일반',
#   '에탄올액',
#   '오배송',
#   '물류'],
#  ['만점',
#   '부외품',
#   '안내주문',
#   '삼성',
#   '삼성카드',
#   '선택',
#   '선택하면',
#   '하면',
#   '결제수단',
#   '수단',
#   '이제',
#   '됬다'],
#  ['란액',
#   '주문내역',
#   '포함',
#   '기존주문건',
#   '주문취소요청',
#   '문의확인후',
#   '취소진행',
#   '안내주문취소요청',
#   '건과',
#   '재주',
#   '재주문건',
#   '주문취소',
#   '모두',
#   '취소후',
#   '재연락'],
#  ['전화번호'],
#  ['신한',
#   '신한카드',
#   '하이',
#   '개월',
#   '무이자',
#   '무이자청구할인',
#   '청구',
#   '청구할인',
#   '우리',
#   '구간',
#   '카드사',
#   '정확'],
#  ['노비',
#   '노비프로스액',
#   '프로',
#   '스액',
#   '티제이',
#   '제이',
#   '소통완료',
#   '제품하자',
#   '하자',
#   '함업체부담',
#   '부담'],
#  ['만점', '부외품'],
#  ['현온누리약국성',
#   '온누리',
#   '백현스피',
#   '현스',
#   '문의확인후',
#   '재연락',
#   '예정제품',
#   '최근',
#   '최근구매',
#   '상위',
#   '개선요청담당부서',
#   '담당',
#   '부서'],
#  ['영업사원관리',
#   '샵관리',
#   '등록해드렷고',
#   '드렷',
#   '현대',
#   '판촉물선택',
#   '선택',
#   '부외품',
#   '부외품쿠폰만원',
#   '가시',
#   '복약지도로',
#   '약지',
#   '도로',
#   '바쁘심'],
#  ['대림', '우리', '약국장', '국장', '대웅공장'],
#  ['라티', '한신', '한신약품', '모스', '모스넷', '가능여부', '백제약품', '복합마데카솔', '데카'],
#  ['주차', '주차편', '약국정성', '정성', '휴면', '휴면처', '정상', '로그', '능아이디'],
#  ['대웅바이오',
#   '리제정',
#   '제정',
#   '향정',
#   '당시',
#   '양도',
#   '양도양수증',
#   '양수',
#   '유미',
#   '유미선님',
#   '상담',
#   '참고',
#   '재요청',
#   '이정식',
#   '정식',
#   '출장',
#   '차주',
#   '재발송'],
#  ['환불요청팩스'],
#  ['천안', '삼거리', '휴게소', '휴게소약국양선아', '선아', '모스', '모스넷', '한신', '한신약품', '가능여부'],
#  ['새대웅',
#   '사약국',
#   '김경진',
#   '경진',
#   '코큐터',
#   '에이스',
#   '대신',
#   '신청요청',
#   '구매이력확인',
#   '한미',
#   '한미바이오대웅코',
#   '큐터',
#   '반품기한'],
#  ['취소요청사유', '수령', '제품하자', '하자', '회수택배비', '택배비', '부담'],
#  ['무지개', '무지개약국', '원주', '취소요청사유', '수령', '제품하자', '하자', '회수택배비', '택배비', '부담'],
#  ['라티', '한신', '한신약품', '모스', '모스넷', '가능여부'],
#  ['역대급이벤트', '만원이상', '매출금액', '도달'],
#  ['무지개', '무지개약국', '원주', '취소요청사유'],
#  ['취소요청사유'],
#  ['전용관매출', '도달', '급이벤트', '청해', '청해드림'],
#  ['지매', '지매약국원남', '숙하', '숙하모', '란액', '주문내역', '포함', '기존주문건', '주문취소요청', '안내메일'],
#  ['비스',
#   '비스정',
#   '성상',
#   '성상변경',
#   '제조번호',
#   '성상문의주심',
#   '주심',
#   '영문',
#   '모두',
#   '학술',
#   '학술팀',
#   '김순주'],
#  ['란액', '주문내역', '포함', '기존주문건', '주문취소요청', '문의확인후', '취소진행'],
#  ['행운', '행운약국김', '가입이력확인', '코드확인요청', '휴면', '휴면상태', '메일발송요청'],
#  ['지매', '지매약국원남', '숙하', '숙하모', '란액', '주문내역', '포함', '기존주문건', '주문취소요청', '안내통화중'],
#  ['란액', '주문내역', '포함', '기존주문건', '주문취소요청'],
#  ['출하', '출하요청', '해피', '타임', '안내라티', '액모스넷푸로', '모스', '푸로', '사입이', '입이'],
#  ['선화', '선화약국김성희', '성희', '웅지', '웅지오', '체취소요청', '사유재주문', '재주', '출고정지요청'],
#  ['선화', '선화약국김성희', '성희', '웅지', '웅지오', '체취소요청', '사유재주', '재주'],
#  ['제일',
#   '제일헬스케어',
#   '헬스',
#   '케어',
#   '메디',
#   '메디고탄력밴드덕',
#   '고탄력',
#   '밴드',
#   '용매',
#   '리뉴얼',
#   '상황',
#   '상황임',
#   '제품명'],
#  ['천안', '삼거리', '휴게소', '휴게소약국양선아', '선아', '출고요청'],
#  ['출고요청', '마감시간', '오늘출고'],
#  ['응답', '안내멘트후', '멘트'],
#  ['카드결제',
#   '세금계산서',
#   '중복',
#   '세무',
#   '세무처리시',
#   '번거로움',
#   '현금',
#   '현금영수증',
#   '영수증',
#   '카드전교',
#   '전교',
#   '이중',
#   '부가',
#   '부가가치세',
#   '가치세',
#   '신고',
#   '가산세',
#   '가산세부과',
#   '부과',
#   '한번'],
#  ['양옥', '양옥주', '실장', '내선', '내선번호'],
#  ['주안',
#   '허브',
#   '영환',
#   '메디',
#   '메디고탄력밴드덕',
#   '고탄력',
#   '밴드',
#   '용매',
#   '확인중',
#   '연락주기',
#   '주기',
#   '통화건제품',
#   '건제품',
#   '리뉴얼',
#   '생산',
#   '사이트',
#   '판매내역',
#   '업체과실',
#   '과실',
#   '선택',
#   '하심정',
#   '전달완료'],
#  ['엠디', '고단', '월로', '거냐며', '냐며', '개월', '개월임'],
#  ['삼원', '삼원약국김여랑', '여랑', '엠디', '고단', '월로', '거냐며', '냐며', '유통기한', '개월'],
#  ['백제약품영남', '영남', '시알', '시알리스정', '리스', '미처리', '처리확인요청', '적립처리완료'],
#  ['출하', '출하요청'],
#  ['주안', '허브', '영환', '메디', '메디고탄력밴드덕', '고탄력', '밴드', '용매', '확인중', '연락주기', '주기'],
#  ['역대급이벤트', '만원이상'],
#  ['고운',
#   '고운약국박용우',
#   '박용',
#   '백제약품영남',
#   '영남',
#   '시알',
#   '시알리스정',
#   '리스',
#   '미처리',
#   '처리확인요청',
#   '지금'],
#  ['가입서류', '서류', '기입', '핸드폰번호'],
#  ['역대급'],
#  ['강남',
#   '강남미약국김',
#   '효현가입서류',
#   '서류',
#   '메일주소',
#   '글자',
#   '요청드림',
#   '일반',
#   '일반약',
#   '배정여부',
#   '네이버',
#   '네이버임'],
#  ['복산나이스', '나이스', '베진코', '에스', '에스정', '메모란', '모란', '개업체소통완료'],
#  ['블랙', '블랙라벨손목보호대', '라벨', '손목', '보호대', '제품문의', '플러스'],
#  ['바다', '바다약국이상미', '복산나이스', '나이스', '베진코', '에스', '에스정', '메모란', '모란'],
#  ['복산나이스', '나이스', '베진코', '에스', '에스정'],
#  ['큰사랑', '약국김학', '봉아이디'],
#  ['주노온누리약국',
#   '온누리',
#   '손동운',
#   '동운',
#   '일전',
#   '반품내역',
#   '조회요청금일',
#   '오후익일',
#   '점심',
#   '로그',
#   '로그인'],
#  ['패밀리', '패밀리존', '스타', '스타벅스', '벅스', '카페', '차주', '수요일', '모바일'],
#  ['기프티콘',
#   '신청방법',
#   '샵플러스',
#   '플러스',
#   '엔터테인먼트',
#   '잔액',
#   '확인해드림',
#   '기옥경',
#   '옥경',
#   '신세계',
#   '신세계상품권',
#   '재발',
#   '재발송후',
#   '연락요청'],
#  ['온누리', '윤경아', '경아', '사랑', '승인대기처', '대기', '요양', '요양기관번호', '기관', '임의', '서류장'],
#  ['올메텍정',
#   '환입처리내역',
#   '확인바업',
#   '마이',
#   '마이페이지',
#   '거래원장',
#   '원장',
#   '제품군',
#   '제품군전문의약품',
#   '전문',
#   '의약품'],
#  ['한양', '약국고금주', '고금주', '대웅거점등록'],
#  ['대웅바이오',
#   '리제정',
#   '제정',
#   '향정',
#   '당시',
#   '양도',
#   '양도양수증',
#   '양수',
#   '유미',
#   '유미선님',
#   '상담',
#   '참고',
#   '재요청',
#   '정식'],
#  ['헬스', '헬스인', '결제요청', '신한', '신한간편일시불', '간편', '일시불'],
#  ['우성당약국', '성당', '기봉', '비스', '비스정', '제조번호', '출고기록', '기록'],
#  ['요청영진',
#   '영진',
#   '추민정베',
#   '개상',
#   '개상록',
#   '약국김',
#   '씨콜',
#   '플러스',
#   '플러스정',
#   '종합',
#   '개씨',
#   '코프'],
#  ['임팩', '민케어', '케어', '직거래처', '납품', '배정시', '정시', '보시기'],
#  ['반품신청방법'],
#  ['대웅바이오',
#   '셋정',
#   '네버',
#   '네버펜',
#   '셉트',
#   '세미',
#   '스타',
#   '디피',
#   '디피네스',
#   '네스',
#   '반품잔고처리',
#   '안됨'],
#  ['연합', '박수경', '연합약국', '수경', '임시', '임시비번', '비번', '전송완료'],
#  ['종수',
#   '종수약품',
#   '레볼',
#   '션소형견',
#   '소형',
#   '심장',
#   '심장사상충',
#   '사상충',
#   '수입품',
#   '제품하자',
#   '하자',
#   '청해',
#   '청해드림'],
#  ['당신',
#   '약국안다희',
#   '다희',
#   '종수',
#   '종수약품',
#   '레볼',
#   '션소형견',
#   '소형',
#   '심장',
#   '심장사상충',
#   '사상충',
#   '하자'],
#  ['종수', '종수약품', '레볼', '션소형견', '소형', '심장', '심장사상충', '사상충'],
#  ['비스', '비스정', '성상', '성상변경', '제조번호', '성상문의주심', '주심', '영문'],
#  ['기프트카드', '프트', '모바일'],
#  ['사용방법', '패밀리', '패밀리존', '샵플러스', '플러스', '신세계', '재발송요청', '사용내역', '전환'],
#  ['통해', '만점', '부외품', '부외품쿠폰'],
#  ['대웅바이오', '회수지연'],
#  ['위치', '구두'],
#  ['프록',
#   '대웅바이오',
#   '일반도',
#   '일반도매상',
#   '매상',
#   '단종',
#   '주문가능',
#   '구매희망',
#   '이정',
#   '이정민',
#   '지금',
#   '전국',
#   '회수중',
#   '다음주중',
#   '주중',
#   '이정식',
#   '정식',
#   '개가',
#   '마지막',
#   '대체',
#   '소진'],
#  ['출석', '출석체크', '체크', '요청체크완료'],
#  ['자로', '잔고환불요청', '처리문의', '미처리', '최대', '최대주', '소요예정', '월말', '월말일자'],
#  ['사용방법',
#   '문의마이',
#   '마이',
#   '가기',
#   '가기패밀리존등급',
#   '패밀리',
#   '상세보',
#   '세보',
#   '왼쪽',
#   '날개',
#   '날개배',
#   '샵플러스포인트',
#   '플러스',
#   '경로',
#   '경로안내'],
#  ['임팩프리미엄', '프리미엄', '주문시', '메인', '메인배', '이마트만원', '모바일', '모바일발송예정'],
#  [],
#  ['덤씬가위포함',
#   '가위',
#   '포함',
#   '매입',
#   '개매매',
#   '매매',
#   '수급',
#   '입고',
#   '대로',
#   '최대한',
#   '현서',
#   '전달완료'],
#  ['백제약품영남', '영남', '시알', '시알리스정', '리스', '미처리', '처리확인요청'],
#  ['마일리지사용방법',
#   '문의마이',
#   '마이',
#   '가기',
#   '가기패밀리존등급',
#   '패밀리',
#   '상세보',
#   '세보',
#   '안내하',
#   '내하',
#   '접속',
#   '일반',
#   '쿠키',
#   '사이트',
#   '데이터',
#   '설정',
#   '보안',
#   '신뢰',
#   '고급',
#   '고급설정복원',
#   '기본',
#   '기본설정복원',
#   '원래',
#   '설정위',
#   '설명',
#   '부팅'],
#  ['인천약품', '모두', '사유오신청', '자동', '자동원복', '원복'],
#  ['엠디', '고단', '월로', '거냐며', '냐며'],
#  ['대웅바이오', '마이너스잔고', '적용방법', '안내예치금'],
#  ['약국김영종',
#   '영종',
#   '공동',
#   '공동구매',
#   '메디칼',
#   '배송지연',
#   '문의업체',
#   '확인후',
#   '재연락',
#   '배송중임',
#   '중임',
#   '고함'],
#  ['주안', '허브', '영환', '메디', '메디고탄력밴드덕', '고탄력', '밴드', '용매', '물류', '연락주기', '주기'],
#  ['대웅바이오', '셋정', '네버', '네버펜', '등시'],
#  ['약국홍태균', '폐업예정', '처리문의', '주시', '환불가능'],
#  ['도매몰', '매몰', '가입문의', '미차장'],
#  ['선물', '선물다가정', '다가', '제휴', '제휴사가', '사가', '하심월', '재발', '재발송완료'],
#  ['공동', '공동구매', '메디칼', '배송지연', '문의업체', '확인후', '재연락'],
#  ['공동',
#   '공동구매',
#   '일양',
#   '바퀴',
#   '통장입금',
#   '창이',
#   '이상하다',
#   '하다',
#   '입력시',
#   '정상적',
#   '화면',
#   '그래프',
#   '간편',
#   '간편결제',
#   '우선',
#   '예치금결제',
#   '체크',
#   '결제창',
#   '안내미선님',
#   '미선',
#   '일양약품',
#   '졸수성',
#   '바퀴에어',
#   '수성',
#   '에어',
#   '레몬향',
#   '하나',
#   '하나은행',
#   '은행',
#   '문자발송'],
#  ['마이너스잔고', '우루', '우루사', '전문', '전문약', '이동완료'],
#  ['젠가드', '가드', '단종'],
#  ['공동',
#   '공동구매',
#   '일양',
#   '바퀴',
#   '통장입금',
#   '창이',
#   '이상하다',
#   '하다',
#   '입력시',
#   '정상적',
#   '화면',
#   '그래프',
#   '간편',
#   '간편결제',
#   '우선',
#   '예치금결제',
#   '체크',
#   '결제창'],
#  ['이지',
#   '이지엔를',
#   '엔를',
#   '구입금액',
#   '문의확인후',
#   '재연락',
#   '약속착신불가',
#   '착신',
#   '함당일기준',
#   '당일',
#   '기준',
#   '월매출',
#   '도달',
#   '마이',
#   '마이페이지',
#   '확인가능',
#   '모든',
#   '해당이벤트',
#   '적용가능'],
#  ['명숙',
#   '세원',
#   '세원피앤씨',
#   '미배송배송추적',
#   '추적',
#   '강남',
#   '미배달',
#   '배달',
#   '김용구',
#   '용구',
#   '재배',
#   '재배송',
#   '내재',
#   '내재배송'],
#  ['세원', '세원피앤씨', '미배송배송추적', '추적', '강남', '미배달', '배달', '김용구', '용구', '재배', '재배송'],
#  ['이지', '이지엔를', '엔를', '구입금액', '문의확인후', '재연락', '약속착신불가', '착신', '연결불가'],
#  ['유진', '유진약품', '회수기사님'],
#  ['행복',
#   '온누리',
#   '김경신',
#   '김경신스팸프',
#   '스팸프',
#   '목표',
#   '목표금액월',
#   '이상분기',
#   '분기',
#   '달성',
#   '스탬프',
#   '증정',
#   '안내드림월',
#   '부족금액'],
#  ['인증',
#   '프로그램',
#   '설치',
#   '설정',
#   '설정방법',
#   '안내차',
#   '인터넷',
#   '인터넷옵션',
#   '옵션',
#   '보안',
#   '지정',
#   '체크',
#   '보안사용자',
#   '지정수준사용',
#   '수준',
#   '고침',
#   '사용자',
#   '시도',
#   '미선',
#   '미선님',
#   '통화건인증',
#   '건인',
#   '엣지',
#   '브라우저',
#   '익플',
#   '해결'],
#  ['공장전체', '취소요청사유오'],
#  ['양평포',
#   '평포',
#   '나무',
#   '나무약국허진서',
#   '진서',
#   '티제이',
#   '제이',
#   '재주',
#   '재주문',
#   '전일',
#   '결제건',
#   '수취',
#   '수취거부'],
#  ['티제이', '제이', '재주', '재주문', '전일', '결제건', '수취', '수취거부'],
#  ['파랑새', '파랑새약국홍세화', '세화', '취소여부', '총카드취소', '부분카드취소완료'],
#  ['양평포',
#   '평포',
#   '나무',
#   '나무약국허진서',
#   '진서',
#   '티제이',
#   '제이',
#   '재주',
#   '재주문',
#   '전일',
#   '결제건',
#   '수취',
#   '수취거부'],
#  ['티제이', '제이', '재주', '재주문'],
#  ['보타', '사업', '사업팀'],
#  ['임팩',
#   '진행중',
#   '비대상처',
#   '대상',
#   '진행시',
#   '며칠',
#   '며칠전',
#   '종료되었냐',
#   '확인요청어제부',
#   '역대급',
#   '프리미엄',
#   '안내쇼핑백개',
#   '쇼핑'],
#  ['소액',
#   '소액처',
#   '월매출',
#   '부족금액',
#   '유도',
#   '안내국장',
#   '국장',
#   '이달',
#   '이달안',
#   '판촉물신청',
#   '전달요청드림',
#   '만유',
#   '진선',
#   '진선님',
#   '통화건매달',
#   '매달',
#   '역대급이벤트',
#   '사은품',
#   '사은품지급',
#   '단위',
#   '당일',
#   '당일기준',
#   '기준',
#   '이마트상품권선택',
#   '선택'],
#  ['송천사',
#   '천사',
#   '철승',
#   '종수',
#   '종수약품캐치',
#   '캐치',
#   '미회수',
#   '회수요청',
#   '기본',
#   '주일',
#   '주일정도',
#   '미선',
#   '미선님',
#   '통화건회수',
#   '금주',
#   '금주내',
#   '재문의회수접수',
#   '방문예정'],
#  ['인증', '프로그램', '설치', '설정', '설정방법', '안내차', '인터넷', '인터넷옵션', '옵션'],
#  ['프록',
#   '대웅바이오',
#   '일반도',
#   '일반도매상',
#   '매상',
#   '단종',
#   '주문가능',
#   '구매희망',
#   '이정',
#   '이정민',
#   '지금',
#   '전국',
#   '회수중',
#   '다음주중',
#   '주중',
#   '함소',
#   '함소영님',
#   '문의건수급',
#   '건수',
#   '입고',
#   '대로'],
#  ['송천사',
#   '천사',
#   '철승',
#   '종수',
#   '종수약품캐치',
#   '캐치',
#   '미회수',
#   '회수요청',
#   '기본',
#   '주일',
#   '주일정도',
#   '미선',
#   '미선님',
#   '통화건회수',
#   '금주',
#   '금주내'],
#  ['보명',
#   '십전',
#   '대보탕',
#   '보명약국',
#   '진경',
#   '진경방',
#   '엑스',
#   '엑스과립',
#   '과립',
#   '통포장',
#   '낱개',
#   '연락주기',
#   '주기',
#   '요청건',
#   '스푼'],
#  ['열린', '산남', '열린약국', '김문수', '문수', '반품건올메', '반품내용', '요청전달완료'],
#  ['우리', '약국정', '배송시간'],
#  ['처리문의', '잔고처리', '마이너스잔고', '환불요청', '우루', '우루사', '고함', '환불예정일', '시이후', '환불예정'],
#  ['세금계산서', '선발', '선발행요청발행', '이메일', '안내반품신청건', '기준', '선발행요청안', '요청안'],
#  ['보명',
#   '십전',
#   '대보탕',
#   '보명약국',
#   '진경',
#   '진경방',
#   '엑스',
#   '엑스과립',
#   '과립',
#   '통포장',
#   '낱개',
#   '연락주기',
#   '주기'],
#  ['이지', '이지엔를', '엔를', '구입금액', '문의확인후', '재연락'],
#  ['보덕',
#   '보덕메디',
#   '메디',
#   '의약품',
#   '회사',
#   '회사대행',
#   '대행',
#   '대량',
#   '배송지',
#   '송지',
#   '배송지로',
#   '지로',
#   '배송가능',
#   '지금',
#   '주문시',
#   '오늘안',
#   '결제시',
#   '당일',
#   '당일출고',
#   '익일정도'],
#  ['동물약품', '종수', '종수약품'],
#  ['김선주대웅', '동수원이화약국', '수원', '선주', '이화', '덤씬매', '신청요청'],
#  ['에이스', '국박희선', '박희', '취소요청카드', '안내요청완료'],
#  ['비밀', '비밀번호', '수정요청', '자택', '자택번호', '신한', '신한간편결제', '간편'],
#  ['우리', '약국김', '룡로', '재발송요청'],
#  ['임팩',
#   '민케어',
#   '케어',
#   '입고',
#   '입고라',
#   '품절임',
#   '절임',
#   '사이',
#   '월초',
#   '안내월초',
#   '하냐',
#   '연락요청',
#   '한번',
#   '주시',
#   '주시길'],
#  ['마트상품권', '재발', '재발송요청재발', '안내진행', '급이벤트'],
#  ['티제이',
#   '제이',
#   '반품쿠폰',
#   '문의신청취소',
#   '통화건취소',
#   '재신청',
#   '며칠',
#   '며칠후',
#   '택밴데',
#   '고려',
#   '고려택배기사',
#   '입고',
#   '당시',
#   '해당기사님'],
#  ['오영넥시',
#   '움세비카',
#   '세비',
#   '단가',
#   '단가인상',
#   '인상',
#   '영업담당자',
#   '전체적',
#   '공유',
#   '건의',
#   '건의요청인상'],
#  ['선물', '선물다가정', '다가', '제휴', '제휴사가', '사가', '하심월'],
#  ['렛잇비정', '비정', '문의담당자', '확인후', '재연락', '연락처안내'],
#  ['우리', '순월', '역대급', '사은품', '신청법', '접속', '접속경로', '경로', '전용관치킨배', '치킨'],
#  ['임팩',
#   '프리미엄',
#   '단가',
#   '단가인상',
#   '인상',
#   '진행중',
#   '비대상처',
#   '대상',
#   '진행시',
#   '며칠',
#   '며칠전',
#   '종료되었냐'],
#  ['테라이트', '라이트'],
#  ['마이', '마이페이지쿠폰신청', '반품방법', '대웅반품신청방법'],
#  ['취소요청카드'],
#  ['선물', '선물다가정', '다가', '잘못', '재발', '재발소요'],
#  ['안찬수담당자',
#   '찬수',
#   '진행중인',
#   '중인',
#   '이벤트관련',
#   '통화요청핸드폰',
#   '안내상품권',
#   '문의확인후',
#   '말씀',
#   '안내멘트후',
#   '멘트',
#   '종료스탬프콕콕',
#   '스탬프',
#   '임팩',
#   '프리미엄',
#   '안내완료임팩'],
#  ['우리', '우리카드', '즉시할인', '행사'],
#  ['손크림', '크림', '규격', '박스묶음주문', '묶음'],
#  ['온누리',
#   '일번가',
#   '번가',
#   '약국최경희',
#   '경희',
#   '쿠폰사용',
#   '재신청',
#   '며칠',
#   '며칠후',
#   '말씀',
#   '입고',
#   '고려',
#   '고려택배'],
#  ['대웅오산', '오후중'],
#  ['온누리',
#   '일번가',
#   '번가',
#   '약국최경희',
#   '경희',
#   '쿠폰사용',
#   '재신청',
#   '며칠',
#   '며칠후',
#   '말씀',
#   '입고',
#   '고려',
#   '고려택배'],
#  ['엠디',
#   '미배송소비자',
#   '판매약속',
#   '클레임',
#   '제기',
#   '정상',
#   '정상출고',
#   '일부',
#   '파손',
#   '공급사',
#   '입고',
#   '재출고',
#   '말씀',
#   '물류',
#   '물류쪽',
#   '체크',
#   '재전',
#   '주시기',
#   '시기',
#   '만약',
#   '손해',
#   '손해배상',
#   '배상',
#   '하라',
#   '지불',
#   '지불금액'],
#  ['삼원',
#   '삼원약국김여랑',
#   '여랑',
#   '엠디',
#   '미배송소비자',
#   '판매약속',
#   '클레임',
#   '제기',
#   '정상',
#   '정상출고',
#   '일부',
#   '파손',
#   '공급사',
#   '입고',
#   '재출고',
#   '말씀',
#   '물류',
#   '물류쪽',
#   '체크',
#   '재전',
#   '지불',
#   '지불금액'],
#  ['기옥경님', '옥경', '호전환', '전환'],
#  ['티제이',
#   '제이',
#   '반품쿠폰',
#   '문의신청취소',
#   '통화건취소',
#   '재신청',
#   '며칠',
#   '며칠후',
#   '택밴데',
#   '고려',
#   '고려택배기사',
#   '입고',
#   '당시',
#   '해당기사님'],
#  ['도매몰', '매몰'],
#  ['반품진행현황',
#   '현황',
#   '문의반품신청',
#   '옆부분',
#   '회색',
#   '회색칸',
#   '클릭',
#   '안내반품쿠폰적용',
#   '문의반품',
#   '업체명',
#   '반품쿠폰'],
#  ['세원', '세원피앤씨', '레스', '확인해', '레스피', '분말', '반품쿠폰사용'],
#  ['엠디',
#   '미배송소비자',
#   '판매약속',
#   '클레임',
#   '제기',
#   '정상',
#   '정상출고',
#   '일부',
#   '파손',
#   '공급사',
#   '입고',
#   '재출고',
#   '말씀',
#   '물류',
#   '물류쪽',
#   '체크',
#   '재전',
#   '주시기',
#   '시기',
#   '만약',
#   '손해',
#   '손해배상',
#   '배상',
#   '하라'],
#  ['가입관련', '배정문의'],
#  ['송천사', '천사', '철승', '종수', '종수약품캐치', '캐치', '미회수', '회수요청', '기본', '주일', '주일정도'],
#  ['종수', '종수약품캐치', '캐치', '미회수', '회수요청'],
#  ['관악',
#   '관악소망약국',
#   '소망',
#   '유성림',
#   '성림',
#   '회수지연',
#   '회수택배비',
#   '택배비',
#   '옥경',
#   '옥경님',
#   '회수요청',
#   '고함',
#   '재전달'],
#  ['지오영', '오영', '회수지연', '회수택배비', '택배비', '옥경', '옥경님', '회수요청'],
#  ['삼원',
#   '삼원약국김여랑',
#   '여랑',
#   '엠디',
#   '미배송소비자',
#   '판매약속',
#   '클레임',
#   '제기',
#   '정상',
#   '정상출고',
#   '일부',
#   '파손',
#   '공급사',
#   '입고',
#   '재출고',
#   '말씀',
#   '물류',
#   '물류쪽',
#   '체크',
#   '재전'],
#  ['신세계', '신세계약국강라', '대신', '준적', '해당약국', '특이', '특이사항', '사항', '레바피큐'],
#  ['분기', '패밀리', '패밀리존', '브론즈', '구매금액', '기준', '제외'],
#  ['약국배민정', '대웅반품건', '미회수', '회수요청'],
#  ['삼원', '삼원약국김여랑', '여랑', '엠디', '미배송소비자', '판매약속', '클레임', '제기', '통화주신'],
#  ['대웅바이오제품',
#   '반품하려',
#   '하려',
#   '주문내역',
#   '신청불가하다',
#   '하다',
#   '안내창',
#   '제정',
#   '개구매',
#   '있으',
#   '있으심',
#   '동안',
#   '반품가능수량',
#   '초과',
#   '신청불가',
#   '추가구입',
#   '재신청',
#   '제외',
#   '대웅바이오',
#   '대리',
#   '대리신청완료'],
#  ['대웅반품건', '미회수', '회수요청'],
#  ['오영넥시',
#   '움세비카',
#   '세비',
#   '단가',
#   '단가인상',
#   '인상',
#   '영업담당자',
#   '전체적',
#   '공유',
#   '건의',
#   '건의요청'],
#  ['여의도',
#   '여의도대학약국신용',
#   '대학',
#   '신용',
#   '년도',
#   '사입이',
#   '입이',
#   '정문',
#   '약국고영상',
#   '국고',
#   '영상',
#   '주소이전',
#   '함상',
#   '함상호',
#   '여의도대학약국',
#   '전화번호'],
#  ['입금창', '미차장', '내선', '내선안내'],
#  ['약국강진', '강진', '가입예정', '요양', '요양번호', '임시', '임시번호', '변경요청'],
#  ['엠디', '미배송소비자', '판매약속', '클레임', '제기'],
#  ['연두', '임지', '임지영반품', '덤뷰티', '뷰티', '낱개', '입실', '한개의', '개의', '개가'],
#  ['삼화', '온누리', '약국심일정', '일정', '회수요청', '회수접수'],
#  ['대웅관련', '이트', '조사', '실수', '제함', '임팩', '프리미엄', '설문', '설문조사', '재발송'],
#  ['신청방법', '약구매시', '약구매', '차주', '수금', '모바일', '모바일발송예정'],
#  ['대웅유진',
#   '유진',
#   '씬가위포함',
#   '가위',
#   '포함',
#   '매입',
#   '개매매',
#   '매매',
#   '받으심',
#   '가위부족',
#   '미출고',
#   '김종각담당자',
#   '종각',
#   '통해',
#   '순차적'],
#  ['역대급', '임팩프리미엄', '프리미엄', '포함', '파워', '제외', '최소'],
#  ['거점상품', '지금', '구매방법', '안내드림현재', '신우택담당', '우택', '담당'],
#  ['페노스', '플라스', '페노스탑', '솔성분', '성분', '첨가'],
#  ['도매부외품',
#   '부외품',
#   '반품진행현황',
#   '현황',
#   '확인방법',
#   '반품신청진행현황',
#   '재고과다쿠폰미사',
#   '과다',
#   '미사',
#   '재신청'],
#  ['임팩', '이플러스', '이플러스정', '추가할인'],
#  ['정철', '퇴사후', '김낙환', '코드이관', '결제문자가', '자가'],
#  ['부재중', '부재중보고', '보고', '전화역대급', '구매금액', '유도'],
#  ['세계',
#   '세계약국박재완',
#   '재완',
#   '한신',
#   '한신약품',
#   '씨트리알',
#   '트리',
#   '개씨',
#   '개주문',
#   '발견',
#   '발견하심'],
#  ['한신', '한신약품', '씨트리알', '트리', '개씨', '개주문', '발견', '발견하심', '전화요청'],
#  ['세금계산서용', '이메일', '변경요청'],
#  ['임팩프리미엄', '프리미엄', '구매경로', '경로', '특별공급관'],
#  ['가입관련', '배정여부'],
#  ['에프엠',
#   '에프엠코리아안',
#   '코리아',
#   '재고과다',
#   '과다',
#   '방법문의',
#   '도매부외품반품',
#   '부외품',
#   '쿠폰사용',
#   '신청방법'],
#  ['페노스', '플라스', '페노스탑', '솔성분', '성분'],
#  ['가입관련', '배정문의'],
#  ['역대급이벤트',
#   '사은품',
#   '초중',
#   '상담원',
#   '임팩',
#   '구매시',
#   '증정',
#   '지급예정',
#   '프리미엄',
#   '주문시',
#   '팝업',
#   '만원정도',
#   '부외품',
#   '쇼핑백',
#   '양해드림'],
#  ['공동', '공동구매', '경로', '구두'],
#  ['탈퇴', '탈퇴요청', '사유폐업', '자동', '로그', '로그인', '하심주문반품', '동의'],
#  ['인증', '인증번호', '카톡으로', '갈수', '갈수있음', '끊으', '끊으심'],
#  ['숙기', '숙기존', '담당자배정', '코드이관문의', '조현', '조현서', '기안', '기안상신', '상신'],
#  ['우루', '일반'],
#  ['휴면', '휴면처', '활성화', '활성화요청', '전화번호', '변경요청주소', '동일', '수정완료'],
#  ['우루', '일반'],
#  ['배정요청', '본사', '본사관리', '전용관혜택', '방문관리'],
#  ['대웅대전',
#   '대전',
#   '취소요청사유',
#   '할부',
#   '할부개월',
#   '개월',
#   '오결',
#   '영님',
#   '통화건현재',
#   '처리중임',
#   '중임'],
#  ['승인요청', '보통', '하루', '하루소요', '완료시', '전송예정'],
#  ['함통화', '상담원'],
#  ['마스크',
#   '문의사유재고과다',
#   '과다',
#   '반품기한',
#   '내추',
#   '내추후',
#   '카드취소',
#   '예치금처리',
#   '통장환불',
#   '전화주시길',
#   '주시',
#   '안내미선님',
#   '미선',
#   '통화건반품신청',
#   '건반',
#   '수량수정가능',
#   '문의취소',
#   '재신청',
#   '반품완료',
#   '약일',
#   '약일정도'],
#  ['우성',
#   '우성약국',
#   '이영상',
#   '영상',
#   '대웅대전',
#   '대전',
#   '취소요청사유',
#   '할부',
#   '할부개월',
#   '개월',
#   '오결제',
#   '재결제',
#   '출고정지'],
#  ['대웅대전', '대전', '취소요청사유', '할부', '할부개월', '개월', '오결'],
#  ['양명진', '명진', '통화요청', '크린', '경로', '대웅거점상품관'],
#  ['약구매시', '사용방법', '마이', '마이페이지', '가기', '상품권등', '교환방법'],
#  ['엠메디칼약국송정', '메디칼', '송정', '운오', '크린', '경로', '통화요청'],
#  ['잔고이동문의', '연락요청', '재안내'],
#  ['폐업예정', '목요일', '운영', '대웅도매', '온라인', '반품기한', '개월', '유의', '주변', '직접'],
#  ['회수요청'],
#  ['이마트상품권', '대리', '대리신청'],
#  ['처방전서비스', '샵플러스포인트몰', '플러스', '접속', '폐기', '박순단님', '교부', '사진', '처방', '처방담당자'],
#  ['바다', '바다약국', '경아', '폐기', '박순단님', '교부', '사진', '해당건'],
#  ['한강',
#   '강동',
#   '강동희더샵',
#   '희더',
#   '민메일',
#   '반품신청요청메일',
#   '처리요청처리',
#   '안내반품박스수',
#   '반품사유확인박스',
#   '유효기간임박',
#   '임박'],
#  ['잔고이동문의', '연락요청'],
#  ['낱알',
#   '낱알반품시',
#   '예상',
#   '예상금액',
#   '실물',
#   '실물처리예정',
#   '신경',
#   '매수',
#   '케이스',
#   '케이스수대',
#   '수대'],
#  ['권삼국담당자',
#   '삼국',
#   '에프',
#   '새살',
#   '새살연고',
#   '연고',
#   '요청담당자',
#   '확인후',
#   '처리후',
#   '안내문자',
#   '예정상품',
#   '구매가능',
#   '당일',
#   '방문예정'],
#  ['신청법', '마이', '마이페이지신청방법'],
#  ['마이너스잔고', '테놀롤', '테놀롤정', '안내사용법', '잔고이동'],
#  ['우리', '약국정', '배송시간'],
#  ['권삼국담당자',
#   '삼국',
#   '대림',
#   '우리',
#   '요청건',
#   '약국장미영이',
#   '국장',
#   '영이',
#   '지에',
#   '지에프',
#   '새살',
#   '새살연고',
#   '연고',
#   '요청담당자',
#   '확인후',
#   '처리후',
#   '안내문자발송예정',
#   '확인사항',
#   '사항',
#   '약국확인요청약국',
#   '연락예정'],
#  ['임팩', '파워', '이플러스', '품절문의', '월일'],
#  ['거래원장', '원장', '미차장', '내선', '내선안내'],
#  ['씨콜', '노즈', '닥터', '닥터베', '반품신청시', '사입이', '입이', '노즈정', '플러스', '제정'],
#  ['대웅관련', '이트', '조사', '실수', '제함'],
#  ['용마',
#   '지스',
#   '대표',
#   '대표번호',
#   '경북',
#   '봉화',
#   '봉화군',
#   '춘양',
#   '춘양면',
#   '의양리',
#   '양리',
#   '우리',
#   '전달완료'],
#  ['대림',
#   '우리',
#   '약국장미영이',
#   '국장',
#   '영이',
#   '지에',
#   '지에프',
#   '새살',
#   '새살연고',
#   '연고',
#   '요청담당자',
#   '확인후',
#   '처리후',
#   '강동',
#   '안내문자',
#   '강동희더샵',
#   '예정한강약국',
#   '한강',
#   '희더',
#   '민메일',
#   '반품신청요청메일',
#   '처리요청처리'],
#  ['패밀리',
#   '패밀리존',
#   '스타',
#   '스타벅스',
#   '벅스',
#   '마끼',
#   '기프티콘',
#   '미수신',
#   '재발',
#   '재발송완료',
#   '통화중',
#   '문자드림'],
#  ['우리', '약국정', '배송시간', '외부', '외부라'],
#  ['전화번호'],
#  ['처방전서비스', '샵플러스포인트몰', '플러스', '접속', '폐기', '박순단님', '교부', '사진'],
#  ['임팩',
#   '민파워',
#   '파워',
#   '프리미엄',
#   '공급가',
#   '판매가',
#   '성분',
#   '성분차이',
#   '차이',
#   '안내역대급이벤트',
#   '포함',
#   '실적'],
#  ['폐업마이너스잔고'],
#  ['마스크',
#   '문의사유재고과다',
#   '과다',
#   '반품기한',
#   '내추',
#   '내추후',
#   '카드취소',
#   '예치금처리',
#   '통장환불',
#   '전화주시길',
#   '주시'],
#  ['주문번호',
#   '최종',
#   '최종결제금액',
#   '결제수단',
#   '수단',
#   '삼성',
#   '삼성카드',
#   '결제상태',
#   '마이너스잔고사용요청',
#   '예정주문번호',
#   '대리',
#   '대리결제완료'],
#  ['화성', '화성약국남기범', '남기', '반품닥터베', '닥터', '신청수량', '신청하심'],
#  ['역대급', '이벤트판촉물', '선택', '경로', '구두'],
#  ['주문금액', '결제금액', '분기', '브론즈', '합산', '취소건', '포함', '만원이상'],
#  ['학산', '학산약국김', '복산나이스', '나이스', '서울지점취소요청사유', '재고과다', '과다', '출고정지완료'],
#  ['사용방법',
#   '문의마이',
#   '마이',
#   '가기',
#   '가기패밀리존등급',
#   '패밀리',
#   '상세보',
#   '세보',
#   '생활기',
#   '생활기프트',
#   '프트',
#   '신청하기',
#   '하기',
#   '경로',
#   '경로안내',
#   '문자발송',
#   '다음주',
#   '수금',
#   '수금요일사이',
#   '요일',
#   '사이'],
#  ['복산나이스', '나이스', '서울지점취소요청사유', '재고과다', '과다'],
#  ['조은', '엔에이스', '에이스', '모바렌'],
#  ['인천약품', '보린', '보린정', '실물', '안됨', '문의반품완료', '주시', '주시길'],
#  ['인천약품', '코스', '코스탑패취', '경과', '경과건', '반품요청', '반품불가'],
#  ['포항', '유진상', '포항마더스약국', '진상', '더스', '마이너스잔고', '요청일반', '일반', '우루', '우루사'],
#  ['모바일', '로그', '로그인시', '인시', '존재', '기입', '임시', '패스', '패스워드', '워드'],
#  ['사랑',
#   '사랑약국김미정',
#   '미정',
#   '복산나이스',
#   '나이스',
#   '로액',
#   '염화',
#   '염화알루미늄',
#   '알루미늄',
#   '전성분표시',
#   '성분',
#   '표시',
#   '반품요청',
#   '배송비',
#   '업체부담',
#   '부담',
#   '고함',
#   '영님',
#   '전달완료',
#   '쿠폰사용',
#   '재신청',
#   '회수접수'],
#  ['복산나이스',
#   '나이스',
#   '로액',
#   '염화',
#   '염화알루미늄',
#   '알루미늄',
#   '반품요청전성분',
#   '성분',
#   '표시',
#   '확인중',
#   '업체부담',
#   '부담',
#   '쿠폰사용',
#   '기반',
#   '기반품건',
#   '재신청'],
#  ['우리', '아기', '날현재'],
#  ['사랑',
#   '사랑약국김미정',
#   '미정',
#   '복산나이스',
#   '나이스',
#   '로액',
#   '염화',
#   '염화알루미늄',
#   '알루미늄',
#   '전성분표시',
#   '성분',
#   '표시',
#   '반품요청',
#   '배송비',
#   '업체부담',
#   '부담',
#   '고함',
#   '영님',
#   '전달완료'],
#  ['바렌굿', '일라', '일라카', '구매문의', '마이', '마이페이지특별공급관'],
#  ['엄지', '정연희', '정연희오', '주문취소요청취소'],
#  ['우리', '아기'],
#  ['임팩케어', '케어', '재입'],
#  ['주문금액', '결제금액', '분기', '브론즈', '합산'],
#  ['역대급', '이마트만원', '선택', '선택완료'],
#  ['만점', '샵플러스포인트', '플러스', '전환', '전환요청'],
#  ['향정', '판매보고', '보고', '판매보고마감', '별개', '수기', '자동', '자동연동', '연동', '안됨'],
#  ['베아',
#   '진열',
#   '진열셋',
#   '주문시',
#   '증정',
#   '단독',
#   '단독진행',
#   '답변',
#   '독진행',
#   '절대',
#   '대성',
#   '주문했겠냐',
#   '했겠냐',
#   '반품쿠폰',
#   '처리확인요청',
#   '대성주문건',
#   '추가발급',
#   '처리완료때',
#   '파손',
#   '상품권발송',
#   '메모란',
#   '모란',
#   '기재후',
#   '주시',
#   '주시길',
#   '다음주',
#   '다음주안'],
#  ['조은', '조은약국김복', '배송시간', '연락주기', '주기'],
#  ['조은',
#   '조은약국건',
#   '연락주신분',
#   '신분',
#   '문의연락',
#   '확인도중',
#   '도중',
#   '끊으심배송',
#   '분안',
#   '하심정',
#   '전달완료'],
#  ['더블',
#   '더블이벤트천원',
#   '천원',
#   '할인쿠폰',
#   '안됨',
#   '마감시간',
#   '당일',
#   '금보',
#   '금보메디넷',
#   '메디',
#   '포비',
#   '포비돈',
#   '급여',
#   '급여제품',
#   '부외품'],
#  ['조은', '조은약국건', '연락주신분', '신분', '문의연락', '확인도중', '도중', '끊으', '끊으심'],
#  ['아람', '아람약국홍계주', '계주', '복산나이스', '나이스', '부산', '부산지점', '반품회수', '금일중'],
#  ['샘물', '샘물약국'],
#  ['대전',
#   '대전종로약국김',
#   '종로',
#   '명제',
#   '헬스',
#   '헬스인',
#   '솔가',
#   '비타민',
#   '식물성',
#   '식물성캡슐',
#   '캡슐',
#   '개중',
#   '오고',
#   '비오틴',
#   '개가',
#   '국과',
#   '직접'],
#  ['바구니',
#   '카드사',
#   '확인요망',
#   '요망',
#   '메세지',
#   '승인문자',
#   '받으심',
# ...
#  ['사랑',
#   '사랑약국김미정',
#   '미정',
#   '복산나이스',
#   '나이스',
#   '로액',
#   '염화',
#   '염화알루미늄',
#   '알루미늄',
#   '반품요청의약품',
#   '의약품',
#   '전성분표시',
#   '성분',
#   '표시',
#   '주기',
#   '반품택배비',
#   '택배비',
#   '부담',
#   '선택',
#   '확인등',
#   '확인중'],
#  ['게시',
#   '게시글월일',
#   '글월',
#   '패밀리',
#   '패밀리존',
#   '마트상품권',
#   '점심',
#   '점심때쯤',
#   '때쯤',
#   '주세',
#   '문자로',
#   '자로',
#   '발송건',
#   '미수신',
#   '재발',
#   '재발송완료수신'],
#  ['임팩케어정', '케어', '품절문', '예정안내'],
#  ['베아',
#   '진열',
#   '진열셋',
#   '주문시',
#   '증정',
#   '단독',
#   '단독진행',
#   '답변',
#   '독진행',
#   '절대',
#   '대성',
#   '주문했겠냐',
#   '했겠냐',
#   '반품쿠폰',
#   '처리확인요청',
#   '대성주문건'],
#  ['임팩', '프리미엄', '개주문시', '이마트상품권', '한번', '한당', '중복', '안내해드림', '내해'],
#  ['게시',
#   '게시글월일',
#   '글월',
#   '패밀리',
#   '패밀리존',
#   '마트상품권',
#   '점심',
#   '점심때쯤',
#   '때쯤',
#   '주세',
#   '문자로',
#   '자로',
#   '국장님',
#   '장님'],
#  ['분당', '백화점', '약국모신영', '모신', '재발송요청'],
#  ['임팩프리미엄', '프리미엄', '도중', '수정문의', '처음', '재접속', '접속', '설정'],
#  ['배송기사님', '신덕', '반품회수', '대웅반품', '사기사', '아무것', '대웅기사님'],
#  ['제일',
#   '제일헬스케어',
#   '헬스',
#   '케어',
#   '쿠폰사용',
#   '사용안됨',
#   '안됨',
#   '인천약품',
#   '쿠폰사용체크',
#   '체크',
#   '하라'],
#  ['큰사랑',
#   '큰사랑약국',
#   '휴업',
#   '휴업중이',
#   '중이',
#   '오픈',
#   '마이너스잔고',
#   '사용기한',
#   '어디',
#   '주문시',
#   '사용가능',
#   '요청통장',
#   '미발송'],
#  ['역대급', '구매금액', '스타', '스타벅스', '벅스', '변경요청'],
#  ['낱알',
#   '낱알반품쿠폰',
#   '반품하려',
#   '하려',
#   '사입근거',
#   '근거',
#   '쿠폰사용',
#   '요청담당부서',
#   '담당',
#   '부서',
#   '한번',
#   '복원어려움'],
#  ['관악',
#   '관악소망약국',
#   '소망',
#   '유성림',
#   '성림',
#   '회수지연',
#   '회수택배비',
#   '택배비',
#   '옥경',
#   '옥경님',
#   '회수요청',
#   '고함',
#   '메디칼',
#   '약국이성봉',
#   '이성',
#   '마디',
#   '마디핀정',
#   '반품가능',
#   '반품불가'],
#  ['코포인트', '어디', '확인가능', '문의결제', '페이코', '선택', '코로그인', '로그'],
#  ['케이',
#   '유유리',
#   '유리',
#   '구매날짜',
#   '날짜',
#   '화장품',
#   '반품기한',
#   '개월',
#   '해당건',
#   '반품거부처리',
#   '양해드림'],
#  ['전체취소요청', '사유추후재주문', '재주'],
#  ['부분카드취소', '운영', '운영팀'],
#  ['청십자약품', '십자'],
#  ['서클', '폐업엠', '세금계산서', '발행발행완료'],
#  ['주소상호약국번호', '상호', '영남', '영남약국', '전달예정', '변경완료'],
#  ['바이오리제정',
#   '제정',
#   '향정',
#   '유효기간남',
#   '양도',
#   '양도양수증',
#   '양수',
#   '작성',
#   '환입실팩스',
#   '입실',
#   '발송요청',
#   '출장',
#   '다음주',
#   '날인',
#   '시도',
#   '시도청',
#   '주시',
#   '주시길',
#   '신청건'],
#  ['김순주', '검색어', '입력시', '자동', '통화요청주심', '주심', '해결'],
#  ['대웅바이오',
#   '대웅세파',
#   '세파',
#   '러캡슐',
#   '캡슐',
#   '낱알',
#   '낱알개',
#   '가지',
#   '문의업체',
#   '확인후',
#   '재연락',
#   '약속대웅바이오',
#   '기사분',
#   '한번'],
#  ['화인',
#   '화인약국박순철',
#   '순철',
#   '대웅바이오',
#   '대웅세파',
#   '세파',
#   '러캡슐',
#   '캡슐',
#   '낱알',
#   '낱알개',
#   '가지',
#   '문의업체',
#   '확인후',
#   '재연락',
#   '약속대웅바이오',
#   '기사분',
#   '한번'],
#  ['종수',
#   '종수약품동물약품',
#   '조건',
#   '동물약품',
#   '개월',
#   '생식품',
#   '식품',
#   '가공',
#   '개월이내',
#   '이내',
#   '반품불가함',
#   '가능여부',
#   '공급사'],
#  ['대웅바이오', '대웅세파', '세파', '러캡슐', '캡슐', '낱알', '낱알개', '가지', '문의업체', '확인후', '재연락'],
#  ['덤씬', '가위', '가위포함', '포함'],
#  ['처방전보관서비스', '어디', '구두'],
#  ['타임',
#   '타임세일',
#   '세일',
#   '공급업체',
#   '확인가능',
#   '경로',
#   '문의왼쪽',
#   '왼쪽',
#   '특가',
#   '특가카',
#   '테고리',
#   '고리',
#   '부외품',
#   '부외품업체'],
#  ['주소번호', '변경요청', '사등', '개인', '휴대폰', '영님', '전달예정'],
#  ['신한',
#   '신한카드',
#   '한도',
#   '한도초과',
#   '초과',
#   '팝업',
#   '팝업뜸',
#   '카드사',
#   '천만',
#   '천만원',
#   '법인',
#   '법인카드',
#   '법인한도',
#   '삼성',
#   '삼성카드',
#   '간편',
#   '간편결제등록방법'],
#  ['혜성',
#   '문박사',
#   '약국문',
#   '박사',
#   '리스트',
#   '출력',
#   '문의리스트',
#   '종이',
#   '종이상자',
#   '상자',
#   '포장부탁드림위',
#   '부탁',
#   '동봉',
#   '서류'],
#  ['임팩프리미엄', '프리미엄', '아이디당'],
#  ['메디', '신약국', '오옥', '오옥주', '검색어', '입력시', '자동', '통화요청주심', '주심'],
#  ['신한', '신한카드', '재등록', '재등록방법', '마이', '페이지회원정보'],
#  ['대웅세파', '세파', '문의자로', '자로', '보험', '보험삭제', '대웅바이오', '캡슐'],
#  ['손약국손숙주', '숙주', '소약국번호', '지영', '사등', '함안지영님', '주소변경', '반영', '변경번호', '수정완료'],
#  ['역대급이벤트',
#   '사십',
#   '사십얼마',
#   '얼마',
#   '재확인',
#   '재확인요청',
#   '우루',
#   '우루사',
#   '포함',
#   '만원정도',
#   '반품포함',
#   '사이트',
#   '매출표기',
#   '표기',
#   '안내베',
#   '닥터',
#   '닥터베',
#   '만원이상',
#   '종료후',
#   '일괄',
#   '일괄적립'],
#  ['마이너스잔고중', '무엇', '문의임팩', '민의', '약자로', '자로', '임팩'],
#  ['대웅오산배송', '도착일정', '일정', '문의배송예정'],
#  ['리스트', '출력', '문의리스트', '종이', '종이상자', '상자'],
#  ['역대급', '매출금액'],
#  ['바이오리제정', '제정', '향정', '유효기간남', '양도', '양도양수증', '양수', '작성', '확인후'],
#  ['임팩케어', '케어', '재입'],
#  ['구두'],
#  ['서클', '폐업엠', '세금계산서'],
#  ['백두산',
#   '백두산약국조성택',
#   '성택',
#   '코리',
#   '혈당',
#   '혈당측정지',
#   '사유오주문',
#   '부분카드취소요청',
#   '전산',
#   '모름',
#   '출고정지',
#   '운영',
#   '운영팀'],
#  ['남용', '남용민', '약국관리', '대웅전', '관배', '혜택이용'],
#  ['마음속', '마음속약국권지훈', '권지', '주문취소요청처리'],
#  ['종합', '조강', '반품관련건', '이정', '이정민', '연결요청전달완료'],
#  ['금보', '금보건강', '배제이엠디', '제이', '사유오주문'],
#  ['임팩실버', '실버', '구매경로', '경로', '상품관'],
#  ['중앙', '중앙약국김태', '전체취소예정'],
#  ['중앙', '중앙약국김태', '출고정지', '출고정지완료'],
#  ['코리', '혈당', '혈당측정지', '사유오주문'],
#  ['역대급이벤트', '사십', '사십얼마', '얼마', '재확인', '재확인요청'],
#  ['역대급', '매출금액'],
#  ['이레', '이레약국', '동섭', '전체취소요청', '사유고객요청'],
#  ['금보', '금보건강', '배제이엠디', '제이', '사유오주문'],
#  ['승인요청', '사등', '첨부', '면허증'],
#  ['오진',
#   '담당자요청건',
#   '주문취소요청취소',
#   '배송기사님',
#   '수취',
#   '수취거절',
#   '거절',
#   '안내차',
#   '않으',
#   '않으심수취거절',
#   '안내완료'],
#  ['오진', '담당자요청건', '주문취소요청취소', '배송기사님', '수취', '수취거절', '거절', '안내차', '않으', '않으심'],
#  ['배정여부', '배정요청'],
#  ['정훈',
#   '정훈일전',
#   '일전',
#   '모범',
#   '모범약국울산',
#   '울산',
#   '동구',
#   '방호',
#   '방호동',
#   '대전',
#   '데이터',
#   '대동',
#   '드림약국',
#   '있음대동',
#   '사등',
#   '전로',
#   '네이버',
#   '어플에서',
#   '안내드림약국',
#   '보신'],
#  ['신대학약국김영준',
#   '대학',
#   '김영준',
#   '대웅공장신한카드',
#   '신한',
#   '간편',
#   '간편결제',
#   '현대',
#   '현대카드',
#   '결제변경요청',
#   '재확인'],
#  ['몰주문건', '주문번호', '주말', '휴무', '휴무라', '수령', '롯데', '롯데택배', '오라', '함재', '함재배송'],
#  ['메디', '정은', '정은주약국정은', '대웅공장', '사유수량오주문'],
#  ['전문',
#   '전문약',
#   '상품권쿠폰',
#   '교환가능',
#   '안내마이너스잔고',
#   '마이너스잔고',
#   '일반',
#   '일반전문',
#   '모두',
#   '구매가능'],
#  ['메디', '정은', '정은주약국정은', '주문취소요청처리', '하려', '개주문후', '재연락'],
#  ['헬스', '헬스인', '마이', '쉬콜라겐', '콜라겐', '낱개', '낱개포장', '오배송'],
#  ['엘림',
#   '엘림약국임재무',
#   '재무',
#   '헬스',
#   '헬스인',
#   '마이',
#   '쉬콜라겐',
#   '콜라겐',
#   '낱개',
#   '낱개포장',
#   '오배송',
#   '교환처리'],
#  ['포약국김',
#   '동화',
#   '동화세파',
#   '세파',
#   '러캡슐',
#   '캡슐',
#   '예치금적립',
#   '카드취소',
#   '차감',
#   '카드취소요청',
#   '부분카드취소완료',
#   '상태값',
#   '발송완료',
#   '해주시길',
#   '주시'],
#  ['알파',
#   '여수',
#   '여수시',
#   '약국장성익',
#   '국장',
#   '성익',
#   '세이',
#   '백단',
#   '백단케어',
#   '케어',
#   '화상',
#   '케어젤',
#   '밴드',
#   '드레싱',
#   '드레싱화상',
#   '표준',
#   '표준매입',
#   '매입',
#   '매가',
#   '문의업체',
#   '확인후',
#   '재연락',
#   '약속약국쪽'],
#  ['헬스', '헬스인', '마이', '쉬콜라겐', '콜라겐', '낱개', '낱개포장', '오배송'],
#  ['세이',
#   '백단',
#   '백단케어',
#   '케어',
#   '화상',
#   '케어젤',
#   '밴드',
#   '드레싱',
#   '드레싱화상',
#   '표준',
#   '표준매입',
#   '매입',
#   '매가',
#   '문의업체',
#   '확인후',
#   '재연락'],
#  ['주소상호약국번호', '상호', '영남', '영남약국', '전달예정'],
#  ['대웅대웅바이오', '낱알', '낱알반품', '구매이력', '년이내', '이내', '반품신청방법'],
#  ['년도', '반품기한', '개월', '최대', '이번년도', '양해드림'],
#  ['신세계',
#   '신세계약국임수희',
#   '수희',
#   '제이',
#   '건영',
#   '오텍',
#   '참옻진액골드',
#   '진액',
#   '골드',
#   '년이상',
#   '옻나무',
#   '옻나무약국',
#   '반품접수후',
#   '문의업체',
#   '확인후',
#   '회수진행',
#   '택배박스',
#   '주시',
#   '주시길',
#   '내재',
#   '내재신청'],
#  ['태양', '태양약국', '보영', '주문취소요청취소'],
#  ['정훈',
#   '정훈일전',
#   '일전',
#   '모범',
#   '모범약국울산',
#   '울산',
#   '동구',
#   '방호',
#   '방호동',
#   '대전',
#   '데이터',
#   '대동',
#   '드림약국',
#   '있음대동',
#   '사등',
#   '전로',
#   '울산동구방호동'],
#  ['제이',
#   '건영',
#   '오텍',
#   '참옻진액골드',
#   '진액',
#   '골드',
#   '년이상',
#   '옻나무',
#   '옻나무약국',
#   '반품접수후',
#   '문의업체',
#   '확인후',
#   '회수진행',
#   '택배박스',
#   '주시',
#   '주시길'],
#  ['포약국김', '동화', '동화세파', '세파', '러캡슐', '캡슐', '예치금적립', '카드취소', '차감', '카드취소요청'],
#  ['말씀', '안내멘트후', '멘트'],
#  ['백세',
#   '백세약국',
#   '명진',
#   '엠디대웅',
#   '우루',
#   '우루에스메가센타',
#   '에스',
#   '메가',
#   '센타',
#   '세트',
#   '주문하심공급가가',
#   '가가',
#   '취소진행',
#   '말씀',
#   '유도',
#   '황사',
#   '황사마스크',
#   '마스크',
#   '배송처리',
#   '함약국',
#   '지속',
#   '지속부재익일'],
#  ['복산나이스', '나이스', '로액', '염화', '염화알루미늄', '알루미늄', '반품요청전성분', '성분', '표시', '확인중'],
#  ['마일리지대방출', '방출', '월별', '분기', '매출금액', '하기', '오안내', '재안내드림'],
#  ['연락주신', '사용방법'],
#  ['임팩',
#   '프리미엄',
#   '인터넷',
#   '가격인상',
#   '인상',
#   '자로',
#   '개인',
#   '행위',
#   '자격자',
#   '제품유통',
#   '모니터링',
#   '모니터링대응',
#   '대응',
#   '양해드림'],
#  ['샵플러스포인트',
#   '플러스',
#   '이벤트참여',
#   '만점',
#   '엔터테인먼트',
#   '퀴즈',
#   '먼크',
#   '올해',
#   '연말',
#   '미사용시',
#   '사용시',
#   '소멸예정'],
#  ['역대급이벤트',
#   '약케이스',
#   '케이스',
#   '도달',
#   '않으심',
#   '상담원',
#   '주문시',
#   '하심확인',
#   '녹음',
#   '녹음파일',
#   '파일',
#   '요청하심',
#   '영님',
#   '월달',
#   '프로',
#   '프로모션',
#   '모션',
#   '만원이상',
#   '행사',
#   '감사',
#   '의미',
#   '증정',
#   '행사임',
#   '니더',
#   '안내해',
#   '내해',
#   '그때',
#   '친절',
#   '녹취',
#   '녹취파일',
#   '정보보호법',
#   '보호법',
#   '유출',
#   '위험',
#   '결론',
#   '예외',
#   '기준',
#   '반발',
#   '우루',
#   '우루사',
#   '이번달',
#   '전용관배',
#   '만약',
#   '만원구매',
#   '조현',
#   '쇼핑백',
#   '감사하다',
#   '하다'],
#  ['종오약국',
#   '오약',
#   '범수',
#   '범수주소',
#   '최두원담당자',
#   '두원',
#   '하심지금',
#   '지금',
#   '톡으',
#   '함소',
#   '함소영님',
#   '건카',
#   '확인문의수신',
#   '처리완료후',
#   '문자발송예정'],
#  ['계좌이체',
#   '이체',
#   '건현',
#   '건현금',
#   '영수증',
#   '휴대폰',
#   '주민',
#   '주민번호',
#   '재전',
#   '세금계산서',
#   '현금',
#   '현금영수증',
#   '이중',
#   '이중신고처리',
#   '신고'],
#  ['티제이',
#   '제이',
#   '한신',
#   '엑스',
#   '과립',
#   '한신스토반',
#   '스토',
#   '반하사심탕',
#   '하사',
#   '단가',
#   '얘기',
#   '통화종료하심'],
#  ['사용방법', '문의차', '연락주시어', '시어', '경로', '경로안내하려', '하려', '조제', '연락주신'],
#  ['폐업예정', '목요일', '운영', '대웅도매', '온라인', '반품기한', '개월', '유의'],
#  ['종오약국', '오약', '범수', '범수주소', '최두원담당자', '두원', '하심지금', '지금', '톡으'],
#  ['임팩', '케어'],
#  ['대허약국홍', '미선', '가입예정요양번호', '요양', '임의', '기입', '기입서류', '서류', '전달예정'],
#  ['최두원담당자', '두원', '내일중', '수정완료시', '완료시'],
#  ['반품쿠폰',
#   '사용가능',
#   '문의신청건',
#   '내재',
#   '내재신청',
#   '클릭',
#   '업체부담일경우',
#   '부담',
#   '안내창',
#   '하심반품신청서',
#   '신청서',
#   '제품때문',
#   '때문',
#   '반품신청서',
#   '모두'],
#  ['계좌이체',
#   '이체',
#   '건현',
#   '건현금',
#   '영수증',
#   '휴대폰',
#   '주민',
#   '주민번호',
#   '재전',
#   '세금계산서',
#   '현금',
#   '현금영수증',
#   '이중',
#   '이중신고처리',
#   '신고'],
#  ['미소지우',
#   '소지',
#   '김진이약',
#   '진이',
#   '포장기',
#   '세금계산서',
#   '집주소',
#   '은평',
#   '은평구',
#   '내부적',
#   '통합발행',
#   '재문의'],
#  ['사랑',
#   '사랑약국김미정',
#   '미정',
#   '복산나이스',
#   '나이스',
#   '로액',
#   '염화',
#   '염화알루미늄',
#   '알루미늄',
#   '반품요청의약품',
#   '의약품',
#   '전성분표시',
#   '성분',
#   '표시',
#   '주기',
#   '반품택배비',
#   '택배비',
#   '부담',
#   '선택',
#   '확인등'],
#  ['계좌이체', '이체', '건현', '건현금', '영수증', '휴대폰', '주민', '주민번호', '재전'],
#  ['복산나이스', '나이스', '로액', '염화', '염화알루미늄', '알루미늄', '반품요청전성분', '성분', '표시'],
#  ['인천약품',
#   '취소요청업체',
#   '확인후',
#   '카드취소',
#   '안내주문상태',
#   '출고완료',
#   '주문취소',
#   '문의업체',
#   '처리중',
#   '대로',
#   '안내취소완료'],
#  ['솔벗약국황진',
#   '황진',
#   '인천약품',
#   '취소요청업체',
#   '확인후',
#   '카드취소',
#   '안내취소',
#   '재연',
#   '재연락주신',
#   '고함'],
#  ['연질', '연질캡슐', '캡슐', '반품시', '택배비', '부과', '회수택배비'],
#  ['반품처리', '잔고으', '미차장님', '장님', '반품확정', '확정', '아침', '반영'],
#  ['소액',
#   '소액처',
#   '월매출',
#   '부족금액',
#   '유도',
#   '만유',
#   '신청방법',
#   '전용관중',
#   '관중',
#   '구매시',
#   '부외품',
#   '부외품쿠폰',
#   '발급가능'],
#  ['기독',
#   '후문',
#   '약국최',
#   '낙현인수인계',
#   '인수인계',
#   '인계',
#   '엠서클',
#   '서클',
#   '현세환',
#   '세환',
#   '담당자님',
#   '현서',
#   '있음확인'],
#  ['엠디',
#   '통화요청건',
#   '엠디대웅',
#   '우루',
#   '우루에스메가센타',
#   '에스',
#   '메가',
#   '센타',
#   '세트',
#   '주문하심공급가가',
#   '가가',
#   '취소진행',
#   '말씀',
#   '유도',
#   '보상',
#   '황사',
#   '황사마스크',
#   '마스크',
#   '배송처리'],
#  ['백세',
#   '백세약국',
#   '명진',
#   '엠디대웅',
#   '우루',
#   '우루에스메가센타',
#   '에스',
#   '메가',
#   '센타',
#   '세트',
#   '주문하심공급가가',
#   '가가',
#   '취소진행',
#   '말씀',
#   '유도',
#   '황사',
#   '황사마스크',
#   '마스크',
#   '배송처리'],
#  ['샵플러스포인트', '플러스'],
#  ['데이', '데이셀코스메', '코스'],
#  ['인천약품',
#   '취소요청업체',
#   '확인후',
#   '카드취소',
#   '안내주문상태',
#   '출고완료',
#   '주문취소',
#   '문의업체',
#   '처리중',
#   '대로'],
#  ['가입관련', '배정문의'],
#  ['부외품', '부외품쿠폰', '마이', '마일리지사용', '신청안내', '건당', '사용가능', '쿠폰사용'],
#  ['파약', '승인요청사업자', '토요일', '수신확인'],
#  ['전용관백제약품영남',
#   '영남',
#   '낱알',
#   '주차',
#   '회수기간',
#   '미회수',
#   '회수중',
#   '미선',
#   '미선님',
#   '회수요청',
#   '됬냐'],
#  ['대덕', '약국민', '대덕프라자', '라자', '경희', '경희알', '최근', '입일자'],
#  ['주노온누리약국',
#   '온누리',
#   '손동운',
#   '동운',
#   '주문착오',
#   '착오',
#   '주문오류착오고객',
#   '변심',
#   '포함',
#   '신청하심',
#   '대웅복산약품',
#   '인수전이면',
#   '전이면',
#   '인수거절',
#   '거절',
#   '수령',
#   '부분취소',
#   '전체취소',
#   '재주',
#   '재주문'],
#  ['역대급이벤트',
#   '대상자',
#   '덤플러스매입',
#   '플러스',
#   '매입',
#   '대리',
#   '대리구매',
#   '스타',
#   '스타벅스',
#   '벅스',
#   '대리선택마일리지',
#   '선택',
#   '사용방법',
#   '문의마이',
#   '마이',
#   '가기',
#   '가기패밀리존등급',
#   '패밀리',
#   '상세보',
#   '세보',
#   '생활기',
#   '생활기프트',
#   '프트',
#   '신청하기',
#   '하기',
#   '경로',
#   '경로안내'],
#  ['약품까스활',
#   '까스',
#   '명수',
#   '명수큐액병',
#   '왼쪽',
#   '왼쪽가격',
#   '최저가',
#   '최저가보상',
#   '보상',
#   '무엇',
#   '오른쪽',
#   '단가',
#   '단가차이',
#   '차이',
#   '가인',
#   '가인상지역',
#   '업체가격',
#   '그것',
#   '냐며',
#   '사지',
#   '사기',
#   '계산',
#   '우선',
#   '전산',
#   '불편',
#   '건의',
#   '변경시행',
#   '시행',
#   '확답',
#   '부외품',
#   '천원',
#   '금액보상',
#   '우측',
#   '공급사',
#   '해주시길',
#   '주시',
#   '양해드림'],
#  ['동물약국개설증', '개설', '승인처리완료', '구두'],
#  ['패밀리', '패밀리존', '낱알', '낱알반품', '한도', '낱알반품쿠폰', '전환', '전환후'],
#  ['메디',
#   '메디디플러스반품',
#   '플러스',
#   '신청건',
#   '페이스',
#   '페이스라이너',
#   '라이너',
#   '있음임팩프리미엄',
#   '프리미엄',
#   '기간차'],
#  ['시도', '연락요청'],
#  ['덤씬매입', '매입', '반품신청요청'],
#  ['천안',
#   '삼거리',
#   '휴게소',
#   '휴게소약국양선아',
#   '선아',
#   '백제약품',
#   '복합마데카',
#   '솔연고반품',
#   '연고',
#   '데카',
#   '쿠폰사용',
#   '입고문',
#   '고문',
#   '지금',
#   '예치금처리'],
#  ['이지', '제품군', '구두'],
#  ['천안',
#   '삼거리',
#   '휴게소',
#   '휴게소약국양선아',
#   '선아',
#   '티제이',
#   '제이',
#   '솔케어',
#   '케어',
#   '데카',
#   '연고',
#   '입고문',
#   '고문',
#   '예치금처리예정'],
#  ['미소지우', '소지', '김진이약', '진이', '포장기', '세금계산서', '집주소', '은평', '은평구', '내부적'],
#  ['티제이',
#   '제이',
#   '데카',
#   '솔케어연고',
#   '케어',
#   '연고',
#   '백제약품',
#   '복합마데카',
#   '솔연고반품',
#   '쿠폰사용',
#   '입고문',
#   '고문'],
#  ['성호',
#   '성호고등학교',
#   '고등',
#   '고등학교',
#   '학교',
#   '선생님',
#   '제약회사',
#   '회사',
#   '담당',
#   '임팩케어리버',
#   '케어',
#   '리버',
#   '골드',
#   '골드우루사',
#   '우루',
#   '등대웅제품',
#   '대응',
#   '하심정확',
#   '정확',
#   '문자오신',
#   '오신'],
#  ['대웅바이오',
#   '입이',
#   '팝업창',
#   '베아겐정이',
#   '입하',
#   '경과',
#   '반품불가',
#   '안내기한',
#   '예외',
#   '예외처리가능',
#   '바이오측',
#   '라비',
#   '라비수디정',
#   '동봉'],
#  ['헬스',
#   '헬스인',
#   '상아',
#   '상아전자',
#   '전자',
#   '조은',
#   '맥반석',
#   '황토',
#   '황토찜질기분',
#   '찜질',
#   '기분',
#   '자동',
#   '자동타이머기능',
#   '타이머',
#   '기능',
#   '제품불량',
#   '불량',
#   '교환요청업체',
#   '확인후',
#   '재연락',
#   '약속불량제품',
#   '하심제품하자',
#   '하자',
#   '선택'],
#  ['포장기', '세금계산서', '집주소', '은평', '은평구', '폐업상태여', '종수', '종수약품'],
#  ['약국이형복',
#   '이형',
#   '헬스',
#   '헬스인',
#   '상아',
#   '상아전자',
#   '전자',
#   '조은',
#   '맥반석',
#   '황토',
#   '황토찜질기분',
#   '찜질',
#   '기분',
#   '자동',
#   '자동타이머기능',
#   '타이머',
#   '기능',
#   '제품불량',
#   '불량',
#   '교환요청업체',
#   '확인후',
#   '재연락',
#   '약속위',
#   '사항',
#   '요청차',
#   '받지않으심제품하자',
#   '반품접수'],
#  ['관악',
#   '관악소망약국',
#   '소망',
#   '유성림',
#   '성림',
#   '회수지연',
#   '회수택배비',
#   '택배비',
#   '옥경',
#   '옥경님',
#   '회수요청',
#   '불친절',
#   '불친절함담당자',
#   '함담',
#   '당자',
#   '퇴근',
#   '요청하라',
#   '하라'],
#  ['대역',
#   '약국김',
#   '메디',
#   '메디미플러스',
#   '플러스',
#   '페이스',
#   '페이스라이너',
#   '라이너',
#   '개입',
#   '개입묶음',
#   '묶음',
#   '상태유효기간',
#   '임박',
#   '반품신청불가',
#   '확인후',
#   '재연락',
#   '약속업체'],
#  ['동물약국', '요청동물', '약국개설등록증', '개설', '등록증', '팩스발송', '승인후'],
#  ['지오영',
#   '오영',
#   '회수지연',
#   '회수택배비',
#   '택배비',
#   '옥경',
#   '옥경님',
#   '회수요청',
#   '상담원',
#   '통화요청',
#   '소액',
#   '소액처',
#   '월매출',
#   '부족금액',
#   '미안',
#   '미안내월요일',
#   '재통화'],
#  ['휴면', '휴면처', '활성화', '수정요청', '완료아이디', '임시', '차주', '재전', '사등'],
#  ['큰사랑',
#   '큰사랑약국',
#   '휴업',
#   '휴업중이',
#   '중이',
#   '오픈',
#   '마이너스잔고',
#   '사용기한',
#   '어디',
#   '주문시',
#   '사용가능',
#   '발송요청',
#   '사용방법',
#   '생활기',
#   '생활기프트',
#   '프트',
#   '상품권신청',
#   '차주',
#   '수요일',
#   '모바일',
#   '모바일발송'],
#  ['메디',
#   '메디미플러스',
#   '플러스',
#   '페이스',
#   '페이스라이너',
#   '라이너',
#   '개입',
#   '개입묶음',
#   '묶음',
#   '상태유효기간',
#   '임박',
#   '반품신청불가',
#   '확인후',
#   '재연락'],
#  ['제일', '그랜드', '약국장경현', '장경', '금주', '수요일'],
#  ['키나', '구매문의', '마이', '마이페이지특별공급관'],
#  ['약국이전', '은하', '은하약국', '임마누엘', '한약국', '상호명', '전화번호', '수정요청'],
#  ['제일', '제일편', '김혜진약국', '주변', '판매가'],
#  ['도매업체염색약', '염색약', '하나', '반품기한', '개월', '처리불가', '년이상', '예외', '예외처리'],
#  ['전용관사용', '생활기', '생활기프트', '프트', '신청방법'],
#  ['승인요청', '가입시', '입시', '프로세스', '안내드림반나절정도', '반나절'],
#  ['종합',
#   '조강',
#   '에스',
#   '에스정',
#   '베진코',
#   '반품쿠폰사용',
#   '소분',
#   '소분반품',
#   '원칙적',
#   '불가함',
#   '하면',
#   '예치금처리방법'],
#  ['일반', '일반카드결제', '진행시', '공인', '공인인증', '인증', '신한', '신한카드', '신한간편결제', '간편'],
#  ['약포지', '유산지', '정사각형', '제품문의'],
#  ['약국이형복',
#   '이형',
#   '헬스',
#   '헬스인',
#   '상아',
#   '상아전자',
#   '전자',
#   '조은',
#   '맥반석',
#   '황토',
#   '황토찜질기분',
#   '찜질',
#   '기분',
#   '자동',
#   '자동타이머기능',
#   '타이머',
#   '기능',
#   '제품불량',
#   '불량',
#   '교환요청업체',
#   '확인후',
#   '재연락',
#   '약속위',
#   '사항',
#   '요청차',
#   '않으',
#   '않으심'],
#  ['헬스',
#   '헬스인',
#   '상아',
#   '상아전자',
#   '전자',
#   '조은',
#   '맥반석',
#   '황토',
#   '황토찜질기분',
#   '찜질',
#   '기분',
#   '자동',
#   '자동타이머기능',
#   '타이머',
#   '기능',
#   '제품불량',
#   '불량',
#   '교환요청업체',
#   '확인후',
#   '재연락',
#   '약속불량제품'],
#  ['헬스',
#   '헬스인',
#   '상아',
#   '상아전자',
#   '전자',
#   '조은',
#   '맥반석',
#   '황토',
#   '황토찜질기분',
#   '찜질',
#   '기분',
#   '자동',
#   '자동타이머기능',
#   '타이머',
#   '기능',
#   '제품불량',
#   '불량',
#   '교환요청업체',
#   '확인후',
#   '재연락'],
#  ['란액커피향', '커피', '구입희망', '수량제한', '제한', '구입가능', '김중흠', '란액', '저희', '원활', '부탁'],
#  ['란액커피향', '커피', '구입희망', '수량제한', '제한', '구입가능'],
#  ['다산', '다산현대약국고승', '현대', '고승', '일전화번호', '변경요청'],
#  ['솔벗약국황진', '황진', '인천약품', '취소요청업체', '확인후', '카드취소', '안내취소', '재연락주신'],
#  ['기업', '기업카드', '선택', '선택창', '일반', '비씨', '우리', '일반신용카드', '신용', '제외', '제외선택'],
#  ['경남',
#   '이선희',
#   '츄정',
#   '품절문의',
#   '생산',
#   '생산중단',
#   '정은',
#   '카스트',
#   '카스트정',
#   '스위칭',
#   '스위칭판매'],
#  ['역대급', '스타', '스타벅스', '벅스', '청해', '청해드림'],
#  ['전환', '소멸기간', '연말', '연말소진', '소진', '권장', '통화건포인트', '모두'],
#  ['미소', '김연', '미소약국', '끊으', '끊으심'],
#  ['피지',
#   '비강',
#   '피지오',
#   '비강세척액',
#   '세척',
#   '펌프',
#   '펌프미스',
#   '미스',
#   '멸균',
#   '등장',
#   '등장해수베이비',
#   '해수',
#   '베이비',
#   '유효성분',
#   '성분',
#   '전성분',
#   '표기',
#   '교환문의업체',
#   '확인후',
#   '재연락',
#   '약속현재',
#   '표시',
#   '불확실',
#   '고함',
#   '제약사',
#   '연락주시',
#   '주시',
#   '안내피지',
#   '단일',
#   '단일성분',
#   '계신',
#   '이기',
#   '안내전성분표시',
#   '별도',
#   '유효성',
#   '하심담당자',
#   '재연',
#   '재연락주신',
#   '처음',
#   '재연락',
#   '예정유효성분'],
#  [],
#  ['역대급', '선택', '선택요청', '도중', '선하심'],
#  ['반품처리', '잔고으'],
#  ...]

# %%
len(gensim_corpus)
# Out:
# C:\Users\manue\AppData\Roaming\Python\Python38\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 14637

# %%
# 토픽 개수, 키워드 개수를 정해주는 변수를 추가.
NUM_TOPICS = 2

NUM_TOPIC_WORDS = 30


def build_doc_term_mat(documents):
    # 문서-단어 행렬 만들어주는 함수.
    print("Building document-term matrix.")
    dictionary = corpora.Dictionary(documents)
    corpus = [dictionary.doc2bow(document) for document in documents]
        
    return corpus, dictionary


def print_topic_words(model):

    # 토픽 모델링 결과를 출력해 주는 함수.
    print("\nPrinting topic words.\n")
    
    for topic_id in range(model.num_topics):
        topic_word_probs = model.show_topic(topic_id, NUM_TOPIC_WORDS)
        print("Topic ID: {}".format(topic_id))
        
        for topic_word, prob in topic_word_probs:
            print("\t{}\t{}".format(topic_word, prob))
            
        print("\n")

def word_cloud(model):
    for topic_id in range(model.num_topics):
        wordcloud = WordCloud(font_path='Font/applegothic.ttf',
                          relative_scaling = 0.2,
                          # stopwords=STOPWORDS,
                          background_color='white',
                          ).generate_from_frequencies(dict(model.show_topic(topic_id,NUM_TOPIC_WORDS)))
        plt.figure(figsize=(16,8))
        plt.imshow(wordcloud)
        plt.axis("off")
        plt.show()
        print("\n\n")
        
        
# document-term matrix를 만들고,
corpus, dictionary = build_doc_term_mat(gensim_corpus)
# LDA를 실행.
model = models.ldamodel.LdaModel(corpus, num_topics=NUM_TOPICS, id2word=dictionary)
# 결과를 출력.
print_topic_words(model)
#워드 클라우드 출력
word_cloud(model)
# Out:
# C:\Users\manue\AppData\Roaming\Python\Python38\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Building document-term matrix.
#
# Printing topic words.
#
# Topic ID: 0
# 	헬스	0.010735541582107544
# 	케어	0.009252236224710941
# 	헬스인	0.004874381236732006
# 	개월	0.003793081035837531
# 	낱알	0.003699712688103318
# 	인하	0.00344143807888031
# 	제조번호	0.003428527619689703
# 	인천약품	0.0034230498131364584
# 	세비	0.0033747097477316856
# 	고함	0.0031969468109309673
# 	주시	0.0031561104115098715
# 	제이	0.0031464281491935253
# 	반품가능	0.003133511869236827
# 	약가	0.002936788136139512
# 	부외품	0.002856798004359007
# 	크림	0.0028170181903988123
# 	반품요청	0.002546057105064392
# 	마스크	0.0024195904843509197
# 	입이	0.0023176809772849083
# 	임팩	0.002241079695522785
# 	주심	0.0022058712784200907
# 	약가인하	0.002176570938900113
# 	처리요청	0.002173664281144738
# 	제일	0.0021481222938746214
# 	신협	0.0021384635474532843
# 	바구니	0.0021203982178121805
# 	대웅바이오	0.0021110614761710167
# 	양해드림	0.0020022112876176834
# 	미차장	0.001978150801733136
# 	낱알반품	0.0019690131302922964
#
#
# Topic ID: 1
# 	프리미엄	0.006830515805631876
# 	우루	0.005752286408096552
# 	임팩	0.005389269907027483
# 	메디	0.005080267321318388
# 	이지	0.004871356301009655
# 	플러스	0.004816933069378138
# 	캡슐	0.004089642781764269
# 	제이	0.004016029182821512
# 	고함	0.0033602507319301367
# 	티제이	0.0027991633396595716
# 	패밀리	0.002546238014474511
# 	특별공급관	0.002540360437706113
# 	의약품	0.0025266685988754034
# 	출하	0.0024530028458684683
# 	부외품	0.0022980559151619673
# 	일반	0.0022971148137003183
# 	에프	0.0021582399494946003
# 	연질	0.0021405762527137995
# 	패밀리존	0.0020612278021872044
# 	파워	0.0020389847923070192
# 	미배송문의	0.0020025791600346565
# 	천원	0.0019836886785924435
# 	선택	0.0019181425450369716
# 	마이	0.001861169352196157
# 	임팩프리미엄	0.001845529885031283
# 	감사	0.001827338244765997
# 	스타	0.001818938530050218
# 	유진	0.001788303954526782
# 	보덕메디	0.0017320475308224559
# 	바구니	0.0017302979249507189

# %%
# pyLDAvis 불러오기
import pyLDAvis
import pyLDAvis.gensim_models as gensimvis

# pyLDAvis를 jupyter notebook에서 실행할 수 있게 활성화.
pyLDAvis.enable_notebook()

# pyLDAvis 실행.
data = gensimvis.prepare(model, corpus, model.id2word)
pyLDAvis.display(data)
# Out:
# C:\Users\manue\AppData\Roaming\Python\Python38\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.3.1/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el1224023897772184644397472448"></div>
# <script type="text/javascript">
#
# var ldavis_el1224023897772184644397472448_data = {"mdsDat": {"x": [0.10969131637034214, -0.10969131637034214], "y": [0.0, 0.0], "topics": [1, 2], "cluster": [1, 1], "Freq": [50.462738043990896, 49.5372619560091]}, "tinfo": {"Term": ["\ud5ec\uc2a4", "\ucf00\uc5b4", "\ud504\ub9ac\ubbf8\uc5c4", "\ud5ec\uc2a4\uc778", "\uc6b0\ub8e8", "\uc774\uc9c0", "\uc778\ud558", "\ud50c\ub7ec\uc2a4", "\uc81c\uc870\ubc88\ud638", "\uba54\ub514", "\uc57d\uac00", "\uc138\ube44", "\uac1c\uc6d4", "\uc778\ucc9c\uc57d\ud488", "\ub9c8\uc2a4\ud06c", "\uc57d\uac00\uc778\ud558", "\ucd9c\ud558", "\ubbf8\ucc28\uc7a5", "\uc5d0\ud504", "\uc81c\uc77c", "\ub9e4\ubab0", "\ubc18\ud488\uac00\ub2a5", "\uc784\ud329\ud504\ub9ac\ubbf8\uc5c4", "\ud328\ubc00\ub9ac\uc874", "\uac00\uc785\uad00\ub828", "\ub0b1\uc54c", "\ud328\ubc00\ub9ac", "\ub3c4\ub9e4\ubab0", "\uc5f0\uc9c8", "\ud0d1\ud5ec\uc2a4\ucf00\uc5b4", "\uc57d\uac00", "\uc778\ud558", "\uc57d\uac00\uc778\ud558", "\ubbf8\ucc28\uc7a5", "\uc138\ube44\uce74", "\ub3c4\ub9e4\ubab0", "\ub9e4\ubab0", "\ub9c8\uc2a4\ud06c", "\ubc30\uc815\uc5ec\ubd80", "\uc790\ub3d9\ubcf4\uc0c1", "\ud5ec\uc2a4\uc778", "\ud669\uc0ac\ub9c8\uc2a4\ud06c", "\uc57d\uac00\uc778\ud558\uac74", "\ud669\uc0ac", "\ud5ec\uc2a4", "\uc138\ud654", "\uc804\uace0\uac1d", "\ub300\uc6c5\uc138\ube44\uce74", "\uac00\uc778", "\uc5f0\uacb0\uc694\uccad", "\uc81c\uc870\ubc88\ud638", "\uc81c\uc77c\ud5ec\uc2a4\ucf00\uc5b4", "\ud5ec\uc2a4\ucf00\uc5b4", "\ubc18\ud488\uc2dc", "\uc644\ub8cc\uc804", "\uc138\ud654\ud5ec\uc2a4\ucf00\uc5b4", "\ubcf4\uc0c1", "\uc778\ud558\uc804", "\uc138\ube44\uce74\uc815", "\uc785\uac00\ub300", "\uc138\ube44", "\uac00\uc785\uad00\ub828", "\uba54\ubaa8", "\ud0d1\ud5ec\uc2a4\ucf00\uc5b4", "\uc81c\uc77c", "\ucf00\uc5b4", "\uc778\ucc9c\uc57d\ud488", "\uac1c\uc6d4", "\ud608\ub2f9", "\ub04a\uc73c", "\ub04a\uc73c\uc2ec", "\ud558\uc774", "\uc11c\uc6b8\uc57d\uc0ac\uc2e0\ud611", "\ucc98\ub9ac\uc694\uccad", "\ubc18\ud488\uac00\ub2a5", "\uc2e0\ud611", "\uc785\uc774", "\ub0b1\uc54c", "\ub0b1\uc54c\ubc18\ud488", "\uc8fc\uc2dc", "\ud06c\ub9bc", "\ubc34\ub4dc", "\uc8fc\uc2ec", "\ubc18\ud488\uc694\uccad", "\uba54\ub514\uce7c", "\uc591\ud574\ub4dc\ub9bc", "\ubd80\uc678\ud488", "\uace0\ud568", "\uc81c\uc774", "\ub300\uc6c5\ubc14\uc774\uc624", "\ubc14\uad6c\ub2c8", "\uc784\ud329", "\ub300\uc6c5\uc81c\uc57d\uacf5\uc7a5", "\uc62c\uba54\ud14d\ud50c\ub7ec\uc2a4", "\ubcf5\ud569\uc6b0\ub8e8\uc0ac\uc5f0\uc9c8", "\ub364\uc52c", "\uae30\uad00", "\ucd9c\ud558\uc815\uc9c0", "\uc694\uc591\uae30\uad00\ubc88\ud638", "\uacb0\uc81c\ud398\uc774\uc9c0", "\ub300\uc6c5\uc81c\uc57d\ubcf5\uc0b0", "\uc784\uc758", "\ud638\ud658\uc131", "\ubcf5\ud569\uc6b0\ub8e8\uc0ac", "\ub2e8\uc120", "\ub300\uc6c5\uc81c\uc57d\uc720\uc9c4\uc57d\ud488", "\ubc00\ub9ac\uadf8\ub7a8", "\uc784\ud329\ud504\ub9ac\ubbf8\uc5c4", "\uc694\uc591", "\uc0ac\uc804\ub4f1\ub85d", "\uc2dc\ub9ac\uc988", "\ud68c\uc6d0\uc815\ubcf4\uc218\uc815", "\uc778\uc99d", "\uac00\uc704", "\uc608\uc815\uc2dc\uac04", "\uc635\uc158", "\uc0ac\uc6a9\uc790", "\uc544\ub798", "\uad6d\ubbfc\uce74\ub4dc", "\uae08\ubcf4\uba54\ub514\ub137", "\uc6a9\ub9c8\uae30\uc0ac\ub2d8", "\uae30\uc5c5", "\uc5d0\ud504", "\uc2e0\uc6a9", "\ub300\uc6c5\uc804", "\ubc30\uc1a1\uc644\ub8cc", "\uc720\uc9c4", "\ub300\uc6c5\uc81c\uc57d\uc624\uc0b0\uac70\uc810", "\ud074\ub9ad", "\uc774\uc9c0", "\ud504\ub9ac\ubbf8\uc5c4", "\uc6a9\ub9c8", "\uc6b0\ub8e8", "\ucd9c\ud558", "\ubc31\uad11\uc758\uc57d\ud488", "\ud328\ubc00\ub9ac\uc874", "\ubc84\ud2bc", "\ud50c\ub7ec\uc2a4", "\ucc9c\uc6d0", "\uba54\ub514", "\uc5f0\uc9c8", "\ubcf4\ub355\uba54\ub514", "\uad6c\ub9e4\ubb38\uc758", "\ud328\ubc00\ub9ac", "\uc2a4\ud0c0", "\ub0b4\ud574", "\ud3ec\ud568", "\uc758\uc57d\ud488", "\ud2b9\ubcc4\uacf5\uae09\uad00", "\uc6b0\ub8e8\uc0ac", "\ucea1\uc290", "\uc784\ud329", "\uc77c\ubc18", "\ubcf4\ub355", "\uc81c\uc774", "\uc120\ud0dd", "\ubbf8\ubc30\uc1a1\ubb38\uc758", "\ud2f0\uc81c\uc774", "\uace0\ud568", "\ud30c\uc6cc", "\ubd80\uc678\ud488", "\uac10\uc0ac", "\ub9c8\uc774", "\uc7ac\uc8fc", "\ubc14\uad6c\u ...

# %%
pyLDAvis.save_html(data,'201904-06_kkma_lda.html')
# Out:
# C:\Users\manue\AppData\Roaming\Python\Python38\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# # 월별 문의사항 데이터 KR-wordrank 분석

# %% [markdown]
# 참조 사이트: https://pypi.org/project/krwordrank/

# %%
from krwordrank.word import KRWordRank
# Out:
# /Users/hyunkyungwoo/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
min_count = 5   # 단어의 최소 출현 빈도수 (그래프 생성 시)
max_length = 10 # 단어의 최대 길이
wordrank_extractor = KRWordRank(min_count=min_count, max_length=max_length)
# Out:
# /Users/hyunkyungwoo/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
beta = 0.85    # PageRank의 decaying factor beta
max_iter = 10
texts = tfidf_corpus #1차원인 list가 필요해 tfidf에서 쓰인 corpus를 그대로 사용함.
keywords, rank, graph = wordrank_extractor.extract(texts, beta, max_iter)
# Out:
# /Users/hyunkyungwoo/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
for word, r in sorted(keywords.items(), key=lambda x:x[1], reverse=True)[:30]:
        print('%8s:\t%.4f' % (word, r))
# Out:
#       플러:	2.7769
#      마일리:	2.7054
#       이벤:	2.5283
#       포인:	2.4820
#       담당:	2.2132
#       주문:	1.5727
#       이마:	1.5708
#       바이:	1.5707
#       제이:	1.5478
#       예치:	1.5256
#       국민:	1.4880
#       어려:	1.4270
#       전용:	1.3967
#      스트로:	1.3859
#       프로:	1.3499
#       신용:	1.2902
#       상품:	1.2789
#       나이:	1.2669
#       연락:	1.2028
#       마이:	1.1553
#       된다:	1.1308
#       메디:	1.0780
#       계산:	1.0664
#       종이:	1.0651
#      프리미:	1.0367
#       판촉:	1.0312
#       스위:	1.0000
#       현금:	1.0000
#       카라:	1.0000
#       장바:	1.0000
# /Users/hyunkyungwoo/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
SW
# Out:
# /Users/hyunkyungwoo/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# {'가\n',
#  '가까스로\n',
#  '가령\n',
#  '각\n',
#  '각각\n',
#  '각자\n',
#  '각종\n',
#  '갖고말하자면\n',
#  '같다\n',
#  '같이\n',
#  '개의치않고\n',
#  '거니와\n',
#  '거바\n',
#  '거의\n',
#  '것\n',
#  '것과 같이\n',
#  '것들\n',
#  '게다가\n',
#  '게우다\n',
#  '겨우\n',
#  '견지에서\n',
#  '결과에 이르다\n',
#  '결국\n',
#  '결론을 낼 수 있다\n',
#  '겸사겸사\n',
#  '고려하면\n',
#  '고로\n',
#  '곧\n',
#  '공동으로\n',
#  '과\n',
#  '과연\n',
#  '관계가 있다\n',
#  '관계없이\n',
#  '관련이 있다\n',
#  '관하여\n',
#  '관한\n',
#  '관해서는\n',
#  '구\n',
#  '구체적으로\n',
#  '구토하다\n',
#  '그\n',
#  '그들\n',
#  '그때\n',
#  '그래\n',
#  '그래도\n',
#  '그래서\n',
#  '그러나\n',
#  '그러니\n',
#  '그러니까\n',
#  '그러면\n',
#  '그러므로\n',
#  '그러한즉\n',
#  '그런 까닭에\n',
#  '그런데\n',
#  '그런즉\n',
#  '그럼\n',
#  '그럼에도 불구하고\n',
#  '그렇게 함으로써\n',
#  '그렇지\n',
#  '그렇지 않다면\n',
#  '그렇지 않으면\n',
#  '그렇지만\n',
#  '그렇지않으면\n',
#  '그리고\n',
#  '그리하여\n',
#  '그만이다\n',
#  '그에 따르는\n',
#  '그위에\n',
#  '그저\n',
#  '그중에서\n',
#  '그치지 않다\n',
#  '근거로\n',
#  '근거하여\n',
#  '기대여\n',
#  '기점으로\n',
#  '기준으로\n',
#  '기타\n',
#  '까닭으로\n',
#  '까악\n',
#  '까지\n',
#  '까지 미치다\n',
#  '까지도\n',
#  '꽈당\n',
#  '끙끙\n',
#  '끼익\n',
#  '나\n',
#  '나머지는\n',
#  '남들\n',
#  '남짓\n',
#  '너\n',
#  '너희\n',
#  '너희들\n',
#  '네\n',
#  '넷\n',
#  '년\n',
#  '논하지 않다\n',
#  '놀라다\n',
#  '누가 알겠는가\n',
#  '누구\n',
#  '다른\n',
#  '다른 방면으로\n',
#  '다만\n',
#  '다섯\n',
#  '다소\n',
#  '다수\n',
#  '다시 말하자면\n',
#  '다시말하면\n',
#  '다음\n',
#  '다음에\n',
#  '다음으로\n',
#  '단지\n',
#  '답다\n',
#  '당신\n',
#  '당장\n',
#  '대로 하다\n',
#  '대하면\n',
#  '대하여\n',
#  '대해 말하자면\n',
#  '대해서\n',
#  '댕그\n',
#  '더구나\n',
#  '더군다나\n',
#  '더라도\n',
#  '더불어\n',
#  '더욱더\n',
#  '더욱이는\n',
#  '도달하다\n',
#  '도착하다\n',
#  '동시에\n',
#  '동안\n',
#  '된바에야\n',
#  '된이상\n',
#  '두번째로\n',
#  '둘\n',
#  '둥둥\n',
#  '뒤따라\n',
#  '뒤이어\n',
#  '든간에\n',
#  '들\n',
#  '등\n',
#  '등등\n',
#  '딩동\n',
#  '따라\n',
#  '따라서\n',
#  '따위\n',
#  '따지지 않다\n',
#  '딱\n',
#  '때\n',
#  '때가 되어\n',
#  '때문에\n',
#  '또\n',
#  '또한\n',
#  '뚝뚝\n',
#  '라 해도\n',
#  '령\n',
#  '로\n',
#  '로 인하여\n',
#  '로부터\n',
#  '로써\n',
#  '륙\n',
#  '를\n',
#  '마음대로\n',
#  '마저\n',
#  '마저도\n',
#  '마치\n',
#  '막론하고\n',
#  '만 못하다\n',
#  '만약\n',
#  '만약에\n',
#  '만은 아니다\n',
#  '만이 아니다\n',
#  '만일\n',
#  '만큼\n',
#  '말하자면\n',
#  '말할것도 없고\n',
#  '매\n',
#  '매번\n',
#  '메쓰겁다\n',
#  '몇\n',
#  '모\n',
#  '모두\n',
#  '무렵\n',
#  '무릎쓰고\n',
#  '무슨\n',
#  '무엇\n',
#  '무엇때문에\n',
#  '물론\n',
#  '및\n',
#  '바꾸어말하면\n',
#  '바꾸어말하자면\n',
#  '바꾸어서 말하면\n',
#  '바꾸어서 한다면\n',
#  '바꿔 말하면\n',
#  '바로\n',
#  '바와같이\n',
#  '밖에 안된다\n',
#  '반대로\n',
#  '반대로 말하자면\n',
#  '반드시\n',
#  '버금\n',
#  '보는데서\n',
#  '보다더\n',
#  '보드득\n',
#  '본대로\n',
#  '봐\n',
#  '봐라\n',
#  '부류의 사람들\n',
#  '부터\n',
#  '불구하고\n',
#  '불문하고\n',
#  '붕붕\n',
#  '비걱거리다\n',
#  '비교적\n',
#  '비길수 없다\n',
#  '비로소\n',
#  '비록\n',
#  '비슷하다\n',
#  '비추어 보아\n',
#  '비하면\n',
#  '뿐만 아니라\n',
#  '뿐만아니라\n',
#  '뿐이다\n',
#  '삐걱\n',
#  '삐걱거리다\n',
#  '사\n',
#  '삼\n',
#  '상대적으로 말하자면\n',
#  '생각한대로\n',
#  '설령\n',
#  '설마\n',
#  '설사\n',
#  '셋\n',
#  '소생\n',
#  '소인\n',
#  '솨\n',
#  '쉿\n',
#  '습니까\n',
#  '습니다\n',
#  '시각\n',
#  '시간\n',
#  '시작하여\n',
#  '시초에\n',
#  '시키다\n',
#  '실로\n',
#  '심지어\n',
#  '아\n',
#  '아니\n',
#  '아니나다를가\n',
#  '아니라면\n',
#  '아니면\n',
#  '아니었다면\n',
#  '아래윗\n',
#  '아무거나\n',
#  '아무도\n',
#  '아야\n',
#  '아울러\n',
#  '아이\n',
#  '아이고\n',
#  '아이구\n',
#  '아이야\n',
#  '아이쿠\n',
#  '아하\n',
#  '아홉\n',
#  '안 그러면\n',
#  '않기 위하여\n',
#  '않기 위해서\n',
#  '알 수 있다\n',
#  '알았어\n',
#  '앗\n',
#  '앞에서\n',
#  '앞의것\n',
#  '야\n',
#  '약간\n',
#  '양자\n',
#  '어\n',
#  '어기여차\n',
#  '어느\n',
#  '어느 년도\n',
#  '어느것\n',
#  '어느곳\n',
#  '어느때\n',
#  '어느쪽\n',
#  '어느해\n',
#  '어디\n',
#  '어때\n',
#  '어떠한\n',
#  '어떤\n',
#  '어떤것\n',
#  '어떤것들\n',
#  '어떻게\n',
#  '어떻해\n',
#  '어이\n',
#  '어째서\n',
#  '어쨋든\n',
#  '어쩔수 없다\n',
#  '어찌\n',
#  '어찌됏든\n',
#  '어찌됏어\n',
#  '어찌하든지\n',
#  '어찌하여\n',
#  '언제\n',
#  '언젠가\n',
#  '얼마\n',
#  '얼마 안 되는 것\n',
#  '얼마간\n',
#  '얼마나\n',
#  '얼마든지\n',
#  '얼마만큼\n',
#  '얼마큼\n',
#  '엉엉\n',
#  '에\n',
#  '에 가서\n',
#  '에 달려 있다\n',
#  '에 대해\n',
#  '에 있다\n',
#  '에 한하다\n',
#  '에게\n',
#  '에서\n',
#  '여\n',
#  '여기\n',
#  '여덟\n',
#  '여러분\n',
#  '여보시오\n',
#  '여부\n',
#  '여섯\n',
#  '여전히\n',
#  '여차\n',
#  '연관되다\n',
#  '연이서\n',
#  '영\n',
#  '영차\n',
#  '옆사람\n',
#  '예\n',
#  '예를 들면\n',
#  '예를 들자면\n',
#  '예컨대\n',
#  '예하면\n',
#  '오\n',
#  '오로지\n',
#  '오르다\n',
#  '오자마자\n',
#  '오직\n',
#  '오호\n',
#  '오히려\n',
#  '와\n',
#  '와 같은 사람들\n',
#  '와르르\n',
#  '와아\n',
#  '왜\n',
#  '왜냐하면\n',
#  '외에도\n',
#  '요만큼\n',
#  '요만한 것\n',
#  '요만한걸\n',
#  '요컨대\n',
#  '우르르\n',
#  '우리\n',
#  '우리들\n',
#  '우선\n',
#  '우에 종합한것과같이\n',
#  '운운\n',
#  '월\n',
#  '위에서 서술한바와같이\n',
#  '위하여\n',
#  '위해서\n',
#  '윙윙\n',
#  '육\n',
#  '으로\n',
#  '으로 인하여\n',
#  '으로서\n',
#  '으로써\n',
#  '을\n',
#  '응\n',
#  '응당\n',
#  '의\n',
#  '의거하여\n',
#  '의지하여\n',
#  '의해\n',
#  '의해되다\n',
#  '의해서\n',
#  '이\n',
#  '이 되다\n',
#  '이 때문에\n',
#  '이 밖에\n',
#  '이 외에\n',
#  '이 정도의\n',
#  '이것\n',
#  '이곳\n',
#  '이때\n',
#  '이라면\n',
#  '이래\n',
#  '이러이러하다\n',
#  '이러한\n',
#  '이런\n',
#  '이럴정도로\n',
#  '이렇게 많은 것\n',
#  '이렇게되면\n',
#  '이렇게말하자면\n',
#  '이렇구나\n',
#  '이로 인하여\n',
#  '이르기까지\n',
#  '이리하여\n',
#  '이만큼\n',
#  '이번\n',
#  '이봐\n',
#  '이상\n',
#  '이어서\n',
#  '이었다\n',
#  '이와 같다\n',
#  '이와 같은\n',
#  '이와 반대로\n',
#  '이와같다면\n',
#  '이외에도\n',
#  '이용하여\n',
#  '이유만으로\n',
#  '이젠\n',
#  '이지만\n',
#  '이쪽\n',
#  '이천구\n',
#  '이천육\n',
#  '이천칠\n',
#  '이천팔\n',
#  '인 듯하다\n',
#  '인젠\n',
#  '일\n',
#  '일것이다\n',
#  '일곱\n',
#  '일단\n',
#  '일때\n',
#  '일반적으로\n',
#  '일지라도\n',
#  '임에 틀림없다\n',
#  '입각하여\n',
#  '입장에서\n',
#  '잇따라\n',
#  '있다\n',
#  '자\n',
#  '자기\n',
#  '자기집\n',
#  '자마자\n',
#  '자신\n',
#  '잠깐\n',
#  '잠시\n',
#  '저\n',
#  '저것\n',
#  '저것만큼\n',
#  '저기\n',
#  '저쪽\n',
#  '저희\n',
#  '전부\n',
#  '전자\n',
#  '전후\n',
#  '점에서 보아\n',
#  '정도에 이르다\n',
#  '제\n',
#  '제각기\n',
#  '제외하고\n',
#  '조금\n',
#  '조차\n',
#  '조차도\n',
#  '졸졸\n',
#  '좀\n',
#  '좋아\n',
#  '좍좍\n',
#  '주룩주룩\n',
#  '주저하지 않고\n',
#  '줄은 몰랏다\n',
#  '줄은모른다\n',
#  '중에서\n',
#  '중의하나\n',
#  '즈음하여\n',
#  '즉\n',
#  '즉시\n',
#  '지든지\n',
#  '지만\n',
#  '지말고\n',
#  '진짜로\n',
#  '쪽으로\n',
#  '차라리\n',
#  '참\n',
#  '참나\n',
#  '첫번째로\n',
#  '쳇\n',
#  '총적으로\n',
#  '총적으로 말하면\n',
#  '총적으로 보면\n',
#  '칠\n',
#  '콸콸\n',
#  '쾅쾅\n',
#  '쿵\n',
#  '타다\n',
#  '타인\n',
#  '탕탕\n',
#  '토하다\n',
#  '통하여\n',
#  '툭\n',
#  '퉤\n',
#  '틈타\n',
#  '팍\n',
#  '팔\n',
#  '퍽\n',
#  '펄렁\n',
#  '하\n',
#  '하게될것이다\n',
#  '하게하다\n',
#  '하겠는가\n',
#  '하고 있다\n',
#  '하고있었다\n',
#  '하곤하였다\n',
#  '하구나\n',
#  '하기 때문에\n',
#  '하기 위하여\n',
#  '하기는한데\n',
#  '하기만 하면\n',
#  '하기보다는\n',
#  '하기에\n',
#  '하나\n',
#  '하느니\n',
#  '하는 김에\n',
#  '하는 편이 낫다\n',
#  '하는것도\n',
#  '하는것만 못하다\n',
#  '하는것이 낫다\n',
#  '하는바\n',
#  '하더라도\n',
#  '하도다\n',
#  '하도록시키다\n',
#  '하도록하다\n',
#  '하든지\n',
#  '하려고하다\n',
#  '하마터면\n',
#  '하면 할수록\n',
#  '하면된다\n',
#  '하면서\n',
#  '하물며\n',
#  '하여금\n',
#  '하여야\n',
#  '하자마자\n',
#  '하지 않는다면\n',
#  '하지 않도록\n',
#  '하지마\n',
#  '하지마라\n',
#  '하지만\n',
#  '하하\n',
#  '한 까닭에\n',
#  '한 이유는\n',
#  '한 후\n',
#  '한다면\n',
#  '한다면 몰라도\n',
#  '한데\n',
#  '한마디\n',
#  '한적이있다\n',
#  '한켠으로는\n',
#  '한항목\n',
#  '할 따름이다\n',
#  '할 생각이다\n',
#  '할 줄 안다\n',
#  '할 지경이다\n',
#  '할 힘이 있다\n',
#  '할때\n',
#  '할만하다\n',
#  '할망정\n',
#  '할뿐\n',
#  '할수있다\n',
#  '할수있어\n',
#  '할줄알다\n',
#  '할지라도\n',
#  '할지언정\n',
#  '함께\n',
#  '해도된다\n',
#  '해도좋다\n',
#  '해봐요\n',
#  '해서는 안된다\n',
#  '해야한다\n',
#  '해요\n',
#  '했어요\n',
#  '향하다\n',
#  '향하여\n',
#  '향해서\n',
#  '허\n',
#  '허걱\n',
#  '허허\n',
#  '헉\n',
#  '헉헉\n',
#  '헐떡헐떡\n',
#  '형식으로 쓰여\n',
#  '혹시\n',
#  '혹은\n',
#  '혼자\n',
#  '훨씬\n',
#  '휘익\n',
#  '휴\n',
#  '흐흐\n',
#  '흥\n',
#  '힘입어'}

# %%
stopwords = SW
passwords = {word:score for word, score in sorted(
    keywords.items(), key=lambda x:-x[1])[:300] if not (word in stopwords)}
# Out:
# /Users/hyunkyungwoo/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
krwordrank_cloud = WordCloud(
    font_path = '/Library/Fonts/AppleGothic.ttf',
    width = 800,
    height = 800,
    background_color="white"
)
krwordrank_cloud = krwordrank_cloud.generate_from_frequencies(passwords)
# Out:
# /Users/hyunkyungwoo/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
fig = plt.figure(figsize=(10, 10))
plt.imshow(krwordrank_cloud, interpolation="bilinear")
plt.show()
# Out:
# /Users/hyunkyungwoo/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
fig.savefig('./lalaland_wordcloud.png') #그림 저장
